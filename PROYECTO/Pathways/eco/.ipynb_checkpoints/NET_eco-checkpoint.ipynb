# %% [markdown]
# # Libreria

# %%
import pandas as pd
import networkx as nx
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
#parsear XML
import csv   
from lxml import etree
#Parsear HTML
import requests
import urllib.request
from bs4 import BeautifulSoup
from urllib.request import urlopen
from bs4.builder import HTMLParserTreeBuilder
#para medir tiempo
from time import time 
import time

# %% [markdown]
# # Carga de Archivos XML

# %%
org = 'eco'
ORGANISM = org
maxi ='01040'

pathways = requests.get('http://rest.kegg.jp/list/pathway/' + ORGANISM)  #lista de las vias metabolicas y otra informacion porpocionada por KEGG

for line in pathways.text.split('\n'):         # Se recorre la lista propocionada por  KEGG donde se estraen los nombres de las vias de KEGG
      pathwayid = line.split('\t')[0].replace('path:', '') 
      A = pathwayid+'.xml'                     # Le ponemos la extencion .xml para poder cargar los archivos
      if A == str(org)+str(maxi)+'.xml':           
            break
      locals()[str(pathwayid)] = etree.parse(A) # Guarda los  XML com el nombre de la via asignado por KEGG
      locals()[str(pathwayid)] = locals()[str(pathwayid)].getroot()  # Para transformar todos lo XML en directorios de python

# %% [markdown]
# ## ARMANDO BASE DE DATOS CON PANDAS

# %% [markdown]
# ##### crear archivo csv para guardar los datos.

# %%
#data= pd.DataFrame(columns=('n', 'enzima', 'gen', 'nob_Keeg', 'path','link')) # Crear tabla csv. 
#data.to_csv('data_'+org+'.csv', sep=';')

# %%
save=len(pd.read_csv('data_'+org+'.csv',index_col=0, delimiter=';')[['n']].values)
print(save)
# Out:
# 1693

# %%
save=len(pd.read_csv('data_'+org+'.csv',index_col=0, delimiter=';')[['n']].values)

n=0

for line in pathways.text.split('\n'):
    
    pathwayid = line.split('\t')[0].replace('path:', '') 
    
    if pathwayid ==  str(org)+str(maxi):           
            break
    
    ii=locals()[str(pathwayid)]
    
    
    for i in range(0,len(ii)):
       
        if ii[i].tag=='entry':         
            A=ii[i].attrib            
            if A['type'] == 'gene':
                n=1+n
                
                if n > save:
                    
                    url = A['link']
                
                    response = requests.get(url)
                    soup = BeautifulSoup(response.text, "html.parser")
                    
                    gen    = soup.html.body.div.table.form.td.table.find_all('td')[3].find_all('div')[0].text.replace('\n', ' ').strip().split()[0].replace(',','')
                    
                    if gen == '(RefSeq)':
                        ll=6
                    else:
                        ll=7
                    
                    enzima = soup.html.body.div.table.form.td.table.find_all('td')[ll].text.strip()
                    
                    NewDat = [n , A['id'] , enzima, gen , A['name'].split( )[0] , pathwayid , A['link'] ]
                
                                
                    with open(r'data_'+org+'.csv', 'a' , newline='') as f:
                        writer = csv.writer(f,delimiter=';')
                        writer.writerow(NewDat)

# %%
n=0

for line in pathways.text.split('\n'):
    
    pathwayid = line.split('\t')[0].replace('path:', '') 
    
    if pathwayid == str(org)+str(maxi):           
            break
            
  
    ii=locals()[str(pathwayid)]
    
        
    
    for i in range(0,len(ii)):
       
        if ii[i].tag=='entry':         
            A=ii[i].attrib            
            if A['type'] == 'group':
                n=1+n 
                
                NewDat = [n , A['id'] , 'undefined_Enzima'+pathwayid , 'none' ,  A['name'] , pathwayid , 'no link']
                
                        
                with open(r'data_'+org+'.csv', 'a' , newline='') as f:
                    writer = csv.writer(f , delimiter=';')
                    writer.writerow(NewDat)

# %% [markdown]
# Compilando no apagar

# %%
data=pd.read_csv('data_'+org+'.csv',index_col=0, sep=';')
data=data[['n' ,'enzima', 'nob_Keeg' ,'path']]
data=data.values
data
# Out:
# array([["'14'", 'fructose-bisphosphate aldolase, class I [EC:4.1.2.13]',
#         'eco:b2097', 'eco00010'],
#        ['14', 'fructose-bisphosphate aldolase, class I [EC:4.1.2.13]',
#         'eco:b2097', 'eco00010'],
#        ['46',
#         'S-(hydroxymethyl)glutathione dehydrogenase / alcohol dehydrogenase [EC:1.1.1.284 1.1.1.1]',
#         'eco:b0356', 'eco00010'],
#        ...,
#        ['175', 'tRNA Phe', 'eco:b2967', 'eco00970'],
#        ['176', 'tRNA Tyr', 'eco:b1230', 'eco00970'],
#        ['177', 'tRNA Trp', 'eco:b3761', 'eco00970']], dtype=object)

# %%
for line in pathways.text.split('\n'):
    
    pathwayid = line.split('\t')[0].replace('path:', '') 
    
    if pathwayid == str(org)+str(maxi):           
            break
    
    locals()['NODES_'+str(pathwayid)]={}
    #print(pathwayid)
    for i in data:
        if i[3] == pathwayid:
            locals()['NODES_'+str(pathwayid)][i[0]]= i[1] 
            print(i[0],i[1], i[2], i[3])
# Out:
# '14' fructose-bisphosphate aldolase, class I [EC:4.1.2.13] eco:b2097 eco00010
# 14 fructose-bisphosphate aldolase, class I [EC:4.1.2.13] eco:b2097 eco00010
# 46 S-(hydroxymethyl)glutathione dehydrogenase / alcohol dehydrogenase [EC:1.1.1.284 1.1.1.1] eco:b0356 eco00010
# 48 pyruvate dehydrogenase E1 component [EC:1.2.4.1] eco:b0114 eco00010
# 49 pyruvate dehydrogenase E1 component [EC:1.2.4.1] eco:b0114 eco00010
# 50 pyruvate dehydrogenase E2 component (dihydrolipoamide acetyltransferase) [EC:2.3.1.12] eco:b0115 eco00010
# 53 pyruvate kinase [EC:2.7.1.40] eco:b1676 eco00010
# 55 enolase [EC:4.2.1.11] eco:b2779 eco00010
# 56 2,3-bisphosphoglycerate-dependent phosphoglycerate mutase [EC:5.4.2.11] eco:b0755 eco00010
# 57 glyceraldehyde 3-phosphate dehydrogenase [EC:1.2.1.12] eco:b1779 eco00010
# 58 triosephosphate isomerase (TIM) [EC:5.3.1.1] eco:b3919 eco00010
# 59 6-phosphofructokinase 2 [EC:2.7.1.11] eco:b1723 eco00010
# 60 fructose-1,6-bisphosphatase II [EC:3.1.3.11] eco:b2930 eco00010
# 61 glucose PTS system EIICB or EIICBA component [EC:2.7.1.199] eco:b1101 eco00010
# 62 glucose-6-phosphate isomerase [EC:5.3.1.9] eco:b4025 eco00010
# 63 phosphoglucomutase [EC:5.4.2.2] eco:b0688 eco00010
# 64 glucose-6-phosphate isomerase [EC:5.3.1.9] eco:b4025 eco00010
# 66 glucokinase [EC:2.7.1.2] eco:b2388 eco00010
# 67 glucose-6-phosphate isomerase [EC:5.3.1.9] eco:b4025 eco00010
# 68 glucose-6-phosphate 1-epimerase [EC:5.1.3.15] eco:b1780 eco00010
# 69 aldose 1-epimerase [EC:5.1.3.3] eco:b0756 eco00010
# 70 glucokinase [EC:2.7.1.2] eco:b2388 eco00010
# 73 glucose-1-phosphatase [EC:3.1.3.10] eco:b1002 eco00010
# 75 dihydrolipoamide dehydrogenase [EC:1.8.1.4] eco:b0116 eco00010
# 76 phosphoglycerate kinase [EC:2.7.2.3] eco:b2926 eco00010
# 79 sugar PTS system EIIA component [EC:2.7.1.-] eco:b2417 eco00010
# 80 sugar PTS system EIIA component [EC:2.7.1.-] eco:b2417 eco00010
# 81 6-phospho-beta-glucosidase [EC:3.2.1.86] eco:b1734 eco00010
# 82 6-phospho-beta-glucosidase [EC:3.2.1.86] eco:b1734 eco00010
# 116 phosphoenolpyruvate carboxykinase (ATP) [EC:4.1.1.49] eco:b3403 eco00010
# 117 alcohol dehydrogenase eco:b2453 eco00010
# 124 pyruvate-ferredoxin/flavodoxin oxidoreductase [EC:1.2.7.1 1.2.7.-] eco:b1378 eco00010
# 131 acetyl-CoA synthetase [EC:6.2.1.1] eco:b4069 eco00010
# 137 2,3-bisphosphoglycerate-independent phosphoglycerate mutase [EC:5.4.2.12] eco:b3612 eco00010
# 138 aldehyde dehydrogenase [EC:1.2.1.-] eco:b3588 eco00010
# 28 dihydrolipoamide dehydrogenase [EC:1.8.1.4] eco:b0116 eco00020
# 29 2-oxoglutarate dehydrogenase E1 component [EC:1.2.4.2] eco:b0726 eco00020
# 30 2-oxoglutarate dehydrogenase E1 component [EC:1.2.4.2] eco:b0726 eco00020
# 31 2-oxoglutarate dehydrogenase E2 component (dihydrolipoamide succinyltransferase) [EC:2.3.1.61] eco:b0727 eco00020
# 32 succinyl-CoA synthetase beta subunit [EC:6.2.1.5] eco:b0728 eco00020
# 34 isocitrate dehydrogenase [EC:1.1.1.42] eco:b1136 eco00020
# 36 isocitrate dehydrogenase [EC:1.1.1.42] eco:b1136 eco00020
# 38 fumarate hydratase, class II [EC:4.2.1.2] eco:b1611 eco00020
# 39 aconitate hydratase 2 / 2-methylisocitrate dehydratase [EC:4.2.1.3 4.2.1.99] eco:b0118 eco00020
# 40 aconitate hydratase 2 / 2-methylisocitrate dehydratase [EC:4.2.1.3 4.2.1.99] eco:b0118 eco00020
# 41 citrate synthase [EC:2.3.3.1] eco:b0720 eco00020
# 42 malate dehydrogenase [EC:1.1.1.37] eco:b3236 eco00020
# 75 pyruvate dehydrogenase E1 component [EC:1.2.4.1] eco:b0114 eco00020
# 77 pyruvate dehydrogenase E1 component [EC:1.2.4.1] eco:b0114 eco00020
# 80 dihydrolipoamide dehydrogenase [EC:1.8.1.4] eco:b0116 eco00020
# 82 pyruvate dehydrogenase E2 component (dihydrolipoamide acetyltransferase) [EC:2.3.1.12] eco:b0115 eco00020
# 86 phosphoenolpyruvate carboxykinase (ATP) [EC:4.1.1.49] eco:b3403 eco00020
# 92 succinate dehydrogenase / fumarate reductase, cytochrome b subunit eco:b0721 eco00020
# 94 malate dehydrogenase (quinone) [EC:1.1.5.4] eco:b2210 eco00020
# 95 succinate dehydrogenase / fumarate reductase, cytochrome b subunit eco:b0721 eco00020
# 101 pyruvate-ferredoxin/flavodoxin oxidoreductase [EC:1.2.7.1 1.2.7.-] eco:b1378 eco00020
# 36 ribose 1,5-bisphosphokinase [EC:2.7.4.23] eco:b4094 eco00030
# 37 glucose-6-phosphate isomerase [EC:5.3.1.9] eco:b4025 eco00030
# 38 2-dehydro-3-deoxyphosphogluconate aldolase / (4S)-4-hydroxy-2-oxoglutarate aldolase [EC:4.1.2.14 4.1.3.42] eco:b1850 eco00030
# 40 ribokinase [EC:2.7.1.15] eco:b3752 eco00030
# 41 phosphopentomutase [EC:5.4.2.7] eco:b4383 eco00030
# 42 deoxyribose-phosphate aldolase [EC:4.1.2.4] eco:b4381 eco00030
# 43 ribose-phosphate pyrophosphokinase [EC:2.7.6.1] eco:b1207 eco00030
# 44 phosphopentomutase [EC:5.4.2.7] eco:b4383 eco00030
# 45 ribokinase [EC:2.7.1.15] eco:b3752 eco00030
# 46 transketolase [EC:2.2.1.1] eco:b2465 eco00030
# 47 ribose 5-phosphate isomerase A [EC:5.3.1.6] eco:b2914 eco00030
# 48 ribulose-phosphate 3-epimerase [EC:5.1.3.1] eco:b3386 eco00030
# 49 transketolase [EC:2.2.1.1] eco:b2465 eco00030
# 50 fructose-bisphosphate aldolase, class I [EC:4.1.2.13] eco:b2097 eco00030
# 51 6-phosphofructokinase 2 [EC:2.7.1.11] eco:b1723 eco00030
# 52 fructose-1,6-bisphosphatase II [EC:3.1.3.11] eco:b2930 eco00030
# 53 glucose-6-phosphate isomerase [EC:5.3.1.9] eco:b4025 eco00030
# 56 6-phosphogluconate dehydrogenase [EC:1.1.1.44 1.1.1.343] eco:b2029 eco00030
# 57 6-phosphogluconolactonase [EC:3.1.1.31] eco:b0767 eco00030
# 58 glucose-6-phosphate 1-dehydrogenase [EC:1.1.1.49 1.1.1.363] eco:b1852 eco00030
# 60 2-dehydro-3-deoxygluconokinase [EC:2.7.1.45] eco:b3526 eco00030
# 61 phosphogluconate dehydratase [EC:4.2.1.12] eco:b1851 eco00030
# 62 gluconokinase [EC:2.7.1.12] eco:b3437 eco00030
# 65 quinoprotein glucose dehydrogenase [EC:1.1.5.2] eco:b0124 eco00030
# 77 transaldolase [EC:2.2.1.2] eco:b0008 eco00030
# 78 phosphoglucomutase [EC:5.4.2.2] eco:b0688 eco00030
# 95 glyoxylate/hydroxypyruvate/2-ketogluconate reductase [EC:1.1.1.79 1.1.1.81 1.1.1.215] eco:b3553 eco00030
# 156 6-phosphogluconate dehydrogenase [EC:1.1.1.44 1.1.1.343] eco:b2029 eco00030
# 157 glucose-6-phosphate 1-dehydrogenase [EC:1.1.1.49 1.1.1.363] eco:b1852 eco00030
# 64 3-dehydro-L-gulonate-6-phosphate decarboxylase [EC:4.1.1.85] eco:b3581 eco00040
# 65 L-xylulokinase [EC:2.7.1.53] eco:b3580 eco00040
# 67 beta-glucuronidase [EC:3.2.1.31] eco:b1617 eco00040
# 68 L-arabinose isomerase [EC:5.3.1.4] eco:b0062 eco00040
# 70 L-ribulokinase [EC:2.7.1.16] eco:b0063 eco00040
# 73 L-ribulokinase [EC:2.7.1.16] eco:b0063 eco00040
# 74 ribulose-phosphate 3-epimerase [EC:5.1.3.1] eco:b3386 eco00040
# 75 L-ribulose-5-phosphate 4-epimerase [EC:5.1.3.4] eco:b0061 eco00040
# 78 L-ribulose-5-phosphate 3-epimerase [EC:5.1.3.22] eco:b3582 eco00040
# 80 xylulokinase [EC:2.7.1.17] eco:b3564 eco00040
# 82 2-dehydro-3-deoxy-D-pentonate aldolase [EC:4.1.2.28] eco:b0268 eco00040
# 83 xylonate dehydratase [EC:4.2.1.82] eco:b0269 eco00040
# 84 L-xylulokinase [EC:2.7.1.53] eco:b3580 eco00040
# 87 xylose isomerase [EC:5.3.1.5] eco:b3565 eco00040
# 96 UTP--glucose-1-phosphate uridylyltransferase [EC:2.7.7.9] eco:b1236 eco00040
# 98 UDPglucose 6-dehydrogenase [EC:1.1.1.22] eco:b2028 eco00040
# 102 glucuronate isomerase [EC:5.3.1.12] eco:b3092 eco00040
# 103 fructuronate reductase [EC:1.1.1.57] eco:b4323 eco00040
# 104 mannonate dehydratase [EC:4.2.1.8] eco:b1581 eco00040
# 105 altronate hydrolase [EC:4.2.1.7] eco:b3091 eco00040
# 106 glucuronate isomerase [EC:5.3.1.12] eco:b3092 eco00040
# 107 tagaturonate reductase [EC:1.1.1.58] eco:b1521 eco00040
# 119 3-dehydro-L-gulonate 2-dehydrogenase [EC:1.1.1.130] eco:b3575 eco00040
# 122 pectinesterase [EC:3.1.1.11] eco:b0772 eco00040
# 125 4-deoxy-L-threo-5-hexosulose-uronate ketol-isomerase [EC:5.3.1.17] eco:b2843 eco00040
# 126 2-dehydro-3-deoxy-D-gluconate 5-dehydrogenase [EC:1.1.1.127] eco:b2842 eco00040
# 127 rhamnulokinase [EC:2.7.1.5] eco:b3904 eco00040
# 128 rhamnulose-1-phosphate aldolase [EC:4.1.2.19] eco:b3902 eco00040
# 199 L-gulonate 5-dehydrogenase [EC:1.1.1.380] eco:b1580 eco00040
# 54 fructose PTS system EIIBC or EIIC component [EC:2.7.1.202] eco:b2167 eco00051
# 59 xylose isomerase [EC:5.3.1.5] eco:b3565 eco00051
# 67 mannitol PTS system EIICBA or EIICB component [EC:2.7.1.197] eco:b2933 eco00051
# 72 mannose PTS system EIIAB component [EC:2.7.1.191] eco:b1817 eco00051
# 74 fructokinase [EC:2.7.1.4] eco:b0394 eco00051
# 77 mannitol-1-phosphate 5-dehydrogenase [EC:1.1.1.17] eco:b3600 eco00051
# 78 mannose-6-phosphate isomerase [EC:5.3.1.8] eco:b1613 eco00051
# 79 phosphomannomutase [EC:5.4.2.8] eco:b2048 eco00051
# 82 GDP-L-fucose synthase [EC:1.1.1.271] eco:b2052 eco00051
# 83 GDPmannose 4,6-dehydratase [EC:4.2.1.47] eco:b2053 eco00051
# 84 mannose-1-phosphate guanylyltransferase [EC:2.7.7.13] eco:b2049 eco00051
# 86 sorbitol-6-phosphate 2-dehydrogenase [EC:1.1.1.140] eco:b2705 eco00051
# 87 glucitol/sorbitol PTS system EIIC component eco:b2702 eco00051
# 88 6-phosphofructokinase 2 [EC:2.7.1.11] eco:b1723 eco00051
# 92 1-phosphofructokinase [EC:2.7.1.56] eco:b2168 eco00051
# 93 triosephosphate isomerase (TIM) [EC:5.3.1.1] eco:b3919 eco00051
# 94 fructose-bisphosphate aldolase, class I [EC:4.1.2.13] eco:b2097 eco00051
# 96 fructose-bisphosphate aldolase, class I [EC:4.1.2.13] eco:b2097 eco00051
# 98 L-rhamnose isomerase [EC:5.3.1.14] eco:b3903 eco00051
# 99 rhamnulokinase [EC:2.7.1.5] eco:b3904 eco00051
# 101 rhamnulose-1-phosphate aldolase [EC:4.1.2.19] eco:b3902 eco00051
# 103 L-rhamnonate dehydratase [EC:4.2.1.90] eco:b2247 eco00051
# 104 2-dehydro-3-deoxy-L-rhamnonate aldolase [EC:4.1.2.53] eco:b2245 eco00051
# 105 fructose-1,6-bisphosphatase II [EC:3.1.3.11] eco:b2930 eco00051
# 115 L-sorbose 1-phosphate reductase [EC:1.1.1.-] eco:b4465 eco00051
# 166 L-fuculokinase [EC:2.7.1.51] eco:b2803 eco00051
# 167 L-fuculose-phosphate aldolase [EC:4.1.2.17] eco:b2800 eco00051
# 168 L-fucose/D-arabinose isomerase [EC:5.3.1.25 5.3.1.3] eco:b2802 eco00051
# 184 D-allulose-6-phosphate 3-epimerase [EC:5.1.3.-] eco:b4085 eco00051
# 187 ribose 5-phosphate isomerase B [EC:5.3.1.6] eco:b4090 eco00051
# 189 allose kinase [EC:2.7.1.55] eco:b4084 eco00051
# 214 mannosyl-3-phosphoglycerate phosphatase [EC:3.1.3.70] eco:b1955 eco00051
# 53 galactitol-1-phosphate 5-dehydrogenase [EC:1.1.1.251] eco:b2091 eco00052
# 54 galactitol PTS system EIIB component [EC:2.7.1.200] eco:b2093 eco00052
# 55 alpha-galactosidase [EC:3.2.1.22] eco:b4119 eco00052
# 57 6-phosphofructokinase 2 [EC:2.7.1.11] eco:b1723 eco00052
# 58 D-tagatose-1,6-bisphosphate aldolase subunit GatZ/KbaZ eco:b2095 eco00052
# 59 2-dehydro-3-deoxyphosphogalactonate aldolase [EC:4.1.2.21] eco:b4477 eco00052
# 61 alpha-galactosidase [EC:3.2.1.22] eco:b4119 eco00052
# 64 alpha-glucosidase [EC:3.2.1.20] eco:b0403 eco00052
# 65 alpha-galactosidase [EC:3.2.1.22] eco:b4119 eco00052
# 69 alpha-galactosidase [EC:3.2.1.22] eco:b4119 eco00052
# 70 alpha-galactosidase [EC:3.2.1.22] eco:b4119 eco00052
# 71 alpha-galactosidase [EC:3.2.1.22] eco:b4119 eco00052
# 72 alpha-galactosidase [EC:3.2.1.22] eco:b4119 eco00052
# 73 glucokinase [EC:2.7.1.2] eco:b2388 eco00052
# 76 beta-galactosidase [EC:3.2.1.23] eco:b0344 eco00052
# 77 phosphoglucomutase [EC:5.4.2.2] eco:b0688 eco00052
# 79 UDP-glucose 4-epimerase [EC:5.1.3.2] eco:b0759 eco00052
# 80 UTP--glucose-1-phosphate uridylyltransferase [EC:2.7.7.9] eco:b1236 eco00052
# 82 UDPglucose--hexose-1-phosphate uridylyltransferase [EC:2.7.7.12] eco:b0758 eco00052
# 83 2-dehydro-3-deoxygalactonokinase [EC:2.7.1.58] eco:b3693 eco00052
# 84 galactonate dehydratase [EC:4.2.1.6] eco:b4478 eco00052
# 94 beta-galactosidase [EC:3.2.1.23] eco:b0344 eco00052
# 101 N-acetylgalactosamine PTS system EIIB component [EC:2.7.1.-] eco:b3133 eco00052
# 103 galactosamine-6-phosphate isomerase [EC:5.3.1.-] eco:b3141 eco00052
# 110 galactosamine PTS system EIIB component [EC:2.7.1.-] eco:b3138 eco00052
# 111 alpha-galactosidase [EC:3.2.1.22] eco:b4119 eco00052
# 171 galactokinase [EC:2.7.1.6] eco:b0757 eco00052
# 172 aldose 1-epimerase [EC:5.1.3.3] eco:b0756 eco00052
# 175 UDP-galactopyranose mutase [EC:5.4.99.9] eco:b2036 eco00052
# 35 UDPglucose 6-dehydrogenase [EC:1.1.1.22] eco:b2028 eco00053
# 89 2-dehydro-3-deoxyglucarate aldolase [EC:4.1.2.20] eco:b3126 eco00053
# 90 glucarate dehydratase [EC:4.2.1.40] eco:b2787 eco00053
# 91 2-dehydro-3-deoxyglucarate aldolase [EC:4.1.2.20] eco:b3126 eco00053
# 92 galactarate dehydratase [EC:4.2.1.42] eco:b3128 eco00053
# 99 glucarate dehydratase [EC:4.2.1.40] eco:b2787 eco00053
# 133 L-xylulokinase [EC:2.7.1.53] eco:b3580 eco00053
# 134 3-dehydro-L-gulonate 2-dehydrogenase [EC:1.1.1.130] eco:b3575 eco00053
# 138 ascorbate PTS system EIIC component eco:b4193 eco00053
# 139 L-ascorbate 6-phosphate lactonase [EC:3.1.1.-] eco:b4192 eco00053
# 165 L-ribulose-5-phosphate 4-epimerase [EC:5.1.3.4] eco:b0061 eco00053
# 166 3-dehydro-L-gulonate-6-phosphate decarboxylase [EC:4.1.1.85] eco:b3581 eco00053
# 167 L-ribulose-5-phosphate 3-epimerase [EC:5.1.3.22] eco:b3582 eco00053
# 180 L-galactonate 5-dehydrogenase [EC:1.1.1.414] eco:b4358 eco00053
# 50 enoyl-[acyl-carrier protein] reductase I [EC:1.3.1.9 1.3.1.10] eco:b1288 eco00061
# 58 3-hydroxyacyl-[acyl-carrier-protein] dehydratase [EC:4.2.1.59] eco:b0180 eco00061
# 59 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] eco:b1095 eco00061
# 60 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] eco:b1093 eco00061
# 64 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] eco:b1095 eco00061
# 65 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] eco:b1095 eco00061
# 66 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] eco:b1095 eco00061
# 67 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] eco:b1095 eco00061
# 68 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] eco:b1095 eco00061
# 69 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] eco:b1095 eco00061
# 76 enoyl-[acyl-carrier protein] reductase I [EC:1.3.1.9 1.3.1.10] eco:b1288 eco00061
# 81 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] eco:b1093 eco00061
# 84 3-oxoacyl-[acyl-carrier-protein] synthase I [EC:2.3.1.41] eco:b2323 eco00061
# 87 enoyl-[acyl-carrier protein] reductase I [EC:1.3.1.9 1.3.1.10] eco:b1288 eco00061
# 92 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] eco:b1093 eco00061
# 95 3-oxoacyl-[acyl-carrier-protein] synthase I [EC:2.3.1.41] eco:b2323 eco00061
# 98 enoyl-[acyl-carrier protein] reductase I [EC:1.3.1.9 1.3.1.10] eco:b1288 eco00061
# 103 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] eco:b1093 eco00061
# 106 3-oxoacyl-[acyl-carrier-protein] synthase I [EC:2.3.1.41] eco:b2323 eco00061
# 109 enoyl-[acyl-carrier protein] reductase I [EC:1.3.1.9 1.3.1.10] eco:b1288 eco00061
# 114 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] eco:b1093 eco00061
# 117 3-oxoacyl-[acyl-carrier-protein] synthase I [EC:2.3.1.41] eco:b2323 eco00061
# 120 enoyl-[acyl-carrier protein] reductase I [EC:1.3.1.9 1.3.1.10] eco:b1288 eco00061
# 125 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] eco:b1093 eco00061
# 128 3-oxoacyl-[acyl-carrier-protein] synthase I [EC:2.3.1.41] eco:b2323 eco00061
# 131 enoyl-[acyl-carrier protein] reductase I [EC:1.3.1.9 1.3.1.10] eco:b1288 eco00061
# 136 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] eco:b1093 eco00061
# 139 3-oxoacyl-[acyl-carrier-protein] synthase I [EC:2.3.1.41] eco:b2323 eco00061
# 142 enoyl-[acyl-carrier protein] reductase I [EC:1.3.1.9 1.3.1.10] eco:b1288 eco00061
# 145 3-hydroxyacyl-[acyl-carrier protein] dehydratase / trans-2-decenoyl-[acyl-carrier protein] isomerase [EC:4.2.1.59 5.3.3.14] eco:b0954 eco00061
# 148 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] eco:b1093 eco00061
# 153 [acyl-carrier-protein] S-malonyltransferase [EC:2.3.1.39] eco:b1092 eco00061
# 159 acetyl-CoA carboxylase carboxyl transferase subunit alpha [EC:6.4.1.2 2.1.3.15] eco:b0185 eco00061
# 262 3-oxoacyl-[acyl-carrier-protein] synthase I [EC:2.3.1.41] eco:b2323 eco00061
# 264 3-oxoacyl-[acyl-carrier-protein] synthase I [EC:2.3.1.41] eco:b2323 eco00061
# 265 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] eco:b1095 eco00061
# 268 3-oxoacyl-[acyl-carrier-protein] synthase III [EC:2.3.1.180] eco:b1091 eco00061
# 272 3-hydroxyacyl-[acyl-carrier-protein] dehydratase [EC:4.2.1.59] eco:b0180 eco00061
# 273 3-hydroxyacyl-[acyl-carrier protein] dehydratase / trans-2-decenoyl-[acyl-carrier protein] isomerase [EC:4.2.1.59 5.3.3.14] eco:b0954 eco00061
# 274 3-hydroxyacyl-[acyl-carrier-protein] dehydratase [EC:4.2.1.59] eco:b0180 eco00061
# 276 3-hydroxyacyl-[acyl-carrier protein] dehydratase / trans-2-decenoyl-[acyl-carrier protein] isomerase [EC:4.2.1.59 5.3.3.14] eco:b0954 eco00061
# 277 3-hydroxyacyl-[acyl-carrier-protein] dehydratase [EC:4.2.1.59] eco:b0180 eco00061
# 278 3-hydroxyacyl-[acyl-carrier protein] dehydratase / trans-2-decenoyl-[acyl-carrier protein] isomerase [EC:4.2.1.59 5.3.3.14] eco:b0954 eco00061
# 279 3-hydroxyacyl-[acyl-carrier-protein] dehydratase [EC:4.2.1.59] eco:b0180 eco00061
# 280 3-hydroxyacyl-[acyl-carrier protein] dehydratase / trans-2-decenoyl-[acyl-carrier protein] isomerase [EC:4.2.1.59 5.3.3.14] eco:b0954 eco00061
# 281 3-hydroxyacyl-[acyl-carrier-protein] dehydratase [EC:4.2.1.59] eco:b0180 eco00061
# 283 3-hydroxyacyl-[acyl-carrier protein] dehydratase / trans-2-decenoyl-[acyl-carrier protein] isomerase [EC:4.2.1.59 5.3.3.14] eco:b0954 eco00061
# 284 3-hydroxyacyl-[acyl-carrier-protein] dehydratase [EC:4.2.1.59] eco:b0180 eco00061
# 286 3-hydroxyacyl-[acyl-carrier protein] dehydratase / trans-2-decenoyl-[acyl-carrier protein] isomerase [EC:4.2.1.59 5.3.3.14] eco:b0954 eco00061
# 287 3-hydroxyacyl-[acyl-carrier-protein] dehydratase [EC:4.2.1.59] eco:b0180 eco00061
# 294 3-hydroxyacyl-[acyl-carrier protein] dehydratase / trans-2-decenoyl-[acyl-carrier protein] isomerase [EC:4.2.1.59 5.3.3.14] eco:b0954 eco00061
# 301 long-chain acyl-CoA synthetase [EC:6.2.1.3] eco:b1805 eco00061
# 348 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] eco:b1093 eco00061
# 369 enoyl-[acyl-carrier protein] reductase I [EC:1.3.1.9 1.3.1.10] eco:b1288 eco00061
# 383 3-oxoacyl-[acyl-carrier-protein] synthase I [EC:2.3.1.41] eco:b2323 eco00061
# 384 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] eco:b1095 eco00061
# 388 long-chain acyl-CoA synthetase [EC:6.2.1.3] eco:b1805 eco00061
# 395 long-chain acyl-CoA synthetase [EC:6.2.1.3] eco:b1805 eco00061
# 401 3-oxoacyl-[acyl-carrier-protein] synthase III [EC:2.3.1.180] eco:b1091 eco00061
# 402 [acyl-carrier-protein] S-malonyltransferase [EC:2.3.1.39] eco:b1092 eco00061
# 403 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] eco:b1093 eco00061
# 404 3-hydroxyacyl-[acyl-carrier-protein] dehydratase [EC:4.2.1.59] eco:b0180 eco00061
# 405 [acyl-carrier-protein] S-malonyltransferase [EC:2.3.1.39] eco:b1092 eco00061
# 406 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] eco:b1095 eco00061
# 409 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] eco:b1095 eco00061
# 411 acetyl-CoA carboxylase carboxyl transferase subunit alpha [EC:6.4.1.2 2.1.3.15] eco:b0185 eco00061
# 413 enoyl-[acyl-carrier protein] reductase I [EC:1.3.1.9 1.3.1.10] eco:b1288 eco00061
# 33 acyl-CoA dehydrogenase [EC:1.3.99.-] eco:b0221 eco00071
# 34 acyl-CoA dehydrogenase [EC:1.3.99.-] eco:b0221 eco00071
# 35 acyl-CoA dehydrogenase [EC:1.3.99.-] eco:b0221 eco00071
# 36 acyl-CoA dehydrogenase [EC:1.3.99.-] eco:b0221 eco00071
# 37 acyl-CoA dehydrogenase [EC:1.3.99.-] eco:b0221 eco00071
# 38 acyl-CoA dehydrogenase [EC:1.3.99.-] eco:b0221 eco00071
# 39 acyl-CoA dehydrogenase [EC:1.3.99.-] eco:b0221 eco00071
# 41 3-hydroxyacyl-CoA dehydrogenase / enoyl-CoA hydratase / 3-hydroxybutyryl-CoA epimerase [EC:1.1.1.35 4.2.1.17 5.1.2.3] eco:b2341 eco00071
# 42 enoyl-CoA hydratase [EC:4.2.1.17] eco:b1393 eco00071
# 45 acyl-[acyl-carrier-protein]-phospholipid O-acyltransferase / long-chain-fatty-acid--[acyl-carrier-protein] ligase [EC:2.3.1.40 6.2.1.20] eco:b2836 eco00071
# 46 3-hydroxyacyl-CoA dehydrogenase / enoyl-CoA hydratase / 3-hydroxybutyryl-CoA epimerase / enoyl-CoA isomerase [EC:1.1.1.35 4.2.1.17 5.1.2.3 5.3.3.8] eco:b3846 eco00071
# 47 3-hydroxyacyl-CoA dehydrogenase / enoyl-CoA hydratase / 3-hydroxybutyryl-CoA epimerase [EC:1.1.1.35 4.2.1.17 5.1.2.3] eco:b2341 eco00071
# 48 acetyl-CoA C-acetyltransferase [EC:2.3.1.9] eco:b2224 eco00071
# 49 acetyl-CoA acyltransferase [EC:2.3.1.16] eco:b2342 eco00071
# 50 3-hydroxyacyl-CoA dehydrogenase / enoyl-CoA hydratase / 3-hydroxybutyryl-CoA epimerase [EC:1.1.1.35 4.2.1.17 5.1.2.3] eco:b2341 eco00071
# 51 enoyl-CoA hydratase [EC:4.2.1.17] eco:b1393 eco00071
# 57 acetyl-CoA acyltransferase [EC:2.3.1.16] eco:b2342 eco00071
# 58 3-hydroxyacyl-CoA dehydrogenase / enoyl-CoA hydratase / 3-hydroxybutyryl-CoA epimerase [EC:1.1.1.35 4.2.1.17 5.1.2.3] eco:b2341 eco00071
# 59 enoyl-CoA hydratase [EC:4.2.1.17] eco:b1393 eco00071
# 64 acetyl-CoA acyltransferase [EC:2.3.1.16] eco:b2342 eco00071
# 65 3-hydroxyacyl-CoA dehydrogenase / enoyl-CoA hydratase / 3-hydroxybutyryl-CoA epimerase [EC:1.1.1.35 4.2.1.17 5.1.2.3] eco:b2341 eco00071
# 66 enoyl-CoA hydratase [EC:4.2.1.17] eco:b1393 eco00071
# 74 acetyl-CoA acyltransferase [EC:2.3.1.16] eco:b2342 eco00071
# 75 3-hydroxyacyl-CoA dehydrogenase / enoyl-CoA hydratase / 3-hydroxybutyryl-CoA epimerase [EC:1.1.1.35 4.2.1.17 5.1.2.3] eco:b2341 eco00071
# 76 enoyl-CoA hydratase [EC:4.2.1.17] eco:b1393 eco00071
# 79 S-(hydroxymethyl)glutathione dehydrogenase / alcohol dehydrogenase [EC:1.1.1.284 1.1.1.1] eco:b0356 eco00071
# 89 acetyl-CoA acyltransferase [EC:2.3.1.16] eco:b2342 eco00071
# 90 enoyl-CoA hydratase [EC:4.2.1.17] eco:b1393 eco00071
# 92 3-hydroxyacyl-CoA dehydrogenase / enoyl-CoA hydratase / 3-hydroxybutyryl-CoA epimerase [EC:1.1.1.35 4.2.1.17 5.1.2.3] eco:b2341 eco00071
# 100 acetyl-CoA acyltransferase [EC:2.3.1.16] eco:b2342 eco00071
# 101 3-hydroxyacyl-CoA dehydrogenase / enoyl-CoA hydratase / 3-hydroxybutyryl-CoA epimerase [EC:1.1.1.35 4.2.1.17 5.1.2.3] eco:b2341 eco00071
# 102 enoyl-CoA hydratase [EC:4.2.1.17] eco:b1393 eco00071
# 104 long-chain acyl-CoA synthetase [EC:6.2.1.3] eco:b1805 eco00071
# 117 3-phenylpropionate/trans-cinnamate dioxygenase ferredoxin reductase component [EC:1.18.1.3] eco:b2542 eco00071
# 195 acetyl-CoA C-acetyltransferase [EC:2.3.1.9] eco:b2224 eco00071
# 208 acetyl-CoA acyltransferase [EC:2.3.1.16] eco:b2342 eco00071
# 99 7-alpha-hydroxysteroid dehydrogenase [EC:1.1.1.159] eco:b1619 eco00121
# 101 7-alpha-hydroxysteroid dehydrogenase [EC:1.1.1.159] eco:b1619 eco00121
# 55 2-succinyl-6-hydroxy-2,4-cyclohexadiene-1-carboxylate synthase [EC:4.2.99.20] eco:b2263 eco00130
# 59 naphthoate synthase [EC:4.1.3.36] eco:b2262 eco00130
# 60 O-succinylbenzoic acid---CoA ligase [EC:6.2.1.26] eco:b2260 eco00130
# 61 O-succinylbenzoate synthase [EC:4.2.1.113] eco:b2261 eco00130
# 62 2-succinyl-5-enolpyruvyl-6-hydroxy-3-cyclohexene-1-carboxylate synthase [EC:2.2.1.9] eco:b2264 eco00130
# 63 2-polyprenyl-6-hydroxyphenyl methylase / 3-demethylubiquinone-9 3-methyltransferase [EC:2.1.1.222 2.1.1.64] eco:b2232 eco00130
# 64 2-polyprenylphenol 6-hydroxylase [EC:1.14.13.240] eco:b2906 eco00130
# 65 flavin prenyltransferase [EC:2.5.1.129] eco:b2311 eco00130
# 67 2-polyprenyl-6-hydroxyphenyl methylase / 3-demethylubiquinone-9 3-methyltransferase [EC:2.1.1.222 2.1.1.64] eco:b2232 eco00130
# 69 chorismate--pyruvate lyase [EC:4.1.3.40] eco:b4039 eco00130
# 70 isochorismate synthase [EC:5.4.4.2] eco:b0593 eco00130
# 86 1,4-dihydroxy-2-naphthoyl-CoA hydrolase [EC:3.1.2.28] eco:b1686 eco00130
# 92 4-hydroxybenzoate polyprenyltransferase [EC:2.5.1.39] eco:b4040 eco00130
# 105 demethylmenaquinone methyltransferase / 2-methoxy-6-polyprenyl-1,4-benzoquinol methylase [EC:2.1.1.163 2.1.1.201] eco:b3833 eco00130
# 107 1,4-dihydroxy-2-naphthoate polyprenyltransferase [EC:2.5.1.74] eco:b3930 eco00130
# 135 2-octaprenyl-6-methoxyphenol hydroxylase [EC:1.14.13.-] eco:b2907 eco00130
# 136 demethylmenaquinone methyltransferase / 2-methoxy-6-polyprenyl-1,4-benzoquinol methylase [EC:2.1.1.163 2.1.1.201] eco:b3833 eco00130
# 137 3-demethoxyubiquinol 3-hydroxylase [EC:1.14.99.60] eco:b0662 eco00130
# 167 NAD(P)H dehydrogenase (quinone) [EC:1.6.5.2] eco:b1004 eco00130
# 170 NAD(P)H dehydrogenase (quinone) [EC:1.6.5.2] eco:b1004 eco00130
# 61 NADH-quinone oxidoreductase subunit N [EC:7.1.1.2] eco:b2276 eco00190
# 62 NADH-quinone oxidoreductase subunit M [EC:7.1.1.2] eco:b2277 eco00190
# 63 NADH-quinone oxidoreductase subunit L [EC:7.1.1.2] eco:b2278 eco00190
# 64 NADH-quinone oxidoreductase subunit K [EC:7.1.1.2] eco:b2279 eco00190
# 65 NADH-quinone oxidoreductase subunit J [EC:7.1.1.2] eco:b2280 eco00190
# 66 NADH-quinone oxidoreductase subunit I [EC:7.1.1.2] eco:b2281 eco00190
# 67 NADH-quinone oxidoreductase subunit H [EC:7.1.1.2] eco:b2282 eco00190
# 68 NADH-quinone oxidoreductase subunit G [EC:7.1.1.2] eco:b2283 eco00190
# 69 NADH-quinone oxidoreductase subunit F [EC:7.1.1.2] eco:b2284 eco00190
# 70 NADH-quinone oxidoreductase subunit E [EC:7.1.1.2] eco:b2285 eco00190
# 71 NADH-quinone oxidoreductase subunit C/D [EC:7.1.1.2] eco:b2286 eco00190
# 72 NADH-quinone oxidoreductase subunit C/D [EC:7.1.1.2] eco:b2286 eco00190
# 73 NADH-quinone oxidoreductase subunit B [EC:7.1.1.2] eco:b2287 eco00190
# 74 NADH-quinone oxidoreductase subunit A [EC:7.1.1.2] eco:b2288 eco00190
# 85 NADH dehydrogenase [EC:1.6.99.3] eco:b1109 eco00190
# 100 NADH-quinone oxidoreductase subunit N [EC:7.1.1.2] eco:b2276 eco00190
# 103 F-type H+-transporting ATPase subunit epsilon eco:b3731 eco00190
# 106 inorganic pyrophosphatase [EC:3.6.1.1] eco:b4226 eco00190
# 107 polyphosphate kinase [EC:2.7.4.1] eco:b2501 eco00190
# 131 succinate dehydrogenase / fumarate reductase, cytochrome b subunit eco:b0721 eco00190
# 132 succinate dehydrogenase / fumarate reductase, membrane anchor subunit eco:b0722 eco00190
# 133 succinate dehydrogenase / fumarate reductase, flavoprotein subunit [EC:1.3.5.1 1.3.5.4] eco:b0723 eco00190
# 134 succinate dehydrogenase / fumarate reductase, iron-sulfur subunit [EC:1.3.5.1 1.3.5.4] eco:b0724 eco00190
# 135 fumarate reductase flavoprotein subunit [EC:1.3.5.4] eco:b4154 eco00190
# 136 fumarate reductase iron-sulfur subunit [EC:1.3.5.4] eco:b4153 eco00190
# 137 fumarate reductase subunit C eco:b4152 eco00190
# 138 fumarate reductase subunit D eco:b4151 eco00190
# 149 cytochrome bd ubiquinol oxidase subunit II [EC:7.1.1.7] eco:b0734 eco00190
# 150 cytochrome bd ubiquinol oxidase subunit I [EC:7.1.1.7] eco:b0733 eco00190
# 160 cytochrome o ubiquinol oxidase subunit I [EC:7.1.1.3] eco:b0431 eco00190
# 161 cytochrome o ubiquinol oxidase subunit III eco:b0430 eco00190
# 162 heme o synthase [EC:2.5.1.141] eco:b0428 eco00190
# 163 cytochrome o ubiquinol oxidase subunit II [EC:7.1.1.3] eco:b0432 eco00190
# 166 cytochrome o ubiquinol oxidase subunit IV eco:b0429 eco00190
# 167 heme o synthase [EC:2.5.1.141] eco:b0428 eco00190
# 169 F-type H+/Na+-transporting ATPase subunit beta [EC:7.1.2.2 7.2.2.1] eco:b3732 eco00190
# 170 F-type H+/Na+-transporting ATPase subunit alpha [EC:7.1.2.2 7.2.2.1] eco:b3734 eco00190
# 171 F-type H+-transporting ATPase subunit gamma eco:b3733 eco00190
# 172 F-type H+-transporting ATPase subunit delta eco:b3735 eco00190
# 173 F-type H+-transporting ATPase subunit epsilon eco:b3731 eco00190
# 174 F-type H+-transporting ATPase subunit c eco:b3737 eco00190
# 175 F-type H+-transporting ATPase subunit a eco:b3738 eco00190
# 176 F-type H+-transporting ATPase subunit b eco:b3736 eco00190
# 217 succinate dehydrogenase / fumarate reductase, cytochrome b subunit eco:b0721 eco00190
# 220 cytochrome bd-I ubiquinol oxidase subunit X [EC:7.1.1.7] eco:b4515 eco00190
# 45 glutaminase [EC:3.5.1.2] eco:b0485 eco00220
# 46 glutamine synthetase [EC:6.3.1.2] eco:b3870 eco00220
# 47 carbamate kinase [EC:2.7.2.2] eco:b0323 eco00220
# 49 ornithine carbamoyltransferase [EC:2.1.3.3] eco:b0273 eco00220
# 50 argininosuccinate synthase [EC:6.3.4.5] eco:b3172 eco00220
# 52 argininosuccinate lyase [EC:4.3.2.1] eco:b3960 eco00220
# 54 amino-acid N-acetyltransferase [EC:2.3.1.1] eco:b2818 eco00220
# 55 acetylglutamate kinase [EC:2.7.2.8] eco:b3959 eco00220
# 56 N-acetyl-gamma-glutamyl-phosphate reductase [EC:1.2.1.38] eco:b3958 eco00220
# 57 acetylornithine/N-succinyldiaminopimelate aminotransferase [EC:2.6.1.11 2.6.1.17] eco:b3359 eco00220
# 59 acetylornithine deacetylase [EC:3.5.1.16] eco:b3957 eco00220
# 68 glutamate dehydrogenase (NADP+) [EC:1.4.1.4] eco:b1761 eco00220
# 82 acetylornithine deacetylase [EC:3.5.1.16] eco:b3957 eco00220
# 88 aspartate aminotransferase [EC:2.6.1.1] eco:b0928 eco00220
# 89 alanine-synthesizing transaminase [EC:2.6.1.66 2.6.1.2] eco:b2290 eco00220
# 137 ribonucleoside-diphosphate reductase alpha chain [EC:1.17.4.1] eco:b2234 eco00230
# 141 (S)-ureidoglycine aminohydrolase [EC:3.5.3.26] eco:b0515 eco00230
# 142 allantoate deiminase [EC:3.5.3.9] eco:b0516 eco00230
# 157 ribose-phosphate pyrophosphokinase [EC:2.7.6.1] eco:b1207 eco00230
# 158 amidophosphoribosyltransferase [EC:2.4.2.14] eco:b2312 eco00230
# 160 phosphoribosylamine---glycine ligase [EC:6.3.4.13] eco:b4005 eco00230
# 161 phosphoribosylglycinamide formyltransferase 2 [EC:2.1.2.2] eco:b1849 eco00230
# 162 phosphoribosylformylglycinamidine cyclo-ligase [EC:6.3.3.1] eco:b2499 eco00230
# 163 phosphoribosylaminoimidazolecarboxamide formyltransferase / IMP cyclohydrolase [EC:2.1.2.3 3.5.4.10] eco:b4006 eco00230
# 164 adenylosuccinate lyase [EC:4.3.2.2] eco:b1131 eco00230
# 165 phosphoribosylaminoimidazole-succinocarboxamide synthase [EC:6.3.2.6] eco:b2476 eco00230
# 167 phosphoribosylaminoimidazolecarboxamide formyltransferase / IMP cyclohydrolase [EC:2.1.2.3 3.5.4.10] eco:b4006 eco00230
# 169 adenylate cyclase, class 1 [EC:4.6.1.1] eco:b3806 eco00230
# 173 nucleoside-diphosphate kinase [EC:2.7.4.6] eco:b2518 eco00230
# 174 nucleoside-diphosphate kinase [EC:2.7.4.6] eco:b2518 eco00230
# 175 ribonucleoside-diphosphate reductase alpha chain [EC:1.17.4.1] eco:b2234 eco00230
# 177 adenylate kinase [EC:2.7.4.3] eco:b0474 eco00230
# 178 adenylosuccinate lyase [EC:4.3.2.2] eco:b1131 eco00230
# 179 adenylosuccinate synthase [EC:6.3.4.4] eco:b4177 eco00230
# 181 5'-nucleotidase / UDP-sugar diphosphatase [EC:3.1.3.5 3.6.1.45] eco:b0480 eco00230
# 183 adenine phosphoribosyltransferase [EC:2.4.2.7] eco:b0469 eco00230
# 185 5'-nucleotidase / UDP-sugar diphosphatase [EC:3.1.3.5 3.6.1.45] eco:b0480 eco00230
# 186 adenosine deaminase [EC:3.5.4.4] eco:b1623 eco00230
# 187 purine-nucleoside phosphorylase [EC:2.4.2.1] eco:b4384 eco00230
# 188 AMP nucleosidase [EC:3.2.2.4] eco:b1982 eco00230
# 189 purine/pyrimidine-nucleoside phosphorylase [EC:2.4.2.1 2.4.2.2] eco:b0391 eco00230
# 190 inosine kinase [EC:2.7.1.73] eco:b0477 eco00230
# 191 5'-nucleotidase / UDP-sugar diphosphatase [EC:3.1.3.5 3.6.1.45] eco:b0480 eco00230
# 192 adenosine deaminase [EC:3.5.4.4] eco:b1623 eco00230
# 195 adenine deaminase [EC:3.5.4.2] eco:b3665 eco00230
# 197 nucleoside-diphosphate kinase [EC:2.7.4.6] eco:b2518 eco00230
# 199 GMP reductase [EC:1.7.1.7] eco:b0104 eco00230
# 200 IMP dehydrogenase [EC:1.1.1.205] eco:b2508 eco00230
# 201 GMP synthase (glutamine-hydrolysing) [EC:6.3.5.2] eco:b2507 eco00230
# 204 hypoxanthine phosphoribosyltransferase [EC:2.4.2.8] eco:b0125 eco00230
# 206 purine/pyrimidine-nucleoside phosphorylase [EC:2.4.2.1 2.4.2.2] eco:b0391 eco00230
# 208 5'-nucleotidase / UDP-sugar diphosphatase [EC:3.1.3.5 3.6.1.45] eco:b0480 eco00230
# 209 purine/pyrimidine-nucleoside phosphorylase [EC:2.4.2.1 2.4.2.2] eco:b0391 eco00230
# 211 hypoxanthine phosphoribosyltransferase [EC:2.4.2.8] eco:b0125 eco00230
# 212 inosine kinase [EC:2.7.1.73] eco:b0477 eco00230
# 213 5'-nucleotidase / UDP-sugar diphosphatase [EC:3.1.3.5 3.6.1.45] eco:b0480 eco00230
# 214 hypoxanthine phosphoribosyltransferase [EC:2.4.2.8] eco:b0125 eco00230
# 215 guanylate kinase [EC:2.7.4.8] eco:b3648 eco00230
# 216 purine-nucleoside phosphorylase [EC:2.4.2.1] eco:b4384 eco00230
# 217 guanine deaminase [EC:3.5.4.3] eco:b2883 eco00230
# 218 ureidoglycolate lyase [EC:4.3.2.3] eco:b0505 eco00230
# 220 allantoinase [EC:3.5.2.5] eco:b0512 eco00230
# 227 5-hydroxyisourate hydrolase [EC:3.5.2.17] eco:b1970 eco00230
# 228 GTP diphosphokinase / guanosine-3',5'-bis(diphosphate) 3'-diphosphatase [EC:2.7.6.5 3.1.7.2] eco:b3650 eco00230
# 229 exopolyphosphatase / guanosine-5'-triphosphate,3'-diphosphate pyrophosphatase [EC:3.6.1.11 3.6.1.40] eco:b2502 eco00230
# 230 exopolyphosphatase / guanosine-5'-triphosphate,3'-diphosphate pyrophosphatase [EC:3.6.1.11 3.6.1.40] eco:b2502 eco00230
# 232 nucleoside-diphosphate kinase [EC:2.7.4.6] eco:b2518 eco00230
# 233 guanylate kinase [EC:2.7.4.8] eco:b3648 eco00230
# 234 nucleoside-diphosphate kinase [EC:2.7.4.6] eco:b2518 eco00230
# 236 5'-nucleotidase / UDP-sugar diphosphatase [EC:3.1.3.5 3.6.1.45] eco:b0480 eco00230
# 237 purine/pyrimidine-nucleoside phosphorylase [EC:2.4.2.1 2.4.2.2] eco:b0391 eco00230
# 238 GTP pyrophosphokinase [EC:2.7.6.5] eco:b2784 eco00230
# 243 bis(5'-nucleosyl)-tetraphosphatase (symmetrical) [EC:3.6.1.41] eco:b0049 eco00230
# 244 sulfate adenylyltransferase subunit 1 [EC:2.7.7.4] eco:b2751 eco00230
# 245 adenylylsulfate kinase [EC:2.7.1.25] eco:b2750 eco00230
# 250 xanthine dehydrogenase YagR molybdenum-binding subunit [EC:1.17.1.4] eco:b0284 eco00230
# 251 xanthine dehydrogenase YagR molybdenum-binding subunit [EC:1.17.1.4] eco:b0284 eco00230
# 252 phosphoribosylformylglycinamidine synthase [EC:6.3.5.3] eco:b2557 eco00230
# 259 xanthine phosphoribosyltransferase [EC:2.4.2.22] eco:b0238 eco00230
# 262 2',3'-cyclic-nucleotide 2'-phosphodiesterase / 3'-nucleotidase [EC:3.1.4.16 3.1.3.6] eco:b4213 eco00230
# 263 2',3'-cyclic-nucleotide 2'-phosphodiesterase / 3'-nucleotidase [EC:3.1.4.16 3.1.3.6] eco:b4213 eco00230
# 264 2',3'-cyclic-nucleotide 2'-phosphodiesterase / 3'-nucleotidase [EC:3.1.4.16 3.1.3.6] eco:b4213 eco00230
# 267 dGTPase [EC:3.1.5.1] eco:b0160 eco00230
# 271 2',3'-cyclic-nucleotide 2'-phosphodiesterase / 3'-nucleotidase [EC:3.1.4.16 3.1.3.6] eco:b4213 eco00230
# 273 phosphopentomutase [EC:5.4.2.7] eco:b4383 eco00230
# 274 ADP-ribose pyrophosphatase [EC:3.6.1.13] eco:b3034 eco00230
# 277 xanthine phosphoribosyltransferase [EC:2.4.2.22] eco:b0238 eco00230
# 278 purine-nucleoside phosphorylase [EC:2.4.2.1] eco:b4384 eco00230
# 279 adenylate kinase [EC:2.7.4.3] eco:b0474 eco00230
# 287 nucleoside-diphosphate kinase [EC:2.7.4.6] eco:b2518 eco00230
# 291 adenylate cyclase, class 1 [EC:4.6.1.1] eco:b3806 eco00230
# 292 pyruvate kinase [EC:2.7.1.40] eco:b1676 eco00230
# 293 pyruvate kinase [EC:2.7.1.40] eco:b1676 eco00230
# 294 adenine phosphoribosyltransferase [EC:2.4.2.7] eco:b0469 eco00230
# 295 ribosylpyrimidine nucleosidase [EC:3.2.2.8] eco:b2162 eco00230
# 296 adenine phosphoribosyltransferase [EC:2.4.2.7] eco:b0469 eco00230
# 301 ribosylpyrimidine nucleosidase [EC:3.2.2.8] eco:b2162 eco00230
# 302 ribosylpyrimidine nucleosidase [EC:3.2.2.8] eco:b2162 eco00230
# 304 pyruvate kinase [EC:2.7.1.40] eco:b1676 eco00230
# 305 pyruvate kinase [EC:2.7.1.40] eco:b1676 eco00230
# 412 carbamate kinase [EC:2.7.2.2] eco:b0323 eco00230
# 413 xanthosine phosphorylase [EC:2.4.2.-] eco:b2407 eco00230
# 414 ADP-ribose diphosphatase [EC:3.6.1.-] eco:b3397 eco00230
# 419 5-(carboxyamino)imidazole ribonucleotide synthase [EC:6.3.4.18] eco:b0522 eco00230
# 420 5-(carboxyamino)imidazole ribonucleotide mutase [EC:5.4.99.18] eco:b0523 eco00230
# 422 3',5'-cyclic-AMP phosphodiesterase [EC:3.1.4.53] eco:b3032 eco00230
# 423 phosphoglucomutase [EC:5.4.2.2] eco:b0688 eco00230
# 428 ureidoglycolate dehydrogenase (NAD+) [EC:1.1.1.350] eco:b0517 eco00230
# 429 XTP/dITP diphosphohydrolase [EC:3.6.1.66] eco:b2954 eco00230
# 430 XTP/dITP diphosphohydrolase [EC:3.6.1.66] eco:b2954 eco00230
# 434 nucleoside triphosphate diphosphatase [EC:3.6.1.9] eco:b2781 eco00230
# 435 nucleoside triphosphate diphosphatase [EC:3.6.1.9] eco:b2781 eco00230
# 437 ribonucleoside-triphosphate reductase (formate) [EC:1.1.98.6] eco:b4238 eco00230
# 438 ribonucleoside-triphosphate reductase (formate) [EC:1.1.98.6] eco:b4238 eco00230
# 81 ribonucleoside-diphosphate reductase alpha chain [EC:1.17.4.1] eco:b2234 eco00240
# 84 uridylate kinase [EC:2.7.4.22] eco:b0171 eco00240
# 88 carbamoyl-phosphate synthase small subunit [EC:6.3.5.5] eco:b0032 eco00240
# 94 aspartate carbamoyltransferase regulatory subunit eco:b4244 eco00240
# 95 dihydroorotase [EC:3.5.2.3] eco:b1062 eco00240
# 98 orotate phosphoribosyltransferase [EC:2.4.2.10] eco:b3642 eco00240
# 99 nucleoside-diphosphate kinase [EC:2.7.4.6] eco:b2518 eco00240
# 101 dCTP deaminase [EC:3.5.4.13] eco:b2065 eco00240
# 102 CTP synthase [EC:6.3.4.2] eco:b2780 eco00240
# 107 uracil phosphoribosyltransferase [EC:2.4.2.9] eco:b2498 eco00240
# 108 uridine kinase [EC:2.7.1.48] eco:b2066 eco00240
# 109 5'-nucleotidase / UDP-sugar diphosphatase [EC:3.1.3.5 3.6.1.45] eco:b0480 eco00240
# 110 purine/pyrimidine-nucleoside phosphorylase [EC:2.4.2.1 2.4.2.2] eco:b0391 eco00240
# 112 dihydropyrimidine dehydrogenase (NAD+) subunit PreT [EC:1.3.1.1] eco:b2146 eco00240
# 114 dihydropyrimidinase [EC:3.5.2.2] eco:b2873 eco00240
# 117 nucleoside-diphosphate kinase [EC:2.7.4.6] eco:b2518 eco00240
# 120 uridine kinase [EC:2.7.1.48] eco:b2066 eco00240
# 121 5'-nucleotidase / UDP-sugar diphosphatase [EC:3.1.3.5 3.6.1.45] eco:b0480 eco00240
# 122 cytidine deaminase [EC:3.5.4.5] eco:b2143 eco00240
# 123 cytosine/creatinine deaminase [EC:3.5.4.1 3.5.4.21] eco:b0337 eco00240
# 124 purine/pyrimidine-nucleoside phosphorylase [EC:2.4.2.1 2.4.2.2] eco:b0391 eco00240
# 125 ribosylpyrimidine nucleosidase [EC:3.2.2.8] eco:b2162 eco00240
# 126 pyrimidine/purine-5'-nucleotide nucleosidase [EC:3.2.2.10 3.2.2.-] eco:b2795 eco00240
# 131 ribonucleoside-diphosphate reductase alpha chain [EC:1.17.4.1] eco:b2234 eco00240
# 132 nucleoside-diphosphate kinase [EC:2.7.4.6] eco:b2518 eco00240
# 133 dCTP deaminase [EC:3.5.4.13] eco:b2065 eco00240
# 138 5'-nucleotidase / UDP-sugar diphosphatase [EC:3.1.3.5 3.6.1.45] eco:b0480 eco00240
# 140 nucleoside-diphosphate kinase [EC:2.7.4.6] eco:b2518 eco00240
# 142 dTMP kinase [EC:2.7.4.9] eco:b1098 eco00240
# 143 thymidine kinase [EC:2.7.1.21] eco:b1238 eco00240
# 144 cytidine deaminase [EC:3.5.4.5] eco:b2143 eco00240
# 146 purine-nucleoside phosphorylase [EC:2.4.2.1] eco:b4384 eco00240
# 147 thymidine phosphorylase [EC:2.4.2.4] eco:b4382 eco00240
# 148 thymidylate synthase [EC:2.1.1.45] eco:b2827 eco00240
# 149 nucleoside-diphosphate kinase [EC:2.7.4.6] eco:b2518 eco00240
# 152 dTMP kinase [EC:2.7.4.9] eco:b1098 eco00240
# 154 5'-nucleotidase / UDP-sugar diphosphatase [EC:3.1.3.5 3.6.1.45] eco:b0480 eco00240
# 155 thymidine kinase [EC:2.7.1.21] eco:b1238 eco00240
# 157 purine/pyrimidine-nucleoside phosphorylase [EC:2.4.2.1 2.4.2.2] eco:b0391 eco00240
# 158 cytosine/creatinine deaminase [EC:3.5.4.1 3.5.4.21] eco:b0337 eco00240
# 160 dihydropyrimidine dehydrogenase (NAD+) subunit PreT [EC:1.3.1.1] eco:b2146 eco00240
# 163 dihydropyrimidinase [EC:3.5.2.2] eco:b2873 eco00240
# 165 dihydroorotate dehydrogenase [EC:1.3.5.2] eco:b0945 eco00240
# 167 pseudouridylate synthase [EC:4.2.1.70] eco:b2165 eco00240
# 168 pseudouridine kinase [EC:2.7.1.83] eco:b2166 eco00240
# 169 orotidine-5'-phosphate decarboxylase [EC:4.1.1.23] eco:b1281 eco00240
# 172 2',3'-cyclic-nucleotide 2'-phosphodiesterase / 3'-nucleotidase [EC:3.1.4.16 3.1.3.6] eco:b4213 eco00240
# 173 2',3'-cyclic-nucleotide 2'-phosphodiesterase / 3'-nucleotidase [EC:3.1.4.16 3.1.3.6] eco:b4213 eco00240
# 174 nucleoside triphosphate diphosphatase [EC:3.6.1.9] eco:b2781 eco00240
# 176 2',3'-cyclic-nucleotide 2'-phosphodiesterase / 3'-nucleotidase [EC:3.1.4.16 3.1.3.6] eco:b4213 eco00240
# 177 2',3'-cyclic-nucleotide 2'-phosphodiesterase / 3'-nucleotidase [EC:3.1.4.16 3.1.3.6] eco:b4213 eco00240
# 250 flavin reductase [EC:1.5.1.-] eco:b1007 eco00240
# 251 ureidoacrylate peracid hydrolase [EC:3.5.1.110] eco:b1011 eco00240
# 257 3-hydroxy acid dehydrogenase / malonic semialdehyde reductase [EC:1.1.1.381 1.1.1.-] eco:b1539 eco00240
# 259 aminoacrylate peracid reductase eco:b1010 eco00240
# 262 aminoacrylate hydrolase [EC:3.5.1.-] eco:b1009 eco00240
# 263 3-hydroxypropanoate dehydrogenase [EC:1.1.1.-] eco:b1008 eco00240
# 267 ureidoacrylate peracid hydrolase [EC:3.5.1.110] eco:b1011 eco00240
# 268 uridine phosphorylase [EC:2.4.2.3] eco:b3831 eco00240
# 269 5'-nucleotidase / UDP-sugar diphosphatase [EC:3.1.3.5 3.6.1.45] eco:b0480 eco00240
# 271 5'-deoxynucleotidase [EC:3.1.3.89] eco:b2291 eco00240
# 274 nucleoside-diphosphate kinase [EC:2.7.4.6] eco:b2518 eco00240
# 275 5'-deoxynucleotidase [EC:3.1.3.89] eco:b2291 eco00240
# 278 5'-deoxynucleotidase [EC:3.1.3.89] eco:b2291 eco00240
# 285 nucleoside triphosphate diphosphatase [EC:3.6.1.9] eco:b2781 eco00240
# 287 nucleoside triphosphate diphosphatase [EC:3.6.1.9] eco:b2781 eco00240
# 288 dUTP pyrophosphatase [EC:3.6.1.23] eco:b3640 eco00240
# 289 CMP/dCMP kinase [EC:2.7.4.25] eco:b0910 eco00240
# 290 CMP/dCMP kinase [EC:2.7.4.25] eco:b0910 eco00240
# 291 ribonucleoside-triphosphate reductase (formate) [EC:1.1.98.6] eco:b4238 eco00240
# 292 ribonucleoside-triphosphate reductase (formate) [EC:1.1.98.6] eco:b4238 eco00240
# 33 omega-amidase [EC:3.5.1.3] eco:b0219 eco00250
# 34 aspartate--ammonia ligase [EC:6.3.1.1] eco:b3744 eco00250
# 35 asparagine synthase (glutamine-hydrolysing) [EC:6.3.5.4] eco:b0674 eco00250
# 38 L-asparaginase / beta-aspartyl-peptidase [EC:3.5.1.1 3.4.19.5] eco:b0828 eco00250
# 48 L-aspartate oxidase [EC:1.4.3.16] eco:b2574 eco00250
# 49 aspartate aminotransferase [EC:2.6.1.1] eco:b0928 eco00250
# 55 argininosuccinate synthase [EC:6.3.4.5] eco:b3172 eco00250
# 56 adenylosuccinate synthase [EC:6.3.4.4] eco:b4177 eco00250
# 57 aspartate ammonia-lyase [EC:4.3.1.1] eco:b4139 eco00250
# 58 argininosuccinate lyase [EC:4.3.2.1] eco:b3960 eco00250
# 59 adenylosuccinate lyase [EC:4.3.2.2] eco:b1131 eco00250
# 63 alanine-synthesizing transaminase [EC:2.6.1.66 2.6.1.2] eco:b2290 eco00250
# 71 aspartate carbamoyltransferase regulatory subunit eco:b4244 eco00250
# 85 succinate-semialdehyde dehydrogenase [EC:1.2.1.16 1.2.1.24] eco:b1525 eco00250
# 86 succinate-semialdehyde dehydrogenase [EC:1.2.1.16 1.2.1.24] eco:b1525 eco00250
# 89 glutamate synthase (NADPH) large chain [EC:1.4.1.13] eco:b3212 eco00250
# 94 glutamate dehydrogenase (NADP+) [EC:1.4.1.4] eco:b1761 eco00250
# 97 4-aminobutyrate aminotransferase [EC:2.6.1.19] eco:b1302 eco00250
# 99 glutamate decarboxylase [EC:4.1.1.15] eco:b1493 eco00250
# 102 glutamine synthetase [EC:6.3.1.2] eco:b3870 eco00250
# 105 glutaminase [EC:3.5.1.2] eco:b0485 eco00250
# 110 carbamoyl-phosphate synthase small subunit [EC:6.3.5.5] eco:b0032 eco00250
# 118 omega-amidase [EC:3.5.1.3] eco:b0219 eco00250
# 121 RHH-type transcriptional regulator, proline utilization regulon repressor / proline dehydrogenase / delta 1-pyrroline-5-carboxylate dehydrogenase [EC:1.5.5.2 1.2.1.88] eco:b1014 eco00250
# 123 glutamine---fructose-6-phosphate transaminase (isomerizing) [EC:2.6.1.16] eco:b3729 eco00250
# 125 amidophosphoribosyltransferase [EC:2.4.2.14] eco:b2312 eco00250
# 160 succinate-semialdehyde dehydrogenase / glutarate-semialdehyde dehydrogenase [EC:1.2.1.16 1.2.1.79 1.2.1.20] eco:b2661 eco00250
# 68 choline dehydrogenase [EC:1.1.99.1] eco:b0311 eco00260
# 70 betaine-aldehyde dehydrogenase [EC:1.2.1.8] eco:b0312 eco00260
# 80 D-3-phosphoglycerate dehydrogenase / 2-oxoglutarate reductase [EC:1.1.1.95 1.1.1.399] eco:b2913 eco00260
# 86 bifunctional aspartokinase / homoserine dehydrogenase 1 [EC:2.7.2.4 1.1.1.3] eco:b0002 eco00260
# 88 phosphoserine aminotransferase [EC:2.6.1.52] eco:b0907 eco00260
# 91 phosphoserine phosphatase [EC:3.1.3.3] eco:b4388 eco00260
# 92 glycine hydroxymethyltransferase [EC:2.1.2.1] eco:b2551 eco00260
# 93 threonine dehydratase [EC:4.3.1.19] eco:b3117 eco00260
# 94 threonine aldolase [EC:4.1.2.48] eco:b0870 eco00260
# 97 threonine synthase [EC:4.2.3.1] eco:b0004 eco00260
# 99 threonine 3-dehydrogenase [EC:1.1.1.103] eco:b3616 eco00260
# 102 glycine C-acetyltransferase [EC:2.3.1.29] eco:b3617 eco00260
# 103 aspartate-semialdehyde dehydrogenase [EC:1.2.1.11] eco:b3433 eco00260
# 105 L-serine dehydratase [EC:4.3.1.17] eco:b1814 eco00260
# 109 homoserine kinase [EC:2.7.1.39] eco:b0003 eco00260
# 111 glycine dehydrogenase [EC:1.4.4.2] eco:b2903 eco00260
# 113 bifunctional aspartokinase / homoserine dehydrogenase 1 [EC:2.7.2.4 1.1.1.3] eco:b0002 eco00260
# 114 D-serine dehydratase [EC:4.3.1.18] eco:b2366 eco00260
# 116 glyoxylate/hydroxypyruvate reductase [EC:1.1.1.79 1.1.1.81] eco:b1033 eco00260
# 117 primary-amine oxidase [EC:1.4.3.21] eco:b1386 eco00260
# 120 aminomethyltransferase [EC:2.1.2.10] eco:b2905 eco00260
# 123 dihydrolipoamide dehydrogenase [EC:1.8.1.4] eco:b0116 eco00260
# 126 threonine dehydratase [EC:4.3.1.19] eco:b3117 eco00260
# 138 threonine aldolase [EC:4.1.2.48] eco:b0870 eco00260
# 195 CDP-diacylglycerol---serine O-phosphatidyltransferase [EC:2.7.8.8] eco:b2585 eco00260
# 199 tryptophan synthase alpha chain [EC:4.2.1.20] eco:b1260 eco00260
# 216 glycerate 2-kinase [EC:2.7.1.165] eco:b0514 eco00260
# 217 2,3-bisphosphoglycerate-dependent phosphoglycerate mutase [EC:5.4.2.11] eco:b0755 eco00260
# 227 2,3-bisphosphoglycerate-independent phosphoglycerate mutase [EC:5.4.2.12] eco:b3612 eco00260
# 228 glycine cleavage system H protein eco:b2904 eco00260
# 236 3-hydroxy acid dehydrogenase / malonic semialdehyde reductase [EC:1.1.1.381 1.1.1.-] eco:b1539 eco00260
# 62 bifunctional aspartokinase / homoserine dehydrogenase 1 [EC:2.7.2.4 1.1.1.3] eco:b0002 eco00261
# 63 aspartate-semialdehyde dehydrogenase [EC:1.2.1.11] eco:b3433 eco00261
# 96 4-hydroxy-tetrahydrodipicolinate reductase [EC:1.17.1.8] eco:b0031 eco00261
# 97 4-hydroxy-tetrahydrodipicolinate synthase [EC:4.3.3.7] eco:b2478 eco00261
# 101 sulfate adenylyltransferase subunit 1 [EC:2.7.7.4] eco:b2751 eco00261
# 77 aromatic-amino-acid transaminase [EC:2.6.1.57] eco:b4054 eco00270
# 88 adenosylhomocysteine nucleosidase [EC:3.2.2.9] eco:b0159 eco00270
# 89 spermidine synthase [EC:2.5.1.16] eco:b0121 eco00270
# 90 S-adenosylmethionine decarboxylase [EC:4.1.1.50] eco:b0120 eco00270
# 91 L-methionine (R)-S-oxide reductase [EC:1.8.4.14] eco:b1832 eco00270
# 97 5-methyltetrahydrofolate--homocysteine methyltransferase [EC:2.1.1.13] eco:b4019 eco00270
# 98 cysteine-S-conjugate beta-lyase [EC:4.4.1.13] eco:b1622 eco00270
# 99 5-methyltetrahydropteroyltriglutamate--homocysteine methyltransferase [EC:2.1.1.14] eco:b3829 eco00270
# 101 S-adenosylmethionine synthetase [EC:2.5.1.6] eco:b2942 eco00270
# 103 DNA (cytosine-5)-methyltransferase 1 [EC:2.1.1.37] eco:b1961 eco00270
# 107 homocysteine S-methyltransferase [EC:2.1.1.10] eco:b0261 eco00270
# 108 S-ribosylhomocysteine lyase [EC:4.4.1.21] eco:b2687 eco00270
# 109 adenosylhomocysteine nucleosidase [EC:3.2.2.9] eco:b0159 eco00270
# 110 cystathionine gamma-synthase [EC:2.5.1.48] eco:b3939 eco00270
# 132 cysteine synthase [EC:2.5.1.47] eco:b2414 eco00270
# 133 serine O-acetyltransferase [EC:2.3.1.30] eco:b3607 eco00270
# 140 S-sulfo-L-cysteine synthase (O-acetyl-L-serine-dependent) [EC:2.5.1.144] eco:b2421 eco00270
# 149 L-serine dehydratase [EC:4.3.1.17] eco:b1814 eco00270
# 158 aspartate aminotransferase [EC:2.6.1.1] eco:b0928 eco00270
# 185 aspartate aminotransferase [EC:2.6.1.1] eco:b0928 eco00270
# 192 D-cysteine desulfhydrase [EC:4.4.1.15] eco:b1919 eco00270
# 194 cysteine-S-conjugate beta-lyase [EC:4.4.1.13] eco:b1622 eco00270
# 198 thiosulfate/3-mercaptopyruvate sulfurtransferase [EC:2.8.1.1 2.8.1.2] eco:b2521 eco00270
# 199 aspartate aminotransferase [EC:2.6.1.1] eco:b0928 eco00270
# 207 homoserine O-succinyltransferase/O-acetyltransferase [EC:2.3.1.46 2.3.1.31] eco:b4013 eco00270
# 208 homoserine O-succinyltransferase/O-acetyltransferase [EC:2.3.1.46 2.3.1.31] eco:b4013 eco00270
# 212 cystathionine gamma-synthase [EC:2.5.1.48] eco:b3939 eco00270
# 213 cystathionine gamma-synthase [EC:2.5.1.48] eco:b3939 eco00270
# 214 cystathionine gamma-synthase [EC:2.5.1.48] eco:b3939 eco00270
# 217 cystathionine gamma-synthase [EC:2.5.1.48] eco:b3939 eco00270
# 224 bifunctional aspartokinase / homoserine dehydrogenase 1 [EC:2.7.2.4 1.1.1.3] eco:b0002 eco00270
# 227 aspartate-semialdehyde dehydrogenase [EC:1.2.1.11] eco:b3433 eco00270
# 230 bifunctional aspartokinase / homoserine dehydrogenase 1 [EC:2.7.2.4 1.1.1.3] eco:b0002 eco00270
# 253 malate dehydrogenase [EC:1.1.1.37] eco:b3236 eco00270
# 260 branched-chain amino acid aminotransferase [EC:2.6.1.42] eco:b3770 eco00270
# 262 glutamate--cysteine ligase [EC:6.3.2.2] eco:b2688 eco00270
# 265 glutathione synthase [EC:6.3.2.3] eco:b2947 eco00270
# 285 cysteine-S-conjugate beta-lyase [EC:4.4.1.13] eco:b1622 eco00270
# 290 D-3-phosphoglycerate dehydrogenase / 2-oxoglutarate reductase [EC:1.1.1.95 1.1.1.399] eco:b2913 eco00270
# 291 phosphoserine aminotransferase [EC:2.6.1.52] eco:b0907 eco00270
# 295 cysteine synthase [EC:2.5.1.47] eco:b2414 eco00270
# 54 dihydrolipoamide dehydrogenase [EC:1.8.1.4] eco:b0116 eco00280
# 62 dihydrolipoamide dehydrogenase [EC:1.8.1.4] eco:b0116 eco00280
# 68 dihydrolipoamide dehydrogenase [EC:1.8.1.4] eco:b0116 eco00280
# ...
# 224 succinate-semialdehyde dehydrogenase [EC:1.2.1.16 1.2.1.24] eco:b1525 eco00760
# 67 dephospho-CoA kinase [EC:2.7.1.24] eco:b0103 eco00770
# 68 holo-[acyl-carrier protein] synthase [EC:2.7.8.7] eco:b2563 eco00770
# 69 nucleoside triphosphate diphosphatase [EC:3.6.1.9] eco:b2781 eco00770
# 70 acyl carrier protein phosphodiesterase [EC:3.1.4.14] eco:b0404 eco00770
# 71 type I pantothenate kinase [EC:2.7.1.33] eco:b3974 eco00770
# 72 phosphopantothenoylcysteine decarboxylase / phosphopantothenate---cysteine ligase [EC:4.1.1.36 6.3.2.5] eco:b3639 eco00770
# 74 type I pantothenate kinase [EC:2.7.1.33] eco:b3974 eco00770
# 75 phosphopantothenoylcysteine decarboxylase / phosphopantothenate---cysteine ligase [EC:4.1.1.36 6.3.2.5] eco:b3639 eco00770
# 76 type I pantothenate kinase [EC:2.7.1.33] eco:b3974 eco00770
# 78 dihydropyrimidinase [EC:3.5.2.2] eco:b2873 eco00770
# 80 dihydropyrimidine dehydrogenase (NAD+) subunit PreT [EC:1.3.1.1] eco:b2146 eco00770
# 81 pantoate--beta-alanine ligase [EC:6.3.2.1] eco:b0133 eco00770
# 82 2-dehydropantoate 2-reductase [EC:1.1.1.169] eco:b0425 eco00770
# 83 3-methyl-2-oxobutanoate hydroxymethyltransferase [EC:2.1.2.11] eco:b0134 eco00770
# 85 dihydroxy-acid dehydratase [EC:4.2.1.9] eco:b3771 eco00770
# 86 ketol-acid reductoisomerase [EC:1.1.1.86] eco:b3774 eco00770
# 87 acetolactate synthase I/II/III large subunit [EC:2.2.1.6] eco:b0077 eco00770
# 90 branched-chain amino acid aminotransferase [EC:2.6.1.42] eco:b3770 eco00770
# 92 pantetheine-phosphate adenylyltransferase [EC:2.7.7.3] eco:b3634 eco00770
# 98 aspartate 1-decarboxylase [EC:4.1.1.11] eco:b0131 eco00770
# 103 4'-phosphopantetheinyl transferase [EC:2.7.8.-] eco:b3475 eco00770
# 29 BirA family transcriptional regulator, biotin operon repressor / biotin---[acetyl-CoA-carboxylase] ligase [EC:6.3.4.15] eco:b3973 eco00780
# 31 BirA family transcriptional regulator, biotin operon repressor / biotin---[acetyl-CoA-carboxylase] ligase [EC:6.3.4.15] eco:b3973 eco00780
# 33 biotin synthase [EC:2.8.1.6] eco:b0775 eco00780
# 34 dethiobiotin synthetase [EC:6.3.3.3] eco:b0778 eco00780
# 35 adenosylmethionine---8-amino-7-oxononanoate aminotransferase [EC:2.6.1.62] eco:b0774 eco00780
# 37 8-amino-7-oxononanoate synthase [EC:2.3.1.47] eco:b0776 eco00780
# 45 pimeloyl-[acyl-carrier protein] methyl ester esterase [EC:3.1.1.85] eco:b3412 eco00780
# 48 8-amino-7-oxononanoate synthase [EC:2.3.1.47] eco:b0776 eco00780
# 52 malonyl-CoA O-methyltransferase [EC:2.1.1.197] eco:b0777 eco00780
# 56 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] eco:b1093 eco00780
# 59 3-hydroxyacyl-[acyl-carrier-protein] dehydratase [EC:4.2.1.59] eco:b0180 eco00780
# 62 enoyl-[acyl-carrier protein] reductase I [EC:1.3.1.9 1.3.1.10] eco:b1288 eco00780
# 67 3-oxoacyl-[acyl-carrier-protein] synthase I [EC:2.3.1.41] eco:b2323 eco00780
# 70 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] eco:b1093 eco00780
# 73 3-hydroxyacyl-[acyl-carrier-protein] dehydratase [EC:4.2.1.59] eco:b0180 eco00780
# 76 enoyl-[acyl-carrier protein] reductase I [EC:1.3.1.9 1.3.1.10] eco:b1288 eco00780
# 77 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] eco:b1095 eco00780
# 98 biotin/methionine sulfoxide reductase [EC:1.-.-.-] eco:b3551 eco00780
# 101 3-oxoacyl-[acyl-carrier-protein] synthase I [EC:2.3.1.41] eco:b2323 eco00780
# 102 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] eco:b1095 eco00780
# 9 lipoyl(octanoyl) transferase [EC:2.3.1.181] eco:b0630 eco00785
# 12 lipoyl synthase [EC:2.8.1.8] eco:b0628 eco00785
# 13 lipoyl(octanoyl) transferase [EC:2.3.1.181] eco:b0630 eco00785
# 24 lipoate---protein ligase [EC:6.3.1.20] eco:b4386 eco00785
# 27 lipoate---protein ligase [EC:6.3.1.20] eco:b4386 eco00785
# 33 lipoate---protein ligase [EC:6.3.1.20] eco:b4386 eco00785
# 40 lipoyl synthase [EC:2.8.1.8] eco:b0628 eco00785
# 50 lipoate---protein ligase [EC:6.3.1.20] eco:b4386 eco00785
# 65 para-aminobenzoate synthetase component I [EC:2.6.1.85] eco:b1812 eco00790
# 66 4-amino-4-deoxychorismate lyase [EC:4.1.3.38] eco:b1096 eco00790
# 67 dihydrofolate synthase / folylpolyglutamate synthase [EC:6.3.2.12 6.3.2.17] eco:b2315 eco00790
# 68 dihydrofolate synthase / folylpolyglutamate synthase [EC:6.3.2.12 6.3.2.17] eco:b2315 eco00790
# 69 dihydrofolate reductase [EC:1.5.1.3] eco:b0048 eco00790
# 70 dihydrofolate reductase [EC:1.5.1.3] eco:b0048 eco00790
# 71 dihydrofolate synthase / folylpolyglutamate synthase [EC:6.3.2.12 6.3.2.17] eco:b2315 eco00790
# 72 dihydropteroate synthase [EC:2.5.1.15] eco:b3177 eco00790
# 73 dihydropteroate synthase [EC:2.5.1.15] eco:b3177 eco00790
# 74 2-amino-4-hydroxy-6-hydroxymethyldihydropteridine diphosphokinase [EC:2.7.6.3] eco:b0142 eco00790
# 75 7,8-dihydroneopterin aldolase/epimerase/oxygenase [EC:4.1.2.25 5.1.99.8 1.13.11.81] eco:b3058 eco00790
# 77 dihydroneopterin triphosphate diphosphatase [EC:3.6.1.67] eco:b1865 eco00790
# 79 GTP cyclohydrolase IA [EC:3.5.4.16] eco:b2153 eco00790
# 80 GTP cyclohydrolase IA [EC:3.5.4.16] eco:b2153 eco00790
# 81 GTP cyclohydrolase IA [EC:3.5.4.16] eco:b2153 eco00790
# 82 dihydrofolate reductase [EC:1.5.1.3] eco:b0048 eco00790
# 83 dihydrofolate synthase / folylpolyglutamate synthase [EC:6.3.2.12 6.3.2.17] eco:b2315 eco00790
# 85 alkaline phosphatase [EC:3.1.3.1] eco:b0383 eco00790
# 86 6-pyruvoyltetrahydropterin/6-carboxytetrahydropterin synthase [EC:4.2.3.12 4.1.2.50] eco:b2765 eco00790
# 93 GTP 3',8-cyclase [EC:4.1.99.22] eco:b0781 eco00790
# 94 molybdopterin synthase catalytic subunit [EC:2.8.1.12] eco:b0785 eco00790
# 96 6-pyruvoyltetrahydropterin/6-carboxytetrahydropterin synthase [EC:4.2.3.12 4.1.2.50] eco:b2765 eco00790
# 102 7-carboxy-7-deazaguanine synthase [EC:4.3.99.3] eco:b2777 eco00790
# 103 7-cyano-7-deazaguanine synthase [EC:6.3.4.20] eco:b0444 eco00790
# 104 7-cyano-7-deazaguanine reductase [EC:1.7.1.13] eco:b2794 eco00790
# 117 cyclic pyranopterin monophosphate synthase [EC:4.6.1.17] eco:b0783 eco00790
# 118 molybdopterin adenylyltransferase [EC:2.7.7.75] eco:b0009 eco00790
# 122 molybdopterin molybdotransferase [EC:2.10.1.1] eco:b0827 eco00790
# 126 molybdenum cofactor guanylyltransferase [EC:2.7.7.77] eco:b3857 eco00790
# 127 molybdenum cofactor cytidylyltransferase [EC:2.7.7.76] eco:b2877 eco00790
# 130 D-erythro-7,8-dihydroneopterin triphosphate epimerase [EC:5.1.99.7] eco:b2303 eco00790
# 148 7,8-dihydroneopterin aldolase/epimerase/oxygenase [EC:4.1.2.25 5.1.99.8 1.13.11.81] eco:b3058 eco00790
# 168 dihydromonapterin reductase / dihydrofolate reductase [EC:1.5.1.50 1.5.1.3] eco:b1606 eco00790
# 171 7,8-dihydroneopterin aldolase/epimerase/oxygenase [EC:4.1.2.25 5.1.99.8 1.13.11.81] eco:b3058 eco00790
# 180 GTP cyclohydrolase IA [EC:3.5.4.16] eco:b2153 eco00790
# 181 GTP cyclohydrolase II [EC:3.5.4.25] eco:b1277 eco00790
# 189 dihydrofolate reductase [EC:1.5.1.3] eco:b0048 eco00790
# 44 oxygen-independent coproporphyrinogen III oxidase [EC:1.3.98.3] eco:b3867 eco00860
# 69 aquacobalamin reductase / NAD(P)H-flavin reductase [EC:1.16.1.3 1.5.1.41] eco:b3844 eco00860
# 75 coproporphyrinogen III oxidase [EC:1.3.3.3] eco:b2436 eco00860
# 238 beta-glucuronidase [EC:3.2.1.31] eco:b1617 eco00860
# 267 heme o synthase [EC:2.5.1.141] eco:b0428 eco00860
# 268 protoporphyrin/coproporphyrin ferrochelatase [EC:4.99.1.1 4.99.1.9] eco:b0475 eco00860
# 270 bacterioferritin [EC:1.16.3.1] eco:b3336 eco00860
# 274 uroporphyrinogen decarboxylase [EC:4.1.1.37] eco:b3997 eco00860
# 275 uroporphyrinogen-III synthase [EC:4.2.1.75] eco:b3804 eco00860
# 276 uroporphyrin-III C-methyltransferase / precorrin-2 dehydrogenase / sirohydrochlorin ferrochelatase [EC:2.1.1.107 1.3.1.76 4.99.1.4] eco:b3368 eco00860
# 277 uroporphyrinogen decarboxylase [EC:4.1.1.37] eco:b3997 eco00860
# 278 hydroxymethylbilane synthase [EC:2.5.1.61] eco:b3805 eco00860
# 279 porphobilinogen synthase [EC:4.2.1.24] eco:b0369 eco00860
# 281 glutamate-1-semialdehyde 2,1-aminomutase [EC:5.4.3.8] eco:b0154 eco00860
# 283 glutamyl-tRNA reductase [EC:1.2.1.70] eco:b1210 eco00860
# 284 glutamyl-tRNA synthetase [EC:6.1.1.17] eco:b2400 eco00860
# 285 uroporphyrin-III C-methyltransferase / precorrin-2 dehydrogenase / sirohydrochlorin ferrochelatase [EC:2.1.1.107 1.3.1.76 4.99.1.4] eco:b3368 eco00860
# 286 uroporphyrin-III C-methyltransferase / precorrin-2 dehydrogenase / sirohydrochlorin ferrochelatase [EC:2.1.1.107 1.3.1.76 4.99.1.4] eco:b3368 eco00860
# 306 cob(I)alamin adenosyltransferase [EC:2.5.1.17] eco:b1270 eco00860
# 309 cob(I)alamin adenosyltransferase [EC:2.5.1.17] eco:b1270 eco00860
# 310 adenosylcobinamide kinase / adenosylcobinamide-phosphate guanylyltransferase [EC:2.7.1.156 2.7.7.62] eco:b1993 eco00860
# 312 cob(I)alamin adenosyltransferase [EC:2.5.1.17] eco:b1270 eco00860
# 313 adenosylcobinamide kinase / adenosylcobinamide-phosphate guanylyltransferase [EC:2.7.1.156 2.7.7.62] eco:b1993 eco00860
# 315 adenosylcobinamide-GDP ribazoletransferase [EC:2.7.8.26] eco:b1992 eco00860
# 316 alpha-ribazole phosphatase [EC:3.1.3.73] eco:b0638 eco00860
# 317 nicotinate-nucleotide--dimethylbenzimidazole phosphoribosyltransferase [EC:2.4.2.21] eco:b1991 eco00860
# 373 menaquinone-dependent protoporphyrinogen oxidase [EC:1.3.5.3] eco:b3850 eco00860
# 418 protoporphyrin/coproporphyrin ferrochelatase [EC:4.99.1.1 4.99.1.9] eco:b0475 eco00860
# 64 1-deoxy-D-xylulose-5-phosphate synthase [EC:2.2.1.7] eco:b0420 eco00900
# 65 1-deoxy-D-xylulose-5-phosphate reductoisomerase [EC:1.1.1.267] eco:b0173 eco00900
# 66 2-C-methyl-D-erythritol 4-phosphate cytidylyltransferase [EC:2.7.7.60] eco:b2747 eco00900
# 67 4-diphosphocytidyl-2-C-methyl-D-erythritol kinase [EC:2.7.1.148] eco:b1208 eco00900
# 68 2-C-methyl-D-erythritol 2,4-cyclodiphosphate synthase [EC:4.6.1.12] eco:b2746 eco00900
# 69 (E)-4-hydroxy-3-methylbut-2-enyl-diphosphate synthase [EC:1.17.7.1 1.17.7.3] eco:b2515 eco00900
# 71 acetyl-CoA C-acetyltransferase [EC:2.3.1.9] eco:b2224 eco00900
# 97 4-hydroxy-3-methylbut-2-en-1-yl diphosphate reductase [EC:1.17.7.4] eco:b0029 eco00900
# 98 isopentenyl-diphosphate Delta-isomerase [EC:5.3.3.2] eco:b2889 eco00900
# 99 4-hydroxy-3-methylbut-2-en-1-yl diphosphate reductase [EC:1.17.7.4] eco:b0029 eco00900
# 103 farnesyl diphosphate synthase [EC:2.5.1.1 2.5.1.10] eco:b0421 eco00900
# 105 farnesyl diphosphate synthase [EC:2.5.1.1 2.5.1.10] eco:b0421 eco00900
# 106 undecaprenyl diphosphate synthase [EC:2.5.1.31] eco:b0174 eco00900
# 122 octaprenyl-diphosphate synthase [EC:2.5.1.90] eco:b3187 eco00900
# 165 (E)-4-hydroxy-3-methylbut-2-enyl-diphosphate synthase [EC:1.17.7.1 1.17.7.3] eco:b2515 eco00900
# 139 enoyl-CoA hydratase [EC:4.2.1.17] eco:b1393 eco00903
# 140 enoyl-CoA hydratase [EC:4.2.1.17] eco:b1393 eco00903
# 25 nitrate reductase / nitrite oxidoreductase, alpha subunit [EC:1.7.5.1 1.7.99.-] eco:b1224 eco00910
# 30 hydroxylamine reductase [EC:1.7.99.1] eco:b0873 eco00910
# 31 nitrite reductase (cytochrome c-552) [EC:1.7.2.2] eco:b4070 eco00910
# 57 cyanate lyase [EC:4.2.1.104] eco:b0340 eco00910
# 64 carbonic anhydrase [EC:4.2.1.1] eco:b0126 eco00910
# 65 carbamate kinase [EC:2.7.2.2] eco:b0323 eco00910
# 70 MFS transporter, NNP family, nitrate/nitrite transporter eco:b1223 eco00910
# 73 MFS transporter, NNP family, nitrate/nitrite transporter eco:b1223 eco00910
# 77 glutamine synthetase [EC:6.3.1.2] eco:b3870 eco00910
# 81 glutamate synthase (NADPH) large chain [EC:1.4.1.13] eco:b3212 eco00910
# 88 glutamate dehydrogenase (NADP+) [EC:1.4.1.4] eco:b1761 eco00910
# 102 nitrate reductase / nitrite oxidoreductase, alpha subunit [EC:1.7.5.1 1.7.99.-] eco:b1224 eco00910
# 103 nitrate reductase (cytochrome), electron transfer subunit eco:b2203 eco00910
# 104 nitrite reductase (cytochrome c-552) [EC:1.7.2.2] eco:b4070 eco00910
# 105 nitrite reductase (NADH) large subunit [EC:1.7.1.15] eco:b3365 eco00910
# 122 nitrate reductase / nitrite oxidoreductase, alpha subunit [EC:1.7.5.1 1.7.99.-] eco:b1224 eco00910
# 123 nitrate reductase (cytochrome), electron transfer subunit eco:b2203 eco00910
# 134 nitrate reductase / nitrite oxidoreductase, alpha subunit [EC:1.7.5.1 1.7.99.-] eco:b1224 eco00910
# 148 nitrite reductase (NADH) large subunit [EC:1.7.1.15] eco:b3365 eco00910
# 150 nitrate reductase / nitrite oxidoreductase, alpha subunit [EC:1.7.5.1 1.7.99.-] eco:b1224 eco00910
# 31 sulfite reductase (NADPH) hemoprotein beta-component [EC:1.8.1.2] eco:b2763 eco00920
# 38 3'(2'), 5'-bisphosphate nucleotidase [EC:3.1.3.7] eco:b4214 eco00920
# 39 adenylylsulfate kinase [EC:2.7.1.25] eco:b2750 eco00920
# 42 sulfate adenylyltransferase subunit 1 [EC:2.7.7.4] eco:b2751 eco00920
# 48 phosphoadenosine phosphosulfate reductase [EC:1.8.4.8 1.8.4.10] eco:b2762 eco00920
# 55 FMN reductase [EC:1.5.1.38] eco:b0937 eco00920
# 57 alkanesulfonate monooxygenase [EC:1.14.14.5] eco:b0935 eco00920
# 67 anaerobic dimethyl sulfoxide reductase subunit A [EC:1.8.5.3] eco:b0894 eco00920
# 90 thiosulfate/3-mercaptopyruvate sulfurtransferase [EC:2.8.1.1 2.8.1.2] eco:b2521 eco00920
# 92 thiosulfate reductase cytochrome b subunit eco:b1670 eco00920
# 103 cysteine synthase [EC:2.5.1.47] eco:b2414 eco00920
# 109 serine O-acetyltransferase [EC:2.3.1.30] eco:b3607 eco00920
# 121 cystathionine gamma-synthase [EC:2.5.1.48] eco:b3939 eco00920
# 125 homoserine O-succinyltransferase/O-acetyltransferase [EC:2.3.1.46 2.3.1.31] eco:b4013 eco00920
# 128 taurine dioxygenase [EC:1.14.11.17] eco:b0368 eco00920
# 130 alkanesulfonate monooxygenase [EC:1.14.14.5] eco:b0935 eco00920
# 133 sulfate/thiosulfate transport system ATP-binding protein [EC:7.3.2.3] eco:b2422 eco00920
# 134 sulfonate transport system ATP-binding protein [EC:3.6.3.-] eco:b0933 eco00920
# 135 taurine transport system substrate-binding protein eco:b0365 eco00920
# 150 phosphoadenosine phosphosulfate reductase [EC:1.8.4.8 1.8.4.10] eco:b2762 eco00920
# 153 sulfite reductase (NADPH) hemoprotein beta-component [EC:1.8.1.2] eco:b2763 eco00920
# 159 adenylylsulfate kinase [EC:2.7.1.25] eco:b2750 eco00920
# 160 sulfate adenylyltransferase subunit 1 [EC:2.7.7.4] eco:b2751 eco00920
# 32 3-hydroxyacyl-CoA dehydrogenase / enoyl-CoA hydratase / 3-hydroxybutyryl-CoA epimerase [EC:1.1.1.35 4.2.1.17 5.1.2.3] eco:b2341 eco00930
# 33 enoyl-CoA hydratase [EC:4.2.1.17] eco:b1393 eco00930
# 24 isoleucyl-tRNA synthetase [EC:6.1.1.5] eco:b0026 eco00970
# 58 asparaginyl-tRNA synthetase [EC:6.1.1.22] eco:b0930 eco00970
# 59 histidyl-tRNA synthetase [EC:6.1.1.21] eco:b2514 eco00970
# 60 phenylalanyl-tRNA synthetase beta chain [EC:6.1.1.20] eco:b1713 eco00970
# 61 arginyl-tRNA synthetase [EC:6.1.1.19] eco:b1876 eco00970
# 62 glutaminyl-tRNA synthetase [EC:6.1.1.18] eco:b0680 eco00970
# 63 cysteinyl-tRNA synthetase [EC:6.1.1.16] eco:b0526 eco00970
# 64 glycyl-tRNA synthetase beta chain [EC:6.1.1.14] eco:b3559 eco00970
# 65 aspartyl-tRNA synthetase [EC:6.1.1.12] eco:b1866 eco00970
# 66 seryl-tRNA synthetase [EC:6.1.1.11] eco:b0893 eco00970
# 67 methionyl-tRNA synthetase [EC:6.1.1.10] eco:b2114 eco00970
# 68 valyl-tRNA synthetase [EC:6.1.1.9] eco:b4258 eco00970
# 69 alanyl-tRNA synthetase [EC:6.1.1.7] eco:b2697 eco00970
# 70 lysyl-tRNA synthetase, class II [EC:6.1.1.6] eco:b2890 eco00970
# 71 leucyl-tRNA synthetase [EC:6.1.1.4] eco:b0642 eco00970
# 72 threonyl-tRNA synthetase [EC:6.1.1.3] eco:b1719 eco00970
# 73 tryptophanyl-tRNA synthetase [EC:6.1.1.2] eco:b3384 eco00970
# 74 methionyl-tRNA formyltransferase [EC:2.1.2.9] eco:b3288 eco00970
# 75 tyrosyl-tRNA synthetase [EC:6.1.1.1] eco:b1637 eco00970
# 76 prolyl-tRNA synthetase [EC:6.1.1.15] eco:b0194 eco00970
# 77 glutamyl-tRNA synthetase [EC:6.1.1.17] eco:b2400 eco00970
# 137 seryl-tRNA synthetase [EC:6.1.1.11] eco:b0893 eco00970
# 145 L-seryl-tRNA(Ser) seleniumtransferase [EC:2.9.1.1] eco:b3591 eco00970
# 156 tRNA Glu eco:b2590 eco00970
# 157 tRNA Gln eco:b0664 eco00970
# 158 tRNA Ala eco:b0203 eco00970
# 159 tRNA Asp eco:b0206 eco00970
# 160 tRNA Ser eco:b0883 eco00970
# 161 tRNA Thr eco:b0244 eco00970
# 162 tRNA Asn eco:b1977 eco00970
# 163 tRNA Gly eco:b1911 eco00970
# 164 tRNA Cys eco:b1910 eco00970
# 165 tRNA Sec eco:b3658 eco00970
# 166 tRNA Met eco:b0666 eco00970
# 167 tRNA Val eco:b0744 eco00970
# 168 tRNA Leu eco:b0672 eco00970
# 169 tRNA Ile eco:b0202 eco00970
# 170 tRNA Lys eco:b0743 eco00970
# 172 tRNA Arg eco:b0536 eco00970
# 173 tRNA Pro eco:b2189 eco00970
# 174 tRNA His eco:b3797 eco00970
# 175 tRNA Phe eco:b2967 eco00970
# 176 tRNA Tyr eco:b1230 eco00970
# 177 tRNA Trp eco:b3761 eco00970

# %%
NODES_eco00010
# Out:
# {"'14'": 'fructose-bisphosphate aldolase, class I [EC:4.1.2.13]',
#  '14': 'fructose-bisphosphate aldolase, class I [EC:4.1.2.13]',
#  '46': 'S-(hydroxymethyl)glutathione dehydrogenase / alcohol dehydrogenase [EC:1.1.1.284 1.1.1.1]',
#  '48': 'pyruvate dehydrogenase E1 component [EC:1.2.4.1]',
#  '49': 'pyruvate dehydrogenase E1 component [EC:1.2.4.1]',
#  '50': 'pyruvate dehydrogenase E2 component (dihydrolipoamide acetyltransferase) [EC:2.3.1.12]',
#  '53': 'pyruvate kinase [EC:2.7.1.40]',
#  '55': 'enolase [EC:4.2.1.11]',
#  '56': '2,3-bisphosphoglycerate-dependent phosphoglycerate mutase [EC:5.4.2.11]',
#  '57': 'glyceraldehyde 3-phosphate dehydrogenase [EC:1.2.1.12]',
#  '58': 'triosephosphate isomerase (TIM) [EC:5.3.1.1]',
#  '59': '6-phosphofructokinase 2 [EC:2.7.1.11]',
#  '60': 'fructose-1,6-bisphosphatase II [EC:3.1.3.11]',
#  '61': 'glucose PTS system EIICB or EIICBA component [EC:2.7.1.199]',
#  '62': 'glucose-6-phosphate isomerase [EC:5.3.1.9]',
#  '63': 'phosphoglucomutase [EC:5.4.2.2]',
#  '64': 'glucose-6-phosphate isomerase [EC:5.3.1.9]',
#  '66': 'glucokinase [EC:2.7.1.2]',
#  '67': 'glucose-6-phosphate isomerase [EC:5.3.1.9]',
#  '68': 'glucose-6-phosphate 1-epimerase [EC:5.1.3.15]',
#  '69': 'aldose 1-epimerase [EC:5.1.3.3]',
#  '70': 'glucokinase [EC:2.7.1.2]',
#  '73': 'glucose-1-phosphatase [EC:3.1.3.10]',
#  '75': 'dihydrolipoamide dehydrogenase [EC:1.8.1.4]',
#  '76': 'phosphoglycerate kinase [EC:2.7.2.3]',
#  '79': 'sugar PTS system EIIA component [EC:2.7.1.-]',
#  '80': 'sugar PTS system EIIA component [EC:2.7.1.-]',
#  '81': '6-phospho-beta-glucosidase [EC:3.2.1.86]',
#  '82': '6-phospho-beta-glucosidase [EC:3.2.1.86]',
#  '116': 'phosphoenolpyruvate carboxykinase (ATP) [EC:4.1.1.49]',
#  '117': 'alcohol dehydrogenase',
#  '124': 'pyruvate-ferredoxin/flavodoxin oxidoreductase [EC:1.2.7.1 1.2.7.-]',
#  '131': 'acetyl-CoA synthetase [EC:6.2.1.1]',
#  '137': '2,3-bisphosphoglycerate-independent phosphoglycerate mutase [EC:5.4.2.12]',
#  '138': 'aldehyde dehydrogenase [EC:1.2.1.-]'}

# %%
#edges.to_string().values

# %%
#locals()['NODOS']={}
#for i in range(len(data)):
#      locals()['NODOS'][data[i][0]]= data[i][1]

# %%
#NODOS

# %%
#NODOS["'18'"]

# %%
#B=A['entry1']
#B

# %%
#NODOS[B]

# %%
#AA={'entry1':'73'}

# %%
#AA['entry1']

# %% [markdown]
# ## PRIMERA RED

# %%
EDGES=[]

for line in pathways.text.split('\n'):        
    pathwayid = line.split('\t')[0].replace('path:', '') 
    
    if pathwayid == str(org)+str(maxi):           
            break
            
    ii=locals()[str(pathwayid)]
    
    #
    
    NODES=locals()['NODES_'+str(pathwayid)]
    #print(NODES)
    for i in range(0,len(ii)):
        if ii[i].tag=='relation':         
            A=ii[i].attrib            
            if A['type'] == 'ECrel':    #relación enzima-enzima, que indica dos enzimas que catalizan pasos de reacción sucesivos
                #print(A)
                EDGES.append( [  NODES[ A['entry1'] ] , NODES[ A['entry2'] ]  ]  ) 

print(EDGES)
# Out:
# [['glucokinase [EC:2.7.1.2]', 'glucose-1-phosphatase [EC:3.1.3.10]'], ['aldose 1-epimerase [EC:5.1.3.3]', 'glucokinase [EC:2.7.1.2]'], ['aldose 1-epimerase [EC:5.1.3.3]', 'glucose-1-phosphatase [EC:3.1.3.10]'], ['glucokinase [EC:2.7.1.2]', 'aldose 1-epimerase [EC:5.1.3.3]'], ['glucokinase [EC:2.7.1.2]', '6-phospho-beta-glucosidase [EC:3.2.1.86]'], ['glucokinase [EC:2.7.1.2]', '6-phospho-beta-glucosidase [EC:3.2.1.86]'], ['glucose-6-phosphate isomerase [EC:5.3.1.9]', 'glucokinase [EC:2.7.1.2]'], ['glucokinase [EC:2.7.1.2]', 'glucose-6-phosphate 1-epimerase [EC:5.1.3.15]'], ['glucose-6-phosphate isomerase [EC:5.3.1.9]', '6-phospho-beta-glucosidase [EC:3.2.1.86]'], ['glucose-6-phosphate 1-epimerase [EC:5.1.3.15]', '6-phospho-beta-glucosidase [EC:3.2.1.86]'], ['glucose-6-phosphate isomerase [EC:5.3.1.9]', '6-phospho-beta-glucosidase [EC:3.2.1.86]'], ['glucose-6-phosphate 1-epimerase [EC:5.1.3.15]', '6-phospho-beta-glucosidase [EC:3.2.1.86]'], ['glucose-6-phosphate isomerase [EC:5.3.1.9]', 'glucose-6-phosphate 1-epimerase [EC:5.1.3.15]'], ['glucose-6-phosphate isomerase [EC:5.3.1.9]', 'glucokinase [EC:2.7.1.2]'], ['glucose-6-phosphate isomerase [EC:5.3.1.9]', 'glucose-6-phosphate 1-epimerase [EC:5.1.3.15]'], ['glucose PTS system EIICB or EIICBA component [EC:2.7.1.199]', 'glucose-6-phosphate isomerase [EC:5.3.1.9]'], ['glucose-6-phosphate isomerase [EC:5.3.1.9]', 'phosphoglucomutase [EC:5.4.2.2]'], ['glucose-6-phosphate 1-epimerase [EC:5.1.3.15]', 'glucokinase [EC:2.7.1.2]'], ['glucose-6-phosphate isomerase [EC:5.3.1.9]', 'glucokinase [EC:2.7.1.2]'], ['glucose PTS system EIICB or EIICBA component [EC:2.7.1.199]', 'glucokinase [EC:2.7.1.2]'], ['phosphoglucomutase [EC:5.4.2.2]', 'glucokinase [EC:2.7.1.2]'], ['glucose PTS system EIICB or EIICBA component [EC:2.7.1.199]', 'glucose-6-phosphate 1-epimerase [EC:5.1.3.15]'], ['phosphoglucomutase [EC:5.4.2.2]', 'glucose-6-phosphate 1-epimerase [EC:5.1.3.15]'], ['glucose PTS system EIICB or EIICBA component [EC:2.7.1.199]', 'glucose-6-phosphate isomerase [EC:5.3.1.9]'], ['phosphoglucomutase [EC:5.4.2.2]', 'glucose-6-phosphate isomerase [EC:5.3.1.9]'], ['glucose PTS system EIICB or EIICBA component [EC:2.7.1.199]', 'phosphoglucomutase [EC:5.4.2.2]'], ['fructose-1,6-bisphosphatase II [EC:3.1.3.11]', 'glucose-6-phosphate isomerase [EC:5.3.1.9]'], ['6-phosphofructokinase 2 [EC:2.7.1.11]', 'glucose-6-phosphate isomerase [EC:5.3.1.9]'], ['fructose-bisphosphate aldolase, class I [EC:4.1.2.13]', 'fructose-1,6-bisphosphatase II [EC:3.1.3.11]'], ['fructose-bisphosphate aldolase, class I [EC:4.1.2.13]', '6-phosphofructokinase 2 [EC:2.7.1.11]'], ['triosephosphate isomerase (TIM) [EC:5.3.1.1]', 'fructose-bisphosphate aldolase, class I [EC:4.1.2.13]'], ['glyceraldehyde 3-phosphate dehydrogenase [EC:1.2.1.12]', 'phosphoglycerate kinase [EC:2.7.2.3]'], ['2,3-bisphosphoglycerate-dependent phosphoglycerate mutase [EC:5.4.2.11]', 'phosphoglycerate kinase [EC:2.7.2.3]'], ['enolase [EC:4.2.1.11]', '2,3-bisphosphoglycerate-dependent phosphoglycerate mutase [EC:5.4.2.11]'], ['pyruvate dehydrogenase E1 component [EC:1.2.4.1]', 'pyruvate dehydrogenase E2 component (dihydrolipoamide acetyltransferase) [EC:2.3.1.12]'], ['pyruvate dehydrogenase E1 component [EC:1.2.4.1]', 'dihydrolipoamide dehydrogenase [EC:1.8.1.4]'], ['pyruvate dehydrogenase E2 component (dihydrolipoamide acetyltransferase) [EC:2.3.1.12]', 'dihydrolipoamide dehydrogenase [EC:1.8.1.4]'], ['pyruvate kinase [EC:2.7.1.40]', 'enolase [EC:4.2.1.11]'], ['sugar PTS system EIIA component [EC:2.7.1.-]', '6-phospho-beta-glucosidase [EC:3.2.1.86]'], ['phosphoglucomutase [EC:5.4.2.2]', 'glucose-1-phosphatase [EC:3.1.3.10]'], ['fructose-1,6-bisphosphatase II [EC:3.1.3.11]', 'glucose-6-phosphate isomerase [EC:5.3.1.9]'], ['6-phosphofructokinase 2 [EC:2.7.1.11]', 'glucose-6-phosphate isomerase [EC:5.3.1.9]'], ['pyruvate dehydrogenase E1 component [EC:1.2.4.1]', 'pyruvate kinase [EC:2.7.1.40]'], ['glucokinase [EC:2.7.1.2]', 'glucose-6-phosphate isomerase [EC:5.3.1.9] ...

# %%
G = nx.DiGraph() #--->DiGrafo para hacer un grado dirigido 
 
G.add_edges_from(EDGES)


plt.figure(3,figsize=(50,50))
#nx.draw_kamada_kawai(G,font_size=15,node_size=1000,node_color='orange')
nx.draw_kamada_kawai(G,font_size=15,node_size=1000,node_color='orange',with_labels=False)
plt.savefig("net_eco_p0.pdf")# Guardar la red en pdf. 
plt.show()

# %%
g=nx.number_of_nodes(G)
print('g=',g)
L=nx.number_of_edges(G)
print('L=',L)
# Out:
# g= 682
# L= 1811

# %%
pd.DataFrame(G.nodes).to_csv('NODOS_EC.csv' ,sep=';')

# %%
nodos=G.nodes

D=[] # un vector donde vamos a colocar el numero de vinvulos de todos los nodos
d=nx.degree(G) # Vector que contiene el par ordenado del nodo y su numero de vinculos
for i in nodos: 
    D.append(d[i])
    

D_in=[] # un vector donde vamos a colocar el numero de vinvulos de todos los nodos
d=G.in_degree(G) # Vector que contiene el par ordenado del nodo y su numero de vinculos
for i in nodos: 
    D_in.append(d[i])
    
    
D_out=[] # un vector donde vamos a colocar el numero de vinvulos de todos los nodos
d=G.out_degree(G) # Vector que contiene el par ordenado del nodo y su numero de vinculos
for i in nodos: 
    D_out.append(d[i])
    
    
P=[]
X=[]
for i in range(1,max(D)+1):
    if D.count(i) != 0: 
        P.append(D.count(i)/len(D))
        X.append(i)
        
P_in=[]
X_in=[]
for i in range(1,max(D_in)+1):
    if D_in.count(i) != 0: 
        P_in.append(D_in.count(i)/len(D_in))
        X_in.append(i)  

P_out=[]
X_out=[]
for i in range(1,max(D)+1):
    if D_out.count(i) != 0: 
        P_out.append(D_out.count(i)/len(D_out))
        X_out.append(i)
        
        
        
# GRAFICA DE LA PROVAVILIDAD VS EL NUMERO DE GRADO        
fig, axs = plt.subplots( 3 ,sharex = True, sharey = True, figsize=(15,8))

fig.suptitle('Distribución de grado 2012',fontsize=20)
axs[0].plot(X,P,'ko')         
axs[0].set_xlabel(r'$K$',fontsize=20)
axs[0].set_ylabel(r'$P(K)$',fontsize=20)

axs[1].plot(X_in,P_in,'o')         
axs[1].set_xlabel(r'$K_{in}$',fontsize=20)
axs[1].set_ylabel(r'$P(K_{in})$',fontsize=20)

axs[2].plot(X_out,P_out, 'ro')         
axs[2].set_xlabel(r'$K_{out}$',fontsize=20)
axs[2].set_ylabel(r'$P(K_{out})$',fontsize=20)

#plt.savefig("P_vs_k_2012.pdf")# Guardar la red en pdf.    

plt.show()

# %%
fig, (ax1, ax2 , ax3) = plt.subplots(1, 3 ,sharex = True, sharey = True, figsize=(15,5))
fig.suptitle('Distribucion Log-Log 2012',fontsize=20)
ax1.plot(X,P,'ko')
ax1.set_xlabel(r'$K$',fontsize=20)
ax1.set_ylabel(r'$P(K)$',fontsize=20)

ax2.plot(X_in,P_in,'o')
ax2.set_xlabel(r'$K_{in}$',fontsize=20)
ax2.set_ylabel(r'$P(K_{in})$',fontsize=20)

ax3.plot(X_out,P_out,'ro')
ax3.set_xlabel(r'$K_{out}$',fontsize=20)
ax3.set_ylabel(r'$P(K_{out})$',fontsize=20)

# Escala log-log
plt.xscale('log') 
plt.yscale('log') 

#plt.savefig("Ley_de_potencias_2012.pdf")# Guardar la red en pdf.

plt.show()

# %%
d=G.degree(G) #Vector con el par ordenado de numero de aristas de entrada a cada uno de los nodos
#d['glucokinase [EC:2.7.1.2]']
degre=[]
for i in G.nodes:
    degre.append([i,d[i]])
df=pd.DataFrame(degre,columns=['Name', 'grado'])
#df
df.sort_values(by='grado', ascending=False)
#df = pd.DataFrame([[key, d[key]] for key in d.keys()], columns=['Name', 'grado'])
# Out:
#                                                   Name  grado
# 185  5'-nucleotidase / UDP-sugar diphosphatase [EC:...     47
# 219  nucleoside triphosphate diphosphatase [EC:3.6....     40
# 22   pyruvate-ferredoxin/flavodoxin oxidoreductase ...     33
# 190  purine/pyrimidine-nucleoside phosphorylase [EC...     29
# 510          formate C-acetyltransferase [EC:2.3.1.54]     29
# 193       purine-nucleoside phosphorylase [EC:2.4.2.1]     28
# 19                       pyruvate kinase [EC:2.7.1.40]     28
# 23                  acetyl-CoA synthetase [EC:6.2.1.1]     28
# 509                       malate synthase [EC:2.3.3.9]     23
# 197         nucleoside-diphosphate kinase [EC:2.7.4.6]     22
# 131        acetyl-CoA C-acetyltransferase [EC:2.3.1.9]     22
# 389           phosphate acetyltransferase [EC:2.3.1.8]     20
# 269      glycine hydroxymethyltransferase [EC:2.1.2.1]     20
# 184  hypoxanthine phosphoribosyltransferase [EC:2.4...     20
# 7                      phosphoglucomutase [EC:5.4.2.2]     20
# 16    pyruvate dehydrogenase E1 component [EC:1.2.4.1]     19
# 160            aspartate aminotransferase [EC:2.6.1.1]     19
# 503  lactaldehyde dehydrogenase / glycolaldehyde de...     19
# 388  gamma-glutamyltranspeptidase / glutathione hyd...     19
# 4           glucose-6-phosphate isomerase [EC:5.3.1.9]     18
# 189        ribosylpyrimidine nucleosidase [EC:3.2.2.8]     17
# 17   pyruvate dehydrogenase E2 component (dihydroli...     16
# 178     adenine phosphoribosyltransferase [EC:2.4.2.7]     16
# 179  phosphoribosylaminoimidazolecarboxamide formyl...     16
# 205   xanthine phosphoribosyltransferase [EC:2.4.2.22]     16
# 584  HTH-type transcriptional regulator, transcript...     16
# 173  phosphoribosylglycinamide formyltransferase 2 ...     15
# 182             adenylosuccinate synthase [EC:6.3.4.4]     15
# 296         cystathionine gamma-synthase [EC:2.5.1.48]     15
# 372           acetaldehyde dehydrogenase [EC:1.2.1.10]     15
# ..                                                 ...    ...
# 472  D-sedoheptulose 7-phosphate isomerase [EC:5.3....      1
# 475  ADP-L-glycero-D-manno-heptose 6-epimerase [EC:...      1
# 477  UDP-N-acetylglucosamine--N-acetylmuramyl-(pent...      1
# 484  phosphoenolpyruvate---glycerone phosphotransfe...      1
# 486           phosphate acyltransferase [EC:2.3.1.274]      1
# 498  ethanolamine ammonia-lyase small subunit [EC:4...      1
# 499              cardiolipin synthase A/B [EC:2.7.8.-]      1
# 374  3-deoxy-7-phosphoheptulonate synthase [EC:2.5....      1
# 558                  cysteine desulfurase [EC:2.8.1.7]      1
# 627     7-cyano-7-deazaguanine reductase [EC:1.7.1.13]      1
# 500                cardiolipin synthase C [EC:2.7.8.-]      1
# 622  para-aminobenzoate synthetase component I [EC:...      1
# 152       NAD(P)H dehydrogenase (quinone) [EC:1.6.5.2]      1
# 154                  polyphosphate kinase [EC:2.7.4.1]      1
# 155      F-type H+-transporting ATPase subunit epsilon      1
# 202                          allantoinase [EC:3.5.2.5]      1
# 239                 pseudouridine kinase [EC:2.7.1.83]      1
# 249     3-hydroxypropanoate dehydrogenase [EC:1.1.1.-]      1
# 273                choline dehydrogenase [EC:1.1.99.1]      1
# 292  S-sulfo-L-cysteine synthase (O-acetyl-L-serine...      1
# 559             2-iminoacetate synthase [EC:4.1.99.19]      1
# 326                 lysine decarboxylase [EC:4.1.1.18]      1
# 582  D-erythrose 4-phosphate dehydrogenase [EC:1.2....      1
# 347        ATP phosphoribosyltransferase [EC:2.4.2.17]      1
# 571  3,4-dihydroxy 2-butanone 4-phosphate synthase ...      1
# 352             histidinol dehydrogenase [EC:1.1.1.23]      1
# 362                primary-amine oxidase [EC:1.4.3.21]      1
# 563          hydroxyethylthiazole kinase [EC:2.7.1.50]      1
# 562    phosphomethylpyrimidine synthase [EC:4.1.99.17]      1
# 681                seryl-tRNA synthetase [EC:6.1.1.11]      1
#
# [682 rows x 2 columns]

# %% [markdown]
# ## GUARDAR LOS VINCULOS

# %%
EDGESdf = pd.DataFrame(EDGES) 
EDGESdf.to_csv('EDGES_hsa.csv')

# %% [markdown]
# ## HACER LAS REDES CON LO GUARDADO

# %%
EDGES=pd.read_csv('EDGES_hsa.csv',index_col=0)
edges=EDGES[['0','1']]

# %%
G = nx.DiGraph() #--->DiGrafo para hacer un grado dirigido 
 
G.add_edges_from(edges.values)


plt.figure(3,figsize=(75,75))
nx.draw_kamada_kawai(G,font_size=15,node_size=1000,node_color='orange')
#nx.draw_kamada_kawai(G,font_size=15,node_size=1000,node_color='orange',with_labels=True)
plt.savefig("net_hsa.pdf")# Guardar la red en pdf. 
plt.show()

# %%
g=nx.number_of_nodes(G)
print('g=',g)
L=nx.number_of_edges(G)
print('L=',L)
