# %% [markdown]
# # Libreria

# %%
import pandas as pd
import networkx as nx
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
#parsear XML
import csv   
from lxml import etree
#Parsear HTML
import requests
import urllib.request
from bs4 import BeautifulSoup
from urllib.request import urlopen
from bs4.builder import HTMLParserTreeBuilder
#para medir tiempo
from time import time 
import time

# %% [markdown]
# # Carga de Archivos XML

# %%
org = 'ptr'
ORGANISM = org
maxi ='01040'

pathways = requests.get('http://rest.kegg.jp/list/pathway/' + ORGANISM)  #lista de las vias metabolicas y otra informacion porpocionada por KEGG

for line in pathways.text.split('\n'):         # Se recorre la lista propocionada por  KEGG donde se estraen los nombres de las vias de KEGG
      pathwayid = line.split('\t')[0].replace('path:', '') 
      A = pathwayid+'.xml'                     # Le ponemos la extencion .xml para poder cargar los archivos
      if A == str(org)+str(maxi)+'.xml':           
            break
      locals()[str(pathwayid)] = etree.parse(A) # Guarda los  XML com el nombre de la via asignado por KEGG
      locals()[str(pathwayid)] = locals()[str(pathwayid)].getroot()  # Para transformar todos lo XML en directorios de python

# %% [markdown]
# ## ARMANDO BASE DE DATOS CON PANDAS

# %% [markdown]
# ##### crear archivo csv para guardar los datos.

# %%
#data= pd.DataFrame(columns=('n', 'enzima', 'gen', 'nob_Keeg', 'path' ,'link')) # Crear tabla csv. 
#data.to_csv('data_'+org+'.csv', sep=';')

# %%
save=len(pd.read_csv('data_'+org+'.csv',index_col=0, delimiter=';')[['n']].values)
print(save)
# Out:
# 2768

# %%
save=len(pd.read_csv('data_'+org+'.csv',index_col=0, delimiter=';')[['n']].values)

n=0

for line in pathways.text.split('\n'):
    
    pathwayid = line.split('\t')[0].replace('path:', '') 
    
    if pathwayid ==  str(org)+str(maxi):           
            break
    
    ii=locals()[str(pathwayid)]
    
    
    for i in range(0,len(ii)):
       
        if ii[i].tag=='entry':         
            A=ii[i].attrib            
            if A['type'] == 'gene':
                n=1+n
                
                if n > save:
                    
                    url = A['link']
                
                    response = requests.get(url)
                    soup = BeautifulSoup(response.text, "html.parser")
                    
                    gen    = soup.html.body.div.table.form.td.table.find_all('td')[3].find_all('div')[0].text.replace('\n', ' ').strip().split()[0].replace(',','')
                    
                    if gen == '(RefSeq)':
                        ll=6
                    else:
                        ll=7
                    
                    enzima = soup.html.body.div.table.form.td.table.find_all('td')[ll].text.strip()
                    
                    NewDat = [n , A['id'] , enzima, gen , A['name'].split( )[0] , pathwayid , A['link'] ]
                
                                
                    with open(r'data_'+org+'.csv', 'a' , newline='') as f:
                        writer = csv.writer(f,delimiter=';')
                        writer.writerow(NewDat)

# %%
n=0

for line in pathways.text.split('\n'):
    
    pathwayid = line.split('\t')[0].replace('path:', '') 
    
    if pathwayid == str(org)+str(maxi):           
            break
            
  
    ii=locals()[str(pathwayid)]
    
        
    
    for i in range(0,len(ii)):
       
        if ii[i].tag=='entry':         
            A=ii[i].attrib            
            if A['type'] == 'group':
                n=1+n 
                
                NewDat = [n , A['id'] , 'undefined_Enzima'+pathwayid , 'none' ,  A['name'] , pathwayid , 'no link']
                
                        
                with open(r'data_'+org+'.csv', 'a' , newline='') as f:
                    writer = csv.writer(f , delimiter=';')
                    writer.writerow(NewDat)

# %%
data=pd.read_csv('data_'+org+'.csv',index_col=0, sep=';')
data=data[['n' ,'enzima', 'nob_Keeg' ,'path']]
data=data.values
data
# Out:
# array([["'14'", 'fructose-bisphosphate aldolase, class I [EC:4.1.2.13]',
#         'ptr:454362', 'ptr00010'],
#        ['14', 'fructose-bisphosphate aldolase, class I [EC:4.1.2.13]',
#         'ptr:454362', 'ptr00010'],
#        ['38', 'aldehyde dehydrogenase (NAD+) [EC:1.2.1.3]',
#         'ptr:107967644', 'ptr00010'],
#        ...,
#        ['72', 'undefined_Enzimaptr00563', 'undefined', 'ptr00563'],
#        ['73', 'undefined_Enzimaptr00563', 'undefined', 'ptr00563'],
#        ['74', 'undefined_Enzimaptr00563', 'undefined', 'ptr00563']],
#       dtype=object)

# %%
for line in pathways.text.split('\n'):
    
    pathwayid = line.split('\t')[0].replace('path:', '') 
    
    if pathwayid == str(org)+str(maxi):           
            break
    
    locals()['NODES_'+str(pathwayid)]={}
    
    for i in data:
        if i[3] == pathwayid:
            locals()['NODES_'+str(pathwayid)][i[0]]= i[1] 
            print(i[0],i[1], i[2], i[3])
# Out:
# '14' fructose-bisphosphate aldolase, class I [EC:4.1.2.13] ptr:454362 ptr00010
# 14 fructose-bisphosphate aldolase, class I [EC:4.1.2.13] ptr:454362 ptr00010
# 38 aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] ptr:107967644 ptr00010
# 40 aldehyde dehydrogenase (NAD(P)+) [EC:1.2.1.5] ptr:453686 ptr00010
# 45 alcohol dehydrogenase (NADP+) [EC:1.1.1.2] ptr:741418 ptr00010
# 46 alcohol dehydrogenase 4 [EC:1.1.1.1] ptr:461394 ptr00010
# 48 pyruvate dehydrogenase E1 component alpha subunit [EC:1.2.4.1] ptr:465525 ptr00010
# 49 pyruvate dehydrogenase E1 component alpha subunit [EC:1.2.4.1] ptr:465525 ptr00010
# 50 pyruvate dehydrogenase E2 component (dihydrolipoamide acetyltransferase) [EC:2.3.1.12] ptr:466780 ptr00010
# 51 L-lactate dehydrogenase [EC:1.1.1.27] ptr:451063 ptr00010
# 53 pyruvate kinase isozymes R/L [EC:2.7.1.40] ptr:469513 ptr00010
# 55 enolase [EC:4.2.1.11] ptr:454457 ptr00010
# 56 2,3-bisphosphoglycerate-dependent phosphoglycerate mutase [EC:5.4.2.11] ptr:450650 ptr00010
# 57 glyceraldehyde 3-phosphate dehydrogenase [EC:1.2.1.12] ptr:451783 ptr00010
# 58 triosephosphate isomerase (TIM) [EC:5.3.1.1] ptr:451799 ptr00010
# 59 6-phosphofructokinase 1 [EC:2.7.1.11] ptr:450266 ptr00010
# 60 fructose-1,6-bisphosphatase I [EC:3.1.3.11] ptr:465260 ptr00010
# 62 glucose-6-phosphate isomerase [EC:5.3.1.9] ptr:100612813 ptr00010
# 63 phosphoglucomutase [EC:5.4.2.2] ptr:456908 ptr00010
# 64 glucose-6-phosphate isomerase [EC:5.3.1.9] ptr:100612813 ptr00010
# 65 hexokinase [EC:2.7.1.1] ptr:450504 ptr00010
# 66 glucokinase [EC:2.7.1.2] ptr:737923 ptr00010
# 67 glucose-6-phosphate isomerase [EC:5.3.1.9] ptr:100612813 ptr00010
# 69 aldose 1-epimerase [EC:5.1.3.3] ptr:459166 ptr00010
# 70 glucokinase [EC:2.7.1.2] ptr:737923 ptr00010
# 71 hexokinase [EC:2.7.1.1] ptr:450504 ptr00010
# 72 glucose-6-phosphatase [EC:3.1.3.9] ptr:454703 ptr00010
# 75 dihydrolipoamide dehydrogenase [EC:1.8.1.4] ptr:463861 ptr00010
# 76 phosphoglycerate kinase [EC:2.7.2.3] ptr:462757 ptr00010
# 112 phosphoenolpyruvate carboxykinase (GTP) [EC:4.1.1.32] ptr:452807 ptr00010
# 128 bisphosphoglycerate/phosphoglycerate mutase [EC:5.4.2.4 5.4.2.11] ptr:463746 ptr00010
# 129 bisphosphoglycerate/phosphoglycerate mutase [EC:5.4.2.4 5.4.2.11] ptr:463746 ptr00010
# 131 acetyl-CoA synthetase [EC:6.2.1.1] ptr:458441 ptr00010
# 133 ADP-dependent glucokinase [EC:2.7.1.147] ptr:748791 ptr00010
# 134 ADP-dependent glucokinase [EC:2.7.1.147] ptr:748791 ptr00010
# 140 multiple inositol-polyphosphate phosphatase / 2,3-bisphosphoglycerate 3-phosphatase [EC:3.1.3.62 3.1.3.80] ptr:450579 ptr00010
# 33 dihydrolipoamide dehydrogenase [EC:1.8.1.4] ptr:463861 ptr00020
# 34 2-oxoglutarate dehydrogenase E1 component [EC:1.2.4.2] ptr:450453 ptr00020
# 35 2-oxoglutarate dehydrogenase E1 component [EC:1.2.4.2] ptr:450453 ptr00020
# 36 2-oxoglutarate dehydrogenase E2 component (dihydrolipoamide succinyltransferase) [EC:2.3.1.61] ptr:453039 ptr00020
# 37 succinyl-CoA synthetase beta subunit [EC:6.2.1.4 6.2.1.5] ptr:452711 ptr00020
# 38 succinyl-CoA synthetase beta subunit [EC:6.2.1.4 6.2.1.5] ptr:452711 ptr00020
# 39 isocitrate dehydrogenase [EC:1.1.1.42] ptr:453645 ptr00020
# 40 isocitrate dehydrogenase (NAD+) [EC:1.1.1.41] ptr:453565 ptr00020
# 41 isocitrate dehydrogenase [EC:1.1.1.42] ptr:453645 ptr00020
# 42 ATP citrate (pro-S)-lyase [EC:2.3.3.8] ptr:454672 ptr00020
# 43 fumarate hydratase, class II [EC:4.2.1.2] ptr:457851 ptr00020
# 44 aconitate hydratase [EC:4.2.1.3] ptr:104003784 ptr00020
# 45 aconitate hydratase [EC:4.2.1.3] ptr:104003784 ptr00020
# 46 citrate synthase [EC:2.3.3.1] ptr:746229 ptr00020
# 47 malate dehydrogenase [EC:1.1.1.37] ptr:459271 ptr00020
# 48 pyruvate carboxylase [EC:6.4.1.1] ptr:451356 ptr00020
# 84 pyruvate dehydrogenase E1 component alpha subunit [EC:1.2.4.1] ptr:465525 ptr00020
# 86 pyruvate dehydrogenase E1 component alpha subunit [EC:1.2.4.1] ptr:465525 ptr00020
# 89 dihydrolipoamide dehydrogenase [EC:1.8.1.4] ptr:463861 ptr00020
# 91 pyruvate dehydrogenase E2 component (dihydrolipoamide acetyltransferase) [EC:2.3.1.12] ptr:466780 ptr00020
# 97 phosphoenolpyruvate carboxykinase (GTP) [EC:4.1.1.32] ptr:452807 ptr00020
# 107 succinate dehydrogenase (ubiquinone) flavoprotein subunit [EC:1.3.5.1] ptr:107974583 ptr00020
# 37 glucose-6-phosphate isomerase [EC:5.3.1.9] ptr:100612813 ptr00030
# 40 ribokinase [EC:2.7.1.15] ptr:100613803 ptr00030
# 41 phosphoglucomutase / phosphopentomutase [EC:5.4.2.2 5.4.2.7] ptr:461162 ptr00030
# 42 deoxyribose-phosphate aldolase [EC:4.1.2.4] ptr:465316 ptr00030
# 43 ribose-phosphate pyrophosphokinase [EC:2.7.6.1] ptr:465800 ptr00030
# 44 phosphoglucomutase / phosphopentomutase [EC:5.4.2.2 5.4.2.7] ptr:461162 ptr00030
# 45 ribokinase [EC:2.7.1.15] ptr:100613803 ptr00030
# 46 transketolase [EC:2.2.1.1] ptr:460443 ptr00030
# 47 ribose 5-phosphate isomerase A [EC:5.3.1.6] ptr:470428 ptr00030
# 48 ribulose-phosphate 3-epimerase [EC:5.1.3.1] ptr:450708 ptr00030
# 49 transketolase [EC:2.2.1.1] ptr:460443 ptr00030
# 50 fructose-bisphosphate aldolase, class I [EC:4.1.2.13] ptr:454362 ptr00030
# 51 6-phosphofructokinase 1 [EC:2.7.1.11] ptr:450266 ptr00030
# 52 fructose-1,6-bisphosphatase I [EC:3.1.3.11] ptr:465260 ptr00030
# 53 glucose-6-phosphate isomerase [EC:5.3.1.9] ptr:100612813 ptr00030
# 56 6-phosphogluconate dehydrogenase [EC:1.1.1.44 1.1.1.343] ptr:100612990 ptr00030
# 57 6-phosphogluconolactonase [EC:3.1.1.31] ptr:748844 ptr00030
# 62 gluconokinase [EC:2.7.1.12] ptr:742025 ptr00030
# 64 gluconolactonase [EC:3.1.1.17] ptr:107970955 ptr00030
# 77 transaldolase [EC:2.2.1.2] ptr:450933 ptr00030
# 78 phosphoglucomutase [EC:5.4.2.2] ptr:456908 ptr00030
# 88 glycerate 2-kinase [EC:2.7.1.165] ptr:460420 ptr00030
# 97 hexose-6-phosphate dehydrogenase [EC:1.1.1.47 3.1.1.31] ptr:100610187 ptr00030
# 156 6-phosphogluconate dehydrogenase [EC:1.1.1.44 1.1.1.343] ptr:100612990 ptr00030
# 71 beta-glucuronidase [EC:3.2.1.31] ptr:463443 ptr00040
# 78 ribulose-phosphate 3-epimerase [EC:5.1.3.1] ptr:450708 ptr00040
# 81 D-ribitol-5-phosphate cytidylyltransferase [EC:2.7.7.40] ptr:744905 ptr00040
# 84 xylulokinase [EC:2.7.1.17] ptr:470793 ptr00040
# 93 aldehyde reductase [EC:1.1.1.21] ptr:463867 ptr00040
# 95 L-xylulose reductase [EC:1.1.1.10] ptr:454983 ptr00040
# 96 aldehyde reductase [EC:1.1.1.21] ptr:463867 ptr00040
# 99 L-gulonate 3-dehydrogenase [EC:1.1.1.45] ptr:452458 ptr00040
# 100 UTP--glucose-1-phosphate uridylyltransferase [EC:2.7.7.9] ptr:459273 ptr00040
# 101 glucuronosyltransferase [EC:2.4.1.17] ptr:100611992 ptr00040
# 102 UDPglucose 6-dehydrogenase [EC:1.1.1.22] ptr:471171 ptr00040
# 193 dihydrodiol dehydrogenase / D-xylose 1-dehydrogenase (NADP) [EC:1.3.1.20 1.1.1.179] ptr:456194 ptr00040
# 215 L-iditol 2-dehydrogenase [EC:1.1.1.14] ptr:107968609 ptr00040
# 216 alcohol dehydrogenase (NADP+) [EC:1.1.1.2] ptr:741418 ptr00040
# 63 aldehyde reductase [EC:1.1.1.21] ptr:463867 ptr00051
# 64 L-iditol 2-dehydrogenase [EC:1.1.1.14] ptr:107968609 ptr00051
# 66 ketohexokinase [EC:2.7.1.3] ptr:740614 ptr00051
# 76 hexokinase [EC:2.7.1.1] ptr:450504 ptr00051
# 79 hexokinase [EC:2.7.1.1] ptr:450504 ptr00051
# 81 6-phosphofructo-2-kinase / fructose-2,6-biphosphatase 2 [EC:2.7.1.105 3.1.3.46] ptr:457687 ptr00051
# 84 mannose-6-phosphate isomerase [EC:5.3.1.8] ptr:453748 ptr00051
# 85 phosphomannomutase [EC:5.4.2.8] ptr:453905 ptr00051
# 87 fucose-1-phosphate guanylyltransferase [EC:2.7.7.30] ptr:100533984 ptr00051
# 88 GDP-L-fucose synthase [EC:1.1.1.271] ptr:464445 ptr00051
# 89 GDPmannose 4,6-dehydratase [EC:4.2.1.47] ptr:462390 ptr00051
# 90 mannose-1-phosphate guanylyltransferase [EC:2.7.7.13] ptr:459966 ptr00051
# 94 6-phosphofructokinase 1 [EC:2.7.1.11] ptr:450266 ptr00051
# 99 triosephosphate isomerase (TIM) [EC:5.3.1.1] ptr:451799 ptr00051
# 100 fructose-bisphosphate aldolase, class I [EC:4.1.2.13] ptr:454362 ptr00051
# 101 triose/dihydroxyacetone kinase / FAD-AMP lyase (cyclizing) [EC:2.7.1.28 2.7.1.29 4.6.1.15] ptr:466626 ptr00051
# 102 fructose-bisphosphate aldolase, class I [EC:4.1.2.13] ptr:454362 ptr00051
# 111 fructose-1,6-bisphosphatase I [EC:3.1.3.11] ptr:465260 ptr00051
# 123 fucokinase [EC:2.7.1.52] ptr:468015 ptr00051
# 208 L-fuconate dehydratase [EC:4.2.1.68] ptr:739934 ptr00051
# 55 alpha-galactosidase [EC:3.2.1.22] ptr:107971043 ptr00052
# 57 6-phosphofructokinase 1 [EC:2.7.1.11] ptr:450266 ptr00052
# 61 alpha-galactosidase [EC:3.2.1.22] ptr:107971043 ptr00052
# 64 neutral alpha-glucosidase C [EC:3.2.1.20] ptr:453361 ptr00052
# 65 alpha-galactosidase [EC:3.2.1.22] ptr:107971043 ptr00052
# 68 aldehyde reductase [EC:1.1.1.21] ptr:463867 ptr00052
# 69 alpha-galactosidase [EC:3.2.1.22] ptr:107971043 ptr00052
# 70 alpha-galactosidase [EC:3.2.1.22] ptr:107971043 ptr00052
# 71 alpha-galactosidase [EC:3.2.1.22] ptr:107971043 ptr00052
# 72 alpha-galactosidase [EC:3.2.1.22] ptr:107971043 ptr00052
# 73 glucokinase [EC:2.7.1.2] ptr:737923 ptr00052
# 74 hexokinase [EC:2.7.1.1] ptr:450504 ptr00052
# 75 lactase-phlorizin hydrolase [EC:3.2.1.108 3.2.1.62] ptr:459633 ptr00052
# 76 beta-galactosidase [EC:3.2.1.23] ptr:460254 ptr00052
# 77 phosphoglucomutase [EC:5.4.2.2] ptr:456908 ptr00052
# 78 beta-1,4-galactosyltransferase 1 [EC:2.4.1.22 2.4.1.90 2.4.1.38 2.4.1.-] ptr:100613700 ptr00052
# 79 UDP-glucose 4-epimerase [EC:5.1.3.2] ptr:456623 ptr00052
# 80 UTP--glucose-1-phosphate uridylyltransferase [EC:2.7.7.9] ptr:459273 ptr00052
# 82 UDPglucose--hexose-1-phosphate uridylyltransferase [EC:2.7.7.12] ptr:473219 ptr00052
# 99 glucose-6-phosphatase [EC:3.1.3.9] ptr:454703 ptr00052
# 111 alpha-galactosidase [EC:3.2.1.22] ptr:107971043 ptr00052
# 156 sucrase-isomaltase [EC:3.2.1.48 3.2.1.10] ptr:470988 ptr00052
# 171 galactokinase [EC:2.7.1.6] ptr:454888 ptr00052
# 172 aldose 1-epimerase [EC:5.1.3.3] ptr:459166 ptr00052
# 32 inositol oxygenase [EC:1.13.99.1] ptr:747218 ptr00053
# 35 UDPglucose 6-dehydrogenase [EC:1.1.1.22] ptr:471171 ptr00053
# 51 gluconolactonase [EC:3.1.1.17] ptr:107970955 ptr00053
# 66 glucuronosyltransferase [EC:2.4.1.17] ptr:100611992 ptr00053
# 73 aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] ptr:107967644 ptr00053
# 44 fatty acid synthase, animal type [EC:2.3.1.85] ptr:454986 ptr00061
# 45 medium-chain acyl-[acyl-carrier-protein] hydrolase [EC:3.1.2.21] ptr:450320 ptr00061
# 47 medium-chain acyl-[acyl-carrier-protein] hydrolase [EC:3.1.2.21] ptr:450320 ptr00061
# 48 medium-chain acyl-[acyl-carrier-protein] hydrolase [EC:3.1.2.21] ptr:450320 ptr00061
# 59 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] ptr:460234 ptr00061
# 64 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] ptr:460234 ptr00061
# 65 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] ptr:460234 ptr00061
# 66 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] ptr:460234 ptr00061
# 67 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] ptr:460234 ptr00061
# 68 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] ptr:460234 ptr00061
# 69 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] ptr:460234 ptr00061
# 75 fatty acid synthase, animal type [EC:2.3.1.85] ptr:454986 ptr00061
# 78 fatty acid synthase, animal type [EC:2.3.1.85] ptr:454986 ptr00061
# 80 fatty acid synthase, animal type [EC:2.3.1.85] ptr:454986 ptr00061
# 83 fatty acid synthase, animal type [EC:2.3.1.85] ptr:454986 ptr00061
# 86 fatty acid synthase, animal type [EC:2.3.1.85] ptr:454986 ptr00061
# 89 fatty acid synthase, animal type [EC:2.3.1.85] ptr:454986 ptr00061
# 91 fatty acid synthase, animal type [EC:2.3.1.85] ptr:454986 ptr00061
# 94 fatty acid synthase, animal type [EC:2.3.1.85] ptr:454986 ptr00061
# 97 fatty acid synthase, animal type [EC:2.3.1.85] ptr:454986 ptr00061
# 100 fatty acid synthase, animal type [EC:2.3.1.85] ptr:454986 ptr00061
# 102 fatty acid synthase, animal type [EC:2.3.1.85] ptr:454986 ptr00061
# 105 fatty acid synthase, animal type [EC:2.3.1.85] ptr:454986 ptr00061
# 108 fatty acid synthase, animal type [EC:2.3.1.85] ptr:454986 ptr00061
# 111 fatty acid synthase, animal type [EC:2.3.1.85] ptr:454986 ptr00061
# 113 fatty acid synthase, animal type [EC:2.3.1.85] ptr:454986 ptr00061
# 116 fatty acid synthase, animal type [EC:2.3.1.85] ptr:454986 ptr00061
# 119 fatty acid synthase, animal type [EC:2.3.1.85] ptr:454986 ptr00061
# 122 fatty acid synthase, animal type [EC:2.3.1.85] ptr:454986 ptr00061
# 124 fatty acid synthase, animal type [EC:2.3.1.85] ptr:454986 ptr00061
# 127 fatty acid synthase, animal type [EC:2.3.1.85] ptr:454986 ptr00061
# 130 fatty acid synthase, animal type [EC:2.3.1.85] ptr:454986 ptr00061
# 133 fatty acid synthase, animal type [EC:2.3.1.85] ptr:454986 ptr00061
# 135 fatty acid synthase, animal type [EC:2.3.1.85] ptr:454986 ptr00061
# 138 fatty acid synthase, animal type [EC:2.3.1.85] ptr:454986 ptr00061
# 140 fatty acid synthase, animal type [EC:2.3.1.85] ptr:454986 ptr00061
# 144 fatty acid synthase, animal type [EC:2.3.1.85] ptr:454986 ptr00061
# 147 fatty acid synthase, animal type [EC:2.3.1.85] ptr:454986 ptr00061
# 150 fatty acid synthase, animal type [EC:2.3.1.85] ptr:454986 ptr00061
# 152 fatty acid synthase, animal type [EC:2.3.1.85] ptr:454986 ptr00061
# 153 [acyl-carrier-protein] S-malonyltransferase [EC:2.3.1.39] ptr:470233 ptr00061
# 155 fatty acid synthase, animal type [EC:2.3.1.85] ptr:454986 ptr00061
# 158 fatty acid synthase, animal type [EC:2.3.1.85] ptr:454986 ptr00061
# 159 acetyl-CoA carboxylase / biotin carboxylase 2 [EC:6.4.1.2 6.3.4.14 2.1.3.15] ptr:452219 ptr00061
# 265 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] ptr:460234 ptr00061
# 301 long-chain acyl-CoA synthetase [EC:6.2.1.3] ptr:450739 ptr00061
# 306 malonyl-CoA/methylmalonyl-CoA synthetase [EC:6.2.1.-] ptr:454311 ptr00061
# 307 mitochondrial enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase [EC:1.3.1.- 1.3.1.38] ptr:456690 ptr00061
# 313 mitochondrial enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase [EC:1.3.1.- 1.3.1.38] ptr:456690 ptr00061
# 314 mitochondrial enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase [EC:1.3.1.- 1.3.1.38] ptr:456690 ptr00061
# 315 mitochondrial enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase [EC:1.3.1.- 1.3.1.38] ptr:456690 ptr00061
# 316 mitochondrial enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase [EC:1.3.1.- 1.3.1.38] ptr:456690 ptr00061
# 317 mitochondrial enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase [EC:1.3.1.- 1.3.1.38] ptr:456690 ptr00061
# 318 mitochondrial enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase [EC:1.3.1.- 1.3.1.38] ptr:456690 ptr00061
# 319 carbonyl reductase 4 / 3-oxoacyl-[acyl-carrier protein] reductase beta subunit [EC:1.1.1.-] ptr:471344 ptr00061
# 320 17beta-estradiol 17-dehydrogenase / 3alpha(17beta)-hydroxysteroid dehydrogenase (NAD+) / 3-oxoacyl-[acyl-carrier protein] reductase alpha subunit [EC:1.1.1.62 1.1.1.239] ptr:746685 ptr00061
# 321 carbonyl reductase 4 / 3-oxoacyl-[acyl-carrier protein] reductase beta subunit [EC:1.1.1.-] ptr:471344 ptr00061
# 322 17beta-estradiol 17-dehydrogenase / 3alpha(17beta)-hydroxysteroid dehydrogenase (NAD+) / 3-oxoacyl-[acyl-carrier protein] reductase alpha subunit [EC:1.1.1.62 1.1.1.239] ptr:746685 ptr00061
# 323 carbonyl reductase 4 / 3-oxoacyl-[acyl-carrier protein] reductase beta subunit [EC:1.1.1.-] ptr:471344 ptr00061
# 324 17beta-estradiol 17-dehydrogenase / 3alpha(17beta)-hydroxysteroid dehydrogenase (NAD+) / 3-oxoacyl-[acyl-carrier protein] reductase alpha subunit [EC:1.1.1.62 1.1.1.239] ptr:746685 ptr00061
# 325 carbonyl reductase 4 / 3-oxoacyl-[acyl-carrier protein] reductase beta subunit [EC:1.1.1.-] ptr:471344 ptr00061
# 326 17beta-estradiol 17-dehydrogenase / 3alpha(17beta)-hydroxysteroid dehydrogenase (NAD+) / 3-oxoacyl-[acyl-carrier protein] reductase alpha subunit [EC:1.1.1.62 1.1.1.239] ptr:746685 ptr00061
# 327 carbonyl reductase 4 / 3-oxoacyl-[acyl-carrier protein] reductase beta subunit [EC:1.1.1.-] ptr:471344 ptr00061
# 328 17beta-estradiol 17-dehydrogenase / 3alpha(17beta)-hydroxysteroid dehydrogenase (NAD+) / 3-oxoacyl-[acyl-carrier protein] reductase alpha subunit [EC:1.1.1.62 1.1.1.239] ptr:746685 ptr00061
# 329 carbonyl reductase 4 / 3-oxoacyl-[acyl-carrier protein] reductase beta subunit [EC:1.1.1.-] ptr:471344 ptr00061
# 330 17beta-estradiol 17-dehydrogenase / 3alpha(17beta)-hydroxysteroid dehydrogenase (NAD+) / 3-oxoacyl-[acyl-carrier protein] reductase alpha subunit [EC:1.1.1.62 1.1.1.239] ptr:746685 ptr00061
# 331 carbonyl reductase 4 / 3-oxoacyl-[acyl-carrier protein] reductase beta subunit [EC:1.1.1.-] ptr:471344 ptr00061
# 332 17beta-estradiol 17-dehydrogenase / 3alpha(17beta)-hydroxysteroid dehydrogenase (NAD+) / 3-oxoacyl-[acyl-carrier protein] reductase alpha subunit [EC:1.1.1.62 1.1.1.239] ptr:746685 ptr00061
# 333 3-hydroxyacyl-thioester dehydratase, animal type [EC:4.2.1.-] ptr:112204078 ptr00061
# 334 3-hydroxyacyl-thioester dehydratase, animal type [EC:4.2.1.-] ptr:112204078 ptr00061
# 335 3-hydroxyacyl-thioester dehydratase, animal type [EC:4.2.1.-] ptr:112204078 ptr00061
# 336 3-hydroxyacyl-thioester dehydratase, animal type [EC:4.2.1.-] ptr:112204078 ptr00061
# 337 3-hydroxyacyl-thioester dehydratase, animal type [EC:4.2.1.-] ptr:112204078 ptr00061
# 338 3-hydroxyacyl-thioester dehydratase, animal type [EC:4.2.1.-] ptr:112204078 ptr00061
# 339 3-hydroxyacyl-thioester dehydratase, animal type [EC:4.2.1.-] ptr:112204078 ptr00061
# 345 carbonyl reductase 4 / 3-oxoacyl-[acyl-carrier protein] reductase beta subunit [EC:1.1.1.-] ptr:471344 ptr00061
# 346 17beta-estradiol 17-dehydrogenase / 3alpha(17beta)-hydroxysteroid dehydrogenase (NAD+) / 3-oxoacyl-[acyl-carrier protein] reductase alpha subunit [EC:1.1.1.62 1.1.1.239] ptr:746685 ptr00061
# 362 mitochondrial enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase [EC:1.3.1.- 1.3.1.38] ptr:456690 ptr00061
# 363 3-hydroxyacyl-thioester dehydratase, animal type [EC:4.2.1.-] ptr:112204078 ptr00061
# 365 malonyl-CoA/methylmalonyl-CoA synthetase [EC:6.2.1.-] ptr:454311 ptr00061
# 384 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] ptr:460234 ptr00061
# 388 long-chain acyl-CoA synthetase [EC:6.2.1.3] ptr:450739 ptr00061
# 390 fatty acid synthase, animal type [EC:2.3.1.85] ptr:454986 ptr00061
# 395 long-chain acyl-CoA synthetase [EC:6.2.1.3] ptr:450739 ptr00061
# 402 [acyl-carrier-protein] S-malonyltransferase [EC:2.3.1.39] ptr:470233 ptr00061
# 405 [acyl-carrier-protein] S-malonyltransferase [EC:2.3.1.39] ptr:470233 ptr00061
# 406 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] ptr:460234 ptr00061
# 409 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] ptr:460234 ptr00061
# 410 acetyl-CoA carboxylase / biotin carboxylase 1 [EC:6.4.1.2 6.3.4.14 2.1.3.15] ptr:454602 ptr00061
# 411 acetyl-CoA carboxylase / biotin carboxylase 1 [EC:6.4.1.2 6.3.4.14 2.1.3.15] ptr:454602 ptr00061
# 412 acetyl-CoA carboxylase / biotin carboxylase 1 [EC:6.4.1.2 6.3.4.14 2.1.3.15] ptr:454602 ptr00061
# 415 undefined_Enzimaptr00061 undefined ptr00061
# 416 undefined_Enzimaptr00061 undefined ptr00061
# 417 undefined_Enzimaptr00061 undefined ptr00061
# 418 undefined_Enzimaptr00061 undefined ptr00061
# 419 undefined_Enzimaptr00061 undefined ptr00061
# 420 undefined_Enzimaptr00061 undefined ptr00061
# 421 undefined_Enzimaptr00061 undefined ptr00061
# 29 palmitoyl-protein thioesterase [EC:3.1.2.22] ptr:456789 ptr00062
# 30 mitochondrial enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase [EC:1.3.1.- 1.3.1.38] ptr:456690 ptr00062
# 31 enoyl-CoA hydratase / long-chain 3-hydroxyacyl-CoA dehydrogenase [EC:4.2.1.17 1.1.1.211] ptr:459079 ptr00062
# 32 enoyl-CoA hydratase / long-chain 3-hydroxyacyl-CoA dehydrogenase [EC:4.2.1.17 1.1.1.211] ptr:459079 ptr00062
# 33 acetyl-CoA acyltransferase 2 [EC:2.3.1.16] ptr:455414 ptr00062
# 34 mitochondrial enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase [EC:1.3.1.- 1.3.1.38] ptr:456690 ptr00062
# 35 enoyl-CoA hydratase / long-chain 3-hydroxyacyl-CoA dehydrogenase [EC:4.2.1.17 1.1.1.211] ptr:459079 ptr00062
# 36 enoyl-CoA hydratase / long-chain 3-hydroxyacyl-CoA dehydrogenase [EC:4.2.1.17 1.1.1.211] ptr:459079 ptr00062
# 37 acetyl-CoA acyltransferase 2 [EC:2.3.1.16] ptr:455414 ptr00062
# 38 mitochondrial enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase [EC:1.3.1.- 1.3.1.38] ptr:456690 ptr00062
# 39 enoyl-CoA hydratase / long-chain 3-hydroxyacyl-CoA dehydrogenase [EC:4.2.1.17 1.1.1.211] ptr:459079 ptr00062
# 40 enoyl-CoA hydratase / long-chain 3-hydroxyacyl-CoA dehydrogenase [EC:4.2.1.17 1.1.1.211] ptr:459079 ptr00062
# 41 acetyl-CoA acyltransferase 2 [EC:2.3.1.16] ptr:455414 ptr00062
# 42 mitochondrial enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase [EC:1.3.1.- 1.3.1.38] ptr:456690 ptr00062
# 43 enoyl-CoA hydratase / long-chain 3-hydroxyacyl-CoA dehydrogenase [EC:4.2.1.17 1.1.1.211] ptr:459079 ptr00062
# 44 enoyl-CoA hydratase / long-chain 3-hydroxyacyl-CoA dehydrogenase [EC:4.2.1.17 1.1.1.211] ptr:459079 ptr00062
# 45 3-hydroxyacyl-CoA dehydrogenase [EC:1.1.1.35] ptr:461424 ptr00062
# 46 acetyl-CoA acyltransferase 2 [EC:2.3.1.16] ptr:455414 ptr00062
# 47 mitochondrial enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase [EC:1.3.1.- 1.3.1.38] ptr:456690 ptr00062
# 48 enoyl-CoA hydratase / long-chain 3-hydroxyacyl-CoA dehydrogenase [EC:4.2.1.17 1.1.1.211] ptr:459079 ptr00062
# 49 enoyl-CoA hydratase / long-chain 3-hydroxyacyl-CoA dehydrogenase [EC:4.2.1.17 1.1.1.211] ptr:459079 ptr00062
# 50 3-hydroxyacyl-CoA dehydrogenase [EC:1.1.1.35] ptr:461424 ptr00062
# 51 acetyl-CoA acyltransferase 2 [EC:2.3.1.16] ptr:455414 ptr00062
# 52 mitochondrial enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase [EC:1.3.1.- 1.3.1.38] ptr:456690 ptr00062
# 53 enoyl-CoA hydratase / long-chain 3-hydroxyacyl-CoA dehydrogenase [EC:4.2.1.17 1.1.1.211] ptr:459079 ptr00062
# 54 enoyl-CoA hydratase / long-chain 3-hydroxyacyl-CoA dehydrogenase [EC:4.2.1.17 1.1.1.211] ptr:459079 ptr00062
# 59 3-hydroxyacyl-CoA dehydrogenase [EC:1.1.1.35] ptr:461424 ptr00062
# 60 acetyl-CoA acyltransferase 2 [EC:2.3.1.16] ptr:455414 ptr00062
# 113 17beta-estradiol 17-dehydrogenase / very-long-chain 3-oxoacyl-CoA reductase [EC:1.1.1.62 1.1.1.330] ptr:741010 ptr00062
# 114 very-long-chain enoyl-CoA reductase [EC:1.3.1.93] ptr:455786 ptr00062
# 115 very-long-chain (3R)-3-hydroxyacyl-CoA dehydratase [EC:4.2.1.134] ptr:450331 ptr00062
# 120 enoyl-CoA hydratase / long-chain 3-hydroxyacyl-CoA dehydrogenase [EC:4.2.1.17 1.1.1.211] ptr:459079 ptr00062
# 121 3-hydroxyacyl-CoA dehydrogenase [EC:1.1.1.35] ptr:461424 ptr00062
# 122 acetyl-CoA acyltransferase 2 [EC:2.3.1.16] ptr:455414 ptr00062
# 132 mitochondrial enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase [EC:1.3.1.- 1.3.1.38] ptr:456690 ptr00062
# 133 enoyl-CoA hydratase / long-chain 3-hydroxyacyl-CoA dehydrogenase [EC:4.2.1.17 1.1.1.211] ptr:459079 ptr00062
# 137 palmitoyl-protein thioesterase [EC:3.1.2.22] ptr:456789 ptr00062
# 141 acyl-coenzyme A thioesterase 7 [EC:3.1.2.2] ptr:100609278 ptr00062
# 143 elongation of very long chain fatty acids protein 1 [EC:2.3.1.199] ptr:456820 ptr00062
# 43 short/branched chain acyl-CoA dehydrogenase [EC:1.3.99.12] ptr:745464 ptr00071
# 44 short/branched chain acyl-CoA dehydrogenase [EC:1.3.99.12] ptr:745464 ptr00071
# 45 butyryl-CoA dehydrogenase [EC:1.3.8.1] ptr:742921 ptr00071
# 46 enoyl-CoA hydratase / 3-hydroxyacyl-CoA dehydrogenase / 3,2-trans-enoyl-CoA isomerase [EC:4.2.1.17 1.1.1.35 5.3.3.8] ptr:460996 ptr00071
# 47 enoyl-CoA hydratase / long-chain 3-hydroxyacyl-CoA dehydrogenase [EC:4.2.1.17 1.1.1.211] ptr:459079 ptr00071
# 49 acyl-CoA dehydrogenase [EC:1.3.8.7] ptr:469356 ptr00071
# 51 enoyl-CoA hydratase / 3-hydroxyacyl-CoA dehydrogenase / 3,2-trans-enoyl-CoA isomerase [EC:4.2.1.17 1.1.1.35 5.3.3.8] ptr:460996 ptr00071
# 53 acetyl-CoA C-acetyltransferase [EC:2.3.1.9] ptr:451528 ptr00071
# 54 acetyl-CoA acyltransferase 2 [EC:2.3.1.16] ptr:455414 ptr00071
# 55 enoyl-CoA hydratase / 3-hydroxyacyl-CoA dehydrogenase / 3,2-trans-enoyl-CoA isomerase [EC:4.2.1.17 1.1.1.35 5.3.3.8] ptr:460996 ptr00071
# 56 enoyl-CoA hydratase / long-chain 3-hydroxyacyl-CoA dehydrogenase [EC:4.2.1.17 1.1.1.211] ptr:459079 ptr00071
# 57 butyryl-CoA dehydrogenase [EC:1.3.8.1] ptr:742921 ptr00071
# 58 acyl-CoA dehydrogenase [EC:1.3.8.7] ptr:469356 ptr00071
# 59 enoyl-CoA hydratase / long-chain 3-hydroxyacyl-CoA dehydrogenase [EC:4.2.1.17 1.1.1.211] ptr:459079 ptr00071
# 61 long-chain-acyl-CoA dehydrogenase [EC:1.3.8.8] ptr:459914 ptr00071
# 62 acetyl-CoA acyltransferase 2 [EC:2.3.1.16] ptr:455414 ptr00071
# 63 enoyl-CoA hydratase / 3-hydroxyacyl-CoA dehydrogenase / 3,2-trans-enoyl-CoA isomerase [EC:4.2.1.17 1.1.1.35 5.3.3.8] ptr:460996 ptr00071
# 64 enoyl-CoA hydratase / long-chain 3-hydroxyacyl-CoA dehydrogenase [EC:4.2.1.17 1.1.1.211] ptr:459079 ptr00071
# 65 acyl-CoA dehydrogenase [EC:1.3.8.7] ptr:469356 ptr00071
# 66 enoyl-CoA hydratase / long-chain 3-hydroxyacyl-CoA dehydrogenase [EC:4.2.1.17 1.1.1.211] ptr:459079 ptr00071
# 68 long-chain-acyl-CoA dehydrogenase [EC:1.3.8.8] ptr:459914 ptr00071
# 69 acetyl-CoA acyltransferase 2 [EC:2.3.1.16] ptr:455414 ptr00071
# 70 enoyl-CoA hydratase / 3-hydroxyacyl-CoA dehydrogenase / 3,2-trans-enoyl-CoA isomerase [EC:4.2.1.17 1.1.1.35 5.3.3.8] ptr:460996 ptr00071
# 71 enoyl-CoA hydratase / long-chain 3-hydroxyacyl-CoA dehydrogenase [EC:4.2.1.17 1.1.1.211] ptr:459079 ptr00071
# 72 acyl-CoA dehydrogenase [EC:1.3.8.7] ptr:469356 ptr00071
# 73 long-chain-acyl-CoA dehydrogenase [EC:1.3.8.8] ptr:459914 ptr00071
# 74 enoyl-CoA hydratase / long-chain 3-hydroxyacyl-CoA dehydrogenase [EC:4.2.1.17 1.1.1.211] ptr:459079 ptr00071
# 79 acetyl-CoA acyltransferase 2 [EC:2.3.1.16] ptr:455414 ptr00071
# 80 enoyl-CoA hydratase / 3-hydroxyacyl-CoA dehydrogenase / 3,2-trans-enoyl-CoA isomerase [EC:4.2.1.17 1.1.1.35 5.3.3.8] ptr:460996 ptr00071
# 81 enoyl-CoA hydratase / long-chain 3-hydroxyacyl-CoA dehydrogenase [EC:4.2.1.17 1.1.1.211] ptr:459079 ptr00071
# 82 acyl-CoA dehydrogenase [EC:1.3.8.7] ptr:469356 ptr00071
# 84 alcohol dehydrogenase 4 [EC:1.1.1.1] ptr:461394 ptr00071
# 86 glutaryl-CoA dehydrogenase [EC:1.3.8.6] ptr:455754 ptr00071
# 88 enoyl-CoA hydratase / long-chain 3-hydroxyacyl-CoA dehydrogenase [EC:4.2.1.17 1.1.1.211] ptr:459079 ptr00071
# 90 long-chain-acyl-CoA dehydrogenase [EC:1.3.8.8] ptr:459914 ptr00071
# 94 acetyl-CoA acyltransferase 2 [EC:2.3.1.16] ptr:455414 ptr00071
# 95 enoyl-CoA hydratase / long-chain 3-hydroxyacyl-CoA dehydrogenase [EC:4.2.1.17 1.1.1.211] ptr:459079 ptr00071
# 96 acyl-CoA dehydrogenase [EC:1.3.8.7] ptr:469356 ptr00071
# 97 enoyl-CoA hydratase / 3-hydroxyacyl-CoA dehydrogenase / 3,2-trans-enoyl-CoA isomerase [EC:4.2.1.17 1.1.1.35 5.3.3.8] ptr:460996 ptr00071
# 100 enoyl-CoA hydratase / long-chain 3-hydroxyacyl-CoA dehydrogenase [EC:4.2.1.17 1.1.1.211] ptr:459079 ptr00071
# 102 long-chain-acyl-CoA dehydrogenase [EC:1.3.8.8] ptr:459914 ptr00071
# 103 long-chain fatty acid omega-monooxygenase [EC:1.14.14.80] ptr:456835 ptr00071
# 105 acetyl-CoA acyltransferase 2 [EC:2.3.1.16] ptr:455414 ptr00071
# 106 enoyl-CoA hydratase / 3-hydroxyacyl-CoA dehydrogenase / 3,2-trans-enoyl-CoA isomerase [EC:4.2.1.17 1.1.1.35 5.3.3.8] ptr:460996 ptr00071
# 107 enoyl-CoA hydratase / long-chain 3-hydroxyacyl-CoA dehydrogenase [EC:4.2.1.17 1.1.1.211] ptr:459079 ptr00071
# 108 acyl-CoA dehydrogenase [EC:1.3.8.7] ptr:469356 ptr00071
# 109 long-chain acyl-CoA synthetase [EC:6.2.1.3] ptr:450739 ptr00071
# 110 enoyl-CoA hydratase / long-chain 3-hydroxyacyl-CoA dehydrogenase [EC:4.2.1.17 1.1.1.211] ptr:459079 ptr00071
# 112 long-chain-acyl-CoA dehydrogenase [EC:1.3.8.8] ptr:459914 ptr00071
# 115 acyl-CoA oxidase [EC:1.3.3.6] ptr:454895 ptr00071
# 116 acyl-CoA oxidase [EC:1.3.3.6] ptr:454895 ptr00071
# 117 acyl-CoA oxidase [EC:1.3.3.6] ptr:454895 ptr00071
# 118 acyl-CoA oxidase [EC:1.3.3.6] ptr:454895 ptr00071
# 119 acyl-CoA oxidase [EC:1.3.3.6] ptr:454895 ptr00071
# 120 acyl-CoA oxidase [EC:1.3.3.6] ptr:454895 ptr00071
# 121 acyl-CoA oxidase [EC:1.3.3.6] ptr:454895 ptr00071
# 202 acetyl-CoA C-acetyltransferase [EC:2.3.1.9] ptr:451528 ptr00071
# 203 very long chain acyl-CoA dehydrogenase [EC:1.3.8.9] ptr:455237 ptr00071
# 204 very long chain acyl-CoA dehydrogenase [EC:1.3.8.9] ptr:455237 ptr00071
# 208 carnitine O-palmitoyltransferase 1, liver isoform [EC:2.3.1.21] ptr:451382 ptr00071
# 211 carnitine O-palmitoyltransferase 2 [EC:2.3.1.21] ptr:737945 ptr00071
# 213 aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] ptr:107967644 ptr00071
# 217 acetyl-CoA acyltransferase 2 [EC:2.3.1.16] ptr:455414 ptr00071
# 11 hydroxymethylglutaryl-CoA synthase [EC:2.3.3.10] ptr:457169 ptr00072
# 12 hydroxymethylglutaryl-CoA lyase [EC:4.1.3.4] ptr:456624 ptr00072
# 14 acetyl-CoA C-acetyltransferase [EC:2.3.1.9] ptr:451528 ptr00072
# 15 3-hydroxybutyrate dehydrogenase [EC:1.1.1.30] ptr:460970 ptr00072
# 18 3-oxoacid CoA-transferase [EC:2.8.3.5] ptr:112209812 ptr00072
# 44 Delta7-sterol 5-desaturase [EC:1.14.19.20] ptr:451624 ptr00100
# 45 cholestenol Delta-isomerase [EC:5.3.3.5] ptr:107971057 ptr00100
# 46 7-dehydrocholesterol reductase [EC:1.3.1.21] ptr:451393 ptr00100
# 47 Delta7-sterol 5-desaturase [EC:1.14.19.20] ptr:451624 ptr00100
# 48 cholestenol Delta-isomerase [EC:5.3.3.5] ptr:107971057 ptr00100
# 51 Delta7-sterol 5-desaturase [EC:1.14.19.20] ptr:451624 ptr00100
# 56 Delta24-sterol reductase [EC:1.3.1.72 1.3.1.-] ptr:456879 ptr00100
# 57 7-dehydrocholesterol reductase [EC:1.3.1.21] ptr:451393 ptr00100
# 58 Delta7-sterol 5-desaturase [EC:1.14.19.20] ptr:451624 ptr00100
# 59 Delta24-sterol reductase [EC:1.3.1.72 1.3.1.-] ptr:456879 ptr00100
# 60 Delta24-sterol reductase [EC:1.3.1.72 1.3.1.-] ptr:456879 ptr00100
# 61 Delta24-sterol reductase [EC:1.3.1.72 1.3.1.-] ptr:456879 ptr00100
# 62 Delta24-sterol reductase [EC:1.3.1.72 1.3.1.-] ptr:456879 ptr00100
# 63 Delta24-sterol reductase [EC:1.3.1.72 1.3.1.-] ptr:456879 ptr00100
# 67 Delta24-sterol reductase [EC:1.3.1.72 1.3.1.-] ptr:456879 ptr00100
# 68 sterol 14alpha-demethylase [EC:1.14.14.154 1.14.15.36] ptr:463527 ptr00100
# 70 Delta14-sterol reductase [EC:1.3.1.70] ptr:451314 ptr00100
# 72 7-dehydrocholesterol reductase [EC:1.3.1.21] ptr:451393 ptr00100
# 89 lanosterol synthase [EC:5.4.99.7] ptr:474058 ptr00100
# 90 Delta14-sterol reductase [EC:1.3.1.70] ptr:451314 ptr00100
# 91 cholestenol Delta-isomerase [EC:5.3.3.5] ptr:107971057 ptr00100
# 92 sterol-4alpha-carboxylate 3-dehydrogenase (decarboxylating) [EC:1.1.1.170] ptr:465960 ptr00100
# 97 Delta24-sterol reductase [EC:1.3.1.72 1.3.1.-] ptr:456879 ptr00100
# 98 methylsterol monooxygenase [EC:1.14.18.9] ptr:738493 ptr00100
# 99 sterol 14alpha-demethylase [EC:1.14.14.154 1.14.15.36] ptr:463527 ptr00100
# 100 17beta-estradiol 17-dehydrogenase / 3beta-hydroxysteroid 3-dehydrogenase [EC:1.1.1.62 1.1.1.270] ptr:466046 ptr00100
# 131 lysosomal acid lipase/cholesteryl ester hydrolase [EC:3.1.1.13] ptr:466150 ptr00100
# 133 sterol O-acyltransferase [EC:2.3.1.26] ptr:457553 ptr00100
# 137 vitamin D 25-hydroxylase [EC:1.14.14.24] ptr:451042 ptr00100
# 139 calcidiol 1-monooxygenase (25-hydroxyvitamin D3 1alpha-hydroxylase) [EC:1.14.15.18] ptr:452027 ptr00100
# 146 vitamin D3 24-hydroxylase [EC:1.14.15.16] ptr:746729 ptr00100
# 149 vitamin D3 24-hydroxylase [EC:1.14.15.16] ptr:746729 ptr00100
# 157 farnesyl-diphosphate farnesyltransferase [EC:2.5.1.21] ptr:740684 ptr00100
# 158 farnesyl-diphosphate farnesyltransferase [EC:2.5.1.21] ptr:740684 ptr00100
# 160 squalene monooxygenase [EC:1.14.14.17] ptr:464383 ptr00100
# 163 Delta24-sterol reductase [EC:1.3.1.72 1.3.1.-] ptr:456879 ptr00100
# 170 sterol 14alpha-demethylase [EC:1.14.14.154 1.14.15.36] ptr:463527 ptr00100
# 195 methylsterol monooxygenase [EC:1.14.18.9] ptr:738493 ptr00100
# 196 sterol-4alpha-carboxylate 3-dehydrogenase (decarboxylating) [EC:1.1.1.170] ptr:465960 ptr00100
# 197 17beta-estradiol 17-dehydrogenase / 3beta-hydroxysteroid 3-dehydrogenase [EC:1.1.1.62 1.1.1.270] ptr:466046 ptr00100
# 9 cholesterol 24-hydroxylase [EC:1.14.14.25] ptr:453154 ptr00120
# 14 25/26-hydroxycholesterol 7alpha-hydroxylase [EC:1.14.14.29] ptr:743817 ptr00120
# 15 cholesterol 7alpha-monooxygenase [EC:1.14.14.23] ptr:464191 ptr00120
# 16 25/26-hydroxycholesterol 7alpha-hydroxylase [EC:1.14.14.29] ptr:743817 ptr00120
# 24 3-oxo-5-beta-steroid 4-dehydrogenase [EC:1.3.1.3] ptr:472607 ptr00120
# 26 3alpha-hydroxysteroid 3-dehydrogenase / chlordecone reductase [EC:1.1.1.50 1.1.1.357 1.1.1.225] ptr:450274 ptr00120
# 28 cholestanetriol 26-monooxygenase [EC:1.14.15.15] ptr:459951 ptr00120
# 33 alpha-methylacyl-CoA racemase [EC:5.1.99.4] ptr:461953 ptr00120
# 35 3alpha,7alpha,12alpha-trihydroxy-5beta-cholestanoyl-CoA 24-hydroxylase [EC:1.17.99.3] ptr:460479 ptr00120
# 40 3alpha-hydroxysteroid 3-dehydrogenase / chlordecone reductase [EC:1.1.1.50 1.1.1.357 1.1.1.225] ptr:450274 ptr00120
# 47 cholesterol 25-hydroxylase [EC:1.14.99.38] ptr:450584 ptr00120
# 49 cholesterol 7alpha-monooxygenase [EC:1.14.14.23] ptr:464191 ptr00120
# 50 (3R)-3-hydroxyacyl-CoA dehydrogenase / 3a,7a,12a-trihydroxy-5b-cholest-24-enoyl-CoA hydratase / enoyl-CoA hydratase 2 [EC:1.1.1.- 4.2.1.107 4.2.1.119] ptr:462019 ptr00120
# 52 sterol carrier protein 2 [EC:2.3.1.176] ptr:456862 ptr00120
# 54 sterol carrier protein 2 [EC:2.3.1.176] ptr:456862 ptr00120
# 60 solute carrier family 27 (fatty acid transporter), member 5 [EC:6.2.1.7] ptr:456351 ptr00120
# 61 bile acid-CoA:amino acid N-acyltransferase [EC:2.3.1.65 3.1.2.2] ptr:472997 ptr00120
# 63 cholestanetriol 26-monooxygenase [EC:1.14.15.15] ptr:459951 ptr00120
# 64 cholestanetriol 26-monooxygenase [EC:1.14.15.15] ptr:459951 ptr00120
# 67 cholestanetriol 26-monooxygenase [EC:1.14.15.15] ptr:459951 ptr00120
# 68 cholest-5-ene-3beta,7alpha-diol 3beta-dehydrogenase [EC:1.1.1.181] ptr:454059 ptr00120
# 69 cholest-5-ene-3beta,7alpha-diol 3beta-dehydrogenase [EC:1.1.1.181] ptr:454059 ptr00120
# 70 cholest-5-ene-3beta,7alpha-diol 3beta-dehydrogenase [EC:1.1.1.181] ptr:454059 ptr00120
# 71 cholest-5-ene-3beta,7alpha-diol 3beta-dehydrogenase [EC:1.1.1.181] ptr:454059 ptr00120
# 73 bile acid-CoA:amino acid N-acyltransferase [EC:2.3.1.65 3.1.2.2] ptr:472997 ptr00120
# 81 solute carrier family 27 (fatty acid transporter), member 5 [EC:6.2.1.7] ptr:456351 ptr00120
# 82 bile acid-CoA:amino acid N-acyltransferase [EC:2.3.1.65 3.1.2.2] ptr:472997 ptr00120
# 86 bile acid-CoA:amino acid N-acyltransferase [EC:2.3.1.65 3.1.2.2] ptr:472997 ptr00120
# 90 sterol 12-alpha-hydroxylase [EC:1.14.18.8 1.14.14.139] ptr:736962 ptr00120
# 91 24-hydroxycholesterol 7alpha-hydroxylase [EC:1.14.14.26] ptr:462743 ptr00120
# 92 solute carrier family 27 (fatty acid transporter), member 5 [EC:6.2.1.7] ptr:456351 ptr00120
# 93 cholestanetriol 26-monooxygenase [EC:1.14.15.15] ptr:459951 ptr00120
# 94 cholestanetriol 26-monooxygenase [EC:1.14.15.15] ptr:459951 ptr00120
# 95 cholestanetriol 26-monooxygenase [EC:1.14.15.15] ptr:459951 ptr00120
# 96 alpha-methylacyl-CoA racemase [EC:5.1.99.4] ptr:461953 ptr00120
# 97 3alpha,7alpha,12alpha-trihydroxy-5beta-cholestanoyl-CoA 24-hydroxylase [EC:1.17.99.3] ptr:460479 ptr00120
# 98 (3R)-3-hydroxyacyl-CoA dehydrogenase / 3a,7a,12a-trihydroxy-5b-cholest-24-enoyl-CoA hydratase / enoyl-CoA hydratase 2 [EC:1.1.1.- 4.2.1.107 4.2.1.119] ptr:462019 ptr00120
# 99 solute carrier family 27 (fatty acid transporter), member 5 [EC:6.2.1.7] ptr:456351 ptr00120
# 106 3-oxo-5-beta-steroid 4-dehydrogenase [EC:1.3.1.3] ptr:472607 ptr00120
# 109 (3R)-3-hydroxyacyl-CoA dehydrogenase / 3a,7a,12a-trihydroxy-5b-cholest-24-enoyl-CoA hydratase / enoyl-CoA hydratase 2 [EC:1.1.1.- 4.2.1.107 4.2.1.119] ptr:462019 ptr00120
# 110 (3R)-3-hydroxyacyl-CoA dehydrogenase / 3a,7a,12a-trihydroxy-5b-cholest-24-enoyl-CoA hydratase / enoyl-CoA hydratase 2 [EC:1.1.1.- 4.2.1.107 4.2.1.119] ptr:462019 ptr00120
# 111 25/26-hydroxycholesterol 7alpha-hydroxylase [EC:1.14.14.29] ptr:743817 ptr00120
# 112 cholest-5-ene-3beta,7alpha-diol 3beta-dehydrogenase [EC:1.1.1.181] ptr:454059 ptr00120
# 170 acyl-CoA thioesterase 8 [EC:3.1.2.27] ptr:458288 ptr00120
# 172 acyl-CoA thioesterase 8 [EC:3.1.2.27] ptr:458288 ptr00120
# 174 sterol 12-alpha-hydroxylase [EC:1.14.18.8 1.14.14.139] ptr:736962 ptr00120
# 66 4-hydroxybenzoate polyprenyltransferase [EC:2.5.1.39] ptr:471210 ptr00130
# 68 polyprenyldihydroxybenzoate methyltransferase / 3-demethylubiquinol 3-O-methyltransferase [EC:2.1.1.114 2.1.1.64] ptr:472079 ptr00130
# 91 4-hydroxyphenylpyruvate dioxygenase [EC:1.13.11.27] ptr:473296 ptr00130
# 102 tyrosine aminotransferase [EC:2.6.1.5] ptr:454227 ptr00130
# 131 ubiquinone biosynthesis monooxygenase Coq6 [EC:1.14.13.-] ptr:740390 ptr00130
# 132 2-methoxy-6-polyprenyl-1,4-benzoquinol methylase [EC:2.1.1.201] ptr:452307 ptr00130
# 133 3-demethoxyubiquinol 3-hydroxylase [EC:1.14.99.60] ptr:740917 ptr00130
# 134 polyprenyldihydroxybenzoate methyltransferase / 3-demethylubiquinol 3-O-methyltransferase [EC:2.1.1.114 2.1.1.64] ptr:472079 ptr00130
# 165 vitamin K-dependent gamma-carboxylase [EC:4.1.1.90] ptr:459364 ptr00130
# 166 vitamin-K-epoxide reductase (warfarin-sensitive) [EC:1.17.4.4] ptr:100610370 ptr00130
# 167 NAD(P)H dehydrogenase (quinone) [EC:1.6.5.2] ptr:468012 ptr00130
# 170 NAD(P)H dehydrogenase (quinone) [EC:1.6.5.2] ptr:468012 ptr00130
# 173 vitamin K-dependent gamma-carboxylase [EC:4.1.1.90] ptr:459364 ptr00130
# 175 vitamin-K-epoxide reductase (warfarin-sensitive) [EC:1.17.4.4] ptr:100610370 ptr00130
# 15 17beta-estradiol 17-dehydrogenase [EC:1.1.1.62] ptr:100614183 ptr00140
# 188 steryl-sulfatase [EC:3.1.6.2] ptr:465478 ptr00140
# 189 alcohol sulfotransferase [EC:2.8.2.2] ptr:747360 ptr00140
# 190 cholesterol monooxygenase (side-chain-cleaving) [EC:1.14.15.6] ptr:748998 ptr00140
# 191 cholesterol monooxygenase (side-chain-cleaving) [EC:1.14.15.6] ptr:748998 ptr00140
# 192 cholesterol monooxygenase (side-chain-cleaving) [EC:1.14.15.6] ptr:748998 ptr00140
# 193 cholesterol monooxygenase (side-chain-cleaving) [EC:1.14.15.6] ptr:748998 ptr00140
# 194 cholesterol monooxygenase (side-chain-cleaving) [EC:1.14.15.6] ptr:748998 ptr00140
# 195 cholesterol monooxygenase (side-chain-cleaving) [EC:1.14.15.6] ptr:748998 ptr00140
# 197 steroid 17alpha-monooxygenase / 17alpha-hydroxyprogesterone deacetylase [EC:1.14.14.19 1.14.14.32] ptr:450141 ptr00140
# 198 steroid 21-monooxygenase [EC:1.14.14.16] ptr:745345 ptr00140
# 199 3beta-hydroxy-Delta5-steroid dehydrogenase / steroid Delta-isomerase [EC:1.1.1.145 5.3.3.1] ptr:457165 ptr00140
# 200 3beta-hydroxy-Delta5-steroid dehydrogenase / steroid Delta-isomerase [EC:1.1.1.145 5.3.3.1] ptr:457165 ptr00140
# 201 25/26-hydroxycholesterol 7alpha-hydroxylase [EC:1.14.14.29] ptr:743817 ptr00140
# 202 steryl-sulfatase [EC:3.1.6.2] ptr:465478 ptr00140
# 203 alcohol sulfotransferase [EC:2.8.2.2] ptr:747360 ptr00140
# 204 3beta-hydroxy-Delta5-steroid dehydrogenase / steroid Delta-isomerase [EC:1.1.1.145 5.3.3.1] ptr:457165 ptr00140
# 205 3beta-hydroxy-Delta5-steroid dehydrogenase / steroid Delta-isomerase [EC:1.1.1.145 5.3.3.1] ptr:457165 ptr00140
# 206 3beta-hydroxy-Delta5-steroid dehydrogenase / steroid Delta-isomerase [EC:1.1.1.145 5.3.3.1] ptr:457165 ptr00140
# 207 3beta-hydroxy-Delta5-steroid dehydrogenase / steroid Delta-isomerase [EC:1.1.1.145 5.3.3.1] ptr:457165 ptr00140
# 208 3beta-hydroxy-Delta5-steroid dehydrogenase / steroid Delta-isomerase [EC:1.1.1.145 5.3.3.1] ptr:457165 ptr00140
# 209 3beta-hydroxy-Delta5-steroid dehydrogenase / steroid Delta-isomerase [EC:1.1.1.145 5.3.3.1] ptr:457165 ptr00140
# 210 3beta-hydroxy-Delta5-steroid dehydrogenase / steroid Delta-isomerase [EC:1.1.1.145 5.3.3.1] ptr:457165 ptr00140
# 211 3beta-hydroxy-Delta5-steroid dehydrogenase / steroid Delta-isomerase [EC:1.1.1.145 5.3.3.1] ptr:457165 ptr00140
# 212 steroid 11beta-monooxygenase [EC:1.14.15.4] ptr:464437 ptr00140
# 213 steroid 17alpha-monooxygenase / 17alpha-hydroxyprogesterone deacetylase [EC:1.14.14.19 1.14.14.32] ptr:450141 ptr00140
# 214 alcohol sulfotransferase [EC:2.8.2.2] ptr:747360 ptr00140
# 215 steryl-sulfatase [EC:3.1.6.2] ptr:465478 ptr00140
# 216 cytochrome P450 family 1 subfamily A polypeptide 1 [EC:1.14.14.1] ptr:453744 ptr00140
# 217 aldo-keto reductase family 1 member C3 [EC:1.1.1.51 1.1.1.188 1.1.1.213 1.1.1.357] ptr:100612718 ptr00140
# 218 3beta-hydroxy-Delta5-steroid dehydrogenase / steroid Delta-isomerase [EC:1.1.1.145 5.3.3.1] ptr:457165 ptr00140
# 219 3beta-hydroxy-Delta5-steroid dehydrogenase / steroid Delta-isomerase [EC:1.1.1.145 5.3.3.1] ptr:457165 ptr00140
# 220 3beta-hydroxy-Delta5-steroid dehydrogenase / steroid Delta-isomerase [EC:1.1.1.145 5.3.3.1] ptr:457165 ptr00140
# 221 3beta-hydroxy-Delta5-steroid dehydrogenase / steroid Delta-isomerase [EC:1.1.1.145 5.3.3.1] ptr:457165 ptr00140
# 222 steroid 21-monooxygenase [EC:1.14.14.16] ptr:745345 ptr00140
# 223 3beta-hydroxy-Delta5-steroid dehydrogenase / steroid Delta-isomerase [EC:1.1.1.145 5.3.3.1] ptr:457165 ptr00140
# 224 3beta-hydroxy-Delta5-steroid dehydrogenase / steroid Delta-isomerase [EC:1.1.1.145 5.3.3.1] ptr:457165 ptr00140
# 225 steroid 17alpha-monooxygenase / 17alpha-hydroxyprogesterone deacetylase [EC:1.14.14.19 1.14.14.32] ptr:450141 ptr00140
# 226 3-oxo-5-alpha-steroid 4-dehydrogenase 2 [EC:1.3.1.22] ptr:100614992 ptr00140
# 227 3alpha-hydroxysteroid 3-dehydrogenase [EC:1.1.1.213 1.1.1.357] ptr:100612191 ptr00140
# 229 3-oxo-5-beta-steroid 4-dehydrogenase [EC:1.3.1.3] ptr:472607 ptr00140
# 230 3alpha-hydroxysteroid 3-dehydrogenase / chlordecone reductase [EC:1.1.1.50 1.1.1.357 1.1.1.225] ptr:450274 ptr00140
# 231 steroid 11beta-monooxygenase [EC:1.14.15.4] ptr:464437 ptr00140
# 232 steroid 21-monooxygenase [EC:1.14.14.16] ptr:745345 ptr00140
# 234 20alpha/3alpha-hydroxysteroid dehydrogenase / dihydrodiol dehydrogenase [EC:1.1.1.149 1.1.1.357 1.3.1.20] ptr:100607996 ptr00140
# 235 corticosteroid 11-beta-dehydrogenase isozyme 1 [EC:1.1.1.146] ptr:457698 ptr00140
# 236 corticosteroid 11-beta-dehydrogenase isozyme 2 [EC:1.1.1.-] ptr:468001 ptr00140
# 237 3alpha-hydroxysteroid 3-dehydrogenase / chlordecone reductase [EC:1.1.1.50 1.1.1.357 1.1.1.225] ptr:450274 ptr00140
# 238 corticosteroid 11-beta-dehydrogenase isozyme 1 [EC:1.1.1.146] ptr:457698 ptr00140
# 240 steroid 11beta-monooxygenase [EC:1.14.15.4] ptr:464437 ptr00140
# 241 steroid 21-monooxygenase [EC:1.14.14.16] ptr:745345 ptr00140
# 242 3-oxo-5-beta-steroid 4-dehydrogenase [EC:1.3.1.3] ptr:472607 ptr00140
# 244 3-oxo-5-alpha-steroid 4-dehydrogenase 2 [EC:1.3.1.22] ptr:100614992 ptr00140
# 245 3alpha-hydroxysteroid 3-dehydrogenase / chlordecone reductase [EC:1.1.1.50 1.1.1.357 1.1.1.225] ptr:450274 ptr00140
# 247 3alpha-hydroxysteroid 3-dehydrogenase [EC:1.1.1.213 1.1.1.357] ptr:100612191 ptr00140
# 248 20alpha/3alpha-hydroxysteroid dehydrogenase / dihydrodiol dehydrogenase [EC:1.1.1.149 1.1.1.357 1.3.1.20] ptr:100607996 ptr00140
# 249 20alpha/3alpha-hydroxysteroid dehydrogenase / dihydrodiol dehydrogenase [EC:1.1.1.149 1.1.1.357 1.3.1.20] ptr:100607996 ptr00140
# 250 3alpha-hydroxysteroid 3-dehydrogenase [EC:1.1.1.213 1.1.1.357] ptr:100612191 ptr00140
# 251 steroid 17alpha-monooxygenase / 17alpha-hydroxyprogesterone deacetylase [EC:1.14.14.19 1.14.14.32] ptr:450141 ptr00140
# 252 steroid 11beta-monooxygenase [EC:1.14.15.4] ptr:464437 ptr00140
# 253 steroid 21-monooxygenase [EC:1.14.14.16] ptr:745345 ptr00140
# 254 steroid 21-monooxygenase [EC:1.14.14.16] ptr:745345 ptr00140
# 255 17beta-estradiol 17-dehydrogenase [EC:1.1.1.62] ptr:100614183 ptr00140
# 256 3-oxo-5-beta-steroid 4-dehydrogenase [EC:1.3.1.3] ptr:472607 ptr00140
# 257 3alpha-hydroxysteroid 3-dehydrogenase / chlordecone reductase [EC:1.1.1.50 1.1.1.357 1.1.1.225] ptr:450274 ptr00140
# 259 steroid 11beta-monooxygenase [EC:1.14.15.4] ptr:464437 ptr00140
# 260 3-oxo-5-beta-steroid 4-dehydrogenase [EC:1.3.1.3] ptr:472607 ptr00140
# 261 3alpha-hydroxysteroid 3-dehydrogenase / chlordecone reductase [EC:1.1.1.50 1.1.1.357 1.1.1.225] ptr:450274 ptr00140
# 263 steroid 17alpha-monooxygenase / 17alpha-hydroxyprogesterone deacetylase [EC:1.14.14.19 1.14.14.32] ptr:450141 ptr00140
# 264 corticosteroid 11-beta-dehydrogenase isozyme 1 [EC:1.1.1.146] ptr:457698 ptr00140
# 265 corticosteroid 11-beta-dehydrogenase isozyme 2 [EC:1.1.1.-] ptr:468001 ptr00140
# 266 steroid 17alpha-monooxygenase / 17alpha-hydroxyprogesterone deacetylase [EC:1.14.14.19 1.14.14.32] ptr:450141 ptr00140
# 267 aldo-keto reductase family 1 member C3 [EC:1.1.1.51 1.1.1.188 1.1.1.213 1.1.1.357] ptr:100612718 ptr00140
# 268 testosterone 17beta-dehydrogenase (NADP+) [EC:1.1.1.64] ptr:742116 ptr00140
# 269 17beta-estradiol 17-dehydrogenase / all-trans-retinol dehydrogenase (NAD+) / 3alpha(17beta)-hydroxysteroid dehydrogenase (NAD+) [EC:1.1.1.62 1.1.1.105 1.1.1.239] ptr:452001 ptr00140
# 270 steroid 11beta-monooxygenase [EC:1.14.15.4] ptr:464437 ptr00140
# 271 corticosteroid 11-beta-dehydrogenase isozyme 1 [EC:1.1.1.146] ptr:457698 ptr00140
# 272 3alpha-hydroxysteroid 3-dehydrogenase / chlordecone reductase [EC:1.1.1.50 1.1.1.357 1.1.1.225] ptr:450274 ptr00140
# 273 3-oxo-5-beta-steroid 4-dehydrogenase [EC:1.3.1.3] ptr:472607 ptr00140
# 275 glucuronosyltransferase [EC:2.4.1.17] ptr:100611992 ptr00140
# 276 3-oxo-5-alpha-steroid 4-dehydrogenase 2 [EC:1.3.1.22] ptr:100614992 ptr00140
# 277 3alpha-hydroxysteroid 3-dehydrogenase / chlordecone reductase [EC:1.1.1.50 1.1.1.357 1.1.1.225] ptr:450274 ptr00140
# 278 glucuronosyltransferase [EC:2.4.1.17] ptr:100611992 ptr00140
# 279 aromatase [EC:1.14.14.14] ptr:453433 ptr00140
# 280 cytochrome P450 family 3 subfamily A polypeptide 5 [EC:1.14.14.1] ptr:737374 ptr00140
# 282 aromatase [EC:1.14.14.14] ptr:453433 ptr00140
# 283 cytochrome P450 family 1 subfamily A polypeptide 1 [EC:1.14.14.1] ptr:453744 ptr00140
# 284 glucuronosyltransferase [EC:2.4.1.17] ptr:100611992 ptr00140
# 285 17beta-estradiol 17-dehydrogenase [EC:1.1.1.62] ptr:100614183 ptr00140
# 286 3-oxo-5-alpha-steroid 4-dehydrogenase 2 [EC:1.3.1.22] ptr:100614992 ptr00140
# 287 3alpha-hydroxysteroid 3-dehydrogenase / chlordecone reductase [EC:1.1.1.50 1.1.1.357 1.1.1.225] ptr:450274 ptr00140
# 288 3-oxo-5-beta-steroid 4-dehydrogenase [EC:1.3.1.3] ptr:472607 ptr00140
# 289 glucuronosyltransferase [EC:2.4.1.17] ptr:100611992 ptr00140
# 290 glucuronosyltransferase [EC:2.4.1.17] ptr:100611992 ptr00140
# 292 cytochrome P450 family 1 subfamily A polypeptide 1 [EC:1.14.14.1] ptr:453744 ptr00140
# 293 catechol O-methyltransferase [EC:2.1.1.6] ptr:458655 ptr00140
# 294 glucuronosyltransferase [EC:2.4.1.17] ptr:100611992 ptr00140
# 296 glucuronosyltransferase [EC:2.4.1.17] ptr:100611992 ptr00140
# 298 catechol O-methyltransferase [EC:2.1.1.6] ptr:458655 ptr00140
# 299 cytochrome P450 family 1 subfamily B polypeptide 1 [EC:1.14.14.1] ptr:459163 ptr00140
# 300 estrone sulfotransferase [EC:2.8.2.4] ptr:461284 ptr00140
# 303 aldo-keto reductase family 1 member C3 [EC:1.1.1.51 1.1.1.188 1.1.1.213 1.1.1.357] ptr:100612718 ptr00140
# 305 glucuronosyltransferase [EC:2.4.1.17] ptr:100611992 ptr00140
# 315 3alpha-hydroxysteroid 3-dehydrogenase / chlordecone reductase [EC:1.1.1.50 1.1.1.357 1.1.1.225] ptr:450274 ptr00140
# 318 20alpha/3alpha-hydroxysteroid dehydrogenase / dihydrodiol dehydrogenase [EC:1.1.1.149 1.1.1.357 1.3.1.20] ptr:100607996 ptr00140
# 322 cholesterol 7alpha-monooxygenase [EC:1.14.14.23] ptr:464191 ptr00140
# 350 aromatase [EC:1.14.14.14] ptr:453433 ptr00140
# 351 aromatase [EC:1.14.14.14] ptr:453433 ptr00140
# 352 aromatase [EC:1.14.14.14] ptr:453433 ptr00140
# 353 aromatase [EC:1.14.14.14] ptr:453433 ptr00140
# 354 cytochrome P450 family 2 subfamily E polypeptide 1 [EC:1.14.13.-] ptr:450857 ptr00140
# 355 cytochrome P450 family 3 subfamily A polypeptide 4 [EC:1.14.13.32 1.14.14.55 1.14.14.56 1.14.14.57 1.14.14.73 1.14.13.-] ptr:463582 ptr00140
# 2 cytochrome c oxidase subunit 4 ptr:454391 ptr00190
# 15 NADH dehydrogenase (ubiquinone) 1 subunit C2 ptr:451445 ptr00190
# 16 NADH dehydrogenase (ubiquinone) 1 subunit C1 ptr:461494 ptr00190
# 17 NADH dehydrogenase (ubiquinone) 1 beta subcomplex subunit 10 ptr:746648 ptr00190
# 18 NADH dehydrogenase (ubiquinone) 1 beta subcomplex subunit 9 ptr:464380 ptr00190
# 19 NADH dehydrogenase (ubiquinone) 1 beta subcomplex subunit 8 ptr:744716 ptr00190
# 20 NADH dehydrogenase (ubiquinone) 1 beta subcomplex subunit 7 ptr:468748 ptr00190
# 21 NADH dehydrogenase (ubiquinone) 1 beta subcomplex subunit 6 ptr:100611615 ptr00190
# 22 NADH dehydrogenase (ubiquinone) 1 beta subcomplex subunit 5 ptr:471008 ptr00190
# 23 NADH dehydrogenase (ubiquinone) 1 beta subcomplex subunit 4 ptr:460612 ptr00190
# 24 NADH dehydrogenase (ubiquinone) 1 beta subcomplex subunit 3 ptr:107968313 ptr00190
# 25 NADH dehydrogenase (ubiquinone) 1 beta subcomplex subunit 2 ptr:463780 ptr00190
# 26 NADH dehydrogenase (ubiquinone) 1 beta subcomplex subunit 1 ptr:453115 ptr00190
# 27 NADH dehydrogenase (ubiquinone) 1 alpha subcomplex subunit 11 ptr:739803 ptr00190
# 28 NADH dehydrogenase (ubiquinone) 1 alpha/beta subcomplex 1, acyl-carrier protein ptr:744435 ptr00190
# ...
# 168 tRNA Leu ptr:tRNA-Leu-1 ptr00970
# 169 tRNA Ile ptr:tRNA-Ile ptr00970
# 170 tRNA Lys ptr:tRNA-Lys ptr00970
# 172 tRNA Arg ptr:tRNA-Arg ptr00970
# 173 tRNA Pro ptr:tRNA-Pro ptr00970
# 174 tRNA His ptr:tRNA-His ptr00970
# 175 tRNA Phe ptr:tRNA-Phe ptr00970
# 176 tRNA Tyr ptr:tRNA-Tyr ptr00970
# 177 tRNA Trp ptr:tRNA-Trp ptr00970
# 38 cytochrome P450 family 2 subfamily E polypeptide 1 [EC:1.14.13.-] ptr:450857 ptr00980
# 39 cytochrome P450 family 2 subfamily E polypeptide 1 [EC:1.14.13.-] ptr:450857 ptr00980
# 40 cytochrome P450 family 2 subfamily E polypeptide 1 [EC:1.14.13.-] ptr:450857 ptr00980
# 41 cytochrome P450 family 2 subfamily E polypeptide 1 [EC:1.14.13.-] ptr:450857 ptr00980
# 42 cytochrome P450 family 2 subfamily E polypeptide 1 [EC:1.14.13.-] ptr:450857 ptr00980
# 72 glutathione S-transferase [EC:2.5.1.18] ptr:100611543 ptr00980
# 73 glutathione S-transferase [EC:2.5.1.18] ptr:100611543 ptr00980
# 74 cytochrome P450 family 2 subfamily E polypeptide 1 [EC:1.14.13.-] ptr:450857 ptr00980
# 75 glucuronosyltransferase [EC:2.4.1.17] ptr:100611992 ptr00980
# 76 aldehyde dehydrogenase (NAD(P)+) [EC:1.2.1.5] ptr:453686 ptr00980
# 77 alcohol dehydrogenase 4 [EC:1.1.1.1] ptr:461394 ptr00980
# 78 glutathione S-transferase [EC:2.5.1.18] ptr:100611543 ptr00980
# 79 glutathione S-transferase [EC:2.5.1.18] ptr:100611543 ptr00980
# 80 glutathione S-transferase [EC:2.5.1.18] ptr:100611543 ptr00980
# 81 microsomal epoxide hydrolase [EC:3.3.2.9] ptr:457777 ptr00980
# 82 glutathione S-transferase [EC:2.5.1.18] ptr:100611543 ptr00980
# 90 glutathione S-transferase [EC:2.5.1.18] ptr:100611543 ptr00980
# 92 glutathione S-transferase [EC:2.5.1.18] ptr:100611543 ptr00980
# 93 glutathione S-transferase [EC:2.5.1.18] ptr:100611543 ptr00980
# 104 cytochrome P450 family 1 subfamily A polypeptide 1 [EC:1.14.14.1] ptr:453744 ptr00980
# 106 glutathione S-transferase [EC:2.5.1.18] ptr:100611543 ptr00980
# 115 microsomal epoxide hydrolase [EC:3.3.2.9] ptr:457777 ptr00980
# 116 glutathione S-transferase [EC:2.5.1.18] ptr:100611543 ptr00980
# 124 cytochrome P450 family 1 subfamily A polypeptide 2 [EC:1.14.14.1] ptr:735881 ptr00980
# 126 microsomal epoxide hydrolase [EC:3.3.2.9] ptr:457777 ptr00980
# 129 cytochrome P450 family 3 subfamily A polypeptide 4 [EC:1.14.13.32 1.14.14.55 1.14.14.56 1.14.14.57 1.14.14.73 1.14.13.-] ptr:463582 ptr00980
# 131 cytochrome P450 family 1 subfamily A polypeptide 2 [EC:1.14.14.1] ptr:735881 ptr00980
# 137 aflatoxin B1 aldehyde reductase ptr:100615181 ptr00980
# 144 glutathione S-transferase [EC:2.5.1.18] ptr:100611543 ptr00980
# 149 aflatoxin B1 aldehyde reductase ptr:100615181 ptr00980
# 154 cytochrome P450 family 1 subfamily A polypeptide 2 [EC:1.14.14.1] ptr:735881 ptr00980
# 162 cytochrome P450 family 1 subfamily A polypeptide 1 [EC:1.14.14.1] ptr:453744 ptr00980
# 163 cytochrome P450 family 1 subfamily A polypeptide 1 [EC:1.14.14.1] ptr:453744 ptr00980
# 164 cytochrome P450 family 1 subfamily A polypeptide 1 [EC:1.14.14.1] ptr:453744 ptr00980
# 175 glutathione S-transferase [EC:2.5.1.18] ptr:100611543 ptr00980
# 176 glutathione S-transferase [EC:2.5.1.18] ptr:100611543 ptr00980
# 177 microsomal epoxide hydrolase [EC:3.3.2.9] ptr:457777 ptr00980
# 183 cytochrome P450 family 1 subfamily B polypeptide 1 [EC:1.14.14.1] ptr:459163 ptr00980
# 186 microsomal epoxide hydrolase [EC:3.3.2.9] ptr:457777 ptr00980
# 189 bile-salt sulfotransferase [EC:2.8.2.14] ptr:456409 ptr00980
# 199 microsomal epoxide hydrolase [EC:3.3.2.9] ptr:457777 ptr00980
# 201 cytochrome P450 family 2 subfamily B polypeptide 6 [EC:1.14.13.-] ptr:104003379 ptr00980
# 202 cytochrome P450 family 1 subfamily A polypeptide 1 [EC:1.14.14.1] ptr:453744 ptr00980
# 203 cytochrome P450 family 1 subfamily A polypeptide 1 [EC:1.14.14.1] ptr:453744 ptr00980
# 230 microsomal epoxide hydrolase [EC:3.3.2.9] ptr:457777 ptr00980
# 231 glutathione S-transferase [EC:2.5.1.18] ptr:100611543 ptr00980
# 232 glutathione S-transferase [EC:2.5.1.18] ptr:100611543 ptr00980
# 237 20alpha/3alpha-hydroxysteroid dehydrogenase / dihydrodiol dehydrogenase [EC:1.1.1.149 1.1.1.357 1.3.1.20] ptr:100607996 ptr00980
# 238 cytochrome P450 family 1 subfamily A polypeptide 1 [EC:1.14.14.1] ptr:453744 ptr00980
# 264 corticosteroid 11-beta-dehydrogenase isozyme 1 [EC:1.1.1.146] ptr:457698 ptr00980
# 280 20alpha/3alpha-hydroxysteroid dehydrogenase / dihydrodiol dehydrogenase [EC:1.1.1.149 1.1.1.357 1.3.1.20] ptr:100607996 ptr00980
# 281 carbonyl reductase 3 [EC:1.1.1.184] ptr:458533 ptr00980
# 291 glucuronosyltransferase [EC:2.4.1.17] ptr:100611992 ptr00980
# 296 cytochrome P450 family 1 subfamily A polypeptide 1 [EC:1.14.14.1] ptr:453744 ptr00980
# 301 cytochrome P450 family 2 subfamily E polypeptide 1 [EC:1.14.13.-] ptr:450857 ptr00980
# 302 cytochrome P450 family 2 subfamily E polypeptide 1 [EC:1.14.13.-] ptr:450857 ptr00980
# 307 cytochrome P450 family 2 subfamily E polypeptide 1 [EC:1.14.13.-] ptr:450857 ptr00980
# 309 cytochrome P450 family 3 subfamily A polypeptide 4 [EC:1.14.13.32 1.14.14.55 1.14.14.56 1.14.14.57 1.14.14.73 1.14.13.-] ptr:463582 ptr00980
# 313 cytochrome P450 family 2 subfamily D polypeptide 6 [EC:1.14.14.1] ptr:470228 ptr00980
# 314 cytochrome P450 family 2 subfamily E polypeptide 1 [EC:1.14.13.-] ptr:450857 ptr00980
# 316 cytochrome P450 family 3 subfamily A polypeptide 4 [EC:1.14.13.32 1.14.14.55 1.14.14.56 1.14.14.57 1.14.14.73 1.14.13.-] ptr:463582 ptr00980
# 320 cytochrome P450 family 2 subfamily C polypeptide 9 [EC:1.14.14.51 1.14.14.52 1.14.14.53 1.14.14.-] ptr:100616515 ptr00980
# 321 cytochrome P450 family 3 subfamily A polypeptide 4 [EC:1.14.13.32 1.14.14.55 1.14.14.56 1.14.14.57 1.14.14.73 1.14.13.-] ptr:463582 ptr00980
# 322 cytochrome P450 family 1 subfamily B polypeptide 1 [EC:1.14.14.1] ptr:459163 ptr00980
# 323 cytochrome P450 family 2 subfamily C polypeptide 9 [EC:1.14.14.51 1.14.14.52 1.14.14.53 1.14.14.-] ptr:100616515 ptr00980
# 324 cytochrome P450 family 2 subfamily C polypeptide 9 [EC:1.14.14.51 1.14.14.52 1.14.14.53 1.14.14.-] ptr:100616515 ptr00980
# 325 cytochrome P450 family 3 subfamily A polypeptide 4 [EC:1.14.13.32 1.14.14.55 1.14.14.56 1.14.14.57 1.14.14.73 1.14.13.-] ptr:463582 ptr00980
# 326 cytochrome P450 family 1 subfamily B polypeptide 1 [EC:1.14.14.1] ptr:459163 ptr00980
# 327 cytochrome P450 family 3 subfamily A polypeptide 4 [EC:1.14.13.32 1.14.14.55 1.14.14.56 1.14.14.57 1.14.14.73 1.14.13.-] ptr:463582 ptr00980
# 328 cytochrome P450 family 1 subfamily B polypeptide 1 [EC:1.14.14.1] ptr:459163 ptr00980
# 329 cytochrome P450 family 3 subfamily A polypeptide 4 [EC:1.14.13.32 1.14.14.55 1.14.14.56 1.14.14.57 1.14.14.73 1.14.13.-] ptr:463582 ptr00980
# 330 cytochrome P450 family 2 subfamily B polypeptide 6 [EC:1.14.13.-] ptr:104003379 ptr00980
# 331 cytochrome P450 family 1 subfamily A polypeptide 1 [EC:1.14.14.1] ptr:453744 ptr00980
# 332 cytochrome P450 family 1 subfamily A polypeptide 1 [EC:1.14.14.1] ptr:453744 ptr00980
# 333 cytochrome P450 family 2 subfamily E polypeptide 1 [EC:1.14.13.-] ptr:450857 ptr00980
# 56 aldehyde dehydrogenase (NAD(P)+) [EC:1.2.1.5] ptr:453686 ptr00982
# 84 dimethylaniline monooxygenase (N-oxide forming) [EC:1.14.13.8] ptr:449587 ptr00982
# 85 cytochrome P450 family 3 subfamily A polypeptide 4 [EC:1.14.13.32 1.14.14.55 1.14.14.56 1.14.14.57 1.14.14.73 1.14.13.-] ptr:463582 ptr00982
# 86 cytochrome P450 family 3 subfamily A polypeptide 4 [EC:1.14.13.32 1.14.14.55 1.14.14.56 1.14.14.57 1.14.14.73 1.14.13.-] ptr:463582 ptr00982
# 88 cytochrome P450 family 3 subfamily A polypeptide 4 [EC:1.14.13.32 1.14.14.55 1.14.14.56 1.14.14.57 1.14.14.73 1.14.13.-] ptr:463582 ptr00982
# 89 cytochrome P450 family 3 subfamily A polypeptide 4 [EC:1.14.13.32 1.14.14.55 1.14.14.56 1.14.14.57 1.14.14.73 1.14.13.-] ptr:463582 ptr00982
# 91 cytochrome P450 family 2 subfamily D polypeptide 6 [EC:1.14.14.1] ptr:470228 ptr00982
# 93 cytochrome P450 family 2 subfamily D polypeptide 6 [EC:1.14.14.1] ptr:470228 ptr00982
# 95 cytochrome P450 family 3 subfamily A polypeptide 4 [EC:1.14.13.32 1.14.14.55 1.14.14.56 1.14.14.57 1.14.14.73 1.14.13.-] ptr:463582 ptr00982
# 97 cytochrome P450 family 3 subfamily A polypeptide 4 [EC:1.14.13.32 1.14.14.55 1.14.14.56 1.14.14.57 1.14.14.73 1.14.13.-] ptr:463582 ptr00982
# 98 cytochrome P450 family 3 subfamily A polypeptide 4 [EC:1.14.13.32 1.14.14.55 1.14.14.56 1.14.14.57 1.14.14.73 1.14.13.-] ptr:463582 ptr00982
# 99 cytochrome P450 family 1 subfamily A polypeptide 2 [EC:1.14.14.1] ptr:735881 ptr00982
# 100 cytochrome P450 family 1 subfamily A polypeptide 2 [EC:1.14.14.1] ptr:735881 ptr00982
# 103 cytochrome P450 family 3 subfamily A polypeptide 4 [EC:1.14.13.32 1.14.14.55 1.14.14.56 1.14.14.57 1.14.14.73 1.14.13.-] ptr:463582 ptr00982
# 104 cytochrome P450 family 3 subfamily A polypeptide 4 [EC:1.14.13.32 1.14.14.55 1.14.14.56 1.14.14.57 1.14.14.73 1.14.13.-] ptr:463582 ptr00982
# 105 cytochrome P450 family 3 subfamily A polypeptide 4 [EC:1.14.13.32 1.14.14.55 1.14.14.56 1.14.14.57 1.14.14.73 1.14.13.-] ptr:463582 ptr00982
# 106 cytochrome P450 family 3 subfamily A polypeptide 4 [EC:1.14.13.32 1.14.14.55 1.14.14.56 1.14.14.57 1.14.14.73 1.14.13.-] ptr:463582 ptr00982
# 107 cytochrome P450 family 3 subfamily A polypeptide 4 [EC:1.14.13.32 1.14.14.55 1.14.14.56 1.14.14.57 1.14.14.73 1.14.13.-] ptr:463582 ptr00982
# 108 cytochrome P450 family 2 subfamily B polypeptide 6 [EC:1.14.13.-] ptr:104003379 ptr00982
# 109 cytochrome P450 family 2 subfamily C polypeptide 9 [EC:1.14.14.51 1.14.14.52 1.14.14.53 1.14.14.-] ptr:100616515 ptr00982
# 110 cytochrome P450 family 2 subfamily B polypeptide 6 [EC:1.14.13.-] ptr:104003379 ptr00982
# 111 glutathione S-transferase [EC:2.5.1.18] ptr:100611543 ptr00982
# 112 alcohol dehydrogenase 4 [EC:1.1.1.1] ptr:461394 ptr00982
# 140 cytochrome P450 family 2 subfamily D polypeptide 6 [EC:1.14.14.1] ptr:470228 ptr00982
# 141 glucuronosyltransferase [EC:2.4.1.17] ptr:100611992 ptr00982
# 142 glucuronosyltransferase [EC:2.4.1.17] ptr:100611992 ptr00982
# 153 cytochrome P450 family 2 subfamily B polypeptide 6 [EC:1.14.13.-] ptr:104003379 ptr00982
# 154 cytochrome P450 family 2 subfamily C polypeptide 9 [EC:1.14.14.51 1.14.14.52 1.14.14.53 1.14.14.-] ptr:100616515 ptr00982
# 168 cytochrome P450 family 3 subfamily A polypeptide 4 [EC:1.14.13.32 1.14.14.55 1.14.14.56 1.14.14.57 1.14.14.73 1.14.13.-] ptr:463582 ptr00982
# 169 cytochrome P450 family 3 subfamily A polypeptide 4 [EC:1.14.13.32 1.14.14.55 1.14.14.56 1.14.14.57 1.14.14.73 1.14.13.-] ptr:463582 ptr00982
# 185 cytochrome P450 family 3 subfamily A polypeptide 4 [EC:1.14.13.32 1.14.14.55 1.14.14.56 1.14.14.57 1.14.14.73 1.14.13.-] ptr:463582 ptr00982
# 186 cytochrome P450 family 3 subfamily A polypeptide 4 [EC:1.14.13.32 1.14.14.55 1.14.14.56 1.14.14.57 1.14.14.73 1.14.13.-] ptr:463582 ptr00982
# 187 cytochrome P450 family 2 subfamily D polypeptide 6 [EC:1.14.14.1] ptr:470228 ptr00982
# 188 cytochrome P450 family 2 subfamily C polypeptide 19 [EC:1.14.14.51 1.14.14.52 1.14.14.53 1.14.14.75 1.14.14.-] ptr:740956 ptr00982
# 189 monoamine oxidase [EC:1.4.3.4] ptr:465588 ptr00982
# 190 monoamine oxidase [EC:1.4.3.4] ptr:465588 ptr00982
# 191 monoamine oxidase [EC:1.4.3.4] ptr:465588 ptr00982
# 192 aldehyde oxidase [EC:1.2.3.1] ptr:459863 ptr00982
# 197 cytochrome P450 family 3 subfamily A polypeptide 4 [EC:1.14.13.32 1.14.14.55 1.14.14.56 1.14.14.57 1.14.14.73 1.14.13.-] ptr:463582 ptr00982
# 198 cytochrome P450 family 3 subfamily A polypeptide 4 [EC:1.14.13.32 1.14.14.55 1.14.14.56 1.14.14.57 1.14.14.73 1.14.13.-] ptr:463582 ptr00982
# 199 cytochrome P450 family 2 subfamily E polypeptide 1 [EC:1.14.13.-] ptr:450857 ptr00982
# 200 cytochrome P450 family 2 subfamily E polypeptide 1 [EC:1.14.13.-] ptr:450857 ptr00982
# 201 alcohol dehydrogenase 4 [EC:1.1.1.1] ptr:461394 ptr00982
# 202 alcohol dehydrogenase 4 [EC:1.1.1.1] ptr:461394 ptr00982
# 203 aldehyde dehydrogenase (NAD(P)+) [EC:1.2.1.5] ptr:453686 ptr00982
# 204 cytochrome P450 family 3 subfamily A polypeptide 4 [EC:1.14.13.32 1.14.14.55 1.14.14.56 1.14.14.57 1.14.14.73 1.14.13.-] ptr:463582 ptr00982
# 207 glucuronosyltransferase [EC:2.4.1.17] ptr:100611992 ptr00982
# 209 cytochrome P450 family 2 subfamily C polypeptide 9 [EC:1.14.14.51 1.14.14.52 1.14.14.53 1.14.14.-] ptr:100616515 ptr00982
# 214 cytochrome P450 family 3 subfamily A polypeptide 4 [EC:1.14.13.32 1.14.14.55 1.14.14.56 1.14.14.57 1.14.14.73 1.14.13.-] ptr:463582 ptr00982
# 215 cytochrome P450 family 3 subfamily A polypeptide 4 [EC:1.14.13.32 1.14.14.55 1.14.14.56 1.14.14.57 1.14.14.73 1.14.13.-] ptr:463582 ptr00982
# 217 cytochrome P450 family 2 subfamily B polypeptide 6 [EC:1.14.13.-] ptr:104003379 ptr00982
# 218 cytochrome P450 family 2 subfamily C polypeptide 8 [EC:1.14.14.1] ptr:450909 ptr00982
# 234 cytochrome P450 family 3 subfamily A polypeptide 4 [EC:1.14.13.32 1.14.14.55 1.14.14.56 1.14.14.57 1.14.14.73 1.14.13.-] ptr:463582 ptr00982
# 236 cytochrome P450 family 3 subfamily A polypeptide 4 [EC:1.14.13.32 1.14.14.55 1.14.14.56 1.14.14.57 1.14.14.73 1.14.13.-] ptr:463582 ptr00982
# 237 cytochrome P450 family 2 subfamily D polypeptide 6 [EC:1.14.14.1] ptr:470228 ptr00982
# 241 cytochrome P450 family 2 subfamily D polypeptide 6 [EC:1.14.14.1] ptr:470228 ptr00982
# 247 cytochrome P450 family 3 subfamily A polypeptide 5 [EC:1.14.14.1] ptr:737374 ptr00982
# 248 cytochrome P450 family 2 subfamily B polypeptide 6 [EC:1.14.13.-] ptr:104003379 ptr00982
# 249 cytochrome P450 family 2 subfamily C polypeptide 9 [EC:1.14.14.51 1.14.14.52 1.14.14.53 1.14.14.-] ptr:100616515 ptr00982
# 69 thiopurine S-methyltransferase [EC:2.1.1.67] ptr:471863 ptr00983
# 70 thiopurine S-methyltransferase [EC:2.1.1.67] ptr:471863 ptr00983
# 71 thiopurine S-methyltransferase [EC:2.1.1.67] ptr:471863 ptr00983
# 72 hypoxanthine phosphoribosyltransferase [EC:2.4.2.8] ptr:735894 ptr00983
# 73 hypoxanthine phosphoribosyltransferase [EC:2.4.2.8] ptr:735894 ptr00983
# 74 hypoxanthine phosphoribosyltransferase [EC:2.4.2.8] ptr:735894 ptr00983
# 75 GMP synthase (glutamine-hydrolysing) [EC:6.3.5.2] ptr:460797 ptr00983
# 76 inosine triphosphate pyrophosphatase [EC:3.6.1.-] ptr:746982 ptr00983
# 77 xanthine dehydrogenase/oxidase [EC:1.17.1.4 1.17.3.2] ptr:470347 ptr00983
# 78 arylamine N-acetyltransferase [EC:2.3.1.5] ptr:464023 ptr00983
# 79 arylamine N-acetyltransferase [EC:2.3.1.5] ptr:464023 ptr00983
# 83 uridine phosphorylase [EC:2.4.2.3] ptr:470566 ptr00983
# 84 thymidine phosphorylase [EC:2.4.2.4] ptr:458941 ptr00983
# 85 dihydropyrimidine dehydrogenase (NADP+) [EC:1.3.1.2] ptr:457047 ptr00983
# 86 dihydropyrimidinase [EC:3.5.2.2] ptr:464330 ptr00983
# 87 beta-ureidopropionase [EC:3.5.1.6] ptr:747532 ptr00983
# 88 uridine monophosphate synthetase [EC:2.4.2.10 4.1.1.23] ptr:460644 ptr00983
# 89 uridine kinase [EC:2.7.1.48] ptr:458424 ptr00983
# 90 thymidine kinase [EC:2.7.1.21] ptr:454144 ptr00983
# 91 IMP dehydrogenase [EC:1.1.1.205] ptr:460362 ptr00983
# 96 thymidine phosphorylase [EC:2.4.2.4] ptr:458941 ptr00983
# 99 cytidine deaminase [EC:3.5.4.5] ptr:744046 ptr00983
# 100 carboxylesterase 2 [EC:3.1.1.1 3.1.1.84 3.1.1.56] ptr:467996 ptr00983
# 102 glucuronosyltransferase [EC:2.4.1.17] ptr:100611992 ptr00983
# 103 cytochrome P450 family 3 subfamily A polypeptide 4 [EC:1.14.13.32 1.14.14.55 1.14.14.56 1.14.14.57 1.14.14.73 1.14.13.-] ptr:463582 ptr00983
# 104 beta-glucuronidase [EC:3.2.1.31] ptr:463443 ptr00983
# 105 carboxylesterase 2 [EC:3.1.1.1 3.1.1.84 3.1.1.56] ptr:467996 ptr00983
# 113 carboxylesterase 2 [EC:3.1.1.1 3.1.1.84 3.1.1.56] ptr:467996 ptr00983
# 127 UMP-CMP kinase [EC:2.7.4.14] ptr:456837 ptr00983
# 128 nucleoside-diphosphate kinase [EC:2.7.4.6] ptr:100533953 ptr00983
# 129 UMP-CMP kinase [EC:2.7.4.14] ptr:456837 ptr00983
# 130 nucleoside-diphosphate kinase [EC:2.7.4.6] ptr:100533953 ptr00983
# 132 ribonucleoside-diphosphate reductase subunit M1 [EC:1.17.4.1] ptr:450974 ptr00983
# 134 dUTP pyrophosphatase [EC:3.6.1.23] ptr:467675 ptr00983
# 146 myeloperoxidase [EC:1.11.2.2] ptr:748680 ptr00983
# 149 arylamine N-acetyltransferase [EC:2.3.1.5] ptr:464023 ptr00983
# 151 cytochrome P450 family 2 subfamily E polypeptide 1 [EC:1.14.13.-] ptr:450857 ptr00983
# 158 carboxylesterase 1 [EC:3.1.1.1] ptr:747009 ptr00983
# 159 carboxylesterase 1 [EC:3.1.1.1] ptr:747009 ptr00983
# 164 glutathione S-transferase [EC:2.5.1.18] ptr:100611543 ptr00983

# %%
NODES_ptr00010
# Out:
# {"'14'": 'fructose-bisphosphate aldolase, class I [EC:4.1.2.13]',
#  '14': 'fructose-bisphosphate aldolase, class I [EC:4.1.2.13]',
#  '38': 'aldehyde dehydrogenase (NAD+) [EC:1.2.1.3]',
#  '40': 'aldehyde dehydrogenase (NAD(P)+) [EC:1.2.1.5]',
#  '45': 'alcohol dehydrogenase (NADP+) [EC:1.1.1.2]',
#  '46': 'alcohol dehydrogenase 4 [EC:1.1.1.1]',
#  '48': 'pyruvate dehydrogenase E1 component alpha subunit [EC:1.2.4.1]',
#  '49': 'pyruvate dehydrogenase E1 component alpha subunit [EC:1.2.4.1]',
#  '50': 'pyruvate dehydrogenase E2 component (dihydrolipoamide acetyltransferase) [EC:2.3.1.12]',
#  '51': 'L-lactate dehydrogenase [EC:1.1.1.27]',
#  '53': 'pyruvate kinase isozymes R/L [EC:2.7.1.40]',
#  '55': 'enolase [EC:4.2.1.11]',
#  '56': '2,3-bisphosphoglycerate-dependent phosphoglycerate mutase [EC:5.4.2.11]',
#  '57': 'glyceraldehyde 3-phosphate dehydrogenase [EC:1.2.1.12]',
#  '58': 'triosephosphate isomerase (TIM) [EC:5.3.1.1]',
#  '59': '6-phosphofructokinase 1 [EC:2.7.1.11]',
#  '60': 'fructose-1,6-bisphosphatase I [EC:3.1.3.11]',
#  '62': 'glucose-6-phosphate isomerase [EC:5.3.1.9]',
#  '63': 'phosphoglucomutase [EC:5.4.2.2]',
#  '64': 'glucose-6-phosphate isomerase [EC:5.3.1.9]',
#  '65': 'hexokinase [EC:2.7.1.1]',
#  '66': 'glucokinase [EC:2.7.1.2]',
#  '67': 'glucose-6-phosphate isomerase [EC:5.3.1.9]',
#  '69': 'aldose 1-epimerase [EC:5.1.3.3]',
#  '70': 'glucokinase [EC:2.7.1.2]',
#  '71': 'hexokinase [EC:2.7.1.1]',
#  '72': 'glucose-6-phosphatase [EC:3.1.3.9]',
#  '75': 'dihydrolipoamide dehydrogenase [EC:1.8.1.4]',
#  '76': 'phosphoglycerate kinase [EC:2.7.2.3]',
#  '112': 'phosphoenolpyruvate carboxykinase (GTP) [EC:4.1.1.32]',
#  '128': 'bisphosphoglycerate/phosphoglycerate mutase [EC:5.4.2.4 5.4.2.11]',
#  '129': 'bisphosphoglycerate/phosphoglycerate mutase [EC:5.4.2.4 5.4.2.11]',
#  '131': 'acetyl-CoA synthetase [EC:6.2.1.1]',
#  '133': 'ADP-dependent glucokinase [EC:2.7.1.147]',
#  '134': 'ADP-dependent glucokinase [EC:2.7.1.147]',
#  '140': 'multiple inositol-polyphosphate phosphatase / 2,3-bisphosphoglycerate 3-phosphatase [EC:3.1.3.62 3.1.3.80]'}

# %% [markdown]
# ## PRIMERA RED

# %%
EDGES=[]

for line in pathways.text.split('\n'):        
    pathwayid = line.split('\t')[0].replace('path:', '') 
    
    if pathwayid == str(org)+str(maxi):           
            break
            
    ii=locals()[str(pathwayid)]
    
    NODES=locals()['NODES_'+str(pathwayid)]
   
    for i in range(0,len(ii)):
        if ii[i].tag=='relation':         
            A=ii[i].attrib            
            if A['type'] == 'ECrel':    #relación enzima-enzima, que indica dos enzimas que catalizan pasos de reacción sucesivos
                #print(A)
                EDGES.append( [  NODES[ A['entry1'] ] , NODES[ A['entry2'] ]  ]  ) 

print(EDGES)
# Out:
# [['aldose 1-epimerase [EC:5.1.3.3]', 'hexokinase [EC:2.7.1.1]'], ['aldose 1-epimerase [EC:5.1.3.3]', 'glucokinase [EC:2.7.1.2]'], ['aldose 1-epimerase [EC:5.1.3.3]', 'glucose-6-phosphatase [EC:3.1.3.9]'], ['glucokinase [EC:2.7.1.2]', 'aldose 1-epimerase [EC:5.1.3.3]'], ['hexokinase [EC:2.7.1.1]', 'aldose 1-epimerase [EC:5.1.3.3]'], ['glucose-6-phosphate isomerase [EC:5.3.1.9]', 'glucokinase [EC:2.7.1.2]'], ['glucose-6-phosphate isomerase [EC:5.3.1.9]', 'hexokinase [EC:2.7.1.1]'], ['glucose-6-phosphate isomerase [EC:5.3.1.9]', 'glucose-6-phosphatase [EC:3.1.3.9]'], ['glucose-6-phosphate isomerase [EC:5.3.1.9]', 'glucose-6-phosphatase [EC:3.1.3.9]'], ['phosphoglucomutase [EC:5.4.2.2]', 'glucose-6-phosphatase [EC:3.1.3.9]'], ['glucose-6-phosphate isomerase [EC:5.3.1.9]', 'hexokinase [EC:2.7.1.1]'], ['glucose-6-phosphate isomerase [EC:5.3.1.9]', 'glucokinase [EC:2.7.1.2]'], ['glucose-6-phosphate isomerase [EC:5.3.1.9]', 'phosphoglucomutase [EC:5.4.2.2]'], ['glucose-6-phosphate isomerase [EC:5.3.1.9]', 'hexokinase [EC:2.7.1.1]'], ['phosphoglucomutase [EC:5.4.2.2]', 'hexokinase [EC:2.7.1.1]'], ['glucose-6-phosphate isomerase [EC:5.3.1.9]', 'glucokinase [EC:2.7.1.2]'], ['phosphoglucomutase [EC:5.4.2.2]', 'glucokinase [EC:2.7.1.2]'], ['phosphoglucomutase [EC:5.4.2.2]', 'glucose-6-phosphate isomerase [EC:5.3.1.9]'], ['fructose-1,6-bisphosphatase I [EC:3.1.3.11]', 'glucose-6-phosphate isomerase [EC:5.3.1.9]'], ['6-phosphofructokinase 1 [EC:2.7.1.11]', 'glucose-6-phosphate isomerase [EC:5.3.1.9]'], ['fructose-bisphosphate aldolase, class I [EC:4.1.2.13]', 'fructose-1,6-bisphosphatase I [EC:3.1.3.11]'], ['fructose-bisphosphate aldolase, class I [EC:4.1.2.13]', '6-phosphofructokinase 1 [EC:2.7.1.11]'], ['triosephosphate isomerase (TIM) [EC:5.3.1.1]', 'fructose-bisphosphate aldolase, class I [EC:4.1.2.13]'], ['glyceraldehyde 3-phosphate dehydrogenase [EC:1.2.1.12]', 'phosphoglycerate kinase [EC:2.7.2.3]'], ['2,3-bisphosphoglycerate-dependent phosphoglycerate mutase [EC:5.4.2.11]', 'phosphoglycerate kinase [EC:2.7.2.3]'], ['enolase [EC:4.2.1.11]', '2,3-bisphosphoglycerate-dependent phosphoglycerate mutase [EC:5.4.2.11]'], ['pyruvate dehydrogenase E1 component alpha subunit [EC:1.2.4.1]', 'pyruvate dehydrogenase E2 component (dihydrolipoamide acetyltransferase) [EC:2.3.1.12]'], ['pyruvate dehydrogenase E1 component alpha subunit [EC:1.2.4.1]', 'dihydrolipoamide dehydrogenase [EC:1.8.1.4]'], ['pyruvate dehydrogenase E2 component (dihydrolipoamide acetyltransferase) [EC:2.3.1.12]', 'dihydrolipoamide dehydrogenase [EC:1.8.1.4]'], ['aldehyde dehydrogenase (NAD+) [EC:1.2.1.3]', 'alcohol dehydrogenase 4 [EC:1.1.1.1]'], ['aldehyde dehydrogenase (NAD(P)+) [EC:1.2.1.5]', 'alcohol dehydrogenase 4 [EC:1.1.1.1]'], ['aldehyde dehydrogenase (NAD+) [EC:1.2.1.3]', 'alcohol dehydrogenase (NADP+) [EC:1.1.1.2]'], ['aldehyde dehydrogenase (NAD(P)+) [EC:1.2.1.5]', 'alcohol dehydrogenase (NADP+) [EC:1.1.1.2]'], ['pyruvate kinase isozymes R/L [EC:2.7.1.40]', 'enolase [EC:4.2.1.11]'], ['fructose-1,6-bisphosphatase I [EC:3.1.3.11]', 'glucose-6-phosphate isomerase [EC:5.3.1.9]'], ['6-phosphofructokinase 1 [EC:2.7.1.11]', 'glucose-6-phosphate isomerase [EC:5.3.1.9]'], ['L-lactate dehydrogenase [EC:1.1.1.27]', 'pyruvate kinase isozymes R/L [EC:2.7.1.40]'], ['pyruvate dehydrogenase E1 component alpha subunit [EC:1.2.4.1]', 'pyruvate kinase isozymes R/L [EC:2.7.1.40]'], ['pyruvate dehydrogenase E1 component alpha subunit [EC:1.2.4.1]', 'L-lactate dehydrogenase [EC:1.1.1.27]'], ['glucokinase [EC:2.7.1.2]', 'glucose-6-phosphate isomerase [EC:5.3.1.9]'], ['hexokinase [EC:2.7.1.1]', 'glucose-6-phosphate isomerase [EC:5.3.1.9]'], ['phosphoglycerate kinase [EC:2.7.2.3]', 'bisphosphoglycerate/phosphoglycerate mutase [EC:5.4.2.4 5.4.2.11]'], ['glyceraldehyde 3-phosphate dehydrogenase [EC:1.2.1.12]', 'bisphosphoglycerate/phosphoglycerate mutase [EC:5.4.2.4 5.4.2.11]'], ['bisphosphoglycerate/phosphoglycerate mutase [EC:5.4.2.4 5.4.2.11]', 'phosphoglycerate kinase [EC:2.7.2.3]'], [' ...

# %%
G = nx.DiGraph() #--->DiGrafo para hacer un grado dirigido 
 
G.add_edges_from(EDGES)


#plt.figure(3,figsize=(50,50))
#nx.draw_kamada_kawai(G,font_size=15,node_size=1000,node_color='orange',with_labels=False)
#plt.savefig("net_"+org+".pdf")# Guardar la red en pdf. 
#plt.show()

# %%
g=nx.number_of_nodes(G)
print('g=',g)
L=nx.number_of_edges(G)
print('L=',L)
# Out:
# g= 811
# L= 3059

# %%
nodos=G.nodes

D=[] # un vector donde vamos a colocar el numero de vinvulos de todos los nodos
d=nx.degree(G) # Vector que contiene el par ordenado del nodo y su numero de vinculos
for i in nodos: 
    D.append(d[i])
    

D_in=[] # un vector donde vamos a colocar el numero de vinvulos de todos los nodos
d=G.in_degree(G) # Vector que contiene el par ordenado del nodo y su numero de vinculos
for i in nodos: 
    D_in.append(d[i])
    
    
D_out=[] # un vector donde vamos a colocar el numero de vinvulos de todos los nodos
d=G.out_degree(G) # Vector que contiene el par ordenado del nodo y su numero de vinculos
for i in nodos: 
    D_out.append(d[i])
    
    
P=[]
X=[]
for i in range(1,max(D)+1):
    if D.count(i) != 0: 
        P.append(D.count(i)/len(D))
        X.append(i)
        
P_in=[]
X_in=[]
for i in range(1,max(D_in)+1):
    if D_in.count(i) != 0: 
        P_in.append(D_in.count(i)/len(D_in))
        X_in.append(i)  

P_out=[]
X_out=[]
for i in range(1,max(D)+1):
    if D_out.count(i) != 0: 
        P_out.append(D_out.count(i)/len(D_out))
        X_out.append(i)
        
        
        
# GRAFICA DE LA PROVAVILIDAD VS EL NUMERO DE GRADO        
fig, axs = plt.subplots( 3 ,sharex = True, sharey = True, figsize=(15,8))

fig.suptitle('Distribución de grado 2012',fontsize=20)
axs[0].plot(X,P,'ko')         
axs[0].set_xlabel(r'$K$',fontsize=20)
axs[0].set_ylabel(r'$P(K)$',fontsize=20)

axs[1].plot(X_in,P_in,'o')         
axs[1].set_xlabel(r'$K_{in}$',fontsize=20)
axs[1].set_ylabel(r'$P(K_{in})$',fontsize=20)

axs[2].plot(X_out,P_out, 'ro')         
axs[2].set_xlabel(r'$K_{out}$',fontsize=20)
axs[2].set_ylabel(r'$P(K_{out})$',fontsize=20)

#plt.savefig("P_vs_k_2012.pdf")# Guardar la red en pdf.    

plt.show()

# %%
fig, (ax1, ax2 , ax3) = plt.subplots(1, 3 ,sharex = True, sharey = True, figsize=(15,5))
fig.suptitle('Distribucion Log-Log 2012',fontsize=20)
ax1.plot(X,P,'ko')
ax1.set_xlabel(r'$K$',fontsize=20)
ax1.set_ylabel(r'$P(K)$',fontsize=20)

ax2.plot(X_in,P_in,'o')
ax2.set_xlabel(r'$K_{in}$',fontsize=20)
ax2.set_ylabel(r'$P(K_{in})$',fontsize=20)

ax3.plot(X_out,P_out,'ro')
ax3.set_xlabel(r'$K_{out}$',fontsize=20)
ax3.set_ylabel(r'$P(K_{out})$',fontsize=20)

# Escala log-log
plt.xscale('log') 
plt.yscale('log') 

#plt.savefig("Ley_de_potencias_2012.pdf")# Guardar la red en pdf.

plt.show()

# %%
d=G.degree(G) #Vector con el par ordenado de numero de aristas de entrada a cada uno de los nodos
d_in=G.in_degree(G)
d_out=G.out_degree(G)
degre=[]

for i in G.nodes:
    degre.append([i,d[i],d_in[i],d_out[i], d_in[i]-d_out[i] ])
df=pd.DataFrame(degre,columns=['Nombre', 'grado', 'grado_in', 'grado_out','dif_grado'])
df.sort_values(by='dif_grado', ascending=False)
df.to_excel("df_2012.xlsx")

# %%
nodos=G.nodes

D=[] #
d_in=G.in_degree(G)
d_out=G.out_degree(G)
for i in nodos: 
    D.append(d_out(i)-d_in[i])
    

print(D)    
P=[]
X=[]
for i in range(1,max(D)+1):
    P.append(D.count(i))
    X.append(i)

plt.figure(3,figsize=(15,8))
plt.title('Distribución de grado 2012',fontsize=20)
plt.plot(X,P,'ko')         
plt.xlabel(r'$K$',fontsize=20)
plt.ylabel(r'$P(K)$',fontsize=20)
# Out:
# [7, 0, 2, -3, -3, -5, -3, -2, 1, 2, 0, -2, -2, -2, -3, -2, -1, -2, 1, 5, -4, 0, -7, 1, 0, 2, 1, -2, -1, 1, 1, -2, 3, 0, -1, -1, 0, -2, -2, 1, -2, -1, -1, 2, 1, -1, 1, 3, 4, 6, -5, 1, -1, 0, -16, 0, 2, -1, 0, 3, 1, 2, -1, 1, 2, -1, -1, -1, 0, -1, 1, 0, -1, 6, -3, 0, -1, -2, 0, -1, -4, -2, 1, -2, -6, -2, 1, 2, 0, 4, 1, -2, -2, 3, 0, 0, 0, 0, 3, 0, 2, 0, 0, -1, -1, 0, 0, -2, 2, 0, 1, -1, -1, 2, -3, 2, 0, 1, 2, 0, 3, -2, 1, -2, 2, 2, -3, 1, -3, 1, 2, 2, 0, 0, 0, -2, 1, 0, 2, 3, 4, -2, -1, -4, 1, 0, 2, 0, -1, 0, 0, 0, 0, -4, 1, 1, -5, 1, 0, 0, -1, 2, -1, -1, 3, -3, 5, -5, 7, -3, 4, -1, 7, -2, -3, -1, 5, -1, -2, -7, -6, 1, 0, 5, 1, 0, 2, 5, 1, -2, 1, -3, 1, -3, -4, -4, -1, 2, 2, 5, -5, 1, -2, 11, -3, 4, -6, 0, 0, -3, -8, 5, 2, 3, 2, 5, 13, 2, 5, -7, -10, -5, -2, -4, -3, 6, -8, -5, 0, -4, -10, -1, -2, 4, 11, 9, 0, -7, 1, -1, 1, 5, 7, 1, -1, 7, 2, 15, 0, 1, 5, 8, -2, -4, -1, 4, 6, 2, -3, -2, -3, 1, 0, -2, -3, 2, 1, 6, -1, -1, 2, 0, 3, -2, 3, 0, 1, -11, 1, 1, -6, 0, 2, -1, -1, 11, -4, 1, 1, 0, 1, 8, -1, 1, -1, 6, 2, 0, 0, 0, 2, 1, 0, -5, 0, -4, -1, -5, -4, -10, 0, -7, 3, 2, 0, -2, 6, -3, -1, -1, -1, -3, 0, 2, -2, -1, 1, 0, 6, -4, 2, 3, -1, -1, 2, -1, 2, 0, 0, 2, -2, -2, -4, -1, 2, 3, 0, 0, 1, -3, 1, 2, -1, 1, 1, 1, -1, -2, -5, -1, -5, 1, -1, -1, -6, -2, 0, 2, 2, 1, 1, 1, -1, 0, 1, 2, 3, 3, 0, 0, 0, -3, -3, -2, 1, 0, 0, 2, 0, 6, -5, 0, 1, 0, 1, -1, -1, -6, 2, 1, -7, 2, 1, 1, -2, 0, 1, -2, -5, 1, 3, 1, -1, 2, 0, 4, 4, -2, 2, 0, 3, 1, -1, -2, 1, -1, 1, 1, 3, -1, 0, 0, -4, -3, -4, 0, 2, 3, -2, -7, -1, 2, 2, 4, 4, -5, 1, -5, -1, 1, 1, 0, 0, 0, 1, -1, 2, 0, 2, 1, -1, 0, 1, -4, 3, -1, 2, -1, 0, -1, 1, 3, -2, -4, -1, 5, 0, -1, -1, 1, -1, -2, -1, 2, 0, 0, 1, -1, 0, 1, 0, 0, -1, 0, 0, 0, -1, 1, 3, 1, 2, 0, 3, 3, -2, 0, -2, 0, 1, 1, -2, -2, 0, 0, 1, -1, 2, 0, -1, 1, 1, 0, 0, -1, 1, 1, 1, 0, -2, 0, 1, 0, 0, 2, -1, 0, 1, 1, 2, 4, -2, -4, 1, 9, 7, 2, 1, 1, -3, -3, -2, -1, 2, 3, 0, -6, 1, 6, -1, -2, -3, -1, -1, -3, 5, 0, 0, 2, 0, 3, 0, -3, 0, 2, 1, -2, -1, 2, -1, -1, -3, 0, -4, -1, -3, 5, -4, 7, 1, -2, -10, -9, 3, -4, -1, -3, 2, -3, 1, 1, 1, -3, -1, -7, -2, 3, 1, 3, 2, -2, 4, -3, 2, 3, -1, -2, -1, -4, 3, -6, -2, 0, 1, 0, -1, -1, -8, 2, 7, 5, 4, -5, 4, -8, -7, 11, 6, -3, 0, -1, 1, -3, -2, 7, 8, 12, -3, 7, 2, -13, -5, -5, -3, -4, 1, -2, -5, 7, -6, 1, 12, 11, 11, 4, 3, -14, -4, -3, 1, 2, -2, -5, 4, -1, -1, -1, -5, -3, -7, -3, 1, 1, -1, -5, -1, 6, -1, 0, 0, -2, 0, 2, -2, 5, -3, 5, -1, -1, -2, 2, 0, -3, -1, 0, 13, -4, 1, 4, 3, -2, -3, 0, 1, 2, 2, 1, -2, 0, 3, 1, 1, -1, -3, -1, -4, 0, 5, 2, -6, -6, 2, -7, 2, 4, 1, -1, -1, -2, 1, 1, 1, -1, 0, 0, -1, 3, 2, 1, -2, 1, 1, 0, 0, 0, -1, 2, 2, 2, 3, 7, 7, 3, -2, -2, 0, -3, 4, 2, -5, -9, -2, 0, 0, 1, 1, 0, 0, -3, 1, 1, -1, 2, 0, 0, 0, 1, -1, 0, 0, -3, 0, 2, 0, 0, -3, -1, 1, 0, 1, 1, 2, -1, -1, -2, -1, 3, 1, -2, 2, 2, 0]
# Text(0,0.5,'$P(K)$')

# %%
intr=nx.betweenness_centrality(G) #dicionario en python
intr = pd.DataFrame([[key, intr[key]] for key in intr.keys()], columns=['Name', 'intermediacion'])
print(intr.sort_values(by='intermediacion', ascending=False))
# Out:
#                                                   Name  intermediacion
# 54               glucuronosyltransferase [EC:2.4.1.17]        0.086095
# 17          aldehyde dehydrogenase (NAD+) [EC:1.2.1.3]        0.071790
# 59                    aldehyde reductase [EC:1.1.1.21]        0.066128
# 343                      aldehyde oxidase [EC:1.2.3.1]        0.063354
# 248  ectonucleotide pyrophosphatase/phosphodiestera...        0.059300
# 591            cytosolic phospholipase A2 [EC:3.1.1.4]        0.053723
# 78   beta-1,4-galactosyltransferase 1 [EC:2.4.1.22 ...        0.048615
# 5                      phosphoglucomutase [EC:5.4.2.2]        0.045428
# 363                     monoamine oxidase [EC:1.4.3.4]        0.044903
# 1                              hexokinase [EC:2.7.1.1]        0.042498
# 18                alcohol dehydrogenase 4 [EC:1.1.1.1]        0.039208
# 186  cytochrome P450 family 2 subfamily E polypepti...        0.038276
# 21          pyruvate kinase isozymes R/L [EC:2.7.1.40]        0.038068
# 56   UTP--glucose-1-phosphate uridylyltransferase [...        0.037711
# 339  malonate-semialdehyde dehydrogenase (acetylati...        0.036998
# 176  aldo-keto reductase family 1 member C3 [EC:1.1...        0.036188
# 187  cytochrome P450 family 3 subfamily A polypepti...        0.035116
# 55            UDPglucose 6-dehydrogenase [EC:1.1.1.22]        0.033388
# 195  aspartate aminotransferase, cytoplasmic [EC:2....        0.033164
# 75                    beta-galactosidase [EC:3.2.1.23]        0.031253
# 704               dihydrofolate reductase [EC:1.5.1.3]        0.029166
# 277                  L-amino-acid oxidase [EC:1.4.3.2]        0.027959
# 499                       hexosaminidase [EC:3.2.1.52]        0.027342
# 76                UDP-glucose 4-epimerase [EC:5.1.3.2]        0.027079
# 105        acetyl-CoA C-acetyltransferase [EC:2.3.1.9]        0.026251
# 0                      aldose 1-epimerase [EC:5.1.3.3]        0.025832
# 211  phosphoribosylaminoimidazolecarboxamide formyl...        0.024894
# 722      nicotinamide N-methyltransferase [EC:2.1.1.1]        0.022837
# 106  enoyl-CoA hydratase / 3-hydroxyacyl-CoA dehydr...        0.022594
# 177  cytochrome P450 family 1 subfamily A polypepti...        0.021939
# ..                                                 ...             ...
# 511  N-acylneuraminate/3-deoxy-D-glycero-D-galacto-...        0.000000
# 507             N-acetylneuraminate lyase [EC:4.1.3.3]        0.000000
# 558                myotubularin [EC:3.1.3.64 3.1.3.95]        0.000000
# 203            argininosuccinate synthase [EC:6.3.4.5]        0.000000
# 204  ADP-sugar pyrophosphatase / 8-oxo-dGDP phospha...        0.000000
# 207  phosphoribosylformylglycinamidine synthase [EC...        0.000000
# 212  3'-phosphoadenosine 5'-phosphosulfate synthase...        0.000000
# 498                            chitinase [EC:3.2.1.14]        0.000000
# 497  D-ribitol-5-phosphate cytidylyltransferase [EC...        0.000000
# 496  glycosyltransferase-like protein LARGE [EC:2.4...        0.000000
# 520                          heparanase 2 [EC:3.2.1.-]        0.000000
# 523        alpha-N-acetylglucosaminidase [EC:3.2.1.50]        0.000000
# 197                  alanine transaminase [EC:2.6.1.2]        0.000000
# 525     N-acetylgalactosamine-6-sulfatase [EC:3.1.6.4]        0.000000
# 557  myo-inositol-1(or 4)-monophosphatase [EC:3.1.3...        0.000000
# 555  phosphatidylinositol 4-kinase type 2 [EC:2.7.1...        0.000000
# 162  vitamin K-dependent gamma-carboxylase [EC:4.1....        0.000000
# 163  vitamin-K-epoxide reductase (warfarin-sensitiv...        0.000000
# 171  3alpha-hydroxysteroid 3-dehydrogenase [EC:1.1....        0.000000
# 173  corticosteroid 11-beta-dehydrogenase isozyme 2...        0.000000
# 543  diacylglycerol diphosphate phosphatase / phosp...        0.000000
# 179  testosterone 17beta-dehydrogenase (NADP+) [EC:...        0.000000
# 188  V-type H+-transporting ATPase 21kDa proteolipi...        0.000000
# 189             inorganic pyrophosphatase [EC:3.6.1.1]        0.000000
# 190  non-gastric H+/K+-exchanging ATPase [EC:7.2.2.19]        0.000000
# 196            N-acetylglutamate synthase [EC:2.3.1.1]        0.000000
# 531  chondroitin sulfate synthase [EC:2.4.1.175 2.4...        0.000000
# 528  galactosylxylosylprotein 3-beta-galactosyltran...        0.000000
# 526           protein xylosyltransferase [EC:2.4.2.26]        0.000000
# 810                      myeloperoxidase [EC:1.11.2.2]        0.000000
#
# [811 rows x 2 columns]
