# %% [markdown]
# # Libreria

# %%
import pandas as pd
import networkx as nx
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
#parsear XML
import csv   
from lxml import etree
#Parsear HTML
import requests
import urllib.request
from bs4 import BeautifulSoup
from urllib.request import urlopen
from bs4.builder import HTMLParserTreeBuilder
#para medir tiempo
from time import time 
import time

# %% [markdown]
# # Carga de Archivos XML

# %%
org = 'cel'
ORGANISM = org
maxi ='01040'

pathways = requests.get('http://rest.kegg.jp/list/pathway/' + ORGANISM)  #lista de las vias metabolicas y otra informacion porpocionada por KEGG

for line in pathways.text.split('\n'):         # Se recorre la lista propocionada por  KEGG donde se estraen los nombres de las vias de KEGG
      pathwayid = line.split('\t')[0].replace('path:', '') 
      A = pathwayid+'.xml'                     # Le ponemos la extencion .xml para poder cargar los archivos
      if A == str(org)+str(maxi)+'.xml':           
            break
      locals()[str(pathwayid)] = etree.parse(A) # Guarda los  XML com el nombre de la via asignado por KEGG
      locals()[str(pathwayid)] = locals()[str(pathwayid)].getroot()  # Para transformar todos lo XML en directorios de python

# %% [markdown]
# ## ARMANDO BASE DE DATOS CON PANDAS

# %% [markdown]
# ##### crear archivo csv para guardar los datos.

# %%
data= pd.DataFrame(columns=('n', 'enzima', 'gen', 'nob_Keeg', 'path' ,'link')) # Crear tabla csv. 
data.to_csv('data_'+org+'.csv', sep=';')

# %%
save=len(pd.read_csv('data_'+org+'.csv',index_col=0, delimiter=';')[['n']].values)
print(save)
# Out:
# 971

# %%
save=len(pd.read_csv('data_'+org+'.csv',index_col=0, delimiter=';')[['n']].values)

n=0

for line in pathways.text.split('\n'):
    
    pathwayid = line.split('\t')[0].replace('path:', '') 
    
    if pathwayid ==  str(org)+str(maxi):           
            break
    
    ii=locals()[str(pathwayid)]
    
    
    for i in range(0,len(ii)):
       
        if ii[i].tag=='entry':         
            A=ii[i].attrib            
            if A['type'] == 'gene':
                n=1+n
                
                if n > save:
                    
                    url = A['link']
                
                    response = requests.get(url)
                    soup = BeautifulSoup(response.text, "html.parser")
                    
                    gen    = soup.html.body.div.table.form.td.table.find_all('td')[3].find_all('div')[0].text.replace('\n', ' ').strip().split()[0].replace(',','')
                    
                    if gen == '(RefSeq)':
                        ll=6
                    else:
                        ll=7
                    
                    enzima = soup.html.body.div.table.form.td.table.find_all('td')[ll].text.strip()
                    
                    NewDat = [n , A['id'] , enzima, gen , A['name'].split( )[0] , pathwayid , A['link'] ]
                
                                
                    with open(r'data_'+org+'.csv', 'a' , newline='') as f:
                        writer = csv.writer(f,delimiter=';')
                        writer.writerow(NewDat)

# %%
n=0

for line in pathways.text.split('\n'):
    
    pathwayid = line.split('\t')[0].replace('path:', '') 
    
    if pathwayid == str(org)+str(maxi):           
            break
            
  
    ii=locals()[str(pathwayid)]
    
        
    
    for i in range(0,len(ii)):
       
        if ii[i].tag=='entry':         
            A=ii[i].attrib            
            if A['type'] == 'group':
                n=1+n 
                
                NewDat = [n , A['id'] , 'undefined_Enzima'+pathwayid , 'none' ,  A['name'] , pathwayid , 'no link']
                
                        
                with open(r'data_'+org+'.csv', 'a' , newline='') as f:
                    writer = csv.writer(f , delimiter=';')
                    writer.writerow(NewDat)

# %%
data=pd.read_csv('data_'+org+'.csv',index_col=0, sep=';')
data=data[['n' ,'enzima', 'nob_Keeg' ,'path']]
data=data.values
data
# Out:
# array([["'14'", 'fructose-bisphosphate aldolase, class II [EC:4.1.2.13]',
#         'cac:CA_C0827', 'cac00010'],
#        ['14', 'fructose-bisphosphate aldolase, class II [EC:4.1.2.13]',
#         'cac:CA_C0827', 'cac00010'],
#        ['46',
#         'S-(hydroxymethyl)glutathione dehydrogenase / alcohol dehydrogenase [EC:1.1.1.284 1.1.1.1]',
#         'cac:CA_C3375', 'cac00010'],
#        ...,
#        ['175', 'tRNA Phe', 'cac:CA_Ct010', 'cac00970'],
#        ['176', 'tRNA Tyr', 'cac:CA_Ct048', 'cac00970'],
#        ['177', 'tRNA Trp', 'cac:CA_Ct047', 'cac00970']], dtype=object)

# %%
for line in pathways.text.split('\n'):
    
    pathwayid = line.split('\t')[0].replace('path:', '') 
    
    if pathwayid == str(org)+str(maxi):           
            break
    
    locals()['NODES_'+str(pathwayid)]={}
    
    for i in data:
        if i[3] == pathwayid:
            locals()['NODES_'+str(pathwayid)][i[0]]= i[1] 
            print(i[0],i[1], i[2], i[3])
# Out:
# '14' fructose-bisphosphate aldolase, class II [EC:4.1.2.13] cac:CA_C0827 cac00010
# 14 fructose-bisphosphate aldolase, class II [EC:4.1.2.13] cac:CA_C0827 cac00010
# 46 S-(hydroxymethyl)glutathione dehydrogenase / alcohol dehydrogenase [EC:1.1.1.284 1.1.1.1] cac:CA_C3375 cac00010
# 51 L-lactate dehydrogenase [EC:1.1.1.27] cac:CA_C0267 cac00010
# 53 pyruvate kinase [EC:2.7.1.40] cac:CA_C0518 cac00010
# 55 enolase [EC:4.2.1.11] cac:CA_C0713 cac00010
# 56 2,3-bisphosphoglycerate-dependent phosphoglycerate mutase [EC:5.4.2.11] cac:CA_C2741 cac00010
# 57 glyceraldehyde 3-phosphate dehydrogenase [EC:1.2.1.12] cac:CA_C0709 cac00010
# 58 triosephosphate isomerase (TIM) [EC:5.3.1.1] cac:CA_C0711 cac00010
# 59 6-phosphofructokinase 1 [EC:2.7.1.11] cac:CA_C0517 cac00010
# 60 fructose-1,6-bisphosphatase II [EC:3.1.3.11] cac:CA_C1088 cac00010
# 61 glucose PTS system EIICBA or EIICB component [EC:2.7.1.199] cac:CA_C0570 cac00010
# 62 glucose-6-phosphate isomerase [EC:5.3.1.9] cac:CA_C2680 cac00010
# 63 phosphoglucomutase [EC:5.4.2.2] cac:CA_C2337 cac00010
# 64 glucose-6-phosphate isomerase [EC:5.3.1.9] cac:CA_C2680 cac00010
# 66 glucokinase [EC:2.7.1.2] cac:CA_C2613 cac00010
# 67 glucose-6-phosphate isomerase [EC:5.3.1.9] cac:CA_C2680 cac00010
# 69 aldose 1-epimerase [EC:5.1.3.3] cac:CA_C0697 cac00010
# 70 glucokinase [EC:2.7.1.2] cac:CA_C2613 cac00010
# 76 phosphoglycerate kinase [EC:2.7.2.3] cac:CA_C0710 cac00010
# 79 sugar PTS system EIIA component [EC:2.7.1.-] cac:CA_C1354 cac00010
# 80 sugar PTS system EIIA component [EC:2.7.1.-] cac:CA_C1354 cac00010
# 81 6-phospho-beta-glucosidase [EC:3.2.1.86] cac:CA_C0385 cac00010
# 82 6-phospho-beta-glucosidase [EC:3.2.1.86] cac:CA_C0385 cac00010
# 122 glyceraldehyde-3-phosphate dehydrogenase (NADP+) [EC:1.2.1.9] cac:CA_C3657 cac00010
# 124 pyruvate-ferredoxin/flavodoxin oxidoreductase [EC:1.2.7.1 1.2.7.-] cac:CA_C2229 cac00010
# 137 2,3-bisphosphoglycerate-independent phosphoglycerate mutase [EC:5.4.2.12] cac:CA_C0712 cac00010
# 144 2-oxoglutarate/2-oxoacid ferredoxin oxidoreductase subunit beta [EC:1.2.7.3 1.2.7.11] cac:CA_C2458 cac00010
# 35 isocitrate dehydrogenase (NAD+) [EC:1.1.1.41] cac:CA_C0972 cac00020
# 38 fumarate hydratase subunit beta [EC:4.2.1.2] cac:CA_C3090 cac00020
# 39 aconitate hydratase [EC:4.2.1.3] cac:CA_C0971 cac00020
# 40 aconitate hydratase [EC:4.2.1.3] cac:CA_C0971 cac00020
# 43 pyruvate carboxylase [EC:6.4.1.1] cac:CA_C2660 cac00020
# 99 2-oxoglutarate/2-oxoacid ferredoxin oxidoreductase subunit beta [EC:1.2.7.3 1.2.7.11] cac:CA_C2458 cac00020
# 101 pyruvate-ferredoxin/flavodoxin oxidoreductase [EC:1.2.7.1 1.2.7.-] cac:CA_C2229 cac00020
# 102 2-oxoglutarate/2-oxoacid ferredoxin oxidoreductase subunit beta [EC:1.2.7.3 1.2.7.11] cac:CA_C2458 cac00020
# 103 2-oxoglutarate/2-oxoacid ferredoxin oxidoreductase subunit beta [EC:1.2.7.3 1.2.7.11] cac:CA_C2458 cac00020
# 104 citrate (Re)-synthase [EC:2.3.3.3] cac:CA_C0970 cac00020
# 37 glucose-6-phosphate isomerase [EC:5.3.1.9] cac:CA_C2680 cac00030
# 38 2-dehydro-3-deoxyphosphogluconate aldolase / (4S)-4-hydroxy-2-oxoglutarate aldolase [EC:4.1.2.14 4.1.3.42] cac:CA_C0394 cac00030
# 41 phosphopentomutase [EC:5.4.2.7] cac:CA_C2065 cac00030
# 42 deoxyribose-phosphate aldolase [EC:4.1.2.4] cac:CA_C1545 cac00030
# 43 ribose-phosphate pyrophosphokinase [EC:2.7.6.1] cac:CA_C0819 cac00030
# 44 phosphopentomutase [EC:5.4.2.7] cac:CA_C2065 cac00030
# 46 transketolase [EC:2.2.1.1] cac:CA_C0944 cac00030
# 47 ribose 5-phosphate isomerase B [EC:5.3.1.6] cac:CA_C0726 cac00030
# 48 ribulose-phosphate 3-epimerase [EC:5.1.3.1] cac:CA_C1730 cac00030
# 49 transketolase [EC:2.2.1.1] cac:CA_C0944 cac00030
# 50 fructose-bisphosphate aldolase, class II [EC:4.1.2.13] cac:CA_C0827 cac00030
# 51 6-phosphofructokinase 1 [EC:2.7.1.11] cac:CA_C0517 cac00030
# 52 fructose-1,6-bisphosphatase II [EC:3.1.3.11] cac:CA_C1088 cac00030
# 53 glucose-6-phosphate isomerase [EC:5.3.1.9] cac:CA_C2680 cac00030
# 60 2-dehydro-3-deoxygluconokinase [EC:2.7.1.45] cac:CA_C0395 cac00030
# 77 transaldolase [EC:2.2.1.2] cac:CA_C1347 cac00030
# 78 phosphoglucomutase [EC:5.4.2.2] cac:CA_C2337 cac00030
# 86 aldehyde:ferredoxin oxidoreductase [EC:1.2.7.5] cac:CA_C2018 cac00030
# 93 xylulose-5-phosphate/fructose-6-phosphate phosphoketolase [EC:4.1.2.9 4.1.2.22] cac:CA_C1343 cac00030
# 135 3-hexulose-6-phosphate synthase [EC:4.1.2.43] cac:CA_C0396 cac00030
# 137 6-phospho-3-hexuloisomerase [EC:5.3.1.27] cac:CA_C0397 cac00030
# 146 glyceraldehyde-3-phosphate dehydrogenase (NADP+) [EC:1.2.1.9] cac:CA_C3657 cac00030
# 72 L-arabinose isomerase [EC:5.3.1.4] cac:CA_C1342 cac00040
# 78 ribulose-phosphate 3-epimerase [EC:5.1.3.1] cac:CA_C1730 cac00040
# 79 L-ribulose-5-phosphate 4-epimerase [EC:5.1.3.4] cac:CA_C1341 cac00040
# 84 xylulokinase [EC:2.7.1.17] cac:CA_C2612 cac00040
# 100 UTP--glucose-1-phosphate uridylyltransferase [EC:2.7.7.9] cac:CA_C2250 cac00040
# 106 glucuronate isomerase [EC:5.3.1.12] cac:CA_C0692 cac00040
# 108 mannonate dehydratase [EC:4.2.1.8] cac:CA_C1332 cac00040
# 109 altronate hydrolase [EC:4.2.1.7] cac:CA_C0696 cac00040
# 110 glucuronate isomerase [EC:5.3.1.12] cac:CA_C0692 cac00040
# 111 tagaturonate reductase [EC:1.1.1.58] cac:CA_C0695 cac00040
# 130 2-dehydro-3-deoxy-D-gluconate 5-dehydrogenase [EC:1.1.1.127] cac:CA_C0361 cac00040
# 54 fructose PTS system EIIA component [EC:2.7.1.202] cac:CA_C0233 cac00051
# 67 mannitol PTS system EIICBA or EIICB component [EC:2.7.1.197] cac:CA_C0154 cac00051
# 69 mannan endo-1,4-beta-mannosidase [EC:3.2.1.78] cac:CA_C0332 cac00051
# 72 Pfam: PTSIIB_sorb cac:CA_C1458 cac00051
# 74 fructokinase [EC:2.7.1.4] cac:CA_C0424 cac00051
# 77 mannitol-1-phosphate 5-dehydrogenase [EC:1.1.1.17] cac:CA_C0157 cac00051
# 78 mannose-6-phosphate isomerase [EC:5.3.1.8] cac:CA_C2918 cac00051
# 79 mannose-1-phosphate guanylyltransferase / phosphomannomutase [EC:2.7.7.13 5.4.2.8] cac:CA_C2981 cac00051
# 82 GDP-L-fucose synthase [EC:1.1.1.271] cac:CA_C2179 cac00051
# 83 GDPmannose 4,6-dehydratase [EC:4.2.1.47] cac:CA_C2180 cac00051
# 84 mannose-1-phosphate guanylyltransferase [EC:2.7.7.13] cac:CA_C2968 cac00051
# 88 6-phosphofructokinase 1 [EC:2.7.1.11] cac:CA_C0517 cac00051
# 92 1-phosphofructokinase [EC:2.7.1.56] cac:CA_C0232 cac00051
# 93 triosephosphate isomerase (TIM) [EC:5.3.1.1] cac:CA_C0711 cac00051
# 94 fructose-bisphosphate aldolase, class II [EC:4.1.2.13] cac:CA_C0827 cac00051
# 96 fructose-bisphosphate aldolase, class II [EC:4.1.2.13] cac:CA_C0827 cac00051
# 105 fructose-1,6-bisphosphatase II [EC:3.1.3.11] cac:CA_C1088 cac00051
# 182 fructan beta-fructosidase [EC:3.2.1.80] cac:CA_C1462 cac00051
# 187 ribose 5-phosphate isomerase B [EC:5.3.1.6] cac:CA_C0726 cac00051
# 56 tagatose 6-phosphate kinase [EC:2.7.1.144] cac:CA_C2951 cac00052
# 57 6-phosphofructokinase 1 [EC:2.7.1.11] cac:CA_C0517 cac00052
# 58 tagatose 1,6-diphosphate aldolase GatY/KbaY [EC:4.1.2.40] cac:CA_C2952 cac00052
# 60 6-phospho-beta-galactosidase [EC:3.2.1.85] cac:CA_C2963 cac00052
# 62 beta-fructofuranosidase [EC:3.2.1.26] cac:CA_C0425 cac00052
# 64 alpha-glucosidase [EC:3.2.1.20] cac:CA_C2891 cac00052
# 66 beta-fructofuranosidase [EC:3.2.1.26] cac:CA_C0425 cac00052
# 67 lactose PTS system EIICB component [EC:2.7.1.207] cac:CA_C2964 cac00052
# 73 glucokinase [EC:2.7.1.2] cac:CA_C2613 cac00052
# 77 phosphoglucomutase [EC:5.4.2.2] cac:CA_C2337 cac00052
# 79 UDP-glucose 4-epimerase [EC:5.1.3.2] cac:CA_C0794 cac00052
# 80 UTP--glucose-1-phosphate uridylyltransferase [EC:2.7.7.9] cac:CA_C2250 cac00052
# 82 UDPglucose--hexose-1-phosphate uridylyltransferase [EC:2.7.7.12] cac:CA_C2844 cac00052
# 94 beta-galactosidase [EC:3.2.1.23] cac:CA_C2514 cac00052
# 100 galactose-6-phosphate isomerase [EC:5.3.1.26] cac:CA_C2953 cac00052
# 101 N-acetylgalactosamine PTS system EIIA component [EC:2.7.1.-] cac:CA_C1457 cac00052
# 110 N-acetylgalactosamine PTS system EIIA component [EC:2.7.1.-] cac:CA_C1457 cac00052
# 171 galactokinase [EC:2.7.1.6] cac:CA_C2959 cac00052
# 172 aldose 1-epimerase [EC:5.1.3.3] cac:CA_C0697 cac00052
# 175 UDP-galactopyranose mutase [EC:5.4.99.9] cac:CA_C2169 cac00052
# 24 enoyl-[acyl-carrier protein] reductase II [EC:1.3.1.9] cac:CA_C3576 cac00061
# 25 enoyl-[acyl-carrier protein] reductase II [EC:1.3.1.9] cac:CA_C3576 cac00061
# 26 enoyl-[acyl-carrier protein] reductase II [EC:1.3.1.9] cac:CA_C3576 cac00061
# 27 enoyl-[acyl-carrier protein] reductase II [EC:1.3.1.9] cac:CA_C3576 cac00061
# 28 enoyl-[acyl-carrier protein] reductase II [EC:1.3.1.9] cac:CA_C3576 cac00061
# 29 enoyl-[acyl-carrier protein] reductase II [EC:1.3.1.9] cac:CA_C3576 cac00061
# 57 enoyl-[acyl-carrier protein] reductase II [EC:1.3.1.9] cac:CA_C3576 cac00061
# 58 3-hydroxyacyl-[acyl-carrier-protein] dehydratase [EC:4.2.1.59] cac:CA_C3571 cac00061
# 59 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] cac:CA_C2008 cac00061
# 60 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] cac:CA_C2626 cac00061
# 64 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] cac:CA_C2008 cac00061
# 65 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] cac:CA_C2008 cac00061
# 66 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] cac:CA_C2008 cac00061
# 67 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] cac:CA_C2008 cac00061
# 68 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] cac:CA_C2008 cac00061
# 69 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] cac:CA_C2008 cac00061
# 81 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] cac:CA_C2626 cac00061
# 92 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] cac:CA_C2626 cac00061
# 103 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] cac:CA_C2626 cac00061
# 114 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] cac:CA_C2626 cac00061
# 125 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] cac:CA_C2626 cac00061
# 136 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] cac:CA_C2626 cac00061
# 148 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] cac:CA_C2626 cac00061
# 153 [acyl-carrier-protein] S-malonyltransferase [EC:2.3.1.39] cac:CA_C3575 cac00061
# 159 acetyl-CoA carboxylase carboxyl transferase subunit alpha [EC:6.4.1.2 2.1.3.15] cac:CA_C3568 cac00061
# 263 enoyl-[acyl-carrier protein] reductase II [EC:1.3.1.9] cac:CA_C3576 cac00061
# 265 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] cac:CA_C2008 cac00061
# 268 3-oxoacyl-[acyl-carrier-protein] synthase III [EC:2.3.1.180] cac:CA_C0814 cac00061
# 269 enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase (NAD+) [EC:1.3.1.9 1.3.1.44] cac:CA_C0462 cac00061
# 270 enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase (NAD+) [EC:1.3.1.9 1.3.1.44] cac:CA_C0462 cac00061
# 271 enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase (NAD+) [EC:1.3.1.9 1.3.1.44] cac:CA_C0462 cac00061
# 272 3-hydroxyacyl-[acyl-carrier-protein] dehydratase [EC:4.2.1.59] cac:CA_C3571 cac00061
# 274 3-hydroxyacyl-[acyl-carrier-protein] dehydratase [EC:4.2.1.59] cac:CA_C3571 cac00061
# 275 enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase (NAD+) [EC:1.3.1.9 1.3.1.44] cac:CA_C0462 cac00061
# 277 3-hydroxyacyl-[acyl-carrier-protein] dehydratase [EC:4.2.1.59] cac:CA_C3571 cac00061
# 279 3-hydroxyacyl-[acyl-carrier-protein] dehydratase [EC:4.2.1.59] cac:CA_C3571 cac00061
# 281 3-hydroxyacyl-[acyl-carrier-protein] dehydratase [EC:4.2.1.59] cac:CA_C3571 cac00061
# 282 enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase (NAD+) [EC:1.3.1.9 1.3.1.44] cac:CA_C0462 cac00061
# 284 3-hydroxyacyl-[acyl-carrier-protein] dehydratase [EC:4.2.1.59] cac:CA_C3571 cac00061
# 285 enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase (NAD+) [EC:1.3.1.9 1.3.1.44] cac:CA_C0462 cac00061
# 287 3-hydroxyacyl-[acyl-carrier-protein] dehydratase [EC:4.2.1.59] cac:CA_C3571 cac00061
# 288 enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase (NAD+) [EC:1.3.1.9 1.3.1.44] cac:CA_C0462 cac00061
# 348 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] cac:CA_C2626 cac00061
# 369 enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase (NAD+) [EC:1.3.1.9 1.3.1.44] cac:CA_C0462 cac00061
# 384 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] cac:CA_C2008 cac00061
# 401 3-oxoacyl-[acyl-carrier-protein] synthase III [EC:2.3.1.180] cac:CA_C0814 cac00061
# 402 [acyl-carrier-protein] S-malonyltransferase [EC:2.3.1.39] cac:CA_C3575 cac00061
# 403 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] cac:CA_C2626 cac00061
# 404 3-hydroxyacyl-[acyl-carrier-protein] dehydratase [EC:4.2.1.59] cac:CA_C3571 cac00061
# 405 [acyl-carrier-protein] S-malonyltransferase [EC:2.3.1.39] cac:CA_C3575 cac00061
# 406 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] cac:CA_C2008 cac00061
# 409 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] cac:CA_C2008 cac00061
# 411 acetyl-CoA carboxylase carboxyl transferase subunit alpha [EC:6.4.1.2 2.1.3.15] cac:CA_C3568 cac00061
# 45 butyryl-CoA dehydrogenase [EC:1.3.8.1] cac:CA_C2711 cac00071
# 53 acetyl-CoA C-acetyltransferase [EC:2.3.1.9] cac:CA_C2873 cac00071
# 57 butyryl-CoA dehydrogenase [EC:1.3.8.1] cac:CA_C2711 cac00071
# 77 rubredoxin---NAD+ reductase [EC:1.18.1.1] cac:CA_C2448 cac00071
# 84 S-(hydroxymethyl)glutathione dehydrogenase / alcohol dehydrogenase [EC:1.1.1.284 1.1.1.1] cac:CA_C3375 cac00071
# 202 acetyl-CoA C-acetyltransferase [EC:2.3.1.9] cac:CA_C2873 cac00071
# 13 acetoacetate decarboxylase [EC:4.1.1.4] cac:CA_P0165 cac00072
# 14 acetyl-CoA C-acetyltransferase [EC:2.3.1.9] cac:CA_C2873 cac00072
# 92 4-hydroxybenzoate polyprenyltransferase [EC:2.5.1.39] cac:CA_C0800 cac00130
# 167 NAD(P)H dehydrogenase (quinone) [EC:1.6.5.2] cac:CA_C0018 cac00130
# 170 NAD(P)H dehydrogenase (quinone) [EC:1.6.5.2] cac:CA_C0018 cac00130
# 112 F-type H+-transporting ATPase subunit epsilon cac:CA_C2864 cac00190
# 115 manganese-dependent inorganic pyrophosphatase [EC:3.6.1.1] cac:CA_C2138 cac00190
# 116 polyphosphate kinase [EC:2.7.4.1] cac:CA_C0622 cac00190
# 178 F-type H+/Na+-transporting ATPase subunit beta [EC:7.1.2.2 7.2.2.1] cac:CA_C2865 cac00190
# 179 F-type H+/Na+-transporting ATPase subunit alpha [EC:7.1.2.2 7.2.2.1] cac:CA_C2867 cac00190
# 180 F-type H+-transporting ATPase subunit gamma cac:CA_C2866 cac00190
# 181 F-type H+-transporting ATPase subunit delta cac:CA_C2868 cac00190
# 182 F-type H+-transporting ATPase subunit epsilon cac:CA_C2864 cac00190
# 183 F-type H+-transporting ATPase subunit c cac:CA_C2870 cac00190
# 184 F-type H+-transporting ATPase subunit a cac:CA_C2871 cac00190
# 185 F-type H+-transporting ATPase subunit b cac:CA_C2869 cac00190
# 46 glutamine synthetase [EC:6.3.1.2] cac:CA_C2658 cac00220
# 49 ornithine carbamoyltransferase [EC:2.1.3.3] cac:CA_C0316 cac00220
# 50 argininosuccinate synthase [EC:6.3.4.5] cac:CA_C0973 cac00220
# 52 argininosuccinate lyase [EC:4.3.2.1] cac:CA_C0974 cac00220
# 53 arginase [EC:3.5.3.1] cac:CA_C1054 cac00220
# 54 glutamate N-acetyltransferase / amino-acid N-acetyltransferase [EC:2.3.1.35 2.3.1.1] cac:CA_C2391 cac00220
# 55 acetylglutamate kinase [EC:2.7.2.8] cac:CA_C2389 cac00220
# 56 N-acetyl-gamma-glutamyl-phosphate reductase [EC:1.2.1.38] cac:CA_C2390 cac00220
# 57 acetylornithine/N-succinyldiaminopimelate aminotransferase [EC:2.6.1.11 2.6.1.17] cac:CA_C2388 cac00220
# 60 glutamate N-acetyltransferase / amino-acid N-acetyltransferase [EC:2.3.1.35 2.3.1.1] cac:CA_C2391 cac00220
# 68 glutamate dehydrogenase (NADP+) [EC:1.4.1.4] cac:CA_C0737 cac00220
# 88 aspartate aminotransferase [EC:2.6.1.1] cac:CA_C1001 cac00220
# 137 ribonucleoside-diphosphate reductase alpha chain [EC:1.17.4.1] cac:CA_C1047 cac00230
# 157 ribose-phosphate pyrophosphokinase [EC:2.7.6.1] cac:CA_C0819 cac00230
# 158 amidophosphoribosyltransferase [EC:2.4.2.14] cac:CA_C1392 cac00230
# 160 phosphoribosylamine---glycine ligase [EC:6.3.4.13] cac:CA_C1396 cac00230
# 161 phosphoribosylglycinamide formyltransferase 1 [EC:2.1.2.2] cac:CA_C1394 cac00230
# 162 phosphoribosylformylglycinamidine cyclo-ligase [EC:6.3.3.1] cac:CA_C1393 cac00230
# 163 phosphoribosylaminoimidazolecarboxamide formyltransferase / IMP cyclohydrolase [EC:2.1.2.3 3.5.4.10] cac:CA_C1395 cac00230
# 164 adenylosuccinate lyase [EC:4.3.2.2] cac:CA_C1821 cac00230
# 165 phosphoribosylaminoimidazole-succinocarboxamide synthase [EC:6.3.2.6] cac:CA_C1391 cac00230
# 167 phosphoribosylaminoimidazolecarboxamide formyltransferase / IMP cyclohydrolase [EC:2.1.2.3 3.5.4.10] cac:CA_C1395 cac00230
# 169 adenylate cyclase, class 2 [EC:4.6.1.1] cac:CA_C0650 cac00230
# 175 ribonucleoside-diphosphate reductase alpha chain [EC:1.17.4.1] cac:CA_C1047 cac00230
# 177 adenylate kinase [EC:2.7.4.3] cac:CA_C3112 cac00230
# 178 adenylosuccinate lyase [EC:4.3.2.2] cac:CA_C1821 cac00230
# 179 adenylosuccinate synthase [EC:6.3.4.4] cac:CA_C3593 cac00230
# 183 adenine phosphoribosyltransferase [EC:2.4.2.7] cac:CA_C2275 cac00230
# 186 adenosine deaminase [EC:3.5.4.4] cac:CA_C3005 cac00230
# 187 purine-nucleoside phosphorylase [EC:2.4.2.1] cac:CA_C2064 cac00230
# 189 purine-nucleoside phosphorylase [EC:2.4.2.1] cac:CA_C2064 cac00230
# 192 adenosine deaminase [EC:3.5.4.4] cac:CA_C3005 cac00230
# 195 adenine deaminase [EC:3.5.4.2] cac:CA_C0887 cac00230
# 199 GMP reductase [EC:1.7.1.7] cac:CA_C3471 cac00230
# 200 IMP dehydrogenase [EC:1.1.1.205] cac:CA_C2701 cac00230
# 201 GMP synthase (glutamine-hydrolysing) [EC:6.3.5.2] cac:CA_C2700 cac00230
# 204 hypoxanthine phosphoribosyltransferase [EC:2.4.2.8] cac:CA_C3203 cac00230
# 206 purine-nucleoside phosphorylase [EC:2.4.2.1] cac:CA_C2064 cac00230
# 209 purine-nucleoside phosphorylase [EC:2.4.2.1] cac:CA_C2064 cac00230
# 211 hypoxanthine phosphoribosyltransferase [EC:2.4.2.8] cac:CA_C3203 cac00230
# 214 hypoxanthine phosphoribosyltransferase [EC:2.4.2.8] cac:CA_C3203 cac00230
# 215 guanylate kinase [EC:2.7.4.8] cac:CA_C1718 cac00230
# 216 purine-nucleoside phosphorylase [EC:2.4.2.1] cac:CA_C2064 cac00230
# 217 guanine deaminase [EC:3.5.4.3] cac:CA_C0282 cac00230
# 229 exopolyphosphatase / guanosine-5'-triphosphate,3'-diphosphate pyrophosphatase [EC:3.6.1.11 3.6.1.40] cac:CA_C0621 cac00230
# 230 exopolyphosphatase / guanosine-5'-triphosphate,3'-diphosphate pyrophosphatase [EC:3.6.1.11 3.6.1.40] cac:CA_C0621 cac00230
# 233 guanylate kinase [EC:2.7.4.8] cac:CA_C1718 cac00230
# 237 purine-nucleoside phosphorylase [EC:2.4.2.1] cac:CA_C2064 cac00230
# 238 putative GTP pyrophosphokinase [EC:2.7.6.5] cac:CA_C0642 cac00230
# 244 sulfate adenylyltransferase subunit 2 [EC:2.7.7.4] cac:CA_C0109 cac00230
# 245 adenylylsulfate kinase [EC:2.7.1.25] cac:CA_C0103 cac00230
# 252 phosphoribosylformylglycinamidine synthase [EC:6.3.5.3] cac:CA_C1655 cac00230
# 259 xanthine phosphoribosyltransferase [EC:2.4.2.22] cac:CA_C0873 cac00230
# 262 2',3'-cyclic-nucleotide 2'-phosphodiesterase / 3'-nucleotidase / 5'-nucleotidase [EC:3.1.4.16 3.1.3.6 3.1.3.5] cac:CA_C0353 cac00230
# 263 2',3'-cyclic-nucleotide 2'-phosphodiesterase / 3'-nucleotidase / 5'-nucleotidase [EC:3.1.4.16 3.1.3.6 3.1.3.5] cac:CA_C0353 cac00230
# 264 2',3'-cyclic-nucleotide 2'-phosphodiesterase / 3'-nucleotidase / 5'-nucleotidase [EC:3.1.4.16 3.1.3.6 3.1.3.5] cac:CA_C0353 cac00230
# 271 2',3'-cyclic-nucleotide 2'-phosphodiesterase / 3'-nucleotidase / 5'-nucleotidase [EC:3.1.4.16 3.1.3.6 3.1.3.5] cac:CA_C0353 cac00230
# 273 phosphopentomutase [EC:5.4.2.7] cac:CA_C2065 cac00230
# 274 ADP-ribose pyrophosphatase [EC:3.6.1.13] cac:CA_C1854 cac00230
# 277 xanthine phosphoribosyltransferase [EC:2.4.2.22] cac:CA_C0873 cac00230
# 278 purine-nucleoside phosphorylase [EC:2.4.2.1] cac:CA_C2064 cac00230
# 279 adenylate kinase [EC:2.7.4.3] cac:CA_C3112 cac00230
# 291 adenylate cyclase, class 2 [EC:4.6.1.1] cac:CA_C0650 cac00230
# 292 pyruvate kinase [EC:2.7.1.40] cac:CA_C0518 cac00230
# 293 pyruvate kinase [EC:2.7.1.40] cac:CA_C0518 cac00230
# 294 adenine phosphoribosyltransferase [EC:2.4.2.7] cac:CA_C2275 cac00230
# 296 adenine phosphoribosyltransferase [EC:2.4.2.7] cac:CA_C2275 cac00230
# 304 pyruvate kinase [EC:2.7.1.40] cac:CA_C0518 cac00230
# 305 pyruvate kinase [EC:2.7.1.40] cac:CA_C0518 cac00230
# 420 5-(carboxyamino)imidazole ribonucleotide mutase [EC:5.4.99.18] cac:CA_C1390 cac00230
# 423 phosphoglucomutase [EC:5.4.2.2] cac:CA_C2337 cac00230
# 429 XTP/dITP diphosphohydrolase [EC:3.6.1.66] cac:CA_C2665 cac00230
# 430 XTP/dITP diphosphohydrolase [EC:3.6.1.66] cac:CA_C2665 cac00230
# 437 ribonucleoside-triphosphate reductase (formate) [EC:1.1.98.6] cac:CA_C0480 cac00230
# 438 ribonucleoside-triphosphate reductase (formate) [EC:1.1.98.6] cac:CA_C0480 cac00230
# 81 ribonucleoside-diphosphate reductase alpha chain [EC:1.17.4.1] cac:CA_C1047 cac00240
# 84 uridylate kinase [EC:2.7.4.22] cac:CA_C1789 cac00240
# 88 carbamoyl-phosphate synthase large subunit [EC:6.3.5.5] cac:CA_C2189 cac00240
# 94 aspartate carbamoyltransferase regulatory subunit cac:CA_C2653 cac00240
# 95 dihydroorotase [EC:3.5.2.3] cac:CA_C0519 cac00240
# 96 dihydroorotate dehydrogenase (NAD+) catalytic subunit [EC:1.3.1.14] cac:CA_C2650 cac00240
# 98 orotate phosphoribosyltransferase [EC:2.4.2.10] cac:CA_C0027 cac00240
# 101 dCTP deaminase [EC:3.5.4.13] cac:CA_C0025 cac00240
# 102 CTP synthase [EC:6.3.4.2] cac:CA_C2892 cac00240
# 107 pyrimidine operon attenuation protein / uracil phosphoribosyltransferase [EC:2.4.2.9] cac:CA_C2113 cac00240
# 108 uridine kinase [EC:2.7.1.48] cac:CA_C0672 cac00240
# 120 uridine kinase [EC:2.7.1.48] cac:CA_C0672 cac00240
# 122 cytidine deaminase [EC:3.5.4.5] cac:CA_C1544 cac00240
# 124 pyrimidine-nucleoside phosphorylase [EC:2.4.2.2] cac:CA_C1546 cac00240
# 131 ribonucleoside-diphosphate reductase alpha chain [EC:1.17.4.1] cac:CA_C1047 cac00240
# 133 dCTP deaminase [EC:3.5.4.13] cac:CA_C0025 cac00240
# 139 dCMP deaminase [EC:3.5.4.12] cac:CA_C2876 cac00240
# 143 thymidine kinase [EC:2.7.1.21] cac:CA_C2887 cac00240
# 144 cytidine deaminase [EC:3.5.4.5] cac:CA_C1544 cac00240
# 145 pyrimidine-nucleoside phosphorylase [EC:2.4.2.2] cac:CA_C1546 cac00240
# 146 purine-nucleoside phosphorylase [EC:2.4.2.1] cac:CA_C2064 cac00240
# 148 thymidylate synthase [EC:2.1.1.45] cac:CA_C3003 cac00240
# 155 thymidine kinase [EC:2.7.1.21] cac:CA_C2887 cac00240
# 169 orotidine-5'-phosphate decarboxylase [EC:4.1.1.23] cac:CA_C2652 cac00240
# 172 2',3'-cyclic-nucleotide 2'-phosphodiesterase / 3'-nucleotidase / 5'-nucleotidase [EC:3.1.4.16 3.1.3.6 3.1.3.5] cac:CA_C0353 cac00240
# 173 2',3'-cyclic-nucleotide 2'-phosphodiesterase / 3'-nucleotidase / 5'-nucleotidase [EC:3.1.4.16 3.1.3.6 3.1.3.5] cac:CA_C0353 cac00240
# 176 2',3'-cyclic-nucleotide 2'-phosphodiesterase / 3'-nucleotidase / 5'-nucleotidase [EC:3.1.4.16 3.1.3.6 3.1.3.5] cac:CA_C0353 cac00240
# 177 2',3'-cyclic-nucleotide 2'-phosphodiesterase / 3'-nucleotidase / 5'-nucleotidase [EC:3.1.4.16 3.1.3.6 3.1.3.5] cac:CA_C0353 cac00240
# 288 dUTP pyrophosphatase [EC:3.6.1.23] cac:CA_C1210 cac00240
# 289 CMP/dCMP kinase [EC:2.7.4.25] cac:CA_C1848 cac00240
# 290 CMP/dCMP kinase [EC:2.7.4.25] cac:CA_C1848 cac00240
# 291 ribonucleoside-triphosphate reductase (formate) [EC:1.1.98.6] cac:CA_C0480 cac00240
# 292 ribonucleoside-triphosphate reductase (formate) [EC:1.1.98.6] cac:CA_C0480 cac00240
# 35 asparagine synthase (glutamine-hydrolysing) [EC:6.3.5.4] cac:CA_C2243 cac00250
# 38 L-asparaginase [EC:3.5.1.1] cac:CA_C1714 cac00250
# 48 L-aspartate oxidase [EC:1.4.3.16] cac:CA_C1024 cac00250
# 49 aspartate aminotransferase [EC:2.6.1.1] cac:CA_C1001 cac00250
# 55 argininosuccinate synthase [EC:6.3.4.5] cac:CA_C0973 cac00250
# 56 adenylosuccinate synthase [EC:6.3.4.4] cac:CA_C3593 cac00250
# 57 aspartate ammonia-lyase [EC:4.3.1.1] cac:CA_C0274 cac00250
# 58 argininosuccinate lyase [EC:4.3.2.1] cac:CA_C0974 cac00250
# 59 adenylosuccinate lyase [EC:4.3.2.2] cac:CA_C1821 cac00250
# 71 aspartate carbamoyltransferase regulatory subunit cac:CA_C2653 cac00250
# 89 glutamate synthase (NADPH) small chain [EC:1.4.1.13] cac:CA_C0764 cac00250
# 94 glutamate dehydrogenase (NADP+) [EC:1.4.1.4] cac:CA_C0737 cac00250
# 97 4-aminobutyrate aminotransferase [EC:2.6.1.19] cac:CA_C0368 cac00250
# 102 glutamine synthetase [EC:6.3.1.2] cac:CA_C2658 cac00250
# 110 carbamoyl-phosphate synthase large subunit [EC:6.3.5.5] cac:CA_C2189 cac00250
# 123 glutamine---fructose-6-phosphate transaminase (isomerizing) [EC:2.6.1.16] cac:CA_C0158 cac00250
# 125 amidophosphoribosyltransferase [EC:2.4.2.14] cac:CA_C1392 cac00250
# 80 D-3-phosphoglycerate dehydrogenase / 2-oxoglutarate reductase [EC:1.1.1.95 1.1.1.399] cac:CA_C0015 cac00260
# 81 glycerate dehydrogenase [EC:1.1.1.29] cac:CA_C2945 cac00260
# 86 aspartate kinase [EC:2.7.2.4] cac:CA_C0278 cac00260
# 92 glycine hydroxymethyltransferase [EC:2.1.2.1] cac:CA_C2264 cac00260
# 94 threonine aldolase [EC:4.1.2.48] cac:CA_C3420 cac00260
# 97 threonine synthase [EC:4.2.3.1] cac:CA_C0999 cac00260
# 103 aspartate-semialdehyde dehydrogenase [EC:1.2.1.11] cac:CA_C0022 cac00260
# 105 L-serine dehydratase [EC:4.3.1.17] cac:CA_C0673 cac00260
# 109 homoserine kinase [EC:2.7.1.39] cac:CA_C1235 cac00260
# 113 homoserine dehydrogenase [EC:1.1.1.3] cac:CA_C0998 cac00260
# 138 threonine aldolase [EC:4.1.2.48] cac:CA_C3420 cac00260
# 195 CDP-diacylglycerol---serine O-phosphatidyltransferase [EC:2.7.8.8] cac:CA_C0676 cac00260
# 199 tryptophan synthase alpha chain [EC:4.2.1.20] cac:CA_C3157 cac00260
# 216 glycerate 2-kinase [EC:2.7.1.165] cac:CA_C2834 cac00260
# 217 2,3-bisphosphoglycerate-dependent phosphoglycerate mutase [EC:5.4.2.11] cac:CA_C2741 cac00260
# 227 2,3-bisphosphoglycerate-independent phosphoglycerate mutase [EC:5.4.2.12] cac:CA_C0712 cac00260
# 62 aspartate kinase [EC:2.7.2.4] cac:CA_C0278 cac00261
# 63 aspartate-semialdehyde dehydrogenase [EC:1.2.1.11] cac:CA_C0022 cac00261
# 96 4-hydroxy-tetrahydrodipicolinate reductase [EC:1.17.1.8] cac:CA_C2379 cac00261
# 97 4-hydroxy-tetrahydrodipicolinate synthase [EC:4.3.3.7] cac:CA_C2378 cac00261
# 101 sulfate adenylyltransferase subunit 2 [EC:2.7.7.4] cac:CA_C0109 cac00261
# 88 adenosylhomocysteine nucleosidase [EC:3.2.2.9] cac:CA_C2117 cac00270
# 89 spermidine synthase [EC:2.5.1.16] cac:CA_C2602 cac00270
# 90 S-adenosylmethionine decarboxylase [EC:4.1.1.50] cac:CA_C2601 cac00270
# 91 L-methionine (R)-S-oxide reductase [EC:1.8.4.14] cac:CA_C2110 cac00270
# 97 5-methyltetrahydrofolate--homocysteine methyltransferase [EC:2.1.1.13] cac:CA_C0578 cac00270
# 98 cysteine-S-conjugate beta-lyase [EC:4.4.1.13] cac:CA_C0391 cac00270
# 101 S-adenosylmethionine synthetase [EC:2.5.1.6] cac:CA_C2856 cac00270
# 103 DNA (cytosine-5)-methyltransferase 1 [EC:2.1.1.37] cac:CA_C1222 cac00270
# 107 methionine synthase / methylenetetrahydrofolate reductase(NADPH) [EC:2.1.1.13 1.5.1.20] cac:CA_C0291 cac00270
# 108 S-ribosylhomocysteine lyase [EC:4.4.1.21] cac:CA_C2942 cac00270
# 109 adenosylhomocysteine nucleosidase [EC:3.2.2.9] cac:CA_C2117 cac00270
# 110 cystathionine gamma-synthase [EC:2.5.1.48] cac:CA_C0390 cac00270
# 132 cysteine synthase [EC:2.5.1.47] cac:CA_C0931 cac00270
# 133 serine O-acetyltransferase [EC:2.3.1.30] cac:CA_C0687 cac00270
# 149 L-serine dehydratase [EC:4.3.1.17] cac:CA_C0673 cac00270
# 158 aspartate aminotransferase [EC:2.6.1.1] cac:CA_C1001 cac00270
# 185 aspartate aminotransferase [EC:2.6.1.1] cac:CA_C1001 cac00270
# 194 cysteine-S-conjugate beta-lyase [EC:4.4.1.13] cac:CA_C0391 cac00270
# 199 aspartate aminotransferase [EC:2.6.1.1] cac:CA_C1001 cac00270
# 202 L-lactate dehydrogenase [EC:1.1.1.27] cac:CA_C0267 cac00270
# 207 homoserine O-succinyltransferase/O-acetyltransferase [EC:2.3.1.46 2.3.1.31] cac:CA_C1825 cac00270
# 208 homoserine O-succinyltransferase/O-acetyltransferase [EC:2.3.1.46 2.3.1.31] cac:CA_C1825 cac00270
# 212 cystathionine gamma-synthase [EC:2.5.1.48] cac:CA_C0390 cac00270
# 213 cystathionine gamma-synthase [EC:2.5.1.48] cac:CA_C0390 cac00270
# 214 cystathionine gamma-synthase [EC:2.5.1.48] cac:CA_C0390 cac00270
# 215 O-acetylhomoserine (thiol)-lyase [EC:2.5.1.49] cac:CA_C0102 cac00270
# 217 cystathionine gamma-synthase [EC:2.5.1.48] cac:CA_C0390 cac00270
# 224 homoserine dehydrogenase [EC:1.1.1.3] cac:CA_C0998 cac00270
# 227 aspartate-semialdehyde dehydrogenase [EC:1.2.1.11] cac:CA_C0022 cac00270
# 230 aspartate kinase [EC:2.7.2.4] cac:CA_C0278 cac00270
# 260 branched-chain amino acid aminotransferase [EC:2.6.1.42] cac:CA_C1479 cac00270
# 262 glutamate--cysteine ligase [EC:6.3.2.2] cac:CA_C1539 cac00270
# 285 cysteine-S-conjugate beta-lyase [EC:4.4.1.13] cac:CA_C0391 cac00270
# 290 D-3-phosphoglycerate dehydrogenase / 2-oxoglutarate reductase [EC:1.1.1.95 1.1.1.399] cac:CA_C0015 cac00270
# 295 cysteine synthase [EC:2.5.1.47] cac:CA_C0931 cac00270
# 72 acetyl-CoA C-acetyltransferase [EC:2.3.1.9] cac:CA_C2873 cac00280
# 85 branched-chain amino acid aminotransferase [EC:2.6.1.42] cac:CA_C1479 cac00280
# 92 branched-chain amino acid aminotransferase [EC:2.6.1.42] cac:CA_C1479 cac00280
# 100 4-aminobutyrate aminotransferase / (S)-3-amino-2-methylpropionate transaminase / 5-aminovalerate transaminase [EC:2.6.1.19 2.6.1.22 2.6.1.48] cac:CA_C1427 cac00280
# 102 3-hydroxyisobutyrate dehydrogenase [EC:1.1.1.31] cac:CA_C3342 cac00280
# 111 branched-chain amino acid aminotransferase [EC:2.6.1.42] cac:CA_C1479 cac00280
# 121 butyryl-CoA dehydrogenase [EC:1.3.8.1] cac:CA_C2711 cac00280
# 122 butyryl-CoA dehydrogenase [EC:1.3.8.1] cac:CA_C2711 cac00280
# 22 3-isopropylmalate/(R)-2-methylmalate dehydratase small subunit [EC:4.2.1.33 4.2.1.35] cac:CA_C3172 cac00290
# 23 3-isopropylmalate dehydrogenase [EC:1.1.1.85] cac:CA_C3171 cac00290
# 32 branched-chain amino acid aminotransferase [EC:2.6.1.42] cac:CA_C1479 cac00290
# 34 branched-chain amino acid aminotransferase [EC:2.6.1.42] cac:CA_C1479 cac00290
# 35 ketol-acid reductoisomerase [EC:1.1.1.86] cac:CA_C0091 cac00290
# 36 3-isopropylmalate/(R)-2-methylmalate dehydratase small subunit [EC:4.2.1.33 4.2.1.35] cac:CA_C3172 cac00290
# 37 3-isopropylmalate dehydrogenase [EC:1.1.1.85] cac:CA_C3171 cac00290
# 38 3-isopropylmalate/(R)-2-methylmalate dehydratase small subunit [EC:4.2.1.33 4.2.1.35] cac:CA_C3172 cac00290
# 39 2-isopropylmalate synthase [EC:2.3.3.13] cac:CA_C0273 cac00290
# 41 branched-chain amino acid aminotransferase [EC:2.6.1.42] cac:CA_C1479 cac00290
# 42 dihydroxy-acid dehydratase [EC:4.2.1.9] cac:CA_C3170 cac00290
# 43 ketol-acid reductoisomerase [EC:1.1.1.86] cac:CA_C0091 cac00290
# 45 ketol-acid reductoisomerase [EC:1.1.1.86] cac:CA_C0091 cac00290
# 46 dihydroxy-acid dehydratase [EC:4.2.1.9] cac:CA_C3170 cac00290
# 47 ketol-acid reductoisomerase [EC:1.1.1.86] cac:CA_C0091 cac00290
# 48 acetolactate synthase I/II/III large subunit [EC:2.2.1.6] cac:CA_C3169 cac00290
# 85 3-isopropylmalate/(R)-2-methylmalate dehydratase small subunit [EC:4.2.1.33 4.2.1.35] cac:CA_C3172 cac00290
# 86 acetolactate synthase I/II/III large subunit [EC:2.2.1.6] cac:CA_C3169 cac00290
# 39 LL-diaminopimelate aminotransferase [EC:2.6.1.83] cac:CA_C1715 cac00300
# 51 UDP-N-acetylmuramoyl-tripeptide--D-alanyl-D-alanine ligase [EC:6.3.2.10] cac:CA_C2128 cac00300
# 55 aspartate kinase [EC:2.7.2.4] cac:CA_C0278 cac00300
# 56 aspartate-semialdehyde dehydrogenase [EC:1.2.1.11] cac:CA_C0022 cac00300
# 57 homoserine dehydrogenase [EC:1.1.1.3] cac:CA_C0998 cac00300
# 58 4-hydroxy-tetrahydrodipicolinate synthase [EC:4.3.3.7] cac:CA_C2378 cac00300
# 59 4-hydroxy-tetrahydrodipicolinate reductase [EC:1.17.1.8] cac:CA_C2379 cac00300
# 62 2,3,4,5-tetrahydropyridine-2,6-dicarboxylate N-succinyltransferase [EC:2.3.1.117] cac:CA_C2381 cac00300
# 63 aminotransferase [EC:2.6.1.-] cac:CA_C0375 cac00300
# 64 acetylornithine/N-succinyldiaminopimelate aminotransferase [EC:2.6.1.11 2.6.1.17] cac:CA_C2388 cac00300
# 66 succinyl-diaminopimelate desuccinylase [EC:3.5.1.18] cac:CA_C2723 cac00300
# 67 diaminopimelate epimerase [EC:5.1.1.7] cac:CA_C2624 cac00300
# 68 diaminopimelate decarboxylase [EC:4.1.1.20] cac:CA_C0608 cac00300
# 82 UDP-N-acetylmuramoyl-L-alanyl-D-glutamate--2,6-diaminopimelate ligase [EC:6.3.2.13] cac:CA_C2129 cac00300
# 70 D-alanine transaminase [EC:2.6.1.21] cac:CA_C0792 cac00310
# 91 acetyl-CoA C-acetyltransferase [EC:2.3.1.9] cac:CA_C2873 cac00310
# 96 4-aminobutyrate aminotransferase / (S)-3-amino-2-methylpropionate transaminase / 5-aminovalerate transaminase [EC:2.6.1.19 2.6.1.22 2.6.1.48] cac:CA_C1427 cac00310
# 178 acetate CoA/acetoacetate CoA-transferase alpha subunit [EC:2.8.3.8 2.8.3.9] cac:CA_P0163 cac00310
# 47 arginase [EC:3.5.3.1] cac:CA_C1054 cac00330
# 67 spermidine synthase [EC:2.5.1.16] cac:CA_C2602 cac00330
# 68 S-adenosylmethionine decarboxylase [EC:4.1.1.50] cac:CA_C2601 cac00330
# 126 arginine decarboxylase [EC:4.1.1.19] cac:CA_C2338 cac00330
# 173 pyrroline-5-carboxylate reductase [EC:1.5.1.2] cac:CA_C3252 cac00330
# 176 glutamate 5-kinase [EC:2.7.2.11] cac:CA_C3253 cac00330
# 177 glutamate-5-semialdehyde dehydrogenase [EC:1.2.1.41] cac:CA_C3254 cac00330
# 206 pyrroline-5-carboxylate reductase [EC:1.5.1.2] cac:CA_C3252 cac00330
# 209 aspartate aminotransferase [EC:2.6.1.1] cac:CA_C1001 cac00330
# 210 D-alanine transaminase [EC:2.6.1.21] cac:CA_C0792 cac00330
# 5 glutamate 5-kinase [EC:2.7.2.11] cac:CA_C3253 cac00332
# 8 glutamate-5-semialdehyde dehydrogenase [EC:1.2.1.41] cac:CA_C3254 cac00332
# 59 ATP phosphoribosyltransferase regulatory subunit cac:CA_C0935 cac00340
# 60 histidinol dehydrogenase [EC:1.1.1.23] cac:CA_C0937 cac00340
# 61 histidinol dehydrogenase [EC:1.1.1.23] cac:CA_C0937 cac00340
# 62 histidinol-phosphatase (PHP family) [EC:3.1.3.15] cac:CA_C2727 cac00340
# 63 histidinol-phosphate aminotransferase [EC:2.6.1.9] cac:CA_C3031 cac00340
# 64 imidazoleglycerol-phosphate dehydratase [EC:4.2.1.19] cac:CA_C0938 cac00340
# 66 phosphoribosylformimino-5-aminoimidazole carboxamide ribotide isomerase [EC:5.3.1.16] cac:CA_C0940 cac00340
# 67 phosphoribosyl-AMP cyclohydrolase [EC:3.5.4.19] cac:CA_C0942 cac00340
# 68 phosphoribosyl-ATP pyrophosphohydrolase [EC:3.6.1.31] cac:CA_C0943 cac00340
# 70 imidazole glycerol-phosphate synthase subunit HisH [EC:4.3.2.10] cac:CA_C0939 cac00340
# 66 aspartate aminotransferase [EC:2.6.1.1] cac:CA_C1001 cac00350
# 104 histidinol-phosphate aminotransferase [EC:2.6.1.9] cac:CA_C3031 cac00350
# 205 S-(hydroxymethyl)glutathione dehydrogenase / alcohol dehydrogenase [EC:1.1.1.284 1.1.1.1] cac:CA_C3375 cac00350
# 115 histidinol-phosphate aminotransferase [EC:2.6.1.9] cac:CA_C3031 cac00360
# 117 aspartate aminotransferase [EC:2.6.1.1] cac:CA_C1001 cac00360
# 120 D-alanine transaminase [EC:2.6.1.21] cac:CA_C0792 cac00360
# 136 2-enoate reductase [EC:1.3.1.31] cac:CA_C3371 cac00360
# 227 3-hydroxybutyryl-CoA dehydrogenase [EC:1.1.1.157] cac:CA_C2708 cac00360
# 129 3-hydroxybutyryl-CoA dehydrogenase [EC:1.1.1.157] cac:CA_C2708 cac00362
# 132 acetyl-CoA C-acetyltransferase [EC:2.3.1.9] cac:CA_C2873 cac00362
# 11 3-deoxy-7-phosphoheptulonate synthase [EC:2.5.1.54] cac:CA_C0892 cac00400
# 51 chorismate synthase [EC:4.2.3.5] cac:CA_C0896 cac00400
# 52 tryptophan synthase alpha chain [EC:4.2.1.20] cac:CA_C3157 cac00400
# 53 tryptophan synthase alpha chain [EC:4.2.1.20] cac:CA_C3157 cac00400
# 54 tryptophan synthase beta chain [EC:4.2.1.20] cac:CA_C3158 cac00400
# 55 indole-3-glycerol phosphate synthase [EC:4.1.1.48] cac:CA_C3160 cac00400
# 56 phosphoribosylanthranilate isomerase [EC:5.3.1.24] cac:CA_C3159 cac00400
# 57 anthranilate phosphoribosyltransferase [EC:2.4.2.18] cac:CA_C3161 cac00400
# 58 anthranilate synthase component II [EC:4.1.3.27] cac:CA_C3162 cac00400
# 59 chorismate mutase [EC:5.4.99.5] cac:CA_C1234 cac00400
# 61 prephenate dehydratase [EC:4.2.1.51] cac:CA_C0217 cac00400
# 68 prephenate dehydratase [EC:4.2.1.51] cac:CA_C0217 cac00400
# 70 prephenate dehydrogenase [EC:1.3.1.12] cac:CA_C0893 cac00400
# 75 3-phosphoshikimate 1-carboxyvinyltransferase [EC:2.5.1.19] cac:CA_C0895 cac00400
# 76 shikimate kinase [EC:2.7.1.71] cac:CA_C0898 cac00400
# 77 shikimate dehydrogenase [EC:1.1.1.25] cac:CA_C0897 cac00400
# 78 3-dehydroquinate dehydratase II [EC:4.2.1.10] cac:CA_C0899 cac00400
# 80 3-dehydroquinate synthase [EC:4.2.3.4] cac:CA_C0894 cac00400
# 83 aspartate aminotransferase [EC:2.6.1.1] cac:CA_C1001 cac00400
# 84 aspartate aminotransferase [EC:2.6.1.1] cac:CA_C1001 cac00400
# 89 histidinol-phosphate aminotransferase [EC:2.6.1.9] cac:CA_C3031 cac00400
# 90 histidinol-phosphate aminotransferase [EC:2.6.1.9] cac:CA_C3031 cac00400
# 67 histidinol-phosphate aminotransferase [EC:2.6.1.9] cac:CA_C3031 cac00401
# 69 prephenate dehydrogenase [EC:1.3.1.12] cac:CA_C0893 cac00401
# 70 aspartate aminotransferase [EC:2.6.1.1] cac:CA_C1001 cac00401
# 42 butyryl-CoA dehydrogenase [EC:1.3.8.1] cac:CA_C2711 cac00410
# 53 4-aminobutyrate aminotransferase [EC:2.6.1.19] cac:CA_C0368 cac00410
# 54 pantoate--beta-alanine ligase [EC:6.3.2.1] cac:CA_C2915 cac00410
# 58 aspartate 1-decarboxylase [EC:4.1.1.11] cac:CA_C2916 cac00410
# 36 phosphate acetyltransferase [EC:2.3.1.8] cac:CA_C1742 cac00430
# 58 acetate kinase [EC:2.7.2.1] cac:CA_C1743 cac00430
# 90 phosphinothricin acetyltransferase [EC:2.3.1.183] cac:CA_C0858 cac00440
# 144 phosphinothricin acetyltransferase [EC:2.3.1.183] cac:CA_C0858 cac00440
# 11 thioredoxin reductase (NADPH) [EC:1.8.1.9] cac:CA_C0869 cac00450
# 15 methionyl-tRNA synthetase [EC:6.1.1.10] cac:CA_C2991 cac00450
# 59 cystathionine gamma-synthase [EC:2.5.1.48] cac:CA_C0390 cac00450
# 60 cysteine desulfurase / selenocysteine lyase [EC:2.8.1.7 4.4.1.16] cac:CA_C3291 cac00450
# 72 sulfate adenylyltransferase subunit 2 [EC:2.7.7.4] cac:CA_C0109 cac00450
# 81 cysteine-S-conjugate beta-lyase [EC:4.4.1.13] cac:CA_C0391 cac00450
# 82 5-methyltetrahydrofolate--homocysteine methyltransferase [EC:2.1.1.13] cac:CA_C0578 cac00450
# 89 thioredoxin reductase (NADPH) [EC:1.8.1.9] cac:CA_C0869 cac00450
# 44 L-asparaginase [EC:3.5.1.1] cac:CA_C1714 cac00460
# 45 beta-glucosidase [EC:3.2.1.21] cac:CA_C1075 cac00460
# 50 glycine hydroxymethyltransferase [EC:2.1.2.1] cac:CA_C2264 cac00460
# 151 beta-glucosidase [EC:3.2.1.21] cac:CA_C1075 cac00460
# 152 beta-glucosidase [EC:3.2.1.21] cac:CA_C1075 cac00460
# 161 beta-glucosidase [EC:3.2.1.21] cac:CA_C1075 cac00460
# 165 beta-glucosidase [EC:3.2.1.21] cac:CA_C1075 cac00460
# 20 UDP-N-acetylmuramate--alanine ligase [EC:6.3.2.8] cac:CA_C3225 cac00471
# 21 UDP-N-acetylmuramoylalanine--D-glutamate ligase [EC:6.3.2.9] cac:CA_C3194 cac00471
# 25 glutamate racemase [EC:5.1.1.3] cac:CA_C3250 cac00471
# 15 D-alanine transaminase [EC:2.6.1.21] cac:CA_C0792 cac00472
# 22 D-alanine transaminase [EC:2.6.1.21] cac:CA_C0792 cac00472
# 13 D-alanine-D-alanine ligase [EC:6.3.2.4] cac:CA_C2895 cac00473
# 15 D-alanine transaminase [EC:2.6.1.21] cac:CA_C0792 cac00473
# 16 alanine racemase [EC:5.1.1.1] cac:CA_C0492 cac00473
# 39 glutathione peroxidase [EC:1.11.1.9] cac:CA_C1549 cac00480
# 53 glutamate--cysteine ligase [EC:6.3.2.2] cac:CA_C1539 cac00480
# 147 spermidine synthase [EC:2.5.1.16] cac:CA_C2602 cac00480
# 155 spermidine synthase [EC:2.5.1.16] cac:CA_C2602 cac00480
# 82 beta-glucosidase [EC:3.2.1.21] cac:CA_C1075 cac00500
# 83 beta-glucosidase [EC:3.2.1.21] cac:CA_C1075 cac00500
# 85 maltose-6'-phosphate glucosidase [EC:3.2.1.122] cac:CA_C0533 cac00500
# 87 beta-fructofuranosidase [EC:3.2.1.26] cac:CA_C0425 cac00500
# 88 fructokinase [EC:2.7.1.4] cac:CA_C0424 cac00500
# 90 alpha-glucosidase [EC:3.2.1.20] cac:CA_C2891 cac00500
# 91 beta-fructofuranosidase [EC:3.2.1.26] cac:CA_C0425 cac00500
# 93 beta-glucosidase [EC:3.2.1.21] cac:CA_C1075 cac00500
# 95 endoglucanase [EC:3.2.1.4] cac:CA_C0561 cac00500
# 110 UTP--glucose-1-phosphate uridylyltransferase [EC:2.7.7.9] cac:CA_C2250 cac00500
# 113 glucose-1-phosphate adenylyltransferase [EC:2.7.7.27] cac:CA_C2237 cac00500
# 114 phosphoglucomutase [EC:5.4.2.2] cac:CA_C2337 cac00500
# 118 glucokinase [EC:2.7.1.2] cac:CA_C2613 cac00500
# 119 glucose-6-phosphate isomerase [EC:5.3.1.9] cac:CA_C2680 cac00500
# 120 1,4-alpha-glucan branching enzyme [EC:2.4.1.18] cac:CA_C2414 cac00500
# 126 beta-phosphoglucomutase [EC:5.4.2.6] cac:CA_C2614 cac00500
# 127 maltose-6'-phosphate glucosidase [EC:3.2.1.122] cac:CA_C0533 cac00500
# 128 maltose phosphorylase [EC:2.4.1.8] cac:CA_C2685 cac00500
# 130 alpha-amylase [EC:3.2.1.1] cac:CA_P0168 cac00500
# 132 alpha-glucosidase [EC:3.2.1.20] cac:CA_C2891 cac00500
# 133 glycogen phosphorylase [EC:2.4.1.1] cac:CA_C0857 cac00500
# 137 starch synthase [EC:2.4.1.21] cac:CA_C2239 cac00500
# 140 levansucrase [EC:2.4.1.10] cac:CA_C1772 cac00500
# 141 levanase [EC:3.2.1.65] cac:CA_C1773 cac00500
# 147 sugar PTS system EIIA component [EC:2.7.1.-] cac:CA_C1354 cac00500
# 148 alpha-glucoside PTS system EIICB component [EC:2.7.1.208 2.7.1.-] cac:CA_C0532 cac00500
# 226 endoglucanase [EC:3.2.1.4] cac:CA_C0561 cac00500
# 232 6-phospho-beta-glucosidase [EC:3.2.1.86] cac:CA_C0385 cac00500
# 233 cellobiose PTS system EIIA component [EC:2.7.1.196 2.7.1.205] cac:CA_C0383 cac00500
# 238 alpha-amylase [EC:3.2.1.1] cac:CA_P0168 cac00500
# 11 bifunctional UDP-N-acetylglucosamine pyrophosphorylase / Glucosamine-1-phosphate N-acetyltransferase [EC:2.7.7.23 2.3.1.157] cac:CA_C3222 cac00520
# 22 glucosamine-6-phosphate deaminase [EC:3.5.99.6] cac:CA_C0187 cac00520
# 24 N-acetylglucosamine-6-phosphate deacetylase [EC:3.5.1.25] cac:CA_C0188 cac00520
# 26 phosphoglucosamine mutase [EC:5.4.2.10] cac:CA_C0484 cac00520
# 28 bifunctional UDP-N-acetylglucosamine pyrophosphorylase / Glucosamine-1-phosphate N-acetyltransferase [EC:2.7.7.23 2.3.1.157] cac:CA_C3222 cac00520
# 30 glutamine---fructose-6-phosphate transaminase (isomerizing) [EC:2.6.1.16] cac:CA_C0158 cac00520
# 43 UDP-N-acetylglucosamine 2-epimerase (non-hydrolysing) [EC:5.1.3.14] cac:CA_C2874 cac00520
# 48 UDP-N-acetylglucosamine 1-carboxyvinyltransferase [EC:2.5.1.7] cac:CA_C2862 cac00520
# 49 UDP-N-acetylmuramate dehydrogenase [EC:1.3.1.98] cac:CA_C0510 cac00520
# 57 sugar PTS system EIIA component [EC:2.7.1.-] cac:CA_C1354 cac00520
# 59 N-acetylmuramic acid 6-phosphate etherase [EC:4.2.1.126] cac:CA_C0175 cac00520
# 73 beta-N-acetylhexosaminidase [EC:3.2.1.52] cac:CA_C0182 cac00520
# 87 fructokinase [EC:2.7.1.4] cac:CA_C0424 cac00520
# 93 N-acetylglucosamine PTS system EIICBA or EIICB component [EC:2.7.1.193] cac:CA_C1353 cac00520
# 173 pseudaminic acid synthase [EC:2.5.1.97] cac:CA_C2187 cac00520
# 192 UDPglucose--hexose-1-phosphate uridylyltransferase [EC:2.7.7.12] cac:CA_C2844 cac00520
# 194 UDP-glucose 4-epimerase [EC:5.1.3.2] cac:CA_C0794 cac00520
# 201 mannose-6-phosphate isomerase [EC:5.3.1.8] cac:CA_C2918 cac00520
# 202 mannose-1-phosphate guanylyltransferase / phosphomannomutase [EC:2.7.7.13 5.4.2.8] cac:CA_C2981 cac00520
# 204 phosphoglucomutase [EC:5.4.2.2] cac:CA_C2337 cac00520
# 208 galactokinase [EC:2.7.1.6] cac:CA_C2959 cac00520
# 211 mannose-1-phosphate guanylyltransferase [EC:2.7.7.13] cac:CA_C2968 cac00520
# 247 phosphoglucomutase [EC:5.4.2.2] cac:CA_C2337 cac00520
# 262 GDPmannose 4,6-dehydratase [EC:4.2.1.47] cac:CA_C2180 cac00520
# 264 GDP-L-fucose synthase [EC:1.1.1.271] cac:CA_C2179 cac00520
# 282 glucose-6-phosphate isomerase [EC:5.3.1.9] cac:CA_C2680 cac00520
# 295 UTP--glucose-1-phosphate uridylyltransferase [EC:2.7.7.9] cac:CA_C2250 cac00520
# 297 Pfam: PTSIIB_sorb cac:CA_C1458 cac00520
# 299 glucose PTS system EIICBA or EIICB component [EC:2.7.1.199] cac:CA_C0570 cac00520
# 304 glucose PTS system EIICBA or EIICB component [EC:2.7.1.199] cac:CA_C0570 cac00520
# 309 glucose-1-phosphate adenylyltransferase [EC:2.7.7.27] cac:CA_C2237 cac00520
# 310 glucokinase [EC:2.7.1.2] cac:CA_C2613 cac00520
# 311 glucokinase [EC:2.7.1.2] cac:CA_C2613 cac00520
# 324 arabinoxylan arabinofuranohydrolase [EC:3.2.1.55] cac:CA_P0120 cac00520
# 326 xylan 1,4-beta-xylosidase [EC:3.2.1.37] cac:CA_C3452 cac00520
# 435 UDP-galactopyranose mutase [EC:5.4.99.9] cac:CA_C2169 cac00520
# 16 glucokinase [EC:2.7.1.2] cac:CA_C2613 cac00521
# 24 dTDP-4-dehydrorhamnose reductase [EC:1.1.1.133] cac:CA_C2315 cac00521
# 42 dTDP-4-dehydrorhamnose 3,5-epimerase [EC:5.1.3.13] cac:CA_C2331 cac00521
# 43 dTDP-glucose 4,6-dehydratase [EC:4.2.1.46] cac:CA_C2332 cac00521
# 44 glucose-1-phosphate thymidylyltransferase [EC:2.7.7.24] cac:CA_C2333 cac00521
# 45 phosphoglucomutase [EC:5.4.2.2] cac:CA_C2337 cac00521
# 26 dTDP-glucose 4,6-dehydratase [EC:4.2.1.46] cac:CA_C2332 cac00523
# 27 glucose-1-phosphate thymidylyltransferase [EC:2.7.7.24] cac:CA_C2333 cac00523
# 28 dTDP-4-dehydrorhamnose reductase [EC:1.1.1.133] cac:CA_C2315 cac00523
# 63 dTDP-4-dehydrorhamnose 3,5-epimerase [EC:5.1.3.13] cac:CA_C2331 cac00523
# 58 glucose-1-phosphate thymidylyltransferase [EC:2.7.7.24] cac:CA_C2333 cac00525
# 59 dTDP-glucose 4,6-dehydratase [EC:4.2.1.46] cac:CA_C2332 cac00525
# 63 D-sedoheptulose 7-phosphate isomerase [EC:5.3.1.28] cac:CA_C3054 cac00540
# 64 D-glycero-D-manno-heptose 1,7-bisphosphate phosphatase [EC:3.1.3.82 3.1.3.83] cac:CA_C3053 cac00540
# 82 D-glycero-alpha-D-manno-heptose-7-phosphate kinase [EC:2.7.1.168] cac:CA_C3055 cac00540
# 86 D-glycero-D-manno-heptose 1,7-bisphosphate phosphatase [EC:3.1.3.82 3.1.3.83] cac:CA_C3053 cac00540
# 90 D-glycero-alpha-D-manno-heptose 1-phosphate guanylyltransferase [EC:2.7.7.71] cac:CA_C3056 cac00540
# 92 D-sedoheptulose 7-phosphate isomerase [EC:5.3.1.28] cac:CA_C3054 cac00540
# 23 UDP-N-acetylmuramoyl-tripeptide--D-alanyl-D-alanine ligase [EC:6.3.2.10] cac:CA_C2128 cac00550
# 26 undecaprenyl-diphosphatase [EC:3.6.1.27] cac:CA_C0501 cac00550
# 27 UDP-N-acetylglucosamine--N-acetylmuramyl-(pentapeptide) pyrophosphoryl-undecaprenol N-acetylglucosamine transferase [EC:2.4.1.227] cac:CA_C2231 cac00550
# 28 phospho-N-acetylmuramoyl-pentapeptide-transferase [EC:2.7.8.13] cac:CA_C2127 cac00550
# 29 UDP-N-acetylmuramoyl-tripeptide--D-alanyl-D-alanine ligase [EC:6.3.2.10] cac:CA_C2128 cac00550
# 30 D-alanine-D-alanine ligase [EC:6.3.2.4] cac:CA_C2895 cac00550
# 32 UDP-N-acetylmuramoylalanine--D-glutamate ligase [EC:6.3.2.9] cac:CA_C3194 cac00550
# 33 UDP-N-acetylmuramate--alanine ligase [EC:6.3.2.8] cac:CA_C3225 cac00550
# 34 UDP-N-acetylmuramoyl-L-alanyl-D-glutamate--2,6-diaminopimelate ligase [EC:6.3.2.13] cac:CA_C2129 cac00550
# 35 phospho-N-acetylmuramoyl-pentapeptide-transferase [EC:2.7.8.13] cac:CA_C2127 cac00550
# 36 UDP-N-acetylglucosamine--N-acetylmuramyl-(pentapeptide) pyrophosphoryl-undecaprenol N-acetylglucosamine transferase [EC:2.4.1.227] cac:CA_C2231 cac00550
# 58 UDP-N-acetylglucosamine 1-carboxyvinyltransferase [EC:2.5.1.7] cac:CA_C2862 cac00550
# 59 UDP-N-acetylmuramate dehydrogenase [EC:1.3.1.98] cac:CA_C0510 cac00550
# 88 serine-type D-Ala-D-Ala carboxypeptidase (penicillin-binding protein 5/6) [EC:3.4.16.4] cac:CA_C1267 cac00550
# 89 zinc D-Ala-D-Ala carboxypeptidase [EC:3.4.17.14] cac:CA_C3297 cac00550
# 91 zinc D-Ala-D-Ala carboxypeptidase [EC:3.4.17.14] cac:CA_C3297 cac00550
# 92 zinc D-Ala-D-Ala carboxypeptidase [EC:3.4.17.14] cac:CA_C3297 cac00550
# 93 penicillin-binding protein 1A [EC:2.4.1.129 3.4.16.4] cac:CA_C2301 cac00550
# 94 penicillin-binding protein 1A [EC:2.4.1.129 3.4.16.4] cac:CA_C2301 cac00550
# 95 penicillin-binding protein 1A [EC:2.4.1.129 3.4.16.4] cac:CA_C2301 cac00550
# 96 penicillin-binding protein 1A [EC:2.4.1.129 3.4.16.4] cac:CA_C2301 cac00550
# 98 penicillin-binding protein 1A [EC:2.4.1.129 3.4.16.4] cac:CA_C2301 cac00550
# 100 penicillin-binding protein 1A [EC:2.4.1.129 3.4.16.4] cac:CA_C2301 cac00550
# 101 penicillin-binding protein A cac:CA_C0506 cac00550
# 102 serine-type D-Ala-D-Ala carboxypeptidase (penicillin-binding protein 5/6) [EC:3.4.16.4] cac:CA_C1267 cac00550
# 103 serine-type D-Ala-D-Ala carboxypeptidase (penicillin-binding protein 5/6) [EC:3.4.16.4] cac:CA_C1267 cac00550
# 104 lipid II isoglutaminyl synthase (glutamine-hydrolysing) [EC:6.3.5.13] cac:CA_C0961 cac00550
# 41 triacylglycerol lipase [EC:3.1.1.3] cac:CA_C1028 cac00561
# 44 1,2-diacylglycerol 3-alpha-glucosyltransferase [EC:2.4.1.337] cac:CA_C2536 cac00561
# 47 triacylglycerol lipase [EC:3.1.1.3] cac:CA_C1028 cac00561
# 48 1-acyl-sn-glycerol-3-phosphate acyltransferase [EC:2.3.1.51] cac:CA_C0688 cac00561
# 55 glycerol kinase [EC:2.7.1.30] cac:CA_C1321 cac00561
# 73 diacylglycerol kinase (ATP) [EC:2.7.1.107] cac:CA_C1294 cac00561
# 127 processive 1,2-diacylglycerol beta-glucosyltransferase [EC:2.4.1.315] cac:CA_C2897 cac00561
# 131 processive 1,2-diacylglycerol beta-glucosyltransferase [EC:2.4.1.315] cac:CA_C2897 cac00561
# 141 glycerate 2-kinase [EC:2.7.1.165] cac:CA_C2834 cac00561
# 152 acyl phosphate:glycerol-3-phosphate acyltransferase [EC:2.3.1.275] cac:CA_C2500 cac00561
# 155 phosphate acyltransferase [EC:2.3.1.274] cac:CA_C1746 cac00561
# 69 phospholipase C [EC:3.1.4.3] cac:CA_C1019 cac00562
# 129 triosephosphate isomerase (TIM) [EC:5.3.1.1] cac:CA_C0711 cac00562
# 175 scyllo-inositol 2-dehydrogenase (NADP+) [EC:1.1.1.-] cac:CA_C1231 cac00562
# 94 phospholipase C [EC:3.1.4.3] cac:CA_C1019 cac00564
# 98 diacylglycerol kinase (ATP) [EC:2.7.1.107] cac:CA_C1294 cac00564
# 103 glycerophosphoryl diester phosphodiesterase [EC:3.1.4.46] cac:CA_C0430 cac00564
# 104 CDP-diacylglycerol---serine O-phosphatidyltransferase [EC:2.7.8.8] cac:CA_C0676 cac00564
# 106 1-acyl-sn-glycerol-3-phosphate acyltransferase [EC:2.3.1.51] cac:CA_C0688 cac00564
# 110 phospholipase C [EC:3.1.4.3] cac:CA_C1019 cac00564
# ...
# 69 thiazole synthase [EC:2.8.1.10] cac:CA_C2922 cac00730
# 71 tRNA uracil 4-sulfurtransferase [EC:2.8.1.4] cac:CA_C2971 cac00730
# 72 cysteine desulfurase [EC:2.8.1.7] cac:CA_C2234 cac00730
# 73 sulfur carrier protein ThiS adenylyltransferase [EC:2.7.7.73] cac:CA_C2923 cac00730
# 74 hydroxyethylthiazole kinase [EC:2.7.1.50] cac:CA_C3096 cac00730
# 75 hydroxymethylpyrimidine/phosphomethylpyrimidine kinase [EC:2.7.1.49 2.7.4.7] cac:CA_C3095 cac00730
# 76 hydroxymethylpyrimidine/phosphomethylpyrimidine kinase [EC:2.7.1.49 2.7.4.7] cac:CA_C3095 cac00730
# 78 1-deoxy-D-xylulose-5-phosphate synthase [EC:2.2.1.7] cac:CA_C2077 cac00730
# 91 2-iminoacetate synthase [EC:4.1.99.19] cac:CA_C1356 cac00730
# 93 thiamine-phosphate pyrophosphorylase [EC:2.5.1.3] cac:CA_C0495 cac00730
# 94 phosphomethylpyrimidine synthase [EC:4.1.99.17] cac:CA_C3014 cac00730
# 97 thiamine-phosphate pyrophosphorylase [EC:2.5.1.3] cac:CA_C0495 cac00730
# 114 ribosome biogenesis GTPase / thiamine phosphate phosphatase [EC:3.6.1.- 3.1.3.100] cac:CA_C1729 cac00730
# 32 3,4-dihydroxy 2-butanone 4-phosphate synthase / GTP cyclohydrolase II [EC:4.1.99.12 3.5.4.25] cac:CA_C0592 cac00740
# 35 riboflavin kinase / FMN adenylyltransferase [EC:2.7.1.26 2.7.7.2] cac:CA_C1806 cac00740
# 37 riboflavin kinase / FMN adenylyltransferase [EC:2.7.1.26 2.7.7.2] cac:CA_C1806 cac00740
# 38 3,4-dihydroxy 2-butanone 4-phosphate synthase / GTP cyclohydrolase II [EC:4.1.99.12 3.5.4.25] cac:CA_C0592 cac00740
# 39 diaminohydroxyphosphoribosylaminopyrimidine deaminase / 5-amino-6-(5-phosphoribosylamino)uracil reductase [EC:3.5.4.26 1.1.1.193] cac:CA_C0590 cac00740
# 40 diaminohydroxyphosphoribosylaminopyrimidine deaminase / 5-amino-6-(5-phosphoribosylamino)uracil reductase [EC:3.5.4.26 1.1.1.193] cac:CA_C0590 cac00740
# 41 6,7-dimethyl-8-ribityllumazine synthase [EC:2.5.1.78] cac:CA_C0593 cac00740
# 42 riboflavin synthase [EC:2.5.1.9] cac:CA_C0591 cac00740
# 64 FMN reductase [NAD(P)H] [EC:1.5.1.39] cac:CA_C0718 cac00740
# 7 pyridoxal 5'-phosphate synthase pdxS subunit [EC:4.3.3.6] cac:CA_C0594 cac00750
# 84 pyridoxine kinase [EC:2.7.1.35] cac:CA_C1622 cac00750
# 86 pyridoxine kinase [EC:2.7.1.35] cac:CA_C1622 cac00750
# 88 pyridoxine kinase [EC:2.7.1.35] cac:CA_C1622 cac00750
# 89 threonine synthase [EC:4.2.3.1] cac:CA_C0999 cac00750
# 74 NAD+ diphosphatase [EC:3.6.1.22] cac:CA_C0145 cac00760
# 78 L-aspartate oxidase [EC:1.4.3.16] cac:CA_C1024 cac00760
# 79 quinolinate synthase [EC:2.5.1.72] cac:CA_C1025 cac00760
# 80 nicotinate-nucleotide pyrophosphorylase (carboxylating) [EC:2.4.2.19] cac:CA_C1023 cac00760
# 89 purine-nucleoside phosphorylase [EC:2.4.2.1] cac:CA_C2064 cac00760
# 90 nicotinate-nucleotide adenylyltransferase [EC:2.7.7.18] cac:CA_C1262 cac00760
# 92 NAD+ synthase (glutamine-hydrolysing) [EC:6.3.5.1] cac:CA_C1050 cac00760
# 94 nicotinamide-nucleotide amidase [EC:3.5.1.42] cac:CA_C3586 cac00760
# 95 nicotinate phosphoribosyltransferase [EC:6.3.4.21] cac:CA_C1002 cac00760
# 98 NAD+ diphosphatase [EC:3.6.1.22] cac:CA_C0145 cac00760
# 100 nicotinate-nucleotide adenylyltransferase [EC:2.7.7.18] cac:CA_C1262 cac00760
# 105 purine-nucleoside phosphorylase [EC:2.4.2.1] cac:CA_C2064 cac00760
# 111 NAD+ kinase [EC:2.7.1.23] cac:CA_C2075 cac00760
# 67 dephospho-CoA kinase [EC:2.7.1.24] cac:CA_C1099 cac00770
# 68 holo-[acyl-carrier protein] synthase [EC:2.7.8.7] cac:CA_C0489 cac00770
# 71 type III pantothenate kinase [EC:2.7.1.33] cac:CA_C3200 cac00770
# 72 phosphopantothenoylcysteine decarboxylase / phosphopantothenate---cysteine ligase [EC:4.1.1.36 6.3.2.5] cac:CA_C1720 cac00770
# 74 type III pantothenate kinase [EC:2.7.1.33] cac:CA_C3200 cac00770
# 75 phosphopantothenoylcysteine decarboxylase / phosphopantothenate---cysteine ligase [EC:4.1.1.36 6.3.2.5] cac:CA_C1720 cac00770
# 76 type III pantothenate kinase [EC:2.7.1.33] cac:CA_C3200 cac00770
# 81 pantoate--beta-alanine ligase [EC:6.3.2.1] cac:CA_C2915 cac00770
# 82 2-dehydropantoate 2-reductase [EC:1.1.1.169] cac:CA_C2937 cac00770
# 83 3-methyl-2-oxobutanoate hydroxymethyltransferase [EC:2.1.2.11] cac:CA_C2914 cac00770
# 85 dihydroxy-acid dehydratase [EC:4.2.1.9] cac:CA_C3170 cac00770
# 86 ketol-acid reductoisomerase [EC:1.1.1.86] cac:CA_C0091 cac00770
# 87 acetolactate synthase I/II/III large subunit [EC:2.2.1.6] cac:CA_C3169 cac00770
# 90 branched-chain amino acid aminotransferase [EC:2.6.1.42] cac:CA_C1479 cac00770
# 92 pantetheine-phosphate adenylyltransferase [EC:2.7.7.3] cac:CA_C1738 cac00770
# 98 aspartate 1-decarboxylase [EC:4.1.1.11] cac:CA_C2916 cac00770
# 103 4'-phosphopantetheinyl transferase [EC:2.7.8.-] cac:CA_C1329 cac00770
# 29 BirA family transcriptional regulator, biotin operon repressor / biotin---[acetyl-CoA-carboxylase] ligase [EC:6.3.4.15] cac:CA_C0212 cac00780
# 31 BirA family transcriptional regulator, biotin operon repressor / biotin---[acetyl-CoA-carboxylase] ligase [EC:6.3.4.15] cac:CA_C0212 cac00780
# 33 biotin synthase [EC:2.8.1.6] cac:CA_C0210 cac00780
# 34 dethiobiotin synthetase [EC:6.3.3.3] cac:CA_C1361 cac00780
# 35 adenosylmethionine---8-amino-7-oxononanoate aminotransferase [EC:2.6.1.62] cac:CA_C1362 cac00780
# 56 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] cac:CA_C2626 cac00780
# 59 3-hydroxyacyl-[acyl-carrier-protein] dehydratase [EC:4.2.1.59] cac:CA_C3571 cac00780
# 70 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] cac:CA_C2626 cac00780
# 73 3-hydroxyacyl-[acyl-carrier-protein] dehydratase [EC:4.2.1.59] cac:CA_C3571 cac00780
# 77 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] cac:CA_C2008 cac00780
# 102 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] cac:CA_C2008 cac00780
# 67 dihydrofolate synthase / folylpolyglutamate synthase [EC:6.3.2.12 6.3.2.17] cac:CA_C2398 cac00790
# 68 dihydrofolate synthase / folylpolyglutamate synthase [EC:6.3.2.12 6.3.2.17] cac:CA_C2398 cac00790
# 69 dihydrofolate reductase [EC:1.5.1.3] cac:CA_C3004 cac00790
# 70 dihydrofolate reductase [EC:1.5.1.3] cac:CA_C3004 cac00790
# 71 dihydrofolate synthase / folylpolyglutamate synthase [EC:6.3.2.12 6.3.2.17] cac:CA_C2398 cac00790
# 72 dihydropteroate synthase [EC:2.5.1.15] cac:CA_C2926 cac00790
# 73 dihydropteroate synthase [EC:2.5.1.15] cac:CA_C2926 cac00790
# 74 dihydroneopterin aldolase / 2-amino-4-hydroxy-6-hydroxymethyldihydropteridine diphosphokinase [EC:4.1.2.25 2.7.6.3] cac:CA_C2927 cac00790
# 75 dihydroneopterin aldolase / 2-amino-4-hydroxy-6-hydroxymethyldihydropteridine diphosphokinase [EC:4.1.2.25 2.7.6.3] cac:CA_C2927 cac00790
# 79 GTP cyclohydrolase IA [EC:3.5.4.16] cac:CA_C3626 cac00790
# 80 GTP cyclohydrolase IA [EC:3.5.4.16] cac:CA_C3626 cac00790
# 81 GTP cyclohydrolase IA [EC:3.5.4.16] cac:CA_C3626 cac00790
# 82 dihydrofolate reductase [EC:1.5.1.3] cac:CA_C3004 cac00790
# 83 dihydrofolate synthase / folylpolyglutamate synthase [EC:6.3.2.12 6.3.2.17] cac:CA_C2398 cac00790
# 86 6-pyruvoyltetrahydropterin/6-carboxytetrahydropterin synthase [EC:4.2.3.12 4.1.2.50] cac:CA_C2585 cac00790
# 93 GTP 3',8-cyclase [EC:4.1.99.22] cac:CA_C1993 cac00790
# 96 6-pyruvoyltetrahydropterin/6-carboxytetrahydropterin synthase [EC:4.2.3.12 4.1.2.50] cac:CA_C2585 cac00790
# 102 7-carboxy-7-deazaguanine synthase [EC:4.3.99.3] cac:CA_C3625 cac00790
# 103 7-cyano-7-deazaguanine synthase [EC:6.3.4.20] cac:CA_C3627 cac00790
# 117 cyclic pyranopterin monophosphate synthase [EC:4.6.1.17] cac:CA_C1992 cac00790
# 122 molybdopterin molybdotransferase [EC:2.10.1.1] cac:CA_C2020 cac00790
# 153 7,8-dihydropterin-6-yl-methyl-4-(beta-D-ribofuranosyl)aminobenzene 5'-phosphate synthase [EC:2.5.1.105] cac:CA_C0535 cac00790
# 180 GTP cyclohydrolase IA [EC:3.5.4.16] cac:CA_C3626 cac00790
# 181 3,4-dihydroxy 2-butanone 4-phosphate synthase / GTP cyclohydrolase II [EC:4.1.99.12 3.5.4.25] cac:CA_C0592 cac00790
# 189 dihydrofolate reductase [EC:1.5.1.3] cac:CA_C3004 cac00790
# 275 uroporphyrinogen III methyltransferase / synthase [EC:2.1.1.107 4.2.1.75] cac:CA_C0098 cac00860
# 276 uroporphyrinogen III methyltransferase / synthase [EC:2.1.1.107 4.2.1.75] cac:CA_C0098 cac00860
# 278 hydroxymethylbilane synthase [EC:2.5.1.61] cac:CA_C0097 cac00860
# 279 porphobilinogen synthase [EC:4.2.1.24] cac:CA_C0100 cac00860
# 281 glutamate-1-semialdehyde 2,1-aminomutase [EC:5.4.3.8] cac:CA_C0099 cac00860
# 283 glutamyl-tRNA reductase [EC:1.2.1.70] cac:CA_C0095 cac00860
# 284 glutamyl-tRNA synthetase [EC:6.1.1.17] cac:CA_C0990 cac00860
# 285 precorrin-2 dehydrogenase / sirohydrochlorin ferrochelatase [EC:1.3.1.76 4.99.1.4] cac:CA_C0096 cac00860
# 286 precorrin-2 dehydrogenase / sirohydrochlorin ferrochelatase [EC:1.3.1.76 4.99.1.4] cac:CA_C0096 cac00860
# 287 sirohydrochlorin cobaltochelatase [EC:4.99.1.3] cac:CA_C1373 cac00860
# 288 precorrin-2/cobalt-factor-2 C20-methyltransferase [EC:2.1.1.130 2.1.1.151] cac:CA_C1379 cac00860
# 289 precorrin-3B C17-methyltransferase [EC:2.1.1.131] cac:CA_C1382 cac00860
# 290 precorrin-4/cobalt-precorrin-4 C11-methyltransferase [EC:2.1.1.133 2.1.1.271] cac:CA_C1380 cac00860
# 291 precorrin-6A/cobalt-precorrin-6A reductase [EC:1.3.1.54 1.3.1.106] cac:CA_C1381 cac00860
# 292 cobalt-precorrin-7 (C5)-methyltransferase [EC:2.1.1.289] cac:CA_C0584 cac00860
# 293 cobalt-precorrin-6B (C15)-methyltransferase [EC:2.1.1.196] cac:CA_C1378 cac00860
# 294 precorrin-2/cobalt-factor-2 C20-methyltransferase [EC:2.1.1.130 2.1.1.151] cac:CA_C1379 cac00860
# 296 precorrin-3B C17-methyltransferase [EC:2.1.1.131] cac:CA_C1382 cac00860
# 297 precorrin-4/cobalt-precorrin-4 C11-methyltransferase [EC:2.1.1.133 2.1.1.271] cac:CA_C1380 cac00860
# 299 precorrin-6A/cobalt-precorrin-6A reductase [EC:1.3.1.54 1.3.1.106] cac:CA_C1381 cac00860
# 300 precorrin-8X/cobalt-precorrin-8 methylmutase [EC:5.4.99.61 5.4.99.60] cac:CA_C1376 cac00860
# 301 cobyrinic acid a,c-diamide synthase [EC:6.3.5.9 6.3.5.11] cac:CA_C1375 cac00860
# 303 precorrin-8X/cobalt-precorrin-8 methylmutase [EC:5.4.99.61 5.4.99.60] cac:CA_C1376 cac00860
# 304 cobyrinic acid a,c-diamide synthase [EC:6.3.5.9 6.3.5.11] cac:CA_C1375 cac00860
# 307 adenosylcobyric acid synthase [EC:6.3.5.10] cac:CA_C1374 cac00860
# 310 adenosylcobinamide kinase / adenosylcobinamide-phosphate guanylyltransferase [EC:2.7.1.156 2.7.7.62] cac:CA_C1383 cac00860
# 313 adenosylcobinamide kinase / adenosylcobinamide-phosphate guanylyltransferase [EC:2.7.1.156 2.7.7.62] cac:CA_C1383 cac00860
# 314 threonine-phosphate decarboxylase [EC:4.1.1.81] cac:CA_C1369 cac00860
# 315 adenosylcobinamide-GDP ribazoletransferase [EC:2.7.8.26] cac:CA_C1384 cac00860
# 316 alpha-ribazole phosphatase [EC:3.1.3.73] cac:CA_C1385 cac00860
# 317 nicotinate-nucleotide--dimethylbenzimidazole phosphoribosyltransferase [EC:2.4.2.21] cac:CA_C1372 cac00860
# 320 adenosylcobinamide-phosphate synthase [EC:6.3.1.10] cac:CA_C0582 cac00860
# 321 adenosylcobinamide-phosphate synthase [EC:6.3.1.10] cac:CA_C0582 cac00860
# 323 cobalt-precorrin 5A hydrolase [EC:3.7.1.12] cac:CA_C1370 cac00860
# 324 cobalt-precorrin-5B (C1)-methyltransferase [EC:2.1.1.195] cac:CA_C1377 cac00860
# 374 L-threonine kinase [EC:2.7.1.177] cac:CA_C1371 cac00860
# 64 1-deoxy-D-xylulose-5-phosphate synthase [EC:2.2.1.7] cac:CA_C2077 cac00900
# 65 1-deoxy-D-xylulose-5-phosphate reductoisomerase [EC:1.1.1.267] cac:CA_C1795 cac00900
# 66 2-C-methyl-D-erythritol 4-phosphate cytidylyltransferase [EC:2.7.7.60] cac:CA_C3184 cac00900
# 67 4-diphosphocytidyl-2-C-methyl-D-erythritol kinase [EC:2.7.1.148] cac:CA_C2902 cac00900
# 68 2-C-methyl-D-erythritol 2,4-cyclodiphosphate synthase [EC:4.6.1.12] cac:CA_C0434 cac00900
# 69 (E)-4-hydroxy-3-methylbut-2-enyl-diphosphate synthase [EC:1.17.7.1 1.17.7.3] cac:CA_C1797 cac00900
# 71 acetyl-CoA C-acetyltransferase [EC:2.3.1.9] cac:CA_C2873 cac00900
# 97 small subunit ribosomal protein S1 cac:CA_C1847 cac00900
# 99 small subunit ribosomal protein S1 cac:CA_C1847 cac00900
# 103 geranylgeranyl diphosphate synthase, type II [EC:2.5.1.1 2.5.1.10 2.5.1.29] cac:CA_C2080 cac00900
# 105 geranylgeranyl diphosphate synthase, type II [EC:2.5.1.1 2.5.1.10 2.5.1.29] cac:CA_C2080 cac00900
# 106 undecaprenyl diphosphate synthase [EC:2.5.1.31] cac:CA_C1432 cac00900
# 116 geranylgeranyl diphosphate synthase, type II [EC:2.5.1.1 2.5.1.10 2.5.1.29] cac:CA_C2080 cac00900
# 165 (E)-4-hydroxy-3-methylbut-2-enyl-diphosphate synthase [EC:1.17.7.1 1.17.7.3] cac:CA_C1797 cac00900
# 34 hydroxylamine reductase [EC:1.7.99.1] cac:CA_C2750 cac00910
# 37 ferredoxin-nitrite reductase [EC:1.7.7.1] cac:CA_C0094 cac00910
# 39 nitrogenase iron protein NifH cac:CA_C0253 cac00910
# 69 carbonic anhydrase [EC:4.2.1.1] cac:CA_C2482 cac00910
# 83 glutamine synthetase [EC:6.3.1.2] cac:CA_C2658 cac00910
# 87 glutamate synthase (NADPH) small chain [EC:1.4.1.13] cac:CA_C0764 cac00910
# 94 glutamate dehydrogenase (NADP+) [EC:1.4.1.4] cac:CA_C0737 cac00910
# 112 ferredoxin-nitrite reductase [EC:1.7.7.1] cac:CA_C0094 cac00910
# 134 nitrogenase iron protein NifH cac:CA_C0253 cac00910
# 32 anaerobic sulfite reductase subunit A cac:CA_C1513 cac00920
# 38 bifunctional oligoribonuclease and PAP phosphatase NrnA [EC:3.1.3.7 3.1.13.3] cac:CA_C1804 cac00920
# 39 adenylylsulfate kinase [EC:2.7.1.25] cac:CA_C0103 cac00920
# 42 sulfate adenylyltransferase subunit 2 [EC:2.7.7.4] cac:CA_C0109 cac00920
# 49 adenylylsulfate reductase, subunit A [EC:1.8.99.2] cac:CA_C0104 cac00920
# 103 cysteine synthase [EC:2.5.1.47] cac:CA_C0931 cac00920
# 109 serine O-acetyltransferase [EC:2.3.1.30] cac:CA_C0687 cac00920
# 121 cystathionine gamma-synthase [EC:2.5.1.48] cac:CA_C0390 cac00920
# 125 homoserine O-succinyltransferase/O-acetyltransferase [EC:2.3.1.46 2.3.1.31] cac:CA_C1825 cac00920
# 159 adenylylsulfate kinase [EC:2.7.1.25] cac:CA_C0103 cac00920
# 160 sulfate adenylyltransferase subunit 2 [EC:2.7.7.4] cac:CA_C0109 cac00920
# 169 adenylylsulfate reductase, subunit A [EC:1.8.99.2] cac:CA_C0104 cac00920
# 24 isoleucyl-tRNA synthetase [EC:6.1.1.5] cac:CA_C3038 cac00970
# 58 asparaginyl-tRNA synthetase [EC:6.1.1.22] cac:CA_C3260 cac00970
# 59 histidyl-tRNA synthetase [EC:6.1.1.21] cac:CA_C2740 cac00970
# 60 phenylalanyl-tRNA synthetase beta chain [EC:6.1.1.20] cac:CA_C2356 cac00970
# 61 arginyl-tRNA synthetase [EC:6.1.1.19] cac:CA_C1041 cac00970
# 63 cysteinyl-tRNA synthetase [EC:6.1.1.16] cac:CA_C3177 cac00970
# 64 glycyl-tRNA synthetase [EC:6.1.1.14] cac:CA_C3195 cac00970
# 65 aspartyl-tRNA synthetase [EC:6.1.1.12] cac:CA_C2269 cac00970
# 66 seryl-tRNA synthetase [EC:6.1.1.11] cac:CA_C0017 cac00970
# 67 methionyl-tRNA synthetase [EC:6.1.1.10] cac:CA_C2991 cac00970
# 68 valyl-tRNA synthetase [EC:6.1.1.9] cac:CA_C2399 cac00970
# 69 alanyl-tRNA synthetase [EC:6.1.1.7] cac:CA_C0906 cac00970
# 70 lysyl-tRNA synthetase, class II [EC:6.1.1.6] cac:CA_C3197 cac00970
# 71 leucyl-tRNA synthetase [EC:6.1.1.4] cac:CA_C0646 cac00970
# 72 threonyl-tRNA synthetase [EC:6.1.1.3] cac:CA_C2362 cac00970
# 73 tryptophanyl-tRNA synthetase [EC:6.1.1.2] cac:CA_C0626 cac00970
# 74 methionyl-tRNA formyltransferase [EC:2.1.2.9] cac:CA_C1723 cac00970
# 75 tyrosyl-tRNA synthetase [EC:6.1.1.1] cac:CA_C0637 cac00970
# 76 prolyl-tRNA synthetase [EC:6.1.1.15] cac:CA_C3178 cac00970
# 77 glutamyl-tRNA synthetase [EC:6.1.1.17] cac:CA_C0990 cac00970
# 128 aspartyl-tRNA(Asn)/glutamyl-tRNA(Gln) amidotransferase subunit B [EC:6.3.5.6 6.3.5.7] cac:CA_C2669 cac00970
# 131 aspartyl-tRNA(Asn)/glutamyl-tRNA(Gln) amidotransferase subunit B [EC:6.3.5.6 6.3.5.7] cac:CA_C2669 cac00970
# 132 nondiscriminating aspartyl-tRNA synthetase [EC:6.1.1.23] cac:CA_C2979 cac00970
# 137 seryl-tRNA synthetase [EC:6.1.1.11] cac:CA_C0017 cac00970
# 151 nondiscriminating aspartyl-tRNA synthetase [EC:6.1.1.23] cac:CA_C2979 cac00970
# 156 tRNA Glu cac:CA_C1056 cac00970
# 157 tRNA Gln cac:CA_Ct014 cac00970
# 158 tRNA Ala cac:CA_Ct002 cac00970
# 159 tRNA Asp cac:CA_Ct021 cac00970
# 160 tRNA Ser cac:CA_Ct003 cac00970
# 161 tRNA Thr cac:CA_Ct049 cac00970
# 162 tRNA Asn cac:CA_Ct016 cac00970
# 163 tRNA Gly cac:CA_Ct019 cac00970
# 164 tRNA Cys cac:CA_Ct013 cac00970
# 166 tRNA Met cac:CA_Ct001 cac00970
# 167 tRNA Val cac:CA_Ct022 cac00970
# 168 tRNA Leu cac:CA_Ct015 cac00970
# 170 tRNA Lys cac:CA_Ct009 cac00970
# 172 tRNA Arg cac:CA_Ct005 cac00970
# 173 tRNA Pro cac:CA_Ct026 cac00970
# 174 tRNA His cac:CA_Ct034 cac00970
# 175 tRNA Phe cac:CA_Ct010 cac00970
# 176 tRNA Tyr cac:CA_Ct048 cac00970
# 177 tRNA Trp cac:CA_Ct047 cac00970

# %%
NODES_cac00010
# Out:
# {"'14'": 'fructose-bisphosphate aldolase, class II [EC:4.1.2.13]',
#  '14': 'fructose-bisphosphate aldolase, class II [EC:4.1.2.13]',
#  '46': 'S-(hydroxymethyl)glutathione dehydrogenase / alcohol dehydrogenase [EC:1.1.1.284 1.1.1.1]',
#  '51': 'L-lactate dehydrogenase [EC:1.1.1.27]',
#  '53': 'pyruvate kinase [EC:2.7.1.40]',
#  '55': 'enolase [EC:4.2.1.11]',
#  '56': '2,3-bisphosphoglycerate-dependent phosphoglycerate mutase [EC:5.4.2.11]',
#  '57': 'glyceraldehyde 3-phosphate dehydrogenase [EC:1.2.1.12]',
#  '58': 'triosephosphate isomerase (TIM) [EC:5.3.1.1]',
#  '59': '6-phosphofructokinase 1 [EC:2.7.1.11]',
#  '60': 'fructose-1,6-bisphosphatase II [EC:3.1.3.11]',
#  '61': 'glucose PTS system EIICBA or EIICB component [EC:2.7.1.199]',
#  '62': 'glucose-6-phosphate isomerase [EC:5.3.1.9]',
#  '63': 'phosphoglucomutase [EC:5.4.2.2]',
#  '64': 'glucose-6-phosphate isomerase [EC:5.3.1.9]',
#  '66': 'glucokinase [EC:2.7.1.2]',
#  '67': 'glucose-6-phosphate isomerase [EC:5.3.1.9]',
#  '69': 'aldose 1-epimerase [EC:5.1.3.3]',
#  '70': 'glucokinase [EC:2.7.1.2]',
#  '76': 'phosphoglycerate kinase [EC:2.7.2.3]',
#  '79': 'sugar PTS system EIIA component [EC:2.7.1.-]',
#  '80': 'sugar PTS system EIIA component [EC:2.7.1.-]',
#  '81': '6-phospho-beta-glucosidase [EC:3.2.1.86]',
#  '82': '6-phospho-beta-glucosidase [EC:3.2.1.86]',
#  '122': 'glyceraldehyde-3-phosphate dehydrogenase (NADP+) [EC:1.2.1.9]',
#  '124': 'pyruvate-ferredoxin/flavodoxin oxidoreductase [EC:1.2.7.1 1.2.7.-]',
#  '137': '2,3-bisphosphoglycerate-independent phosphoglycerate mutase [EC:5.4.2.12]',
#  '144': '2-oxoglutarate/2-oxoacid ferredoxin oxidoreductase subunit beta [EC:1.2.7.3 1.2.7.11]'}

# %% [markdown]
# ## PRIMERA RED

# %%
EDGES=[]

for line in pathways.text.split('\n'):        
    pathwayid = line.split('\t')[0].replace('path:', '') 
    
    if pathwayid == str(org)+str(maxi):           
            break
            
    ii=locals()[str(pathwayid)]
    
    NODES=locals()['NODES_'+str(pathwayid)]
   
    for i in range(0,len(ii)):
        if ii[i].tag=='relation':         
            A=ii[i].attrib            
            if A['type'] == 'ECrel':    #relación enzima-enzima, que indica dos enzimas que catalizan pasos de reacción sucesivos
                #print(A)
                EDGES.append( [  NODES[ A['entry1'] ] , NODES[ A['entry2'] ]  ]  ) 

print(EDGES)
# Out:
# [['aldose 1-epimerase [EC:5.1.3.3]', 'glucokinase [EC:2.7.1.2]'], ['glucokinase [EC:2.7.1.2]', 'aldose 1-epimerase [EC:5.1.3.3]'], ['glucokinase [EC:2.7.1.2]', '6-phospho-beta-glucosidase [EC:3.2.1.86]'], ['glucokinase [EC:2.7.1.2]', '6-phospho-beta-glucosidase [EC:3.2.1.86]'], ['glucose-6-phosphate isomerase [EC:5.3.1.9]', 'glucokinase [EC:2.7.1.2]'], ['glucose-6-phosphate isomerase [EC:5.3.1.9]', '6-phospho-beta-glucosidase [EC:3.2.1.86]'], ['glucose-6-phosphate isomerase [EC:5.3.1.9]', '6-phospho-beta-glucosidase [EC:3.2.1.86]'], ['glucose-6-phosphate isomerase [EC:5.3.1.9]', 'glucokinase [EC:2.7.1.2]'], ['glucose PTS system EIICBA or EIICB component [EC:2.7.1.199]', 'glucose-6-phosphate isomerase [EC:5.3.1.9]'], ['glucose-6-phosphate isomerase [EC:5.3.1.9]', 'phosphoglucomutase [EC:5.4.2.2]'], ['glucose-6-phosphate isomerase [EC:5.3.1.9]', 'glucokinase [EC:2.7.1.2]'], ['glucose PTS system EIICBA or EIICB component [EC:2.7.1.199]', 'glucokinase [EC:2.7.1.2]'], ['phosphoglucomutase [EC:5.4.2.2]', 'glucokinase [EC:2.7.1.2]'], ['glucose PTS system EIICBA or EIICB component [EC:2.7.1.199]', 'glucose-6-phosphate isomerase [EC:5.3.1.9]'], ['phosphoglucomutase [EC:5.4.2.2]', 'glucose-6-phosphate isomerase [EC:5.3.1.9]'], ['glucose PTS system EIICBA or EIICB component [EC:2.7.1.199]', 'phosphoglucomutase [EC:5.4.2.2]'], ['fructose-1,6-bisphosphatase II [EC:3.1.3.11]', 'glucose-6-phosphate isomerase [EC:5.3.1.9]'], ['6-phosphofructokinase 1 [EC:2.7.1.11]', 'glucose-6-phosphate isomerase [EC:5.3.1.9]'], ['fructose-bisphosphate aldolase, class II [EC:4.1.2.13]', 'fructose-1,6-bisphosphatase II [EC:3.1.3.11]'], ['fructose-bisphosphate aldolase, class II [EC:4.1.2.13]', '6-phosphofructokinase 1 [EC:2.7.1.11]'], ['triosephosphate isomerase (TIM) [EC:5.3.1.1]', 'fructose-bisphosphate aldolase, class II [EC:4.1.2.13]'], ['glyceraldehyde 3-phosphate dehydrogenase [EC:1.2.1.12]', 'phosphoglycerate kinase [EC:2.7.2.3]'], ['2,3-bisphosphoglycerate-dependent phosphoglycerate mutase [EC:5.4.2.11]', 'phosphoglycerate kinase [EC:2.7.2.3]'], ['enolase [EC:4.2.1.11]', '2,3-bisphosphoglycerate-dependent phosphoglycerate mutase [EC:5.4.2.11]'], ['pyruvate kinase [EC:2.7.1.40]', 'enolase [EC:4.2.1.11]'], ['sugar PTS system EIIA component [EC:2.7.1.-]', '6-phospho-beta-glucosidase [EC:3.2.1.86]'], ['fructose-1,6-bisphosphatase II [EC:3.1.3.11]', 'glucose-6-phosphate isomerase [EC:5.3.1.9]'], ['6-phosphofructokinase 1 [EC:2.7.1.11]', 'glucose-6-phosphate isomerase [EC:5.3.1.9]'], ['L-lactate dehydrogenase [EC:1.1.1.27]', 'pyruvate kinase [EC:2.7.1.40]'], ['glucokinase [EC:2.7.1.2]', 'glucose-6-phosphate isomerase [EC:5.3.1.9]'], ['glucose-6-phosphate isomerase [EC:5.3.1.9]', '6-phospho-beta-glucosidase [EC:3.2.1.86]'], ['glucose-6-phosphate isomerase [EC:5.3.1.9]', '6-phospho-beta-glucosidase [EC:3.2.1.86]'], ['sugar PTS system EIIA component [EC:2.7.1.-]', '6-phospho-beta-glucosidase [EC:3.2.1.86]'], ['phosphoglycerate kinase [EC:2.7.2.3]', 'glyceraldehyde-3-phosphate dehydrogenase (NADP+) [EC:1.2.1.9]'], ['2,3-bisphosphoglycerate-dependent phosphoglycerate mutase [EC:5.4.2.11]', 'glyceraldehyde-3-phosphate dehydrogenase (NADP+) [EC:1.2.1.9]'], ['L-lactate dehydrogenase [EC:1.1.1.27]', 'pyruvate-ferredoxin/flavodoxin oxidoreductase [EC:1.2.7.1 1.2.7.-]'], ['pyruvate kinase [EC:2.7.1.40]', 'pyruvate-ferredoxin/flavodoxin oxidoreductase [EC:1.2.7.1 1.2.7.-]'], ['triosephosphate isomerase (TIM) [EC:5.3.1.1]', 'glyceraldehyde 3-phosphate dehydrogenase [EC:1.2.1.12]'], ['triosephosphate isomerase (TIM) [EC:5.3.1.1]', 'glyceraldehyde-3-phosphate dehydrogenase (NADP+) [EC:1.2.1.9]'], ['glyceraldehyde 3-phosphate dehydrogenase [EC:1.2.1.12]', 'glyceraldehyde-3-phosphate dehydrogenase (NADP+) [EC:1.2.1.9]'], ['fructose-bisphosphate aldolase, class II [EC:4.1.2.13]', 'triosephosphate isomerase (TIM) [EC:5.3.1.1]'], ['fructose-bisphosphate aldolase, class II [EC:4.1.2.13]', 'glyceraldehyde 3-phosphate dehydrogenase [EC:1.2.1.12]'], ['fructose-bisphosphate aldolase ...

# %%
G = nx.DiGraph() #--->DiGrafo para hacer un grado dirigido 
 
G.add_edges_from(EDGES)


plt.figure(3,figsize=(50,50))
nx.draw_kamada_kawai(G,font_size=15,node_size=1000,node_color='orange',with_labels=False)
plt.savefig("net_"+org+"1.pdf")# Guardar la red en pdf. 
plt.show()

# %%
g=nx.number_of_nodes(G)
print('g=',g)
L=nx.number_of_edges(G)
print('L=',L)
# Out:
# g= 414
# L= 877

# %%
nx.square_clustering(G)
# Out:
# {'aldose 1-epimerase [EC:5.1.3.3]': 0,
#  'glucokinase [EC:2.7.1.2]': 0.02247191011235955,
#  '6-phospho-beta-glucosidase [EC:3.2.1.86]': 0.125,
#  'glucose-6-phosphate isomerase [EC:5.3.1.9]': 0.038461538461538464,
#  'glucose PTS system EIICBA or EIICB component [EC:2.7.1.199]': 0.3333333333333333,
#  'phosphoglucomutase [EC:5.4.2.2]': 0.047619047619047616,
#  'fructose-1,6-bisphosphatase II [EC:3.1.3.11]': 0.25,
#  '6-phosphofructokinase 1 [EC:2.7.1.11]': 0.7777777777777778,
#  'fructose-bisphosphate aldolase, class II [EC:4.1.2.13]': 0.16049382716049382,
#  'triosephosphate isomerase (TIM) [EC:5.3.1.1]': 1,
#  'glyceraldehyde 3-phosphate dehydrogenase [EC:1.2.1.12]': 0.3333333333333333,
#  'phosphoglycerate kinase [EC:2.7.2.3]': 0,
#  '2,3-bisphosphoglycerate-dependent phosphoglycerate mutase [EC:5.4.2.11]': 0.3333333333333333,
#  'enolase [EC:4.2.1.11]': 0,
#  'pyruvate kinase [EC:2.7.1.40]': 0.09713375796178345,
#  'sugar PTS system EIIA component [EC:2.7.1.-]': 0.0,
#  'L-lactate dehydrogenase [EC:1.1.1.27]': 0.1261682242990654,
#  'glyceraldehyde-3-phosphate dehydrogenase (NADP+) [EC:1.2.1.9]': 0,
#  'pyruvate-ferredoxin/flavodoxin oxidoreductase [EC:1.2.7.1 1.2.7.-]': 0.10023584905660378,
#  '2,3-bisphosphoglycerate-independent phosphoglycerate mutase [EC:5.4.2.12]': 1.0,
#  '2-oxoglutarate/2-oxoacid ferredoxin oxidoreductase subunit beta [EC:1.2.7.3 1.2.7.11]': 0.14772727272727273,
#  'pyruvate carboxylase [EC:6.4.1.1]': 0.37349397590361444,
#  'isocitrate dehydrogenase (NAD+) [EC:1.1.1.41]': 0,
#  'aconitate hydratase [EC:4.2.1.3]': 0,
#  'citrate (Re)-synthase [EC:2.3.3.3]': 0,
#  '2-dehydro-3-deoxyphosphogluconate aldolase / (4S)-4-hydroxy-2-oxoglutarate aldolase [EC:4.1.2.14 4.1.3.42]': 0,
#  '2-dehydro-3-deoxygluconokinase [EC:2.7.1.45]': 0,
#  'ribose 5-phosphate isomerase B [EC:5.3.1.6]': 0.0,
#  'ribulose-phosphate 3-epimerase [EC:5.1.3.1]': 0,
#  'transketolase [EC:2.2.1.1]': 0.06060606060606061,
#  'phosphopentomutase [EC:5.4.2.7]': 1.3333333333333333,
#  'ribose-phosphate pyrophosphokinase [EC:2.7.6.1]': 0.04504504504504504,
#  'transaldolase [EC:2.2.1.2]': 0,
#  'deoxyribose-phosphate aldolase [EC:4.1.2.4]': 4,
#  'xylulose-5-phosphate/fructose-6-phosphate phosphoketolase [EC:4.1.2.9 4.1.2.22]': 3,
#  '6-phospho-3-hexuloisomerase [EC:5.3.1.27]': 0.6428571428571429,
#  '3-hexulose-6-phosphate synthase [EC:4.1.2.43]': 0.0,
#  'glucuronate isomerase [EC:5.3.1.12]': 0,
#  'tagaturonate reductase [EC:1.1.1.58]': 0,
#  'altronate hydrolase [EC:4.2.1.7]': 0.0,
#  'L-ribulose-5-phosphate 4-epimerase [EC:5.1.3.4]': 0,
#  'xylulokinase [EC:2.7.1.17]': 0,
#  '2-dehydro-3-deoxy-D-gluconate 5-dehydrogenase [EC:1.1.1.127]': 0,
#  'mannonate dehydratase [EC:4.2.1.8]': 0,
#  'fructan beta-fructosidase [EC:3.2.1.80]': 0.0,
#  'fructokinase [EC:2.7.1.4]': 0.15151515151515152,
#  'mannitol PTS system EIICBA or EIICB component [EC:2.7.1.197]': 0,
#  'mannitol-1-phosphate 5-dehydrogenase [EC:1.1.1.17]': 0.125,
#  'mannose-6-phosphate isomerase [EC:5.3.1.8]': 0.375,
#  '1-phosphofructokinase [EC:2.7.1.56]': 0.125,
#  'Pfam:\xa0PTSIIB_sorb': 0,
#  'mannose-1-phosphate guanylyltransferase / phosphomannomutase [EC:2.7.7.13 5.4.2.8]': 0,
#  'mannose-1-phosphate guanylyltransferase [EC:2.7.7.13]': 0,
#  'GDPmannose 4,6-dehydratase [EC:4.2.1.47]': 0,
#  'GDP-L-fucose synthase [EC:1.1.1.271]': 0,
#  'fructose PTS system EIIA component [EC:2.7.1.202]': 0.4,
#  'mannan endo-1,4-beta-mannosidase [EC:3.2.1.78]': 0,
#  'tagatose 1,6-diphosphate aldolase GatY/KbaY [EC:4.1.2.40]': 0,
#  'tagatose 6-phosphate kinase [EC:2.7.1.144]': 0.0,
#  'galactose-6-phosphate isomerase [EC:5.3.1.26]': 0,
#  '6-phospho-beta-galactosidase [EC:3.2.1.85]': 0.0,
#  'lactose PTS system EIICB component [EC:2.7.1.207]': 0,
#  'UTP--glucose-1-phosphate uridylyltransferase [EC:2.7.7.9]': 0.11764705882352941,
#  'UDP-glucose 4-epimerase [EC:5.1.3.2]': 1.0,
#  'UDPglucose--hexose-1-phosphate uridylyltransferase [EC:2.7.7.12]': 0,
#  'beta-fructofuranosidase [EC:3.2.1.26]': 0,
#  'alpha-glucosidase [EC:3.2.1.20]': 0,
#  'galactokinase [EC:2.7.1.6]': 0,
#  'beta-galactosidase [EC:3.2.1.23]': 0,
#  'UDP-galactopyranose mutase [EC:5.4.99.9]': 0,
#  '[acyl-carrier-protein] S-malonyltransferase [EC:2.3.1.39]': 0.2,
#  'acetyl-CoA carboxylase carboxyl transferase subunit alpha [EC:6.4.1.2 2.1.3.15]': 1.0,
#  '3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179]': 0.5,
#  '3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100]': 0,
#  '3-hydroxyacyl-[acyl-carrier-protein] dehydratase [EC:4.2.1.59]': 0,
#  'enoyl-[acyl-carrier protein] reductase II [EC:1.3.1.9]': 0,
#  '3-oxoacyl-[acyl-carrier-protein] synthase III [EC:2.3.1.180]': 1.0,
#  'enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase (NAD+) [EC:1.3.1.9 1.3.1.44]': 0.12195121951219512,
#  'butyryl-CoA dehydrogenase [EC:1.3.8.1]': 0.425,
#  'acetyl-CoA C-acetyltransferase [EC:2.3.1.9]': 0.17721518987341772,
#  'manganese-dependent inorganic pyrophosphatase [EC:3.6.1.1]': 0,
#  'polyphosphate kinase [EC:2.7.4.1]': 0,
#  'F-type H+-transporting ATPase subunit epsilon': 0,
#  'glutamine synthetase [EC:6.3.1.2]': 1,
#  'glutamate dehydrogenase (NADP+) [EC:1.4.1.4]': 1,
#  'aspartate aminotransferase [EC:2.6.1.1]': 0.0,
#  'glutamate N-acetyltransferase / amino-acid N-acetyltransferase [EC:2.3.1.35 2.3.1.1]': 0,
#  'acetylglutamate kinase [EC:2.7.2.8]': 0,
#  'N-acetyl-gamma-glutamyl-phosphate reductase [EC:1.2.1.38]': 0,
#  'acetylornithine/N-succinyldiaminopimelate aminotransferase [EC:2.6.1.11 2.6.1.17]': 0,
#  'arginase [EC:3.5.3.1]': 0.0,
#  'ornithine carbamoyltransferase [EC:2.1.3.3]': 0,
#  'argininosuccinate synthase [EC:6.3.4.5]': 15,
#  'argininosuccinate lyase [EC:4.3.2.1]': 0,
#  'ADP-ribose pyrophosphatase [EC:3.6.1.13]': 0,
#  'amidophosphoribosyltransferase [EC:2.4.2.14]': 5.0,
#  'phosphoribosylamine---glycine ligase [EC:6.3.4.13]': 0,
#  'phosphoribosylglycinamide formyltransferase 1 [EC:2.1.2.2]': 0.06666666666666667,
#  'phosphoribosylformylglycinamidine synthase [EC:6.3.5.3]': 0,
#  'phosphoribosylformylglycinamidine cyclo-ligase [EC:6.3.3.1]': 0,
#  'phosphoribosylaminoimidazole-succinocarboxamide synthase [EC:6.3.2.6]': 0,
#  'adenylosuccinate lyase [EC:4.3.2.2]': 1,
#  'adenine phosphoribosyltransferase [EC:2.4.2.7]': 0.04,
#  'phosphoribosylaminoimidazolecarboxamide formyltransferase / IMP cyclohydrolase [EC:2.1.2.3 3.5.4.10]': 0.09900990099009901,
#  'sulfate adenylyltransferase subunit 2 [EC:2.7.7.4]': 0,
#  'adenylylsulfate kinase [EC:2.7.1.25]': 0,
#  'adenylosuccinate synthase [EC:6.3.4.4]': 0.11564625850340136,
#  'IMP dehydrogenase [EC:1.1.1.205]': 0.6666666666666666,
#  'hypoxanthine phosphoribosyltransferase [EC:2.4.2.8]': 0,
#  "2',3'-cyclic-nucleotide 2'-phosphodiesterase / 3'-nucleotidase / 5'-nucleotidase [EC:3.1.4.16 3.1.3.6 3.1.3.5]": 4,
#  'adenosine deaminase [EC:3.5.4.4]': 0,
#  'purine-nucleoside phosphorylase [EC:2.4.2.1]': 11,
#  'adenine deaminase [EC:3.5.4.2]': 2,
#  'adenylate kinase [EC:2.7.4.3]': 0.05128205128205128,
#  'ribonucleoside-diphosphate reductase alpha chain [EC:1.17.4.1]': 0.027777777777777776,
#  'adenylate cyclase, class 2 [EC:4.6.1.1]': 0,
#  'GMP reductase [EC:1.7.1.7]': 0.14285714285714285,
#  'GMP synthase (glutamine-hydrolysing) [EC:6.3.5.2]': 0.6,
#  'xanthine phosphoribosyltransferase [EC:2.4.2.22]': 0,
#  'guanine deaminase [EC:3.5.4.3]': 0.15384615384615385,
#  'guanylate kinase [EC:2.7.4.8]': 0.05263157894736842,
#  'putative GTP pyrophosphokinase [EC:2.7.6.5]': 0,
#  "exopolyphosphatase / guanosine-5'-triphosphate,3'-diphosphate pyrophosphatase [EC:3.6.1.11 3.6.1.40]": 0,
#  '5-(carboxyamino)imidazole ribonucleotide mutase [EC:5.4.99.18]': 0,
#  'XTP/dITP diphosphohydrolase [EC:3.6.1.66]': 0,
#  'ribonucleoside-triphosphate reductase (formate) [EC:1.1.98.6]': 1,
#  'carbamoyl-phosphate synthase large subunit [EC:6.3.5.5]': 0.06451612903225806,
#  'aspartate carbamoyltransferase regulatory subunit': 0.6666666666666666,
#  'dihydroorotase [EC:3.5.2.3]': 0,
#  'dihydroorotate dehydrogenase (NAD+) catalytic subunit [EC:1.3.1.14]': 0,
#  'orotate phosphoribosyltransferase [EC:2.4.2.10]': 0,
#  "orotidine-5'-phosphate decarboxylase [EC:4.1.1.23]": 0,
#  'uridine kinase [EC:2.7.1.48]': 6.0,
#  'pyrimidine operon attenuation protein / uracil phosphoribosyltransferase [EC:2.4.2.9]': 0.3333333333333333,
#  'uridylate kinase [EC:2.7.4.22]': 2,
#  'pyrimidine-nucleoside phosphorylase [EC:2.4.2.2]': 2,
#  'cytidine deaminase [EC:3.5.4.5]': 5,
#  'thymidine kinase [EC:2.7.1.21]': 0.0975609756097561,
#  'dCMP deaminase [EC:3.5.4.12]': 0.25,
#  'thymidylate synthase [EC:2.1.1.45]': 0.075,
#  'dUTP pyrophosphatase [EC:3.6.1.23]': 0.0,
#  'dCTP deaminase [EC:3.5.4.13]': 0,
#  'CMP/dCMP kinase [EC:2.7.4.25]': 0.0,
#  'CTP synthase [EC:6.3.4.2]': 0,
#  'aspartate ammonia-lyase [EC:4.3.1.1]': 0.4,
#  'glutamate synthase (NADPH) small chain [EC:1.4.1.13]': 0,
#  'glutamine---fructose-6-phosphate transaminase (isomerizing) [EC:2.6.1.16]': 0.09302325581395349,
#  'asparagine synthase (glutamine-hydrolysing) [EC:6.3.5.4]': 0,
#  'L-asparaginase [EC:3.5.1.1]': 0,
#  'L-aspartate oxidase [EC:1.4.3.16]': 0,
#  'glycine hydroxymethyltransferase [EC:2.1.2.1]': 0.07751937984496124,
#  'L-serine dehydratase [EC:4.3.1.17]': 0.0,
#  'threonine aldolase [EC:4.1.2.48]': 0,
#  'threonine synthase [EC:4.2.3.1]': 0,
#  'homoserine kinase [EC:2.7.1.39]': 0,
#  'homoserine dehydrogenase [EC:1.1.1.3]': 0,
#  'aspartate-semialdehyde dehydrogenase [EC:1.2.1.11]': 0,
#  'aspartate kinase [EC:2.7.2.4]': 0,
#  'tryptophan synthase alpha chain [EC:4.2.1.20]': 0.0,
#  'CDP-diacylglycerol---serine O-phosphatidyltransferase [EC:2.7.8.8]': 0.0,
#  'glycerate dehydrogenase [EC:1.1.1.29]': 0,
#  'glycerate 2-kinase [EC:2.7.1.165]': 0,
#  'D-3-phosphoglycerate dehydrogenase / 2-oxoglutarate reductase [EC:1.1.1.95 1.1.1.399]': 0.0,
#  '4-hydroxy-tetrahydrodipicolinate synthase [EC:4.3.3.7]': 0,
#  '4-hydroxy-tetrahydrodipicolinate reductase [EC:1.17.1.8]': 0,
#  'serine O-acetyltransferase [EC:2.3.1.30]': 0.0,
#  'cysteine synthase [EC:2.5.1.47]': 0,
#  'cysteine-S-conjugate beta-lyase [EC:4.4.1.13]': 0.0,
#  'cystathionine gamma-synthase [EC:2.5.1.48]': 7,
#  'homoserine O-succinyltransferase/O-acetyltransferase [EC:2.3.1.46 2.3.1.31]': 0.16666666666666666,
#  'O-acetylhomoserine (thiol)-lyase [EC:2.5.1.49]': 1.0,
#  '5-methyltetrahydrofolate--homocysteine methyltransferase [EC:2.1.1.13]': 0.6956521739130435,
#  'S-ribosylhomocysteine lyase [EC:4.4.1.21]': 3,
#  'methionine synthase / methylenetetrahydrofolate reductase(NADPH) [EC:2.1.1.13 1.5.1.20]': 0.13793103448275862,
#  'L-methionine (R)-S-oxide reductase [EC:1.8.4.14]': 0.8333333333333334,
#  'S-adenosylmethionine synthetase [EC:2.5.1.6]': 0,
#  'DNA (cytosine-5)-methyltransferase 1 [EC:2.1.1.37]': 0,
#  'adenosylhomocysteine nucleosidase [EC:3.2.2.9]': 0,
#  'S-adenosylmethionine decarboxylase [EC:4.1.1.50]': 0,
#  'spermidine synthase [EC:2.5.1.16]': 0,
#  'branched-chain amino acid aminotransferase [EC:2.6.1.42]': 0,
#  'glutamate--cysteine ligase [EC:6.3.2.2]': 0,
#  '4-aminobutyrate aminotransferase / (S)-3-amino-2-methylpropionate transaminase / 5-aminovalerate transaminase [EC:2.6.1.19 2.6.1.22 2.6.1.48]': 0,
#  '3-hydroxyisobutyrate dehydrogenase [EC:1.1.1.31]': 0,
#  '3-isopropylmalate dehydrogenase [EC:1.1.1.85]': 0.0,
#  'acetolactate synthase I/II/III large subunit [EC:2.2.1.6]': 0.0,
#  '3-isopropylmalate/(R)-2-methylmalate dehydratase small subunit [EC:4.2.1.33 4.2.1.35]': 0.0,
#  'ketol-acid reductoisomerase [EC:1.1.1.86]': 0.0,
#  'dihydroxy-acid dehydratase [EC:4.2.1.9]': 0.0,
#  '2-isopropylmalate synthase [EC:2.3.3.13]': 0.0,
#  '2,3,4,5-tetrahydropyridine-2,6-dicarboxylate N-succinyltransferase [EC:2.3.1.117]': 0,
#  'LL-diaminopimelate aminotransferase [EC:2.6.1.83]': 0.0,
#  'succinyl-diaminopimelate desuccinylase [EC:3.5.1.18]': 0,
#  'diaminopimelate epimerase [EC:5.1.1.7]': 0,
#  'UDP-N-acetylmuramoyl-L-alanyl-D-glutamate--2,6-diaminopimelate ligase [EC:6.3.2.13]': 0,
#  'diaminopimelate decarboxylase [EC:4.1.1.20]': 0,
#  'UDP-N-acetylmuramoyl-tripeptide--D-alanyl-D-alanine ligase [EC:6.3.2.10]': 0,
#  'acetate CoA/acetoacetate CoA-transferase alpha subunit [EC:2.8.3.8 2.8.3.9]': 0,
#  'arginine decarboxylase [EC:4.1.1.19]': 0,
#  'glutamate-5-semialdehyde dehydrogenase [EC:1.2.1.41]': 0,
#  'glutamate 5-kinase [EC:2.7.2.11]': 0,
#  'ATP phosphoribosyltransferase regulatory subunit': 0,
#  'phosphoribosyl-ATP pyrophosphohydrolase [EC:3.6.1.31]': 0,
#  'phosphoribosyl-AMP cyclohydrolase [EC:3.5.4.19]': 0,
#  'phosphoribosylformimino-5-aminoimidazole carboxamide ribotide isomerase [EC:5.3.1.16]': 0,
#  'histidinol-phosphate aminotransferase [EC:2.6.1.9]': 0,
#  'imidazoleglycerol-phosphate dehydratase [EC:4.2.1.19]': 0,
#  'histidinol-phosphatase (PHP family) [EC:3.1.3.15]': 0,
#  'histidinol dehydrogenase [EC:1.1.1.23]': 0,
#  'imidazole glycerol-phosphate synthase subunit HisH [EC:4.3.2.10]': 0,
#  'D-alanine transaminase [EC:2.6.1.21]': 0,
#  '3-hydroxybutyryl-CoA dehydrogenase [EC:1.1.1.157]': 0.0,
#  '3-dehydroquinate synthase [EC:4.2.3.4]': 0,
#  '3-deoxy-7-phosphoheptulonate synthase [EC:2.5.1.54]': 0,
#  '3-dehydroquinate dehydratase II [EC:4.2.1.10]': 0,
#  'shikimate dehydrogenase [EC:1.1.1.25]': 0,
#  'shikimate kinase [EC:2.7.1.71]': 0,
#  '3-phosphoshikimate 1-carboxyvinyltransferase [EC:2.5.1.19]': 0,
#  'chorismate synthase [EC:4.2.3.5]': 0,
#  'anthranilate synthase component II [EC:4.1.3.27]': 0,
#  'chorismate mutase [EC:5.4.99.5]': 1.0,
#  'anthranilate phosphoribosyltransferase [EC:2.4.2.18]': 0,
#  'phosphoribosylanthranilate isomerase [EC:5.3.1.24]': 0,
#  'indole-3-glycerol phosphate synthase [EC:4.1.1.48]': 0,
#  'prephenate dehydratase [EC:4.2.1.51]': 0.16666666666666666,
#  'prephenate dehydrogenase [EC:1.3.1.12]': 0.3333333333333333,
#  '4-aminobutyrate aminotransferase [EC:2.6.1.19]': 0,
#  'pantoate--beta-alanine ligase [EC:6.3.2.1]': 0,
#  'aspartate 1-decarboxylase [EC:4.1.1.11]': 0,
#  'phosphate acetyltransferase [EC:2.3.1.8]': 0.574468085106383,
#  'acetate kinase [EC:2.7.2.1]': 0,
#  'methionyl-tRNA synthetase [EC:6.1.1.10]': 0.0,
#  'thioredoxin reductase (NADPH) [EC:1.8.1.9]': 0,
#  'cysteine desulfurase / selenocysteine lyase [EC:2.8.1.7 4.4.1.16]': 0,
#  'beta-glucosidase [EC:3.2.1.21]': 5,
#  'UDP-N-acetylmuramoylalanine--D-glutamate ligase [EC:6.3.2.9]': 0,
#  'glutamate racemase [EC:5.1.1.3]': 0,
#  'UDP-N-acetylmuramate--alanine ligase [EC:6.3.2.8]': 0,
#  'alanine racemase [EC:5.1.1.1]': 0,
#  'D-alanine-D-alanine ligase [EC:6.3.2.4]': 0,
#  '1,4-alpha-glucan branching enzyme [EC:2.4.1.18]': 0.0,
#  'glycogen phosphorylase [EC:2.4.1.1]': 0,
#  'beta-phosphoglucomutase [EC:5.4.2.6]': 0,
#  'maltose phosphorylase [EC:2.4.1.8]': 0,
#  "maltose-6'-phosphate glucosidase [EC:3.2.1.122]": 0,
#  'alpha-glucoside PTS system EIICB component [EC:2.7.1.208 2.7.1.-]': 0,
#  'starch synthase [EC:2.4.1.21]': 0,
#  'glucose-1-phosphate adenylyltransferase [EC:2.7.7.27]': 0,
#  'endoglucanase [EC:3.2.1.4]': 0,
#  'levansucrase [EC:2.4.1.10]': 0.5,
#  'levanase [EC:3.2.1.65]': 0,
#  'cellobiose PTS system EIIA component [EC:2.7.1.196 2.7.1.205]': 0,
#  'alpha-amylase [EC:3.2.1.1]': 0.0,
#  'N-acetylmuramic acid 6-phosphate etherase [EC:4.2.1.126]': 0,
#  'N-acetylglucosamine PTS system EIICBA or EIICB component [EC:2.7.1.193]': 0,
#  'N-acetylglucosamine-6-phosphate deacetylase [EC:3.5.1.25]': 4,
#  'bifunctional UDP-N-acetylglucosamine pyrophosphorylase / Glucosamine-1-phosphate N-acetyltransferase [EC:2.7.7.23 2.3.1.157]': 1,
#  'UDP-N-acetylglucosamine 1-carboxyvinyltransferase [EC:2.5.1.7]': 0,
#  'UDP-N-acetylglucosamine 2-epimerase (non-hydrolysing) [EC:5.1.3.14]': 0,
#  'glucosamine-6-phosphate deaminase [EC:3.5.99.6]': 0.375,
#  'phosphoglucosamine mutase [EC:5.4.2.10]': 0,
#  'UDP-N-acetylmuramate dehydrogenase [EC:1.3.1.98]': 0,
#  'glucose-1-phosphate thymidylyltransferase [EC:2.7.7.24]': 0,
#  'dTDP-glucose 4,6-dehydratase [EC:4.2.1.46]': 0,
#  'dTDP-4-dehydrorhamnose 3,5-epimerase [EC:5.1.3.13]': 0,
#  'dTDP-4-dehydrorhamnose reductase [EC:1.1.1.133]': 0,
#  'D-sedoheptulose 7-phosphate isomerase [EC:5.3.1.28]': 0,
#  'D-glycero-alpha-D-manno-heptose-7-phosphate kinase [EC:2.7.1.168]': 0,
#  'D-glycero-D-manno-heptose 1,7-bisphosphate phosphatase [EC:3.1.3.82 3.1.3.83]': 0,
#  'D-glycero-alpha-D-manno-heptose 1-phosphate guanylyltransferase [EC:2.7.7.71]': 0,
#  'phospho-N-acetylmuramoyl-pentapeptide-transferase [EC:2.7.8.13]': 0,
#  'UDP-N-acetylglucosamine--N-acetylmuramyl-(pentapeptide) pyrophosphoryl-undecaprenol N-acetylglucosamine transferase [EC:2.4.1.227]': 0,
#  'undecaprenyl-diphosphatase [EC:3.6.1.27]': 0,
#  'lipid II isoglutaminyl synthase (glutamine-hydrolysing) [EC:6.3.5.13]': 0,
#  '1-acyl-sn-glycerol-3-phosphate acyltransferase [EC:2.3.1.51]': 0.0,
#  'diacylglycerol kinase (ATP) [EC:2.7.1.107]': 0.0,
#  'triacylglycerol lipase [EC:3.1.1.3]': 0.25,
#  '1,2-diacylglycerol 3-alpha-glucosyltransferase [EC:2.4.1.337]': 0.0,
#  'processive 1,2-diacylglycerol beta-glucosyltransferase [EC:2.4.1.315]': 0.5,
#  'acyl phosphate:glycerol-3-phosphate acyltransferase [EC:2.3.1.275]': 1.0,
#  'phosphate acyltransferase [EC:2.3.1.274]': 0,
#  'glycerol kinase [EC:2.7.1.30]': 0,
#  'CDP-diacylglycerol---glycerol-3-phosphate 3-phosphatidyltransferase [EC:2.7.8.5]': 0,
#  'cardiolipin synthase (CMP-forming) [EC:2.7.8.41]': 0,
#  'phosphatidylserine decarboxylase [EC:4.1.1.65]': 0,
#  'phospholipase C [EC:3.1.4.3]': 0,
#  'glycerophosphoryl diester phosphodiesterase [EC:3.1.4.46]': 0,
#  'lysophospholipase [EC:3.1.1.5]': 0,
#  'ethanolamine ammonia-lyase small subunit [EC:4.3.1.7]': 0,
#  'glycerol-3-phosphate dehydrogenase [EC:1.1.5.3]': 0,
#  'glycerol-1-phosphate dehydrogenase [NAD(P)+] [EC:1.1.1.261]': 0,
#  'glycerol-3-phosphate dehydrogenase (NAD(P)+) [EC:1.1.1.94]': 0,
#  'cardiolipin synthase A/B [EC:2.7.8.-]': 0,
#  'hydroxyacylglutathione hydrolase [EC:3.1.2.6]': 0,
#  'lactate racemase [EC:5.1.2.1]': 0,
#  'D-lactate dehydrogenase [EC:1.1.1.28]': 0.46774193548387094,
#  'acylphosphatase [EC:3.6.1.7]': 0,
#  'acetaldehyde dehydrogenase / alcohol dehydrogenase [EC:1.2.1.10 1.1.1.1]': 4,
#  'homocitrate synthase NifV [EC:2.3.3.14]': 0,
#  'formate C-acetyltransferase [EC:2.3.1.54]': 0.184,
#  'malate dehydrogenase (oxaloacetate-decarboxylating) [EC:1.1.1.38]': 0.41935483870967744,
#  'pyruvate, water dikinase [EC:2.7.9.2]': 0.2608695652173913,
#  'fumarate hydratase subunit beta [EC:4.2.1.2]': 0,
#  'phosphoglycolate phosphatase [EC:3.1.3.18]': 0,
#  'glycolate oxidase [EC:1.1.3.15]': 0.0,
#  'acetoacetate decarboxylase [EC:4.1.1.4]': 0,
#  'methylglyoxal synthase [EC:4.2.3.3]': 0.0,
#  'NADP-dependent alcohol dehydrogenase [EC:1.1.-.-]': 0,
#  'methylglyoxal/glyoxal reductase [EC:1.1.1.283 1.1.1.-]': 0,
#  '4-hydroxybutyrate dehydrogenase [EC:1.1.1.61]': 0,
#  'phosphate butyryltransferase [EC:2.3.1.19]': 1,
#  'butyrate kinase [EC:2.7.2.7]': 0,
#  'butanol dehydrogenase [EC:1.1.1.-]': 0,
#  'enoyl-CoA hydratase [EC:4.2.1.17]': 0.75,
#  'acetolactate decarboxylase [EC:4.1.1.5]': 0,
#  'dihydrofolate reductase [EC:1.5.1.3]': 0.2926829268292683,
#  'methylenetetrahydrofolate dehydrogenase (NADP+) / methenyltetrahydrofolate cyclohydrolase [EC:1.5.1.5 3.5.4.9]': 0.6410256410256411,
#  'formate--tetrahydrofolate ligase [EC:6.3.4.3]': 0.11538461538461539,
#  'methionyl-tRNA formyltransferase [EC:2.1.2.9]': 0.0,
#  '5-formyltetrahydrofolate cyclo-ligase [EC:6.3.3.2]': 0.25,
#  'hydroxymethylpyrimidine/phosphomethylpyrimidine kinase [EC:2.7.1.49 2.7.4.7]': 0,
#  'thiamine pyrophosphokinase [EC:2.7.6.2]': 0.0,
#  'ribosome biogenesis GTPase / thiamine phosphate phosphatase [EC:3.6.1.- 3.1.3.100]': 0,
#  'tRNA uracil 4-sulfurtransferase [EC:2.8.1.4]': 0.0,
#  'sulfur carrier protein ThiS adenylyltransferase [EC:2.7.7.73]': 0,
#  'cysteine desulfurase [EC:2.8.1.7]': 0,
#  '2-iminoacetate synthase [EC:4.1.99.19]': 0,
#  'thiazole synthase [EC:2.8.1.10]': 0,
#  '1-deoxy-D-xylulose-5-phosphate synthase [EC:2.2.1.7]': 0,
#  'phosphomethylpyrimidine synthase [EC:4.1.99.17]': 0,
#  'hydroxyethylthiazole kinase [EC:2.7.1.50]': 0,
#  'thiamine-phosphate pyrophosphorylase [EC:2.5.1.3]': 0,
#  'diaminohydroxyphosphoribosylaminopyrimidine deaminase / 5-amino-6-(5-phosphoribosylamino)uracil reductase [EC:3.5.4.26 1.1.1.193]': 0,
#  '3,4-dihydroxy 2-butanone 4-phosphate synthase / GTP cyclohydrolase II [EC:4.1.99.12 3.5.4.25]': 0,
#  '6,7-dimethyl-8-ribityllumazine synthase [EC:2.5.1.78]': 0,
#  'riboflavin synthase [EC:2.5.1.9]': 0,
#  'riboflavin kinase / FMN adenylyltransferase [EC:2.7.1.26 2.7.7.2]': 0,
#  'FMN reductase [NAD(P)H] [EC:1.5.1.39]': 0,
#  'pyridoxine kinase [EC:2.7.1.35]': 0,
#  "pyridoxal 5'-phosphate synthase pdxS subunit [EC:4.3.3.6]": 0,
#  'nicotinamide-nucleotide amidase [EC:3.5.1.42]': 3,
#  'NAD+ diphosphatase [EC:3.6.1.22]': 4,
#  'nicotinate-nucleotide adenylyltransferase [EC:2.7.7.18]': 1,
#  'NAD+ synthase (glutamine-hydrolysing) [EC:6.3.5.1]': 3,
#  'NAD+ kinase [EC:2.7.1.23]': 0,
#  'nicotinate phosphoribosyltransferase [EC:6.3.4.21]': 0,
#  'nicotinate-nucleotide pyrophosphorylase (carboxylating) [EC:2.4.2.19]': 1,
#  'quinolinate synthase [EC:2.5.1.72]': 0,
#  '3-methyl-2-oxobutanoate hydroxymethyltransferase [EC:2.1.2.11]': 0,
#  '2-dehydropantoate 2-reductase [EC:1.1.1.169]': 0,
#  'type III pantothenate kinase [EC:2.7.1.33]': 0,
#  'phosphopantothenoylcysteine decarboxylase / phosphopantothenate---cysteine ligase [EC:4.1.1.36 6.3.2.5]': 1,
#  'pantetheine-phosphate adenylyltransferase [EC:2.7.7.3]': 0,
#  'dephospho-CoA kinase [EC:2.7.1.24]': 0.0,
#  'holo-[acyl-carrier protein] synthase [EC:2.7.8.7]': 0,
#  "4'-phosphopantetheinyl transferase [EC:2.7.8.-]": 0,
#  'adenosylmethionine---8-amino-7-oxononanoate aminotransferase [EC:2.6.1.62]': 0,
#  'dethiobiotin synthetase [EC:6.3.3.3]': 0,
#  'biotin synthase [EC:2.8.1.6]': 0,
#  'BirA family transcriptional regulator, biotin operon repressor / biotin---[acetyl-CoA-carboxylase] ligase [EC:6.3.4.15]': 0,
#  'GTP cyclohydrolase IA [EC:3.5.4.16]': 0.0,
#  '6-pyruvoyltetrahydropterin/6-carboxytetrahydropterin synthase [EC:4.2.3.12 4.1.2.50]': 0,
#  'dihydroneopterin aldolase / 2-amino-4-hydroxy-6-hydroxymethyldihydropteridine diphosphokinase [EC:4.1.2.25 2.7.6.3]': 0,
#  'dihydropteroate synthase [EC:2.5.1.15]': 0,
#  'dihydrofolate synthase / folylpolyglutamate synthase [EC:6.3.2.12 6.3.2.17]': 0.0,
#  "GTP 3',8-cyclase [EC:4.1.99.22]": 0,
#  '7-carboxy-7-deazaguanine synthase [EC:4.3.99.3]': 0,
#  '7-cyano-7-deazaguanine synthase [EC:6.3.4.20]': 0,
#  'cyclic pyranopterin monophosphate synthase [EC:4.6.1.17]': 0,
#  "7,8-dihydropterin-6-yl-methyl-4-(beta-D-ribofuranosyl)aminobenzene 5'-phosphate synthase [EC:2.5.1.105]": 0,
#  'porphobilinogen synthase [EC:4.2.1.24]': 0,
#  'glutamate-1-semialdehyde 2,1-aminomutase [EC:5.4.3.8]': 0,
#  'hydroxymethylbilane synthase [EC:2.5.1.61]': 0,
#  'uroporphyrinogen III methyltransferase / synthase [EC:2.1.1.107 4.2.1.75]': 0,
#  'precorrin-2 dehydrogenase / sirohydrochlorin ferrochelatase [EC:1.3.1.76 4.99.1.4]': 1,
#  'sirohydrochlorin cobaltochelatase [EC:4.99.1.3]': 0,
#  'precorrin-2/cobalt-factor-2 C20-methyltransferase [EC:2.1.1.130 2.1.1.151]': 1,
#  'precorrin-4/cobalt-precorrin-4 C11-methyltransferase [EC:2.1.1.133 2.1.1.271]': 0,
#  'precorrin-3B C17-methyltransferase [EC:2.1.1.131]': 0,
#  'cobalt-precorrin 5A hydrolase [EC:3.7.1.12]': 0,
#  'cobalt-precorrin-5B (C1)-methyltransferase [EC:2.1.1.195]': 0,
#  'precorrin-6A/cobalt-precorrin-6A reductase [EC:1.3.1.54 1.3.1.106]': 0,
#  'cobyrinic acid a,c-diamide synthase [EC:6.3.5.9 6.3.5.11]': 0,
#  'precorrin-8X/cobalt-precorrin-8 methylmutase [EC:5.4.99.61 5.4.99.60]': 0,
#  'adenosylcobyric acid synthase [EC:6.3.5.10]': 0,
#  'adenosylcobinamide-phosphate synthase [EC:6.3.1.10]': 0,
#  'adenosylcobinamide kinase / adenosylcobinamide-phosphate guanylyltransferase [EC:2.7.1.156 2.7.7.62]': 0,
#  'adenosylcobinamide-GDP ribazoletransferase [EC:2.7.8.26]': 0,
#  'alpha-ribazole phosphatase [EC:3.1.3.73]': 0,
#  'nicotinate-nucleotide--dimethylbenzimidazole phosphoribosyltransferase [EC:2.4.2.21]': 0,
#  'threonine-phosphate decarboxylase [EC:4.1.1.81]': 0,
#  'glutamyl-tRNA reductase [EC:1.2.1.70]': 0,
#  'glutamyl-tRNA synthetase [EC:6.1.1.17]': 0,
#  'L-threonine kinase [EC:2.7.1.177]': 0,
#  'cobalt-precorrin-6B (C15)-methyltransferase [EC:2.1.1.196]': 0,
#  'cobalt-precorrin-7 (C5)-methyltransferase [EC:2.1.1.289]': 0,
#  '1-deoxy-D-xylulose-5-phosphate reductoisomerase [EC:1.1.1.267]': 0,
#  '2-C-methyl-D-erythritol 4-phosphate cytidylyltransferase [EC:2.7.7.60]': 0,
#  '4-diphosphocytidyl-2-C-methyl-D-erythritol kinase [EC:2.7.1.148]': 0,
#  '2-C-methyl-D-erythritol 2,4-cyclodiphosphate synthase [EC:4.6.1.12]': 0,
#  '(E)-4-hydroxy-3-methylbut-2-enyl-diphosphate synthase [EC:1.17.7.1 1.17.7.3]': 0,
#  'small subunit ribosomal protein S1': 0,
#  'geranylgeranyl diphosphate synthase, type II [EC:2.5.1.1 2.5.1.10 2.5.1.29]': 0,
#  'undecaprenyl diphosphate synthase [EC:2.5.1.31]': 0,
#  'nitrogenase iron protein NifH': 5,
#  'hydroxylamine reductase [EC:1.7.99.1]': 0,
#  'ferredoxin-nitrite reductase [EC:1.7.7.1]': 0,
#  'adenylylsulfate reductase, subunit A [EC:1.8.99.2]': 0.0,
#  'bifunctional oligoribonuclease and PAP phosphatase NrnA [EC:3.1.3.7 3.1.13.3]': 0,
#  'anaerobic sulfite reductase subunit A': 0.25,
#  'aspartyl-tRNA synthetase [EC:6.1.1.12]': 0,
#  'nondiscriminating aspartyl-tRNA synthetase [EC:6.1.1.23]': 0,
#  'aspartyl-tRNA(Asn)/glutamyl-tRNA(Gln) amidotransferase subunit B [EC:6.3.5.6 6.3.5.7]': 0,
#  'asparaginyl-tRNA synthetase [EC:6.1.1.22]': 0}

# %%
nodos=G.nodes

D=[] # un vector donde vamos a colocar el numero de vinvulos de todos los nodos
d=nx.degree(G) # Vector que contiene el par ordenado del nodo y su numero de vinculos
for i in nodos: 
    D.append(d[i])
    

D_in=[] # un vector donde vamos a colocar el numero de vinvulos de todos los nodos
d=G.in_degree(G) # Vector que contiene el par ordenado del nodo y su numero de vinculos
for i in nodos: 
    D_in.append(d[i])
    
    
D_out=[] # un vector donde vamos a colocar el numero de vinvulos de todos los nodos
d=G.out_degree(G) # Vector que contiene el par ordenado del nodo y su numero de vinculos
for i in nodos: 
    D_out.append(d[i])
    
    
P=[]
X=[]
for i in range(1,max(D)+1):
    if D.count(i) != 0: 
        P.append(D.count(i)/len(D))
        X.append(i)
        
P_in=[]
X_in=[]
for i in range(1,max(D_in)+1):
    if D_in.count(i) != 0: 
        P_in.append(D_in.count(i)/len(D_in))
        X_in.append(i)  

P_out=[]
X_out=[]
for i in range(1,max(D)+1):
    if D_out.count(i) != 0: 
        P_out.append(D_out.count(i)/len(D_out))
        X_out.append(i)
        
        
        
# GRAFICA DE LA PROVAVILIDAD VS EL NUMERO DE GRADO        
fig, axs = plt.subplots( 3 ,sharex = True, sharey = True, figsize=(15,8))

fig.suptitle('Distribución de grado 2012',fontsize=20)
axs[0].plot(X,P,'ko')         
axs[0].set_xlabel(r'$K$',fontsize=20)
axs[0].set_ylabel(r'$P(K)$',fontsize=20)

axs[1].plot(X_in,P_in,'o')         
axs[1].set_xlabel(r'$K_{in}$',fontsize=20)
axs[1].set_ylabel(r'$P(K_{in})$',fontsize=20)

axs[2].plot(X_out,P_out, 'ro')         
axs[2].set_xlabel(r'$K_{out}$',fontsize=20)
axs[2].set_ylabel(r'$P(K_{out})$',fontsize=20)

#plt.savefig("P_vs_k_2012.pdf")# Guardar la red en pdf.    

plt.show()

# %%
fig, (ax1, ax2 , ax3) = plt.subplots(1, 3 ,sharex = True, sharey = True, figsize=(15,5))
fig.suptitle('Distribucion Log-Log 2012',fontsize=20)
ax1.plot(X,P,'ko')
ax1.set_xlabel(r'$K$',fontsize=20)
ax1.set_ylabel(r'$P(K)$',fontsize=20)

ax2.plot(X_in,P_in,'o')
ax2.set_xlabel(r'$K_{in}$',fontsize=20)
ax2.set_ylabel(r'$P(K_{in})$',fontsize=20)

ax3.plot(X_out,P_out,'ro')
ax3.set_xlabel(r'$K_{out}$',fontsize=20)
ax3.set_ylabel(r'$P(K_{out})$',fontsize=20)

# Escala log-log
plt.xscale('log') 
plt.yscale('log') 

#plt.savefig("Ley_de_potencias_2012.pdf")# Guardar la red en pdf.

plt.show()

# %%
d=G.degree(G) #Vector con el par ordenado de numero de aristas de entrada a cada uno de los nodos
d_in=G.in_degree(G)
d_out=G.out_degree(G)
degre=[]

for i in G.nodes:
    degre.append([i,d[i],d_in[i],d_out[i], d_in[i]-d_out[i] ])
df=pd.DataFrame(degre,columns=['Nombre', 'grado', 'grado_in', 'grado_out','dif_grado'])
df.sort_values(by='dif_grado', ascending=False)
# Out:
#                                                 Nombre  grado  grado_in  \
# 71   acetyl-CoA carboxylase carboxyl transferase su...     12        10
# 108  hypoxanthine phosphoribosyltransferase [EC:2.4...     11         9
# 16               L-lactate dehydrogenase [EC:1.1.1.27]     14        10
# 85             aspartate aminotransferase [EC:2.6.1.1]     14        10
# 32                          transaldolase [EC:2.2.1.2]      8         7
# 298            homocitrate synthase NifV [EC:2.3.3.14]      8         7
# 102     adenine phosphoribosyltransferase [EC:2.4.2.7]     10         8
# 97   phosphoribosylglycinamide formyltransferase 1 ...     13         9
# 241                glycogen phosphorylase [EC:2.4.1.1]      5         5
# 66                     alpha-glucosidase [EC:3.2.1.20]      7         6
# 149                  L-aspartate oxidase [EC:1.4.3.16]      7         6
# 345  nicotinate phosphoribosyltransferase [EC:6.3.4...      5         5
# 17   glyceraldehyde-3-phosphate dehydrogenase (NADP...      7         6
# 131  orotidine-5'-phosphate decarboxylase [EC:4.1.1...      4         4
# 167      cysteine-S-conjugate beta-lyase [EC:4.4.1.13]      8         6
# 197  acetate CoA/acetoacetate CoA-transferase alpha...      8         6
# 260            phosphoglucosamine mutase [EC:5.4.2.10]      4         4
# 118   xanthine phosphoribosyltransferase [EC:2.4.2.22]      8         6
# 406          ferredoxin-nitrite reductase [EC:1.7.7.1]      4         4
# 6         fructose-1,6-bisphosphatase II [EC:3.1.3.11]     10         7
# 124          XTP/dITP diphosphohydrolase [EC:3.6.1.66]      4         4
# 145  glutamate synthase (NADPH) small chain [EC:1.4...      6         5
# 94            ADP-ribose pyrophosphatase [EC:3.6.1.13]      3         3
# 3           glucose-6-phosphate isomerase [EC:5.3.1.9]     17        10
# 344                          NAD+ kinase [EC:2.7.1.23]      3         3
# 327                    thiazole synthase [EC:2.8.1.10]      3         3
# 189           2-isopropylmalate synthase [EC:2.3.3.13]     11         7
# 160              glycerate dehydrogenase [EC:1.1.1.29]      5         4
# 101                adenylosuccinate lyase [EC:4.3.2.2]      7         5
# 283   cardiolipin synthase (CMP-forming) [EC:2.7.8.41]      3         3
# ..                                                 ...    ...       ...
# 409              anaerobic sulfite reductase subunit A      3         0
# 8    fructose-bisphosphate aldolase, class II [EC:4...     15         6
# 341                   NAD+ diphosphatase [EC:3.6.1.22]      7         2
# 323       tRNA uracil 4-sulfurtransferase [EC:2.8.1.4]      3         0
# 104  sulfate adenylyltransferase subunit 2 [EC:2.7....      3         0
# 134                     uridylate kinase [EC:2.7.4.22]      3         0
# 133  pyrimidine operon attenuation protein / uracil...      5         1
# 295              D-lactate dehydrogenase [EC:1.1.1.28]     11         4
# 126  carbamoyl-phosphate synthase large subunit [EC...      5         1
# 376  precorrin-2/cobalt-factor-2 C20-methyltransfer...      3         0
# 174   L-methionine (R)-S-oxide reductase [EC:1.8.4.14]      3         0
# 252                         alpha-amylase [EC:3.2.1.1]      4         0
# 404                      nitrogenase iron protein NifH      4         0
# 191  LL-diaminopimelate aminotransferase [EC:2.6.1.83]      4         0
# 25   2-dehydro-3-deoxyphosphogluconate aldolase / (...      4         0
# 20   2-oxoglutarate/2-oxoacid ferredoxin oxidoreduc...     18         7
# 95        amidophosphoribosyltransferase [EC:2.4.2.14]      6         1
# 30                     phosphopentomutase [EC:5.4.2.7]      6         1
# 14                       pyruvate kinase [EC:2.7.1.40]     19         7
# 31     ribose-phosphate pyrophosphokinase [EC:2.7.6.1]      7         1
# 229           phosphate acetyltransferase [EC:2.3.1.8]     13         4
# 315               dihydrofolate reductase [EC:1.5.1.3]      9         2
# 144               aspartate ammonia-lyase [EC:4.3.1.1]      8         1
# 125  ribonucleoside-triphosphate reductase (formate...      6         0
# 116                         GMP reductase [EC:1.7.1.7]      8         1
# 18   pyruvate-ferredoxin/flavodoxin oxidoreductase ...     21         7
# 301              pyruvate, water dikinase [EC:2.7.9.2]      9         1
# 117  GMP synthase (glutamine-hydrolysing) [EC:6.3.5.2]      7         0
# 92             argininosuccinate synthase [EC:6.3.4.5]      8         0
# 106             adenylosuccinate synthase [EC:6.3.4.4]     12         2
#
#      grado_out  dif_grado
# 71           2          8
# 108          2          7
# 16           4          6
# 85           4          6
# 32           1          6
# 298          1          6
# 102          2          6
# 97           4          5
# 241          0          5
# 66           1          5
# 149          1          5
# 345          0          5
# 17           1          5
# 131          0          4
# 167          2          4
# 197          2          4
# 260          0          4
# 118          2          4
# 406          0          4
# 6            3          4
# 124          0          4
# 145          1          4
# 94           0          3
# 3            7          3
# 344          0          3
# 327          0          3
# 189          4          3
# 160          1          3
# 101          2          3
# 283          0          3
# ..         ...        ...
# 409          3         -3
# 8            9         -3
# 341          5         -3
# 323          3         -3
# 104          3         -3
# 134          3         -3
# 133          4         -3
# 295          7         -3
# 126          4         -3
# 376          3         -3
# 174          3         -3
# 252          4         -4
# 404          4         -4
# 191          4         -4
# 25           4         -4
# 20          11         -4
# 95           5         -4
# 30           5         -4
# 14          12         -5
# 31           6         -5
# 229          9         -5
# 315          7         -5
# 144          7         -6
# 125          6         -6
# 116          7         -6
# 18          14         -7
# 301          8         -7
# 117          7         -7
# 92           8         -8
# 106         10         -8
#
# [414 rows x 5 columns]

# %%
intr=nx.betweenness_centrality(G) #dicionario en python
intr = pd.DataFrame([[key, intr[key]] for key in intr.keys()], columns=['Name', 'intermediacion'])
print(intr.sort_values(by='intermediacion', ascending=False))
# Out:
#                                                   Name  intermediacion
# 170  aspartate aminotransferase, cytoplasmic [EC:2....        0.080279
# 19                       pyruvate kinase [EC:2.7.1.40]        0.066031
# 1                              hexokinase [EC:2.7.1.1]        0.065222
# 11   2,3-bisphosphoglycerate-dependent phosphoglyce...        0.056590
# 18          aldehyde dehydrogenase (NAD+) [EC:1.2.1.3]        0.055253
# 4                      phosphoglucomutase [EC:5.4.2.2]        0.049236
# 243  glutamine---fructose-6-phosphate transaminase ...        0.048742
# 44                          transketolase [EC:2.2.1.1]        0.045338
# 10                phosphoglycerate kinase [EC:2.7.2.3]        0.041271
# 9    glyceraldehyde 3-phosphate dehydrogenase [EC:1...        0.040072
# 245              glutamate decarboxylase [EC:4.1.1.15]        0.039165
# 12                               enolase [EC:4.2.1.11]        0.035353
# 241            glutamate synthase (NADH) [EC:1.4.1.14]        0.035244
# 70                   alpha-galactosidase [EC:3.2.1.22]        0.032228
# 484                       phospholipase C [EC:3.1.4.3]        0.032175
# 251                 D-glycerate 3-kinase [EC:2.7.1.31]        0.030824
# 472  1,2-diacylglycerol 3-beta-galactosyltransferas...        0.028767
# 242                         omega-amidase [EC:3.5.1.3]        0.026382
# 548                       malate synthase [EC:2.3.3.9]        0.024093
# 78                     alpha-glucosidase [EC:3.2.1.20]        0.022261
# 109        acetyl-CoA C-acetyltransferase [EC:2.3.1.9]        0.022130
# 55   UTP--glucose-1-phosphate uridylyltransferase [...        0.021490
# 22   phosphoenolpyruvate carboxykinase (ATP) [EC:4....        0.021415
# 91   acetyl-CoA carboxylase / biotin carboxylase 1 ...        0.021399
# 29                  malate dehydrogenase [EC:1.1.1.37]        0.021257
# 25   multiple inositol-polyphosphate phosphatase / ...        0.019683
# 467  diacylglycerol diphosphate phosphatase / phosp...        0.019014
# 167                  glutamine synthetase [EC:6.3.1.2]        0.018339
# 53           UDP-sugar pyrophosphorylase [EC:2.7.7.64]        0.017414
# 74               beta-fructofuranosidase [EC:3.2.1.26]        0.017242
# ..                                                 ...             ...
# 370  2-oxoglutarate-dependent dioxygenase [EC:1.14....        0.000000
# 363                               amidase [EC:3.5.1.4]        0.000000
# 362  benzaldehyde dehydrogenase (NAD+) / indole-3-a...        0.000000
# 359  acetylserotonin O-methyltransferase, plant [EC...        0.000000
# 357                          myrosinase [EC:3.2.1.147]        0.000000
# 430       alpha-1,6-mannosyltransferase [EC:2.4.1.260]        0.000000
# 434  mannosyl-oligosaccharide alpha-1,3-glucosidase...        0.000000
# 492  inositol-pentakisphosphate 2-kinase [EC:2.7.1....        0.000000
# 459  alpha-1,4-galacturonosyltransferase [EC:2.4.1.43]        0.000000
# 489  3'(2'), 5'-bisphosphate nucleotidase / inosito...        0.000000
# 488     myo-inositol-1-phosphate synthase [EC:5.5.1.4]        0.000000
# 478  phosphatidylinositol-3,4,5-trisphosphate 3-pho...        0.000000
# 476     2-lysophosphatidate phosphatase [EC:3.1.3.106]        0.000000
# 475  UTP---glucose-1-phosphate uridylyltransferase ...        0.000000
# 464                      glycerol kinase [EC:2.7.1.30]        0.000000
# 462        alpha-N-acetylglucosaminidase [EC:3.2.1.50]        0.000000
# 461  heparan-alpha-glucosaminide N-acetyltransferas...        0.000000
# 460  reversibly glycosylated polypeptide / UDP-arab...        0.000000
# 458     3,5-epimerase/4-reductase [EC:5.1.3.- 1.1.1.-]        0.000000
# 438  beta-1,4-mannosyl-glycoprotein beta-1,4-N-acet...        0.000000
# 454            xylan 1,4-beta-xylosidase [EC:3.2.1.37]        0.000000
# 449          alpha-L-arabinofuranosidase [EC:3.2.1.55]        0.000000
# 448                      L-arabinokinase [EC:2.7.1.46]        0.000000
# 447  UDP-N-acetylglucosamine/UDP-N-acetylgalactosam...        0.000000
# 445  glucosamine-phosphate N-acetyltransferase [EC:...        0.000000
# 443                            chitinase [EC:3.2.1.14]        0.000000
# 442  mannosyl-oligosaccharide alpha-1,2-mannosidase...        0.000000
# 441  3-oxo-5-alpha-steroid 4-dehydrogenase 3 / poly...        0.000000
# 440  endoplasmic reticulum Man9GlcNAc2 1,2-alpha-ma...        0.000000
# 786  pinoresinol/lariciresinol reductase [EC:1.23.1...        0.000000
#
# [787 rows x 2 columns]
