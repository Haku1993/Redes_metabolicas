# %% [markdown]
# # Libreria

# %%
import pandas as pd
import networkx as nx
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
#parsear XML
import csv   
from lxml import etree
#Parsear HTML
import requests
import urllib.request
from bs4 import BeautifulSoup
from urllib.request import urlopen
from bs4.builder import HTMLParserTreeBuilder
#para medir tiempo
from time import time 
import time

# %% [markdown]
# # Carga de Archivos XML

# %%
org = 'tac'
ORGANISM = org
maxi ='01100'

pathways = requests.get('http://rest.kegg.jp/list/pathway/' + ORGANISM)  #lista de las vias metabolicas y otra informacion porpocionada por KEGG

for line in pathways.text.split('\n'):         # Se recorre la lista propocionada por  KEGG donde se estraen los nombres de las vias de KEGG
      pathwayid = line.split('\t')[0].replace('path:', '') 
      A = pathwayid+'.xml'                     # Le ponemos la extencion .xml para poder cargar los archivos
      if A == str(org)+str(maxi)+'.xml':           
            break
      locals()[str(pathwayid)] = etree.parse(A) # Guarda los  XML com el nombre de la via asignado por KEGG
      locals()[str(pathwayid)] = locals()[str(pathwayid)].getroot()  # Para transformar todos lo XML en directorios de python

# %% [markdown]
# ## ARMANDO BASE DE DATOS CON PANDAS

# %% [markdown]
# ##### crear archivo csv para guardar los datos.

# %%
#data= pd.DataFrame(columns=('n', 'enzima', 'gen', 'nob_Keeg', 'path' ,'link')) # Crear tabla csv. 
#data.to_csv('data_'+org+'.csv', sep=';')

# %%
save=len(pd.read_csv('data_'+org+'.csv',index_col=0, delimiter=';')[['n']].values)
print(save)
# Out:
# 693

# %%
save=len(pd.read_csv('data_'+org+'.csv',index_col=0, delimiter=';')[['n']].values)

n=0

for line in pathways.text.split('\n'):
    
    pathwayid = line.split('\t')[0].replace('path:', '') 
    
    if pathwayid ==  str(org)+str(maxi):           
            break
    
    ii=locals()[str(pathwayid)]
    
    
    for i in range(0,len(ii)):
       
        if ii[i].tag=='entry':         
            A=ii[i].attrib            
            if A['type'] == 'gene':
                n=1+n
                
                if n > save:
                    
                    url = A['link']
                
                    response = requests.get(url)
                    soup = BeautifulSoup(response.text, "html.parser")
                    
                    gen    = soup.html.body.div.table.form.td.table.find_all('td')[3].find_all('div')[0].text.replace('\n', ' ').strip().split()[0].replace(',','')
                    
                    if gen == '(GenBank)' or gen == '(RefSeq)' :
                        ll=6
                    else:
                        ll=7
                    
                    enzima = soup.html.body.div.table.form.td.table.find_all('td')[ll].text.strip()
                    
                    NewDat = [n , A['id'] , enzima, gen , A['name'].split( )[0] , pathwayid , A['link'] ]
                
                                
                    with open(r'data_'+org+'.csv', 'a' , newline='') as f:
                        writer = csv.writer(f,delimiter=';')
                        writer.writerow(NewDat)

# %%
n=0

for line in pathways.text.split('\n'):
    
    pathwayid = line.split('\t')[0].replace('path:', '') 
    
    if pathwayid == str(org)+str(maxi):           
            break
            
  
    ii=locals()[str(pathwayid)]
    
        
    
    for i in range(0,len(ii)):
       
        if ii[i].tag=='entry':         
            A=ii[i].attrib            
            if A['type'] == 'group':
                n=1+n 
                
                NewDat = [n , A['id'] , 'undefined_Enzima'+pathwayid , 'none' ,  A['name'] , pathwayid , 'no link']
                
                        
                with open(r'data_'+org+'.csv', 'a' , newline='') as f:
                    writer = csv.writer(f , delimiter=';')
                    writer.writerow(NewDat)

# %%
data=pd.read_csv('data_'+org+'.csv',index_col=0, sep=';')
data=data[['n' ,'enzima', 'nob_Keeg' ,'path']]
data=data.values
data
# Out:
# array([["'14'",
#         'fructose 1,6-bisphosphate aldolase/phosphatase [EC:4.1.2.13 3.1.3.11]',
#         'tac:Ta1428', 'tac00010'],
#        ['14',
#         'fructose 1,6-bisphosphate aldolase/phosphatase [EC:4.1.2.13 3.1.3.11]',
#         'tac:Ta1428', 'tac00010'],
#        ['38', 'aldehyde dehydrogenase (NAD+) [EC:1.2.1.3]', 'tac:Ta0439',
#         'tac00010'],
#        ...,
#        ['174', 'tRNA His', 'tac:tRNA-His', 'tac00970'],
#        ['176', 'tRNA Tyr', 'tac:tRNA-Tyr', 'tac00970'],
#        ['177', 'tRNA Trp', 'tac:tRNA-Trp', 'tac00970']], dtype=object)

# %%
for line in pathways.text.split('\n'):
    
    pathwayid = line.split('\t')[0].replace('path:', '') 
    
    if pathwayid == str(org)+str(maxi):           
            break
    
    locals()['NODES_'+str(pathwayid)]={}
    
    for i in data:
        if i[3] == pathwayid:
            locals()['NODES_'+str(pathwayid)][i[0]]= i[1] 
            print(i[0],i[1], i[2], i[3])
# Out:
# '14' fructose 1,6-bisphosphate aldolase/phosphatase [EC:4.1.2.13 3.1.3.11] tac:Ta1428 tac00010
# 14 fructose 1,6-bisphosphate aldolase/phosphatase [EC:4.1.2.13 3.1.3.11] tac:Ta1428 tac00010
# 38 aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] tac:Ta0439 tac00010
# 39 acetate---CoA ligase (ADP-forming) [EC:6.2.1.13] tac:Ta1153 tac00010
# 48 pyruvate dehydrogenase E1 component beta subunit [EC:1.2.4.1] tac:Ta1437 tac00010
# 49 pyruvate dehydrogenase E1 component beta subunit [EC:1.2.4.1] tac:Ta1437 tac00010
# 50 pyruvate dehydrogenase E2 component (dihydrolipoamide acetyltransferase) [EC:2.3.1.12] tac:Ta1436 tac00010
# 53 pyruvate kinase [EC:2.7.1.40] tac:Ta0896 tac00010
# 55 enolase [EC:4.2.1.11] tac:Ta0882 tac00010
# 58 triosephosphate isomerase (TIM) [EC:5.3.1.1] tac:Ta0313 tac00010
# 60 fructose 1,6-bisphosphate aldolase/phosphatase [EC:4.1.2.13 3.1.3.11] tac:Ta1428 tac00010
# 62 glucose/mannose-6-phosphate isomerase [EC:5.3.1.9 5.3.1.8] tac:Ta1419 tac00010
# 63 phosphomannomutase / phosphoglucomutase [EC:5.4.2.8 5.4.2.2] tac:Ta0568 tac00010
# 64 glucose/mannose-6-phosphate isomerase [EC:5.3.1.9 5.3.1.8] tac:Ta1419 tac00010
# 66 glucokinase [EC:2.7.1.2] tac:Ta0825 tac00010
# 67 glucose/mannose-6-phosphate isomerase [EC:5.3.1.9 5.3.1.8] tac:Ta1419 tac00010
# 69 aldose 1-epimerase [EC:5.1.3.3] tac:Ta0674 tac00010
# 70 glucokinase [EC:2.7.1.2] tac:Ta0825 tac00010
# 75 dihydrolipoamide dehydrogenase [EC:1.8.1.4] tac:Ta0208 tac00010
# 76 phosphoglycerate kinase [EC:2.7.2.3] tac:Ta1075 tac00010
# 112 phosphoenolpyruvate carboxykinase (GTP) [EC:4.1.1.32] tac:Ta0123 tac00010
# 119 glyceraldehyde-3-phosphate dehydrogenase (NAD(P)) [EC:1.2.1.59] tac:Ta1103 tac00010
# 124 2-oxoisovalerate/pyruvate ferredoxin oxidoreductase gamma subunit [EC:1.2.7.7 1.2.7.1] tac:Ta0626 tac00010
# 131 acetyl-CoA synthetase [EC:6.2.1.1] tac:Ta0229 tac00010
# 137 2,3-bisphosphoglycerate-independent phosphoglycerate mutase [EC:5.4.2.12] tac:Ta0413 tac00010
# 144 2-oxoglutarate/2-oxoacid ferredoxin oxidoreductase subunit alpha [EC:1.2.7.3 1.2.7.11] tac:Ta0259 tac00010
# 28 dihydrolipoamide dehydrogenase [EC:1.8.1.4] tac:Ta0208 tac00020
# 32 succinyl-CoA synthetase alpha subunit [EC:6.2.1.5] tac:Ta1331 tac00020
# 34 isocitrate dehydrogenase [EC:1.1.1.42] tac:Ta0117 tac00020
# 36 isocitrate dehydrogenase [EC:1.1.1.42] tac:Ta0117 tac00020
# 38 fumarate hydratase, class II [EC:4.2.1.2] tac:Ta0258 tac00020
# 39 aconitate hydratase [EC:4.2.1.3] tac:Ta0112 tac00020
# 40 aconitate hydratase [EC:4.2.1.3] tac:Ta0112 tac00020
# 41 citrate synthase [EC:2.3.3.1] tac:Ta0169 tac00020
# 42 malate dehydrogenase [EC:1.1.1.37] tac:Ta0952 tac00020
# 75 pyruvate dehydrogenase E1 component beta subunit [EC:1.2.4.1] tac:Ta1437 tac00020
# 77 pyruvate dehydrogenase E1 component beta subunit [EC:1.2.4.1] tac:Ta1437 tac00020
# 80 dihydrolipoamide dehydrogenase [EC:1.8.1.4] tac:Ta0208 tac00020
# 82 pyruvate dehydrogenase E2 component (dihydrolipoamide acetyltransferase) [EC:2.3.1.12] tac:Ta1436 tac00020
# 87 phosphoenolpyruvate carboxykinase (GTP) [EC:4.1.1.32] tac:Ta0123 tac00020
# 92 succinate dehydrogenase / fumarate reductase, flavoprotein subunit [EC:1.3.5.1 1.3.5.4] tac:Ta1001 tac00020
# 95 succinate dehydrogenase / fumarate reductase, flavoprotein subunit [EC:1.3.5.1 1.3.5.4] tac:Ta1001 tac00020
# 99 2-oxoglutarate/2-oxoacid ferredoxin oxidoreductase subunit alpha [EC:1.2.7.3 1.2.7.11] tac:Ta0259 tac00020
# 101 2-oxoisovalerate/pyruvate ferredoxin oxidoreductase gamma subunit [EC:1.2.7.7 1.2.7.1] tac:Ta0626 tac00020
# 102 2-oxoglutarate/2-oxoacid ferredoxin oxidoreductase subunit alpha [EC:1.2.7.3 1.2.7.11] tac:Ta0259 tac00020
# 103 2-oxoglutarate/2-oxoacid ferredoxin oxidoreductase subunit alpha [EC:1.2.7.3 1.2.7.11] tac:Ta0259 tac00020
# 37 glucose/mannose-6-phosphate isomerase [EC:5.3.1.9 5.3.1.8] tac:Ta1419 tac00030
# 42 deoxyribose-phosphate aldolase [EC:4.1.2.4] tac:Ta0684 tac00030
# 43 ribose-phosphate pyrophosphokinase [EC:2.7.6.1] tac:Ta0119 tac00030
# 46 transketolase [EC:2.2.1.1] tac:Ta0617 tac00030
# 47 ribose 5-phosphate isomerase A [EC:5.3.1.6] tac:Ta0878 tac00030
# 48 ribulose-phosphate 3-epimerase [EC:5.1.3.1] tac:Ta1315 tac00030
# 49 transketolase [EC:2.2.1.1] tac:Ta0617 tac00030
# 50 fructose 1,6-bisphosphate aldolase/phosphatase [EC:4.1.2.13 3.1.3.11] tac:Ta1428 tac00030
# 52 fructose 1,6-bisphosphate aldolase/phosphatase [EC:4.1.2.13 3.1.3.11] tac:Ta1428 tac00030
# 53 glucose/mannose-6-phosphate isomerase [EC:5.3.1.9 5.3.1.8] tac:Ta1419 tac00030
# 77 transaldolase [EC:2.2.1.2] tac:Ta0616 tac00030
# 78 phosphomannomutase / phosphoglucomutase [EC:5.4.2.8 5.4.2.2] tac:Ta0568 tac00030
# 84 2-dehydro-3-deoxy-phosphogluconate/2-dehydro-3-deoxy-6-phosphogalactonate aldolase [EC:4.1.2.55] tac:Ta0619 tac00030
# 86 aldehyde:ferredoxin oxidoreductase [EC:1.2.7.5] tac:Ta0810 tac00030
# 88 glycerate 2-kinase [EC:2.7.1.165] tac:Ta0453 tac00030
# 91 2-dehydro-3-deoxy-phosphogluconate/2-dehydro-3-deoxy-6-phosphogalactonate aldolase [EC:4.1.2.55] tac:Ta0619 tac00030
# 147 2-dehydro-3-deoxy-D-gluconate aldolase [EC:4.1.2.51] tac:Ta1157 tac00030
# 149 glucose/galactose 1-dehydrogenase (NADP+) [EC:1.1.1.360] tac:Ta0897 tac00030
# 152 D-glyceraldehyde dehydrogenase (NADP+) [EC:1.2.1.89] tac:Ta0809 tac00030
# 78 ribulose-phosphate 3-epimerase [EC:5.1.3.1] tac:Ta1315 tac00040
# 108 mannonate dehydratase [EC:4.2.1.8] tac:Ta0753 tac00040
# 78 glucose/mannose-6-phosphate isomerase [EC:5.3.1.9 5.3.1.8] tac:Ta1419 tac00051
# 79 phosphomannomutase / phosphoglucomutase [EC:5.4.2.8 5.4.2.2] tac:Ta0568 tac00051
# 84 mannose-1-phosphate guanylyltransferase [EC:2.7.7.13] tac:Ta1486 tac00051
# 93 triosephosphate isomerase (TIM) [EC:5.3.1.1] tac:Ta0313 tac00051
# 94 fructose 1,6-bisphosphate aldolase/phosphatase [EC:4.1.2.13 3.1.3.11] tac:Ta1428 tac00051
# 96 fructose 1,6-bisphosphate aldolase/phosphatase [EC:4.1.2.13 3.1.3.11] tac:Ta1428 tac00051
# 100 L-rhamnose 1-dehydrogenase [EC:1.1.1.378 1.1.1.377 1.1.1.173] tac:Ta0747 tac00051
# 105 fructose 1,6-bisphosphate aldolase/phosphatase [EC:4.1.2.13 3.1.3.11] tac:Ta1428 tac00051
# 218 L-rhamnose 1-dehydrogenase [EC:1.1.1.378 1.1.1.377 1.1.1.173] tac:Ta0747 tac00051
# 219 L-rhamnose 1-dehydrogenase [EC:1.1.1.378 1.1.1.377 1.1.1.173] tac:Ta0747 tac00051
# 64 alpha-glucosidase [EC:3.2.1.20] tac:Ta0298 tac00052
# 73 glucokinase [EC:2.7.1.2] tac:Ta0825 tac00052
# 76 beta-galactosidase [EC:3.2.1.23] tac:Ta1323 tac00052
# 77 phosphomannomutase / phosphoglucomutase [EC:5.4.2.8 5.4.2.2] tac:Ta0568 tac00052
# 79 UDP-glucose 4-epimerase [EC:5.1.3.2] tac:Ta0011 tac00052
# 84 galactonate dehydratase [EC:4.2.1.6] tac:Ta0756 tac00052
# 94 beta-galactosidase [EC:3.2.1.23] tac:Ta1323 tac00052
# 157 2-dehydro-3-deoxy-D-gluconate aldolase [EC:4.1.2.51] tac:Ta1157 tac00052
# 159 2-dehydro-3-deoxy-phosphogluconate/2-dehydro-3-deoxy-6-phosphogalactonate aldolase [EC:4.1.2.55] tac:Ta0619 tac00052
# 161 2-dehydro-3-deoxy-phosphogluconate/2-dehydro-3-deoxy-6-phosphogalactonate aldolase [EC:4.1.2.55] tac:Ta0619 tac00052
# 165 glucose/galactose 1-dehydrogenase (NADP+) [EC:1.1.1.360] tac:Ta0897 tac00052
# 172 aldose 1-epimerase [EC:5.1.3.3] tac:Ta0674 tac00052
# 62 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] tac:Ta0251 tac00061
# 83 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] tac:Ta0251 tac00061
# 94 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] tac:Ta0251 tac00061
# 105 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] tac:Ta0251 tac00061
# 116 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] tac:Ta0251 tac00061
# 127 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] tac:Ta0251 tac00061
# 138 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] tac:Ta0251 tac00061
# 150 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] tac:Ta0251 tac00061
# 363 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] tac:Ta0251 tac00061
# 419 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] tac:Ta0251 tac00061
# 49 acyl-CoA dehydrogenase [EC:1.3.8.7] tac:Ta0398 tac00071
# 53 acetyl-CoA C-acetyltransferase [EC:2.3.1.9] tac:Ta0030 tac00071
# 58 acyl-CoA dehydrogenase [EC:1.3.8.7] tac:Ta0398 tac00071
# 65 acyl-CoA dehydrogenase [EC:1.3.8.7] tac:Ta0398 tac00071
# 72 acyl-CoA dehydrogenase [EC:1.3.8.7] tac:Ta0398 tac00071
# 82 acyl-CoA dehydrogenase [EC:1.3.8.7] tac:Ta0398 tac00071
# 96 acyl-CoA dehydrogenase [EC:1.3.8.7] tac:Ta0398 tac00071
# 108 acyl-CoA dehydrogenase [EC:1.3.8.7] tac:Ta0398 tac00071
# 202 acetyl-CoA C-acetyltransferase [EC:2.3.1.9] tac:Ta0030 tac00071
# 213 aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] tac:Ta0439 tac00071
# 11 hydroxymethylglutaryl-CoA synthase [EC:2.3.3.10] tac:Ta1455 tac00072
# 14 acetyl-CoA C-acetyltransferase [EC:2.3.1.9] tac:Ta0030 tac00072
# 61 O-succinylbenzoate synthase [EC:4.2.1.113] tac:Ta0249 tac00130
# 65 flavin prenyltransferase [EC:2.5.1.129] tac:Ta1100 tac00130
# 92 4-hydroxybenzoate polyprenyltransferase [EC:2.5.1.39] tac:Ta1198 tac00130
# 105 demethylmenaquinone methyltransferase / 2-methoxy-6-polyprenyl-1,4-benzoquinol methylase [EC:2.1.1.163 2.1.1.201] tac:Ta0801 tac00130
# 136 demethylmenaquinone methyltransferase / 2-methoxy-6-polyprenyl-1,4-benzoquinol methylase [EC:2.1.1.163 2.1.1.201] tac:Ta0801 tac00130
# 191 1,4-dihydroxy-6-naphthoate synthase [EC:1.14.-.-] tac:Ta0174 tac00130
# 70 NADH-quinone oxidoreductase subunit N [EC:7.1.1.2] tac:Ta0959 tac00190
# 71 NADH-quinone oxidoreductase subunit M [EC:7.1.1.2] tac:Ta0960 tac00190
# 72 NADH-quinone oxidoreductase subunit L [EC:7.1.1.2] tac:Ta0961 tac00190
# 73 NADH-quinone oxidoreductase subunit K [EC:7.1.1.2] tac:Ta0962 tac00190
# 74 NADH-quinone oxidoreductase subunit J [EC:7.1.1.2] tac:Ta0963 tac00190
# 75 NADH-quinone oxidoreductase subunit I [EC:7.1.1.2] tac:Ta0965 tac00190
# 76 NADH-quinone oxidoreductase subunit H [EC:7.1.1.2] tac:Ta0966 tac00190
# 80 NADH-quinone oxidoreductase subunit D [EC:7.1.1.2] tac:Ta0967 tac00190
# 81 NADH-quinone oxidoreductase subunit C [EC:7.1.1.2] tac:Ta0968 tac00190
# 82 NADH-quinone oxidoreductase subunit B [EC:7.1.1.2] tac:Ta0969 tac00190
# 83 NADH-quinone oxidoreductase subunit A [EC:7.1.1.2] tac:Ta0970 tac00190
# 109 NADH-quinone oxidoreductase subunit N [EC:7.1.1.2] tac:Ta0959 tac00190
# 112 V/A-type H+/Na+-transporting ATPase subunit E tac:Ta0001 tac00190
# 114 H+-transporting ATPase [EC:7.1.2.1] tac:Ta1045 tac00190
# 115 inorganic pyrophosphatase [EC:3.6.1.1] tac:Ta0399 tac00190
# 140 succinate dehydrogenase / fumarate reductase, cytochrome b subunit tac:Ta1003 tac00190
# 141 succinate dehydrogenase / fumarate reductase, membrane anchor subunit tac:Ta1004 tac00190
# 142 succinate dehydrogenase / fumarate reductase, flavoprotein subunit [EC:1.3.5.1 1.3.5.4] tac:Ta1001 tac00190
# 143 succinate dehydrogenase / fumarate reductase, iron-sulfur subunit [EC:1.3.5.1 1.3.5.4] tac:Ta1002 tac00190
# 158 cytochrome bd ubiquinol oxidase subunit II [EC:7.1.1.7] tac:Ta0993 tac00190
# 159 cytochrome bd ubiquinol oxidase subunit I [EC:7.1.1.7] tac:Ta0992 tac00190
# 171 heme o synthase [EC:2.5.1.141] tac:Ta0435 tac00190
# 176 heme o synthase [EC:2.5.1.141] tac:Ta0435 tac00190
# 202 V/A-type H+/Na+-transporting ATPase subunit A [EC:7.1.2.2 7.2.2.1] tac:Ta0004 tac00190
# 203 V/A-type H+/Na+-transporting ATPase subunit B tac:Ta0005 tac00190
# 204 V/A-type H+/Na+-transporting ATPase subunit C tac:Ta0002 tac00190
# 205 V/A-type H+/Na+-transporting ATPase subunit D tac:Ta0006 tac00190
# 206 V/A-type H+/Na+-transporting ATPase subunit E tac:Ta0001 tac00190
# 207 V/A-type H+/Na+-transporting ATPase subunit F tac:Ta0003 tac00190
# 208 V/A-type H+/Na+-transporting ATPase subunit I tac:Ta0008 tac00190
# 255 succinate dehydrogenase / fumarate reductase, flavoprotein subunit [EC:1.3.5.1 1.3.5.4] tac:Ta1001 tac00190
# 45 phosphoribosylformylglycinamidine synthase subunit PurQ / glutaminase [EC:6.3.5.3 3.5.1.2] tac:Ta1318 tac00220
# 46 glutamine synthetase [EC:6.3.1.2] tac:Ta1498 tac00220
# 47 carbamate kinase [EC:2.7.2.2] tac:Ta1350 tac00220
# 49 ornithine carbamoyltransferase [EC:2.1.3.3] tac:Ta1330 tac00220
# 50 argininosuccinate synthase [EC:6.3.4.5] tac:Ta0650 tac00220
# 52 argininosuccinate lyase [EC:4.3.2.1] tac:Ta0649 tac00220
# 64 arginine deiminase [EC:3.5.3.6] tac:Ta0987 tac00220
# 67 glutamate dehydrogenase (NAD(P)+) [EC:1.4.1.3] tac:Ta0635 tac00220
# 88 aspartate aminotransferase [EC:2.6.1.1] tac:Ta0529 tac00220
# 137 ribonucleoside-diphosphate reductase alpha chain [EC:1.17.4.1] tac:Ta1475 tac00230
# 157 ribose-phosphate pyrophosphokinase [EC:2.7.6.1] tac:Ta0119 tac00230
# 158 amidophosphoribosyltransferase [EC:2.4.2.14] tac:Ta1242 tac00230
# 160 phosphoribosylamine---glycine ligase [EC:6.3.4.13] tac:Ta0594 tac00230
# 161 phosphoribosylglycinamide formyltransferase 1 [EC:2.1.2.2] tac:Ta0082 tac00230
# 162 phosphoribosylformylglycinamidine cyclo-ligase [EC:6.3.3.1] tac:Ta0090 tac00230
# 163 phosphoribosylaminoimidazolecarboxamide formyltransferase / IMP cyclohydrolase [EC:2.1.2.3 3.5.4.10] tac:Ta0060 tac00230
# 164 adenylosuccinate lyase [EC:4.3.2.2] tac:Ta0523 tac00230
# 165 phosphoribosylaminoimidazole-succinocarboxamide synthase [EC:6.3.2.6] tac:Ta0309 tac00230
# 167 phosphoribosylaminoimidazolecarboxamide formyltransferase / IMP cyclohydrolase [EC:2.1.2.3 3.5.4.10] tac:Ta0060 tac00230
# 173 nucleoside-diphosphate kinase [EC:2.7.4.6] tac:Ta1113 tac00230
# 174 nucleoside-diphosphate kinase [EC:2.7.4.6] tac:Ta1113 tac00230
# 175 ribonucleoside-diphosphate reductase alpha chain [EC:1.17.4.1] tac:Ta1475 tac00230
# 177 adenylate kinase [EC:2.7.4.3] tac:Ta0570 tac00230
# 178 adenylosuccinate lyase [EC:4.3.2.2] tac:Ta0523 tac00230
# 179 adenylosuccinate synthase [EC:6.3.4.4] tac:Ta1367 tac00230
# 190 nucleoside kinase [EC:2.7.1.73 2.7.1.213 2.7.1.-] tac:Ta0880 tac00230
# 197 nucleoside-diphosphate kinase [EC:2.7.4.6] tac:Ta1113 tac00230
# 200 IMP dehydrogenase [EC:1.1.1.205] tac:Ta0219 tac00230
# 201 GMP synthase (glutamine-hydrolysing) [EC:6.3.5.2] tac:Ta0944 tac00230
# 212 nucleoside kinase [EC:2.7.1.73 2.7.1.213 2.7.1.-] tac:Ta0880 tac00230
# 232 nucleoside-diphosphate kinase [EC:2.7.4.6] tac:Ta1113 tac00230
# 234 nucleoside-diphosphate kinase [EC:2.7.4.6] tac:Ta1113 tac00230
# 252 phosphoribosylformylglycinamidine synthase subunit PurS [EC:6.3.5.3] tac:Ta1044 tac00230
# 279 adenylate kinase [EC:2.7.4.3] tac:Ta0570 tac00230
# 287 nucleoside-diphosphate kinase [EC:2.7.4.6] tac:Ta1113 tac00230
# 292 pyruvate kinase [EC:2.7.1.40] tac:Ta0896 tac00230
# 293 pyruvate kinase [EC:2.7.1.40] tac:Ta0896 tac00230
# 304 pyruvate kinase [EC:2.7.1.40] tac:Ta0896 tac00230
# 305 pyruvate kinase [EC:2.7.1.40] tac:Ta0896 tac00230
# 306 nucleoside-triphosphatase [EC:3.6.1.15] tac:Ta0998 tac00230
# 412 carbamate kinase [EC:2.7.2.2] tac:Ta1350 tac00230
# 419 5-(carboxyamino)imidazole ribonucleotide synthase [EC:6.3.4.18] tac:Ta1107 tac00230
# 420 5-(carboxyamino)imidazole ribonucleotide mutase [EC:5.4.99.18] tac:Ta0303 tac00230
# 423 phosphomannomutase / phosphoglucomutase [EC:5.4.2.8 5.4.2.2] tac:Ta0568 tac00230
# 429 XTP/dITP diphosphohydrolase [EC:3.6.1.66] tac:Ta0325 tac00230
# 430 XTP/dITP diphosphohydrolase [EC:3.6.1.66] tac:Ta0325 tac00230
# 81 ribonucleoside-diphosphate reductase alpha chain [EC:1.17.4.1] tac:Ta1475 tac00240
# 84 uridylate kinase [EC:2.7.4.22] tac:Ta0486 tac00240
# 88 carbamoyl-phosphate synthase large subunit [EC:6.3.5.5] tac:Ta0791 tac00240
# 94 aspartate carbamoyltransferase regulatory subunit tac:Ta0574 tac00240
# 95 dihydroorotase [EC:3.5.2.3] tac:Ta1319 tac00240
# 96 dihydroorotate dehydrogenase electron transfer subunit tac:Ta0403 tac00240
# 98 orotate phosphoribosyltransferase [EC:2.4.2.10] tac:Ta0056 tac00240
# 99 nucleoside-diphosphate kinase [EC:2.7.4.6] tac:Ta1113 tac00240
# 101 dCTP deaminase [EC:3.5.4.13] tac:Ta0598 tac00240
# 102 CTP synthase [EC:6.3.4.2] tac:Ta0044 tac00240
# 117 nucleoside-diphosphate kinase [EC:2.7.4.6] tac:Ta1113 tac00240
# 131 ribonucleoside-diphosphate reductase alpha chain [EC:1.17.4.1] tac:Ta1475 tac00240
# 132 nucleoside-diphosphate kinase [EC:2.7.4.6] tac:Ta1113 tac00240
# 133 dCTP deaminase [EC:3.5.4.13] tac:Ta0598 tac00240
# 139 dCMP deaminase [EC:3.5.4.12] tac:Ta0312 tac00240
# 140 nucleoside-diphosphate kinase [EC:2.7.4.6] tac:Ta1113 tac00240
# 142 dTMP kinase [EC:2.7.4.9] tac:Ta0081 tac00240
# 143 thymidine kinase [EC:2.7.1.21] tac:Ta1214 tac00240
# 149 nucleoside-diphosphate kinase [EC:2.7.4.6] tac:Ta1113 tac00240
# 152 dTMP kinase [EC:2.7.4.9] tac:Ta0081 tac00240
# 155 thymidine kinase [EC:2.7.1.21] tac:Ta1214 tac00240
# 169 orotidine-5'-phosphate decarboxylase [EC:4.1.1.23] tac:Ta0073 tac00240
# 274 nucleoside-diphosphate kinase [EC:2.7.4.6] tac:Ta1113 tac00240
# 289 CMP/dCMP kinase [EC:2.7.4.25] tac:Ta1245 tac00240
# 290 CMP/dCMP kinase [EC:2.7.4.25] tac:Ta1245 tac00240
# 293 nucleoside kinase [EC:2.7.1.73 2.7.1.213 2.7.1.-] tac:Ta0880 tac00240
# 35 asparagine synthase (glutamine-hydrolysing) [EC:6.3.5.4] tac:Ta0315 tac00250
# 38 L-asparaginase [EC:3.5.1.1] tac:Ta0338 tac00250
# 49 aspartate aminotransferase [EC:2.6.1.1] tac:Ta0529 tac00250
# 55 argininosuccinate synthase [EC:6.3.4.5] tac:Ta0650 tac00250
# 56 adenylosuccinate synthase [EC:6.3.4.4] tac:Ta1367 tac00250
# 58 argininosuccinate lyase [EC:4.3.2.1] tac:Ta0649 tac00250
# 59 adenylosuccinate lyase [EC:4.3.2.2] tac:Ta0523 tac00250
# 66 alanine dehydrogenase [EC:1.4.1.1] tac:Ta0480 tac00250
# 71 aspartate carbamoyltransferase regulatory subunit tac:Ta0574 tac00250
# 89 glutamate synthase (NADPH) small chain [EC:1.4.1.13] tac:Ta0414 tac00250
# 93 glutamate dehydrogenase (NAD(P)+) [EC:1.4.1.3] tac:Ta0635 tac00250
# 97 4-aminobutyrate aminotransferase [EC:2.6.1.19] tac:Ta0068 tac00250
# 102 glutamine synthetase [EC:6.3.1.2] tac:Ta1498 tac00250
# 105 phosphoribosylformylglycinamidine synthase subunit PurQ / glutaminase [EC:6.3.5.3 3.5.1.2] tac:Ta1318 tac00250
# 110 carbamoyl-phosphate synthase large subunit [EC:6.3.5.5] tac:Ta0791 tac00250
# 121 1-pyrroline-5-carboxylate dehydrogenase [EC:1.2.1.88] tac:Ta0603 tac00250
# 123 glutamine---fructose-6-phosphate transaminase (isomerizing) [EC:2.6.1.16] tac:Ta0479 tac00250
# 125 amidophosphoribosyltransferase [EC:2.4.2.14] tac:Ta1242 tac00250
# 81 glycerate dehydrogenase [EC:1.1.1.29] tac:Ta0858 tac00260
# 84 cystathionine gamma-lyase [EC:4.4.1.1] tac:Ta0080 tac00260
# 86 aspartate kinase [EC:2.7.2.4] tac:Ta0364 tac00260
# 91 phosphoserine phosphatase [EC:3.1.3.3] tac:Ta0936 tac00260
# 92 glycine hydroxymethyltransferase [EC:2.1.2.1] tac:Ta0811 tac00260
# 93 threonine dehydratase [EC:4.3.1.19] tac:Ta0113 tac00260
# 97 threonine synthase [EC:4.2.3.1] tac:Ta0026 tac00260
# 102 glycine C-acetyltransferase [EC:2.3.1.29] tac:Ta1189 tac00260
# 103 aspartate-semialdehyde dehydrogenase [EC:1.2.1.11] tac:Ta0363 tac00260
# 109 homoserine kinase [EC:2.7.1.39] tac:Ta0530 tac00260
# 111 glycine dehydrogenase subunit 2 [EC:1.4.4.2] tac:Ta1357 tac00260
# 113 homoserine dehydrogenase [EC:1.1.1.3] tac:Ta1179 tac00260
# 120 aminomethyltransferase [EC:2.1.2.10] tac:Ta0010 tac00260
# 123 dihydrolipoamide dehydrogenase [EC:1.8.1.4] tac:Ta0208 tac00260
# 126 threonine dehydratase [EC:4.3.1.19] tac:Ta0113 tac00260
# 199 tryptophan synthase beta chain [EC:4.2.1.20] tac:Ta0669 tac00260
# 216 glycerate 2-kinase [EC:2.7.1.165] tac:Ta0453 tac00260
# 227 2,3-bisphosphoglycerate-independent phosphoglycerate mutase [EC:5.4.2.12] tac:Ta0413 tac00260
# 228 glycine cleavage system H protein tac:Ta1366 tac00260
# 62 aspartate kinase [EC:2.7.2.4] tac:Ta0364 tac00261
# 63 aspartate-semialdehyde dehydrogenase [EC:1.2.1.11] tac:Ta0363 tac00261
# 86 5'-methylthioadenosine phosphorylase [EC:2.4.2.28] tac:Ta0332 tac00270
# 89 spermidine synthase [EC:2.5.1.16] tac:Ta0355 tac00270
# 90 S-adenosylmethionine decarboxylase [EC:4.1.1.50] tac:Ta1196 tac00270
# 91 L-methionine (R)-S-oxide reductase [EC:1.8.4.14] tac:Ta0848 tac00270
# 94 cystathionine gamma-lyase [EC:4.4.1.1] tac:Ta0080 tac00270
# 99 5-methyltetrahydropteroyltriglutamate--homocysteine methyltransferase [EC:2.1.1.14] tac:Ta0977 tac00270
# 101 S-adenosylmethionine synthetase [EC:2.5.1.6] tac:Ta0059 tac00270
# 102 adenosylhomocysteinase [EC:3.3.1.1] tac:Ta0469 tac00270
# 110 cystathionine gamma-synthase [EC:2.5.1.48] tac:Ta0531 tac00270
# 132 cysteine synthase [EC:2.5.1.47] tac:Ta0535 tac00270
# 158 aspartate aminotransferase [EC:2.6.1.1] tac:Ta0529 tac00270
# 162 (2R)-sulfolactate sulfo-lyase subunit alpha [EC:4.4.1.24] tac:Ta1392 tac00270
# 179 cystathionine gamma-lyase [EC:4.4.1.1] tac:Ta0080 tac00270
# 185 aspartate aminotransferase [EC:2.6.1.1] tac:Ta0529 tac00270
# 195 cystathionine gamma-lyase [EC:4.4.1.1] tac:Ta0080 tac00270
# 199 aspartate aminotransferase [EC:2.6.1.1] tac:Ta0529 tac00270
# 212 cystathionine gamma-synthase [EC:2.5.1.48] tac:Ta0531 tac00270
# 213 cystathionine gamma-synthase [EC:2.5.1.48] tac:Ta0531 tac00270
# 214 cystathionine gamma-synthase [EC:2.5.1.48] tac:Ta0531 tac00270
# 217 cystathionine gamma-synthase [EC:2.5.1.48] tac:Ta0531 tac00270
# 224 homoserine dehydrogenase [EC:1.1.1.3] tac:Ta1179 tac00270
# 227 aspartate-semialdehyde dehydrogenase [EC:1.2.1.11] tac:Ta0363 tac00270
# 230 aspartate kinase [EC:2.7.2.4] tac:Ta0364 tac00270
# 253 malate dehydrogenase [EC:1.1.1.37] tac:Ta0952 tac00270
# 271 5-methylthioadenosine/S-adenosylhomocysteine deaminase [EC:3.5.4.31 3.5.4.28] tac:Ta1060 tac00270
# 295 cysteine synthase [EC:2.5.1.47] tac:Ta0535 tac00270
# 54 dihydrolipoamide dehydrogenase [EC:1.8.1.4] tac:Ta0208 tac00280
# 62 dihydrolipoamide dehydrogenase [EC:1.8.1.4] tac:Ta0208 tac00280
# 68 dihydrolipoamide dehydrogenase [EC:1.8.1.4] tac:Ta0208 tac00280
# 72 acetyl-CoA C-acetyltransferase [EC:2.3.1.9] tac:Ta0030 tac00280
# 75 hydroxymethylglutaryl-CoA synthase [EC:2.3.3.10] tac:Ta1455 tac00280
# 81 isovaleryl-CoA dehydrogenase [EC:1.3.8.4] tac:Ta0230 tac00280
# 94 methylmalonyl-CoA mutase, N-terminal domain [EC:5.4.99.2] tac:Ta0462 tac00280
# 98 aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] tac:Ta0439 tac00280
# 102 3-hydroxyisobutyrate dehydrogenase [EC:1.1.1.31] tac:Ta0161 tac00280
# 106 acyl-CoA dehydrogenase [EC:1.3.8.7] tac:Ta0398 tac00280
# 116 acyl-CoA dehydrogenase [EC:1.3.8.7] tac:Ta0398 tac00280
# 117 acyl-CoA dehydrogenase [EC:1.3.8.7] tac:Ta0398 tac00280
# 118 2-oxoisovalerate ferredoxin oxidoreductase delta subunit [EC:1.2.7.7] tac:Ta0627 tac00280
# 119 2-oxoisovalerate ferredoxin oxidoreductase delta subunit [EC:1.2.7.7] tac:Ta0627 tac00280
# 120 2-oxoisovalerate ferredoxin oxidoreductase delta subunit [EC:1.2.7.7] tac:Ta0627 tac00280
# 24 threonine dehydratase [EC:4.3.1.19] tac:Ta0113 tac00290
# 48 acetolactate synthase I/II/III large subunit [EC:2.2.1.6] tac:Ta0691 tac00290
# 86 acetolactate synthase I/II/III large subunit [EC:2.2.1.6] tac:Ta0691 tac00290
# 55 aspartate kinase [EC:2.7.2.4] tac:Ta0364 tac00300
# 56 aspartate-semialdehyde dehydrogenase [EC:1.2.1.11] tac:Ta0363 tac00300
# 57 homoserine dehydrogenase [EC:1.1.1.3] tac:Ta1179 tac00300
# 66 succinyl-diaminopimelate desuccinylase [EC:3.5.1.18] tac:Ta0934 tac00300
# 68 diaminopimelate decarboxylase [EC:4.1.1.20] tac:Ta0788 tac00300
# 73 2-aminoadipate transaminase [EC:2.6.1.-] tac:Ta1193 tac00300
# 90 dihydrolipoamide dehydrogenase [EC:1.8.1.4] tac:Ta0208 tac00310
# 91 acetyl-CoA C-acetyltransferase [EC:2.3.1.9] tac:Ta0030 tac00310
# 151 aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] tac:Ta0439 tac00310
# 66 aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] tac:Ta0439 tac00330
# 67 spermidine synthase [EC:2.5.1.16] tac:Ta0355 tac00330
# 68 S-adenosylmethionine decarboxylase [EC:4.1.1.50] tac:Ta1196 tac00330
# 73 aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] tac:Ta0439 tac00330
# 126 arginine decarboxylase [EC:4.1.1.19] tac:Ta0778 tac00330
# 127 agmatinase [EC:3.5.3.11] tac:Ta1058 tac00330
# 173 pyrroline-5-carboxylate reductase [EC:1.5.1.2] tac:Ta0139 tac00330
# 175 1-pyrroline-5-carboxylate dehydrogenase [EC:1.2.1.88] tac:Ta0603 tac00330
# 181 1-pyrroline-5-carboxylate dehydrogenase [EC:1.2.1.88] tac:Ta0603 tac00330
# 206 pyrroline-5-carboxylate reductase [EC:1.5.1.2] tac:Ta0139 tac00330
# 207 1-pyrroline-5-carboxylate dehydrogenase [EC:1.2.1.88] tac:Ta0603 tac00330
# 208 1-pyrroline-5-carboxylate dehydrogenase [EC:1.2.1.88] tac:Ta0603 tac00330
# 209 aspartate aminotransferase [EC:2.6.1.1] tac:Ta0529 tac00330
# 233 proline iminopeptidase [EC:3.4.11.5] tac:Ta0830 tac00330
# 42 glutamate formiminotransferase / 5-formyltetrahydrofolate cyclo-ligase [EC:2.1.2.5 6.3.3.2] tac:Ta1476 tac00340
# 43 imidazolonepropionase [EC:3.5.2.7] tac:Ta0238 tac00340
# 44 urocanate hydratase [EC:4.2.1.49] tac:Ta0239 tac00340
# 45 histidine ammonia-lyase [EC:4.3.1.3] tac:Ta0242 tac00340
# 53 aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] tac:Ta0439 tac00340
# 117 aspartate aminotransferase [EC:2.6.1.1] tac:Ta0529 tac00360
# 227 3-hydroxybutyryl-CoA dehydrogenase [EC:1.1.1.157] tac:Ta0476 tac00360
# 62 carboxymethylenebutenolidase [EC:3.1.1.45] tac:Ta0228 tac00361
# 115 carboxymethylenebutenolidase [EC:3.1.1.45] tac:Ta0228 tac00361
# 151 carboxymethylenebutenolidase [EC:3.1.1.45] tac:Ta0228 tac00361
# 169 carboxymethylenebutenolidase [EC:3.1.1.45] tac:Ta0228 tac00361
# 198 carboxymethylenebutenolidase [EC:3.1.1.45] tac:Ta0228 tac00361
# 231 carboxymethylenebutenolidase [EC:3.1.1.45] tac:Ta0228 tac00361
# 129 3-hydroxybutyryl-CoA dehydrogenase [EC:1.1.1.157] tac:Ta0476 tac00362
# 132 acetyl-CoA C-acetyltransferase [EC:2.3.1.9] tac:Ta0030 tac00362
# 32 carboxymethylenebutenolidase [EC:3.1.1.45] tac:Ta0228 tac00364
# 33 carboxymethylenebutenolidase [EC:3.1.1.45] tac:Ta0228 tac00364
# 101 acetyl-CoA C-acetyltransferase [EC:2.3.1.9] tac:Ta0030 tac00380
# 104 dihydrolipoamide dehydrogenase [EC:1.8.1.4] tac:Ta0208 tac00380
# 131 aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] tac:Ta0439 tac00380
# 138 aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] tac:Ta0439 tac00380
# 11 3-deoxy-7-phosphoheptulonate synthase [EC:2.5.1.54] tac:Ta0247 tac00400
# 51 chorismate synthase [EC:4.2.3.5] tac:Ta0824 tac00400
# 52 tryptophan synthase beta chain [EC:4.2.1.20] tac:Ta0669 tac00400
# 53 tryptophan synthase alpha chain [EC:4.2.1.20] tac:Ta0803 tac00400
# 54 tryptophan synthase beta chain [EC:4.2.1.20] tac:Ta0669 tac00400
# 55 indole-3-glycerol phosphate synthase [EC:4.1.1.48] tac:Ta0808 tac00400
# 56 phosphoribosylanthranilate isomerase [EC:5.3.1.24] tac:Ta0805 tac00400
# 57 anthranilate phosphoribosyltransferase [EC:2.4.2.18] tac:Ta0804 tac00400
# 58 anthranilate synthase component I [EC:4.1.3.27] tac:Ta0806 tac00400
# 61 prephenate dehydratase [EC:4.2.1.51] tac:Ta0915 tac00400
# 68 prephenate dehydratase [EC:4.2.1.51] tac:Ta0915 tac00400
# 75 3-phosphoshikimate 1-carboxyvinyltransferase [EC:2.5.1.19] tac:Ta0282 tac00400
# 76 shikimate kinase [EC:2.7.1.71] tac:Ta0283 tac00400
# 77 shikimate dehydrogenase [EC:1.1.1.25] tac:Ta0284 tac00400
# 78 3-dehydroquinate dehydratase I [EC:4.2.1.10] tac:Ta0116 tac00400
# 80 3-dehydroquinate synthase [EC:4.2.3.4] tac:Ta0285 tac00400
# 83 aspartate aminotransferase [EC:2.6.1.1] tac:Ta0529 tac00400
# 84 aspartate aminotransferase [EC:2.6.1.1] tac:Ta0529 tac00400
# 53 4-aminobutyrate aminotransferase [EC:2.6.1.19] tac:Ta0068 tac00410
# 65 aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] tac:Ta0439 tac00410
# 30 alanine dehydrogenase [EC:1.4.1.1] tac:Ta0480 tac00430
# 56 gamma-glutamyltranspeptidase / glutathione hydrolase [EC:2.3.2.2 3.4.19.13] tac:Ta0994 tac00430
# 11 thioredoxin reductase (NADPH) [EC:1.8.1.9] tac:Ta0984 tac00450
# 15 methionyl-tRNA synthetase [EC:6.1.1.10] tac:Ta1162 tac00450
# 58 cystathionine gamma-lyase [EC:4.4.1.1] tac:Ta0080 tac00450
# 59 cystathionine gamma-synthase [EC:2.5.1.48] tac:Ta0531 tac00450
# 80 L-seryl-tRNA(Ser) seleniumtransferase [EC:2.9.1.1] tac:Ta0673 tac00450
# 82 5-methyltetrahydropteroyltriglutamate--homocysteine methyltransferase [EC:2.1.1.14] tac:Ta0977 tac00450
# 89 thioredoxin reductase (NADPH) [EC:1.8.1.9] tac:Ta0984 tac00450
# 91 cystathionine gamma-lyase [EC:4.4.1.1] tac:Ta0080 tac00450
# 41 gamma-glutamyltranspeptidase / glutathione hydrolase [EC:2.3.2.2 3.4.19.13] tac:Ta0994 tac00460
# 44 L-asparaginase [EC:3.5.1.1] tac:Ta0338 tac00460
# 46 gamma-glutamyltranspeptidase / glutathione hydrolase [EC:2.3.2.2 3.4.19.13] tac:Ta0994 tac00460
# 50 glycine hydroxymethyltransferase [EC:2.1.2.1] tac:Ta0811 tac00460
# 24 glutamate dehydrogenase (NAD(P)+) [EC:1.4.1.3] tac:Ta0635 tac00471
# 28 phosphoribosylformylglycinamidine synthase subunit PurQ / glutaminase [EC:6.3.5.3 3.5.1.2] tac:Ta1318 tac00471
# 29 phosphoribosylformylglycinamidine synthase subunit PurQ / glutaminase [EC:6.3.5.3 3.5.1.2] tac:Ta1318 tac00471
# 38 gamma-glutamyltranspeptidase / glutathione hydrolase [EC:2.3.2.2 3.4.19.13] tac:Ta0994 tac00480
# 51 isocitrate dehydrogenase [EC:1.1.1.42] tac:Ta0117 tac00480
# 54 gamma-glutamyltranspeptidase / glutathione hydrolase [EC:2.3.2.2 3.4.19.13] tac:Ta0994 tac00480
# 58 gamma-glutamyltranspeptidase / glutathione hydrolase [EC:2.3.2.2 3.4.19.13] tac:Ta0994 tac00480
# 147 spermidine synthase [EC:2.5.1.16] tac:Ta0355 tac00480
# 155 spermidine synthase [EC:2.5.1.16] tac:Ta0355 tac00480
# 90 alpha-glucosidase [EC:3.2.1.20] tac:Ta0298 tac00500
# 102 cellulose synthase (UDP-forming) [EC:2.4.1.12] tac:Ta0484 tac00500
# 111 trehalose 6-phosphate synthase [EC:2.4.1.15 2.4.1.347] tac:Ta1210 tac00500
# 114 phosphomannomutase / phosphoglucomutase [EC:5.4.2.8 5.4.2.2] tac:Ta0568 tac00500
# 118 glucokinase [EC:2.7.1.2] tac:Ta0825 tac00500
# 119 glucose/mannose-6-phosphate isomerase [EC:5.3.1.9 5.3.1.8] tac:Ta1419 tac00500
# 121 trehalose 6-phosphate phosphatase [EC:3.1.3.12] tac:Ta1209 tac00500
# 132 alpha-glucosidase [EC:3.2.1.20] tac:Ta0298 tac00500
# 4 beta-galactosidase [EC:3.2.1.23] tac:Ta1323 tac00511
# 12 beta-galactosidase [EC:3.2.1.23] tac:Ta1323 tac00511
# 20 beta-galactosidase [EC:3.2.1.23] tac:Ta1323 tac00511
# 26 beta-galactosidase [EC:3.2.1.23] tac:Ta1323 tac00511
# 7 N-acetylglucosamine kinase [EC:2.7.1.59] tac:Ta0122 tac00520
# 30 glutamine---fructose-6-phosphate transaminase (isomerizing) [EC:2.6.1.16] tac:Ta0479 tac00520
# 194 UDP-glucose 4-epimerase [EC:5.1.3.2] tac:Ta0011 tac00520
# 201 glucose/mannose-6-phosphate isomerase [EC:5.3.1.9 5.3.1.8] tac:Ta1419 tac00520
# 202 phosphomannomutase / phosphoglucomutase [EC:5.4.2.8 5.4.2.2] tac:Ta0568 tac00520
# 204 phosphomannomutase / phosphoglucomutase [EC:5.4.2.8 5.4.2.2] tac:Ta0568 tac00520
# 211 mannose-1-phosphate guanylyltransferase [EC:2.7.7.13] tac:Ta1486 tac00520
# 229 UDP-sulfoquinovose synthase [EC:3.13.1.1] tac:Ta1073 tac00520
# 247 phosphomannomutase / phosphoglucomutase [EC:5.4.2.8 5.4.2.2] tac:Ta0568 tac00520
# 282 glucose/mannose-6-phosphate isomerase [EC:5.3.1.9 5.3.1.8] tac:Ta1419 tac00520
# 310 glucokinase [EC:2.7.1.2] tac:Ta0825 tac00520
# 311 glucokinase [EC:2.7.1.2] tac:Ta0825 tac00520
# 16 glucokinase [EC:2.7.1.2] tac:Ta0825 tac00521
# 44 glucose-1-phosphate thymidylyltransferase [EC:2.7.7.24] tac:Ta1074 tac00521
# 45 phosphomannomutase / phosphoglucomutase [EC:5.4.2.8 5.4.2.2] tac:Ta0568 tac00521
# 36 UDP-sulfoquinovose synthase [EC:3.13.1.1] tac:Ta1073 tac00561
# 55 glycerol kinase [EC:2.7.1.30] tac:Ta1096 tac00561
# 60 aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] tac:Ta0439 tac00561
# 141 glycerate 2-kinase [EC:2.7.1.165] tac:Ta0453 tac00561
# 103 glycerophosphoryl diester phosphodiesterase [EC:3.1.4.46] tac:Ta0634 tac00564
# 117 glycerol-3-phosphate dehydrogenase [EC:1.1.5.3] tac:Ta0633 tac00564
# 141 glycerophosphoryl diester phosphodiesterase [EC:3.1.4.46] tac:Ta0634 tac00564
# 228 glycerol-1-phosphate dehydrogenase [NAD(P)+] [EC:1.1.1.261] tac:Ta1158 tac00564
# 232 phosphoglycerol geranylgeranyltransferase [EC:2.5.1.41] tac:Ta0995 tac00564
# 235 geranylgeranylglycerol-phosphate geranylgeranyltransferase [EC:2.5.1.42] tac:Ta0996 tac00564
# 238 CDP-2,3-bis-(O-geranylgeranyl)-sn-glycerol synthase [EC:2.7.7.67] tac:Ta0107 tac00564
# 245 digeranylgeranylglycerophospholipid reductase [EC:1.3.1.101 1.3.7.11] tac:Ta0516 tac00564
# 246 digeranylgeranylglycerophospholipid reductase [EC:1.3.1.101 1.3.7.11] tac:Ta0516 tac00564
# 68 3-dehydrosphinganine reductase [EC:1.1.1.102] tac:Ta0191 tac00600
# 74 beta-galactosidase [EC:3.2.1.23] tac:Ta1323 tac00600
# 55 pyruvate dehydrogenase E1 component beta subunit [EC:1.2.4.1] tac:Ta1437 tac00620
# 60 phosphoenolpyruvate carboxykinase (GTP) [EC:4.1.1.32] tac:Ta0123 tac00620
# 63 pyruvate, orthophosphate dikinase [EC:2.7.9.1] tac:Ta0886 tac00620
# 65 pyruvate kinase [EC:2.7.1.40] tac:Ta0896 tac00620
# 80 malate dehydrogenase (oxaloacetate-decarboxylating) [EC:1.1.1.38] tac:Ta0456 tac00620
# 85 2-oxoisovalerate/pyruvate ferredoxin oxidoreductase gamma subunit [EC:1.2.7.7 1.2.7.1] tac:Ta0626 tac00620
# 86 malate dehydrogenase [EC:1.1.1.37] tac:Ta0952 tac00620
# 95 pyruvate dehydrogenase (quinone) [EC:1.2.5.1] tac:Ta0816 tac00620
# 98 acetyl-CoA synthetase [EC:6.2.1.1] tac:Ta0229 tac00620
# 101 acetate---CoA ligase (ADP-forming) [EC:6.2.1.13] tac:Ta1153 tac00620
# 103 acetyl-CoA synthetase [EC:6.2.1.1] tac:Ta0229 tac00620
# 104 aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] tac:Ta0439 tac00620
# 109 acetyl-CoA C-acetyltransferase [EC:2.3.1.9] tac:Ta0030 tac00620
# 123 pyruvate dehydrogenase E1 component beta subunit [EC:1.2.4.1] tac:Ta1437 tac00620
# 124 pyruvate dehydrogenase E2 component (dihydrolipoamide acetyltransferase) [EC:2.3.1.12] tac:Ta1436 tac00620
# 125 dihydrolipoamide dehydrogenase [EC:1.8.1.4] tac:Ta0208 tac00620
# 130 acylphosphatase [EC:3.6.1.7] tac:Ta0064 tac00620
# 174 fumarate hydratase, class II [EC:4.2.1.2] tac:Ta0258 tac00620
# 179 2-oxoglutarate/2-oxoacid ferredoxin oxidoreductase subunit alpha [EC:1.2.7.3 1.2.7.11] tac:Ta0259 tac00620
# 106 carboxymethylenebutenolidase [EC:3.1.1.45] tac:Ta0228 tac00623
# 110 carboxymethylenebutenolidase [EC:3.1.1.45] tac:Ta0228 tac00623
# 62 aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] tac:Ta0439 tac00625
# 64 aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] tac:Ta0439 tac00625
# 102 aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] tac:Ta0439 tac00625
# 133 flavin prenyltransferase [EC:2.5.1.129] tac:Ta1100 tac00627
# 162 acylphosphatase [EC:3.6.1.7] tac:Ta0064 tac00627
# 197 benzoylformate decarboxylase [EC:4.1.1.7] tac:Ta0500 tac00627
# 208 benzoylformate decarboxylase [EC:4.1.1.7] tac:Ta0500 tac00627
# 84 aconitate hydratase [EC:4.2.1.3] tac:Ta0112 tac00630
# 98 aconitate hydratase [EC:4.2.1.3] tac:Ta0112 tac00630
# 102 glycolate oxidase [EC:1.1.3.15] tac:Ta0542 tac00630
# 111 formate dehydrogenase major subunit [EC:1.17.1.9] tac:Ta0425 tac00630
# 114 citrate synthase [EC:2.3.3.1] tac:Ta0169 tac00630
# 131 malate dehydrogenase [EC:1.1.1.37] tac:Ta0952 tac00630
# 147 phosphoglycolate phosphatase [EC:3.1.3.18] tac:Ta0175 tac00630
# 148 glycerate dehydrogenase [EC:1.1.1.29] tac:Ta0858 tac00630
# 149 glycerate dehydrogenase [EC:1.1.1.29] tac:Ta0858 tac00630
# 208 acetyl-CoA C-acetyltransferase [EC:2.3.1.9] tac:Ta0030 tac00630
# 219 methylmalonyl-CoA mutase, N-terminal domain [EC:5.4.99.2] tac:Ta0462 tac00630
# 230 glycine hydroxymethyltransferase [EC:2.1.2.1] tac:Ta0811 tac00630
# 231 aminomethyltransferase [EC:2.1.2.10] tac:Ta0010 tac00630
# 245 glutamine synthetase [EC:6.3.1.2] tac:Ta1498 tac00630
# 264 glycerate 2-kinase [EC:2.7.1.165] tac:Ta0453 tac00630
# 271 acetyl-CoA synthetase [EC:6.2.1.1] tac:Ta0229 tac00630
# 26 4-aminobutyrate aminotransferase [EC:2.6.1.19] tac:Ta0068 tac00640
# 70 acetate---CoA ligase (ADP-forming) [EC:6.2.1.13] tac:Ta1153 tac00640
# 71 acetyl-CoA synthetase [EC:6.2.1.1] tac:Ta0229 tac00640
# 72 acetyl-CoA synthetase [EC:6.2.1.1] tac:Ta0229 tac00640
# 76 2-oxoisovalerate/pyruvate ferredoxin oxidoreductase gamma subunit [EC:1.2.7.7 1.2.7.1] tac:Ta0626 tac00640
# 108 2-methylcitrate dehydratase [EC:4.2.1.79] tac:Ta1226 tac00640
# 110 methylmalonyl-CoA mutase, N-terminal domain [EC:5.4.99.2] tac:Ta0462 tac00640
# 119 succinyl-CoA synthetase alpha subunit [EC:6.2.1.5] tac:Ta1331 tac00640
# 121 methylisocitrate lyase [EC:4.1.3.30] tac:Ta1227 tac00640
# 129 acetyl-CoA C-acetyltransferase [EC:2.3.1.9] tac:Ta0030 tac00640
# 197 dihydrolipoamide dehydrogenase [EC:1.8.1.4] tac:Ta0208 tac00640
# 63 hydroxymethylglutaryl-CoA synthase [EC:2.3.3.10] tac:Ta1455 tac00650
# 64 acetyl-CoA C-acetyltransferase [EC:2.3.1.9] tac:Ta0030 tac00650
# 65 3-hydroxybutyryl-CoA dehydrogenase [EC:1.1.1.157] tac:Ta0476 tac00650
# 75 4-aminobutyrate aminotransferase [EC:2.6.1.19] tac:Ta0068 tac00650
# 77 2-oxoisovalerate/pyruvate ferredoxin oxidoreductase gamma subunit [EC:1.2.7.7 1.2.7.1] tac:Ta0626 tac00650
# 92 succinate dehydrogenase / fumarate reductase, flavoprotein subunit [EC:1.3.5.1 1.3.5.4] tac:Ta1001 tac00650
# 162 acetolactate synthase I/II/III large subunit [EC:2.2.1.6] tac:Ta0691 tac00650
# 182 succinate dehydrogenase / fumarate reductase, flavoprotein subunit [EC:1.3.5.1 1.3.5.4] tac:Ta1001 tac00650
# 183 2-oxoglutarate/2-oxoacid ferredoxin oxidoreductase subunit alpha [EC:1.2.7.3 1.2.7.11] tac:Ta0259 tac00650
# 48 succinyl-CoA synthetase alpha subunit [EC:6.2.1.5] tac:Ta1331 tac00660
# 52 acetolactate synthase I/II/III large subunit [EC:2.2.1.6] tac:Ta0691 tac00660
# 18 glutamate formiminotransferase / 5-formyltetrahydrofolate cyclo-ligase [EC:2.1.2.5 6.3.3.2] tac:Ta1476 tac00670
# 20 phosphoribosylglycinamide formyltransferase 1 [EC:2.1.2.2] tac:Ta0082 tac00670
# 25 glutamate formiminotransferase / 5-formyltetrahydrofolate cyclo-ligase [EC:2.1.2.5 6.3.3.2] tac:Ta1476 tac00670
# 28 methylenetetrahydrofolate dehydrogenase (NADP+) / methenyltetrahydrofolate cyclohydrolase [EC:1.5.1.5 3.5.4.9] tac:Ta0898 tac00670
# 29 methylenetetrahydrofolate dehydrogenase (NADP+) / methenyltetrahydrofolate cyclohydrolase [EC:1.5.1.5 3.5.4.9] tac:Ta0898 tac00670
# 41 glutamate formiminotransferase / 5-formyltetrahydrofolate cyclo-ligase [EC:2.1.2.5 6.3.3.2] tac:Ta1476 tac00670
# 42 aminomethyltransferase [EC:2.1.2.10] tac:Ta0010 tac00670
# 49 formate--tetrahydrofolate ligase [EC:6.3.4.3] tac:Ta1478 tac00670
# 50 phosphoribosylglycinamide formyltransferase 1 [EC:2.1.2.2] tac:Ta0082 tac00670
# 51 phosphoribosylaminoimidazolecarboxamide formyltransferase / IMP cyclohydrolase [EC:2.1.2.3 3.5.4.10] tac:Ta0060 tac00670
# 61 glycine hydroxymethyltransferase [EC:2.1.2.1] tac:Ta0811 tac00670
# 64 aminomethyltransferase [EC:2.1.2.10] tac:Ta0010 tac00670
# 40 formate dehydrogenase major subunit [EC:1.17.1.9] tac:Ta0425 tac00680
# 55 formylmethanofuran dehydrogenase subunit E [EC:1.2.7.12] tac:Ta1109 tac00680
# 59 formylmethanofuran dehydrogenase subunit E [EC:1.2.7.12] tac:Ta1109 tac00680
# 127 glycine hydroxymethyltransferase [EC:2.1.2.1] tac:Ta0811 tac00680
# 136 2-oxoisovalerate/pyruvate ferredoxin oxidoreductase gamma subunit [EC:1.2.7.7 1.2.7.1] tac:Ta0626 tac00680
# 142 enolase [EC:4.2.1.11] tac:Ta0882 tac00680
# 153 phosphoserine phosphatase [EC:3.1.3.3] tac:Ta0936 tac00680
# 163 glycerate dehydrogenase [EC:1.1.1.29] tac:Ta0858 tac00680
# 166 glycerate 2-kinase [EC:2.7.1.165] tac:Ta0453 tac00680
# 167 malate dehydrogenase [EC:1.1.1.37] tac:Ta0952 tac00680
# 181 fructose 1,6-bisphosphate aldolase/phosphatase [EC:4.1.2.13 3.1.3.11] tac:Ta1428 tac00680
# 194 fructose 1,6-bisphosphate aldolase/phosphatase [EC:4.1.2.13 3.1.3.11] tac:Ta1428 tac00680
# 198 glycine hydroxymethyltransferase [EC:2.1.2.1] tac:Ta0811 tac00680
# 206 acetyl-CoA synthetase [EC:6.2.1.1] tac:Ta0229 tac00680
# 253 2-phosphosulfolactate phosphatase [EC:3.1.3.71] tac:Ta1432 tac00680
# 293 2,3-bisphosphoglycerate-independent phosphoglycerate mutase [EC:5.4.2.12] tac:Ta0413 tac00680
# 322 formate dehydrogenase (coenzyme F420) alpha subunit [EC:1.17.98.3 1.8.98.6] tac:Ta0045 tac00680
# 323 formate dehydrogenase (coenzyme F420) alpha subunit [EC:1.17.98.3 1.8.98.6] tac:Ta0045 tac00680
# 56 acetyl-CoA C-acetyltransferase [EC:2.3.1.9] tac:Ta0030 tac00720
# 57 2-oxoisovalerate/pyruvate ferredoxin oxidoreductase gamma subunit [EC:1.2.7.7 1.2.7.1] tac:Ta0626 tac00720
# 60 malate dehydrogenase [EC:1.1.1.37] tac:Ta0952 tac00720
# 61 fumarate hydratase, class II [EC:4.2.1.2] tac:Ta0258 tac00720
# 62 succinate dehydrogenase / fumarate reductase, flavoprotein subunit [EC:1.3.5.1 1.3.5.4] tac:Ta1001 tac00720
# 63 succinyl-CoA synthetase alpha subunit [EC:6.2.1.5] tac:Ta1331 tac00720
# 68 enoyl-CoA hydratase / 3-hydroxyacyl-CoA dehydrogenase [EC:4.2.1.17 1.1.1.35] tac:Ta0291 tac00720
# 69 enoyl-CoA hydratase / 3-hydroxyacyl-CoA dehydrogenase [EC:4.2.1.17 1.1.1.35] tac:Ta0291 tac00720
# 70 2-oxoglutarate/2-oxoacid ferredoxin oxidoreductase subunit alpha [EC:1.2.7.3 1.2.7.11] tac:Ta0259 tac00720
# 71 isocitrate dehydrogenase [EC:1.1.1.42] tac:Ta0117 tac00720
# 72 aconitate hydratase [EC:4.2.1.3] tac:Ta0112 tac00720
# 73 aconitate hydratase [EC:4.2.1.3] tac:Ta0112 tac00720
# 75 acetyl-CoA synthetase [EC:6.2.1.1] tac:Ta0229 tac00720
# 86 3-hydroxypropionyl-coenzyme A dehydratase [EC:4.2.1.116] tac:Ta0121 tac00720
# 87 acryloyl-coenzyme A reductase [EC:1.3.1.84] tac:Ta0841 tac00720
# 90 methylmalonyl-CoA mutase, N-terminal domain [EC:5.4.99.2] tac:Ta0462 tac00720
# 107 formate--tetrahydrofolate ligase [EC:6.3.4.3] tac:Ta1478 tac00720
# 108 methylenetetrahydrofolate dehydrogenase (NADP+) / methenyltetrahydrofolate cyclohydrolase [EC:1.5.1.5 3.5.4.9] tac:Ta0898 tac00720
# 109 methylenetetrahydrofolate dehydrogenase (NADP+) / methenyltetrahydrofolate cyclohydrolase [EC:1.5.1.5 3.5.4.9] tac:Ta0898 tac00720
# 165 pyruvate, orthophosphate dikinase [EC:2.7.9.1] tac:Ta0886 tac00720
# 167 succinate dehydrogenase / fumarate reductase, flavoprotein subunit [EC:1.3.5.1 1.3.5.4] tac:Ta1001 tac00720
# 59 adenylate kinase [EC:2.7.4.3] tac:Ta1247 tac00730
# 62 nucleoside-triphosphatase [EC:3.6.1.15] tac:Ta0998 tac00730
# 63 thiamine-monophosphate kinase [EC:2.7.4.16] tac:Ta0526 tac00730
# 71 tRNA uracil 4-sulfurtransferase [EC:2.8.1.4] tac:Ta0506 tac00730
# 75 hydroxymethylpyrimidine/phosphomethylpyrimidine kinase [EC:2.7.1.49 2.7.4.7] tac:Ta1281 tac00730
# 76 hydroxymethylpyrimidine/phosphomethylpyrimidine kinase [EC:2.7.1.49 2.7.4.7] tac:Ta1281 tac00730
# 93 thiamine-phosphate pyrophosphorylase [EC:2.5.1.3] tac:Ta1277 tac00730
# 97 thiamine-phosphate pyrophosphorylase [EC:2.5.1.3] tac:Ta1277 tac00730
# 35 FAD synthetase [EC:2.7.7.2] tac:Ta1139 tac00740
# 38 GTP cyclohydrolase II [EC:3.5.4.25] tac:Ta1014 tac00740
# 44 riboflavin kinase, archaea type [EC:2.7.1.161] tac:Ta1064 tac00740
# 7 5'-phosphate synthase pdxT subunit [EC:4.3.3.6] tac:Ta0009 tac00750
# 89 threonine synthase [EC:4.2.3.1] tac:Ta0026 tac00750
# 91 nicotinamide-nucleotide adenylyltransferase [EC:2.7.7.1] tac:Ta0774 tac00760
# 93 NAD+ synthase [EC:6.3.1.5] tac:Ta0899 tac00760
# 95 nicotinate phosphoribosyltransferase [EC:6.3.4.21] tac:Ta1145 tac00760
# 101 nicotinamide-nucleotide adenylyltransferase [EC:2.7.7.1] tac:Ta0774 tac00760
# 111 NAD+ kinase [EC:2.7.1.23] tac:Ta0622 tac00760
# 72 phosphopantothenoylcysteine decarboxylase / phosphopantothenate---cysteine ligase [EC:4.1.1.36 6.3.2.5] tac:Ta0889 tac00770
# 75 phosphopantothenoylcysteine decarboxylase / phosphopantothenate---cysteine ligase [EC:4.1.1.36 6.3.2.5] tac:Ta0889 tac00770
# 87 acetolactate synthase I/II/III large subunit [EC:2.2.1.6] tac:Ta0691 tac00770
# 92 inosine/xanthosine triphosphatase [EC:3.6.1.73] tac:Ta1194 tac00770
# 56 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] tac:Ta0251 tac00780
# 70 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] tac:Ta0251 tac00780
# 24 lipoate---protein ligase [EC:6.3.1.20] tac:Ta0513 tac00785
# 27 lipoate---protein ligase [EC:6.3.1.20] tac:Ta0513 tac00785
# 33 lipoate---protein ligase [EC:6.3.1.20] tac:Ta0513 tac00785
# 50 lipoate---protein ligase [EC:6.3.1.20] tac:Ta0513 tac00785
# 67 dihydrofolate synthase / folylpolyglutamate synthase [EC:6.3.2.12 6.3.2.17] tac:Ta0637 tac00790
# 68 dihydrofolate synthase / folylpolyglutamate synthase [EC:6.3.2.12 6.3.2.17] tac:Ta0637 tac00790
# 71 dihydrofolate synthase / folylpolyglutamate synthase [EC:6.3.2.12 6.3.2.17] tac:Ta0637 tac00790
# 72 dihydropteroate synthase [EC:2.5.1.15] tac:Ta0079 tac00790
# 73 dihydropteroate synthase [EC:2.5.1.15] tac:Ta0079 tac00790
# 74 2-amino-4-hydroxy-6-hydroxymethyldihydropteridine diphosphokinase [EC:2.7.6.3] tac:Ta1431 tac00790
# 75 dihydroneopterin aldolase [EC:4.1.2.25] tac:Ta0999 tac00790
# 83 dihydrofolate synthase / folylpolyglutamate synthase [EC:6.3.2.12 6.3.2.17] tac:Ta0637 tac00790
# 86 6-pyruvoyltetrahydropterin/6-carboxytetrahydropterin synthase [EC:4.2.3.12 4.1.2.50] tac:Ta0950 tac00790
# 93 GTP 3',8-cyclase [EC:4.1.99.22] tac:Ta0443 tac00790
# 94 molybdopterin synthase catalytic subunit [EC:2.8.1.12] tac:Ta1480 tac00790
# 96 6-pyruvoyltetrahydropterin/6-carboxytetrahydropterin synthase [EC:4.2.3.12 4.1.2.50] tac:Ta0950 tac00790
# 102 7-carboxy-7-deazaguanine synthase [EC:4.3.99.3] tac:Ta1359 tac00790
# 103 7-cyano-7-deazaguanine synthase [EC:6.3.4.20] tac:Ta0951 tac00790
# 117 cyclic pyranopterin monophosphate synthase [EC:4.6.1.17] tac:Ta0492 tac00790
# 118 molybdopterin adenylyltransferase [EC:2.7.7.75] tac:Ta0493 tac00790
# 122 molybdopterin molybdotransferase [EC:2.10.1.1] tac:Ta1022 tac00790
# 139 GTP cyclohydrolase IV [EC:3.5.4.39] tac:Ta1138 tac00790
# 181 GTP cyclohydrolase II [EC:3.5.4.25] tac:Ta1014 tac00790
# 267 heme o synthase [EC:2.5.1.141] tac:Ta0435 tac00860
# 268 protoporphyrin/coproporphyrin ferrochelatase [EC:4.99.1.1 4.99.1.9] tac:Ta0311 tac00860
# 272 magnesium chelatase subunit D [EC:6.6.1.1] tac:Ta0576 tac00860
# 274 uroporphyrinogen decarboxylase [EC:4.1.1.37] tac:Ta0310 tac00860
# 275 uroporphyrinogen-III synthase [EC:4.2.1.75] tac:Ta0573 tac00860
# 276 uroporphyrin-III C-methyltransferase [EC:2.1.1.107] tac:Ta0653 tac00860
# 277 uroporphyrinogen decarboxylase [EC:4.1.1.37] tac:Ta0310 tac00860
# 278 hydroxymethylbilane synthase [EC:2.5.1.61] tac:Ta0572 tac00860
# 279 porphobilinogen synthase [EC:4.2.1.24] tac:Ta0955 tac00860
# 281 glutamate-1-semialdehyde 2,1-aminomutase [EC:5.4.3.8] tac:Ta0571 tac00860
# 283 glutamyl-tRNA reductase [EC:1.2.1.70] tac:Ta0536 tac00860
# 284 glutamyl-tRNA synthetase [EC:6.1.1.17] tac:Ta0942 tac00860
# 285 precorrin-2 dehydrogenase / sirohydrochlorin ferrochelatase [EC:1.3.1.76 4.99.1.4] tac:Ta0652 tac00860
# 286 precorrin-2 dehydrogenase / sirohydrochlorin ferrochelatase [EC:1.3.1.76 4.99.1.4] tac:Ta0652 tac00860
# 288 precorrin-2/cobalt-factor-2 C20-methyltransferase [EC:2.1.1.130 2.1.1.151] tac:Ta0658 tac00860
# 289 precorrin-3B C17-methyltransferase [EC:2.1.1.131] tac:Ta0655 tac00860
# 290 precorrin-4/cobalt-precorrin-4 C11-methyltransferase [EC:2.1.1.133 2.1.1.271] tac:Ta0659 tac00860
# 293 cobalt-precorrin-6B (C15)-methyltransferase [EC:2.1.1.196] tac:Ta0657 tac00860
# 294 precorrin-2/cobalt-factor-2 C20-methyltransferase [EC:2.1.1.130 2.1.1.151] tac:Ta0658 tac00860
# 296 precorrin-3B C17-methyltransferase [EC:2.1.1.131] tac:Ta0655 tac00860
# 297 precorrin-4/cobalt-precorrin-4 C11-methyltransferase [EC:2.1.1.133 2.1.1.271] tac:Ta0659 tac00860
# 300 precorrin-8X/cobalt-precorrin-8 methylmutase [EC:5.4.99.61 5.4.99.60] tac:Ta0654 tac00860
# 301 cobyrinic acid a,c-diamide synthase [EC:6.3.5.9 6.3.5.11] tac:Ta1200 tac00860
# 303 precorrin-8X/cobalt-precorrin-8 methylmutase [EC:5.4.99.61 5.4.99.60] tac:Ta0654 tac00860
# 304 cobyrinic acid a,c-diamide synthase [EC:6.3.5.9 6.3.5.11] tac:Ta1200 tac00860
# 306 cob(I)alamin adenosyltransferase [EC:2.5.1.17] tac:Ta1121 tac00860
# 307 adenosylcobyric acid synthase [EC:6.3.5.10] tac:Ta0075 tac00860
# 309 cob(I)alamin adenosyltransferase [EC:2.5.1.17] tac:Ta1121 tac00860
# 312 cob(I)alamin adenosyltransferase [EC:2.5.1.17] tac:Ta1121 tac00860
# 314 threonine-phosphate decarboxylase [EC:4.1.1.81] tac:Ta0021 tac00860
# 315 adenosylcobinamide-GDP ribazoletransferase [EC:2.7.8.26] tac:Ta1079 tac00860
# 320 adenosylcobinamide-phosphate synthase [EC:6.3.1.10] tac:Ta0076 tac00860
# 321 adenosylcobinamide-phosphate synthase [EC:6.3.1.10] tac:Ta0076 tac00860
# 324 cobalt-precorrin-5B (C1)-methyltransferase [EC:2.1.1.195] tac:Ta0656 tac00860
# 418 protoporphyrin/coproporphyrin ferrochelatase [EC:4.99.1.1 4.99.1.9] tac:Ta0311 tac00860
# 460 cob(I)alamin adenosyltransferase [EC:2.5.1.17] tac:Ta1121 tac00860
# 71 acetyl-CoA C-acetyltransferase [EC:2.3.1.9] tac:Ta0030 tac00900
# 72 hydroxymethylglutaryl-CoA synthase [EC:2.3.3.10] tac:Ta1455 tac00900
# 74 hydroxymethylglutaryl-CoA reductase [EC:1.1.1.88] tac:Ta0406 tac00900
# 98 isopentenyl-diphosphate Delta-isomerase [EC:5.3.3.2] tac:Ta0102 tac00900
# 103 geranylgeranyl diphosphate synthase, type I [EC:2.5.1.1 2.5.1.10 2.5.1.29] tac:Ta1313 tac00900
# 105 geranylgeranyl diphosphate synthase, type I [EC:2.5.1.1 2.5.1.10 2.5.1.29] tac:Ta1313 tac00900
# 116 geranylgeranyl diphosphate synthase, type I [EC:2.5.1.1 2.5.1.10 2.5.1.29] tac:Ta1313 tac00900
# 122 octaprenyl-diphosphate synthase [EC:2.5.1.90] tac:Ta0436 tac00900
# 132 tritrans,polycis-undecaprenyl-diphosphate synthase [geranylgeranyl-diphosphate specific] [EC:2.5.1.89] tac:Ta0546 tac00900
# 158 isopentenyl phosphate kinase [EC:2.7.4.26] tac:Ta0103 tac00900
# 161 mevalonate-3-kinase [EC:2.7.1.185] tac:Ta1305 tac00900
# 163 mevalonate-3-phosphate-5-kinase [EC:2.7.1.186] tac:Ta0762 tac00900
# 168 bisphosphomevalonate decarboxylase [EC:4.1.1.110] tac:Ta0893 tac00900
# 70 carbamate kinase [EC:2.7.2.2] tac:Ta1350 tac00910
# 83 glutamine synthetase [EC:6.3.1.2] tac:Ta1498 tac00910
# 87 glutamate synthase (NADPH) small chain [EC:1.4.1.13] tac:Ta0414 tac00910
# 93 glutamate dehydrogenase (NAD(P)+) [EC:1.4.1.3] tac:Ta0635 tac00910
# 77 sulfide:quinone oxidoreductase [EC:1.8.5.4] tac:Ta1129 tac00920
# 103 cysteine synthase [EC:2.5.1.47] tac:Ta0535 tac00920
# 121 cystathionine gamma-synthase [EC:2.5.1.48] tac:Ta0531 tac00920
# 24 isoleucyl-tRNA synthetase [EC:6.1.1.5] tac:Ta0879 tac00970
# 58 asparaginyl-tRNA synthetase [EC:6.1.1.22] tac:Ta0519 tac00970
# 59 histidyl-tRNA synthetase [EC:6.1.1.21] tac:Ta0099 tac00970
# 60 phenylalanyl-tRNA synthetase beta chain [EC:6.1.1.20] tac:Ta0551 tac00970
# 61 arginyl-tRNA synthetase [EC:6.1.1.19] tac:Ta0281 tac00970
# 63 cysteinyl-tRNA synthetase [EC:6.1.1.16] tac:Ta1147 tac00970
# 64 glycyl-tRNA synthetase [EC:6.1.1.14] tac:Ta0206 tac00970
# 66 seryl-tRNA synthetase [EC:6.1.1.11] tac:Ta0468 tac00970
# 67 methionyl-tRNA synthetase [EC:6.1.1.10] tac:Ta1162 tac00970
# 68 valyl-tRNA synthetase [EC:6.1.1.9] tac:Ta0040 tac00970
# 69 alanyl-tRNA synthetase [EC:6.1.1.7] tac:Ta0499 tac00970
# 70 lysyl-tRNA synthetase, class I [EC:6.1.1.6] tac:Ta1163 tac00970
# 71 leucyl-tRNA synthetase [EC:6.1.1.4] tac:Ta0777 tac00970
# 72 threonyl-tRNA synthetase [EC:6.1.1.3] tac:Ta0330 tac00970
# 73 tryptophanyl-tRNA synthetase [EC:6.1.1.2] tac:Ta1211 tac00970
# 75 tyrosyl-tRNA synthetase [EC:6.1.1.1] tac:Ta0512 tac00970
# 76 prolyl-tRNA synthetase [EC:6.1.1.15] tac:Ta0937 tac00970
# 77 glutamyl-tRNA synthetase [EC:6.1.1.17] tac:Ta0942 tac00970
# 128 glutamyl-tRNA(Gln) amidotransferase subunit E [EC:6.3.5.7] tac:Ta0971 tac00970
# 132 nondiscriminating aspartyl-tRNA synthetase [EC:6.1.1.23] tac:Ta0946 tac00970
# 137 seryl-tRNA synthetase [EC:6.1.1.11] tac:Ta0468 tac00970
# 145 L-seryl-tRNA(Ser) seleniumtransferase [EC:2.9.1.1] tac:Ta0673 tac00970
# 151 nondiscriminating aspartyl-tRNA synthetase [EC:6.1.1.23] tac:Ta0946 tac00970
# 156 tRNA Glu tac:tRNA-Glu-1 tac00970
# 157 tRNA Gln tac:tRNA-Gln-1 tac00970
# 158 tRNA Ala tac:tRNA-Ala-1 tac00970
# 159 tRNA Asp tac:tRNA-Asp tac00970
# 160 tRNA Ser tac:tRNA-Ser-1 tac00970
# 161 tRNA Thr tac:tRNA-Thr-1 tac00970
# 162 tRNA Asn tac:tRNA-Asn tac00970
# 163 tRNA Gly tac:tRNA-Gly-1 tac00970
# 164 tRNA Cys tac:tRNA-Cys tac00970
# 166 tRNA Met tac:tRNA-Met-1 tac00970
# 167 tRNA Val tac:tRNA-Val-1 tac00970
# 168 tRNA Leu tac:tRNA-Leu-1 tac00970
# 169 tRNA Ile tac:tRNA-Ile tac00970
# 170 tRNA Lys tac:tRNA-Lys-1 tac00970
# 172 tRNA Arg tac:tRNA-Arg-1 tac00970
# 173 tRNA Pro tac:tRNA-Pro-1 tac00970
# 174 tRNA His tac:tRNA-His tac00970
# 176 tRNA Tyr tac:tRNA-Tyr tac00970
# 177 tRNA Trp tac:tRNA-Trp tac00970

# %%
NODES_tac00010
# Out:
# {"'14'": 'fructose 1,6-bisphosphate aldolase/phosphatase [EC:4.1.2.13 3.1.3.11]',
#  '14': 'fructose 1,6-bisphosphate aldolase/phosphatase [EC:4.1.2.13 3.1.3.11]',
#  '38': 'aldehyde dehydrogenase (NAD+) [EC:1.2.1.3]',
#  '39': 'acetate---CoA ligase (ADP-forming) [EC:6.2.1.13]',
#  '48': 'pyruvate dehydrogenase E1 component beta subunit [EC:1.2.4.1]',
#  '49': 'pyruvate dehydrogenase E1 component beta subunit [EC:1.2.4.1]',
#  '50': 'pyruvate dehydrogenase E2 component (dihydrolipoamide acetyltransferase) [EC:2.3.1.12]',
#  '53': 'pyruvate kinase [EC:2.7.1.40]',
#  '55': 'enolase [EC:4.2.1.11]',
#  '58': 'triosephosphate isomerase (TIM) [EC:5.3.1.1]',
#  '60': 'fructose 1,6-bisphosphate aldolase/phosphatase [EC:4.1.2.13 3.1.3.11]',
#  '62': 'glucose/mannose-6-phosphate isomerase [EC:5.3.1.9 5.3.1.8]',
#  '63': 'phosphomannomutase / phosphoglucomutase [EC:5.4.2.8 5.4.2.2]',
#  '64': 'glucose/mannose-6-phosphate isomerase [EC:5.3.1.9 5.3.1.8]',
#  '66': 'glucokinase [EC:2.7.1.2]',
#  '67': 'glucose/mannose-6-phosphate isomerase [EC:5.3.1.9 5.3.1.8]',
#  '69': 'aldose 1-epimerase [EC:5.1.3.3]',
#  '70': 'glucokinase [EC:2.7.1.2]',
#  '75': 'dihydrolipoamide dehydrogenase [EC:1.8.1.4]',
#  '76': 'phosphoglycerate kinase [EC:2.7.2.3]',
#  '112': 'phosphoenolpyruvate carboxykinase (GTP) [EC:4.1.1.32]',
#  '119': 'glyceraldehyde-3-phosphate dehydrogenase (NAD(P)) [EC:1.2.1.59]',
#  '124': '2-oxoisovalerate/pyruvate ferredoxin oxidoreductase gamma subunit [EC:1.2.7.7 1.2.7.1]',
#  '131': 'acetyl-CoA synthetase [EC:6.2.1.1]',
#  '137': '2,3-bisphosphoglycerate-independent phosphoglycerate mutase [EC:5.4.2.12]',
#  '144': '2-oxoglutarate/2-oxoacid ferredoxin oxidoreductase subunit alpha [EC:1.2.7.3 1.2.7.11]'}

# %% [markdown]
# ## PRIMERA RED

# %%
EDGES=[]

for line in pathways.text.split('\n'):        
    pathwayid = line.split('\t')[0].replace('path:', '') 
    
    if pathwayid == str(org)+str(maxi):           
            break
            
    ii=locals()[str(pathwayid)]
    
    NODES=locals()['NODES_'+str(pathwayid)]
   
    for i in range(0,len(ii)):
        if ii[i].tag=='relation':         
            A=ii[i].attrib            
            if A['type'] == 'ECrel':    #relación enzima-enzima, que indica dos enzimas que catalizan pasos de reacción sucesivos
                #print(A)
                EDGES.append( [  NODES[ A['entry1'] ] , NODES[ A['entry2'] ]  ]  ) 

print(EDGES)
# Out:
# [['aldose 1-epimerase [EC:5.1.3.3]', 'glucokinase [EC:2.7.1.2]'], ['glucokinase [EC:2.7.1.2]', 'aldose 1-epimerase [EC:5.1.3.3]'], ['glucose/mannose-6-phosphate isomerase [EC:5.3.1.9 5.3.1.8]', 'glucokinase [EC:2.7.1.2]'], ['glucose/mannose-6-phosphate isomerase [EC:5.3.1.9 5.3.1.8]', 'glucokinase [EC:2.7.1.2]'], ['glucose/mannose-6-phosphate isomerase [EC:5.3.1.9 5.3.1.8]', 'phosphomannomutase / phosphoglucomutase [EC:5.4.2.8 5.4.2.2]'], ['glucose/mannose-6-phosphate isomerase [EC:5.3.1.9 5.3.1.8]', 'glucokinase [EC:2.7.1.2]'], ['phosphomannomutase / phosphoglucomutase [EC:5.4.2.8 5.4.2.2]', 'glucokinase [EC:2.7.1.2]'], ['phosphomannomutase / phosphoglucomutase [EC:5.4.2.8 5.4.2.2]', 'glucose/mannose-6-phosphate isomerase [EC:5.3.1.9 5.3.1.8]'], ['fructose 1,6-bisphosphate aldolase/phosphatase [EC:4.1.2.13 3.1.3.11]', 'glucose/mannose-6-phosphate isomerase [EC:5.3.1.9 5.3.1.8]'], ['fructose 1,6-bisphosphate aldolase/phosphatase [EC:4.1.2.13 3.1.3.11]', 'fructose 1,6-bisphosphate aldolase/phosphatase [EC:4.1.2.13 3.1.3.11]'], ['triosephosphate isomerase (TIM) [EC:5.3.1.1]', 'fructose 1,6-bisphosphate aldolase/phosphatase [EC:4.1.2.13 3.1.3.11]'], ['pyruvate dehydrogenase E1 component beta subunit [EC:1.2.4.1]', 'pyruvate dehydrogenase E2 component (dihydrolipoamide acetyltransferase) [EC:2.3.1.12]'], ['pyruvate dehydrogenase E1 component beta subunit [EC:1.2.4.1]', 'dihydrolipoamide dehydrogenase [EC:1.8.1.4]'], ['pyruvate dehydrogenase E2 component (dihydrolipoamide acetyltransferase) [EC:2.3.1.12]', 'dihydrolipoamide dehydrogenase [EC:1.8.1.4]'], ['pyruvate kinase [EC:2.7.1.40]', 'enolase [EC:4.2.1.11]'], ['aldehyde dehydrogenase (NAD+) [EC:1.2.1.3]', 'acetate---CoA ligase (ADP-forming) [EC:6.2.1.13]'], ['fructose 1,6-bisphosphate aldolase/phosphatase [EC:4.1.2.13 3.1.3.11]', 'glucose/mannose-6-phosphate isomerase [EC:5.3.1.9 5.3.1.8]'], ['pyruvate dehydrogenase E1 component beta subunit [EC:1.2.4.1]', 'pyruvate kinase [EC:2.7.1.40]'], ['acetate---CoA ligase (ADP-forming) [EC:6.2.1.13]', 'pyruvate dehydrogenase E2 component (dihydrolipoamide acetyltransferase) [EC:2.3.1.12]'], ['glucokinase [EC:2.7.1.2]', 'glucose/mannose-6-phosphate isomerase [EC:5.3.1.9 5.3.1.8]'], ['phosphoglycerate kinase [EC:2.7.2.3]', 'glyceraldehyde-3-phosphate dehydrogenase (NAD(P)) [EC:1.2.1.59]'], ['phosphoenolpyruvate carboxykinase (GTP) [EC:4.1.1.32]', 'enolase [EC:4.2.1.11]'], ['phosphoenolpyruvate carboxykinase (GTP) [EC:4.1.1.32]', 'pyruvate kinase [EC:2.7.1.40]'], ['pyruvate dehydrogenase E1 component beta subunit [EC:1.2.4.1]', '2-oxoisovalerate/pyruvate ferredoxin oxidoreductase gamma subunit [EC:1.2.7.7 1.2.7.1]'], ['pyruvate kinase [EC:2.7.1.40]', '2-oxoisovalerate/pyruvate ferredoxin oxidoreductase gamma subunit [EC:1.2.7.7 1.2.7.1]'], ['acetate---CoA ligase (ADP-forming) [EC:6.2.1.13]', '2-oxoisovalerate/pyruvate ferredoxin oxidoreductase gamma subunit [EC:1.2.7.7 1.2.7.1]'], ['pyruvate dehydrogenase E2 component (dihydrolipoamide acetyltransferase) [EC:2.3.1.12]', '2-oxoisovalerate/pyruvate ferredoxin oxidoreductase gamma subunit [EC:1.2.7.7 1.2.7.1]'], ['triosephosphate isomerase (TIM) [EC:5.3.1.1]', 'glyceraldehyde-3-phosphate dehydrogenase (NAD(P)) [EC:1.2.1.59]'], ['fructose 1,6-bisphosphate aldolase/phosphatase [EC:4.1.2.13 3.1.3.11]', 'triosephosphate isomerase (TIM) [EC:5.3.1.1]'], ['fructose 1,6-bisphosphate aldolase/phosphatase [EC:4.1.2.13 3.1.3.11]', 'glyceraldehyde-3-phosphate dehydrogenase (NAD(P)) [EC:1.2.1.59]'], ['acetyl-CoA synthetase [EC:6.2.1.1]', 'aldehyde dehydrogenase (NAD+) [EC:1.2.1.3]'], ['acetyl-CoA synthetase [EC:6.2.1.1]', 'pyruvate dehydrogenase E2 component (dihydrolipoamide acetyltransferase) [EC:2.3.1.12]'], ['acetyl-CoA synthetase [EC:6.2.1.1]', '2-oxoisovalerate/pyruvate ferredoxin oxidoreductase gamma subunit [EC:1.2.7.7 1.2.7.1]'], ['phosphoglycerate kinase [EC:2.7.2.3]', '2,3-bisphosphoglycerate-independent phosphoglycerate mutase [EC:5.4.2.12]'], ['2,3-bisphosphoglycerate-independent phosphoglycera ...

# %%
G = nx.DiGraph() #--->DiGrafo para hacer un grado dirigido 
 
G.add_edges_from(EDGES)


plt.figure(3,figsize=(50,50))
nx.draw_kamada_kawai(G,font_size=15,node_size=1000,node_color='orange',with_labels=False)
plt.savefig("net_"+org+"1.pdf")# Guardar la red en pdf. 
plt.show()

# %%
g=nx.number_of_nodes(G)
print('g=',g)
L=nx.number_of_edges(G)
print('L=',L)
# Out:
# g= 240
# L= 471

# %%
nodos=G.nodes

D=[] # un vector donde vamos a colocar el numero de vinvulos de todos los nodos
d=nx.degree(G) # Vector que contiene el par ordenado del nodo y su numero de vinculos
for i in nodos: 
    D.append(d[i])
    

D_in=[] # un vector donde vamos a colocar el numero de vinvulos de todos los nodos
d=G.in_degree(G) # Vector que contiene el par ordenado del nodo y su numero de vinculos
for i in nodos: 
    D_in.append(d[i])
    
    
D_out=[] # un vector donde vamos a colocar el numero de vinvulos de todos los nodos
d=G.out_degree(G) # Vector que contiene el par ordenado del nodo y su numero de vinculos
for i in nodos: 
    D_out.append(d[i])
    
    
P=[]
X=[]
for i in range(1,max(D)+1):
    if D.count(i) != 0: 
        P.append(D.count(i)/len(D))
        X.append(i)
        
P_in=[]
X_in=[]
for i in range(1,max(D_in)+1):
    if D_in.count(i) != 0: 
        P_in.append(D_in.count(i)/len(D_in))
        X_in.append(i)  

P_out=[]
X_out=[]
for i in range(1,max(D)+1):
    if D_out.count(i) != 0: 
        P_out.append(D_out.count(i)/len(D_out))
        X_out.append(i)
        
        
        
# GRAFICA DE LA PROVAVILIDAD VS EL NUMERO DE GRADO        
fig, axs = plt.subplots( 3 ,sharex = True, sharey = True, figsize=(15,8))

fig.suptitle('Distribución de grado 2012',fontsize=20)
axs[0].plot(X,P,'ko')         
axs[0].set_xlabel(r'$K$',fontsize=20)
axs[0].set_ylabel(r'$P(K)$',fontsize=20)

axs[1].plot(X_in,P_in,'o')         
axs[1].set_xlabel(r'$K_{in}$',fontsize=20)
axs[1].set_ylabel(r'$P(K_{in})$',fontsize=20)

axs[2].plot(X_out,P_out, 'ro')         
axs[2].set_xlabel(r'$K_{out}$',fontsize=20)
axs[2].set_ylabel(r'$P(K_{out})$',fontsize=20)

#plt.savefig("P_vs_k_2012.pdf")# Guardar la red en pdf.    

plt.show()

# %%
fig, (ax1, ax2 , ax3) = plt.subplots(1, 3 ,sharex = True, sharey = True, figsize=(15,5))
fig.suptitle('Distribucion Log-Log 2012',fontsize=20)
ax1.plot(X,P,'ko')
ax1.set_xlabel(r'$K$',fontsize=20)
ax1.set_ylabel(r'$P(K)$',fontsize=20)

ax2.plot(X_in,P_in,'o')
ax2.set_xlabel(r'$K_{in}$',fontsize=20)
ax2.set_ylabel(r'$P(K_{in})$',fontsize=20)

ax3.plot(X_out,P_out,'ro')
ax3.set_xlabel(r'$K_{out}$',fontsize=20)
ax3.set_ylabel(r'$P(K_{out})$',fontsize=20)

# Escala log-log
plt.xscale('log') 
plt.yscale('log') 

#plt.savefig("Ley_de_potencias_2012.pdf")# Guardar la red en pdf.

plt.show()

# %%
d=G.degree(G) #Vector con el par ordenado de numero de aristas de entrada a cada uno de los nodos
d_in=G.in_degree(G)
d_out=G.out_degree(G)
degre=[]

for i in G.nodes:
    degre.append([i,d[i],d_in[i],d_out[i], d_in[i]-d_out[i] ])
df=pd.DataFrame(degre,columns=['Nombre', 'grado', 'grado_in', 'grado_out','dif_grado'])
df.sort_values(by='dif_grado', ascending=False)
# Out:
#                                                 Nombre  grado  grado_in  \
# 55             aspartate aminotransferase [EC:2.6.1.1]     11         9
# 92   glutamate synthase (NADPH) small chain [EC:1.4...      8         7
# 44         acetyl-CoA C-acetyltransferase [EC:2.3.1.9]     13         9
# 70   nucleoside kinase [EC:2.7.1.73 2.7.1.213 2.7.1.-]      5         5
# 10                               enolase [EC:4.2.1.11]      4         4
# 210  uroporphyrin-III C-methyltransferase [EC:2.1.1...      4         4
# 165                       acylphosphatase [EC:3.6.1.7]      4         4
# 40                    beta-galactosidase [EC:3.2.1.23]      5         4
# 78           XTP/dITP diphosphohydrolase [EC:3.6.1.66]      3         3
# 62   phosphoribosylglycinamide formyltransferase 1 ...     13         8
# 74             nucleoside-triphosphatase [EC:3.6.1.15]      5         4
# 218     cob(I)alamin adenosyltransferase [EC:2.5.1.17]      5         4
# 53      glutamate dehydrogenase (NAD(P)+) [EC:1.4.1.3]      9         6
# 54                   glutamine synthetase [EC:6.3.1.2]      9         6
# 59         ornithine carbamoyltransferase [EC:2.1.3.3]      3         3
# 66                 adenylosuccinate lyase [EC:4.3.2.2]      5         4
# 182  thiamine-phosphate pyrophosphorylase [EC:2.5.1.3]      3         3
# 31                          transaldolase [EC:2.2.1.2]      5         4
# 14   glyceraldehyde-3-phosphate dehydrogenase (NAD(...      3         3
# 6    pyruvate dehydrogenase E1 component beta subun...     15         9
# 8          dihydrolipoamide dehydrogenase [EC:1.8.1.4]      6         4
# 162  CDP-2,3-bis-(O-geranylgeranyl)-sn-glycerol syn...      2         2
# 84   orotidine-5'-phosphate decarboxylase [EC:4.1.1...      2         2
# 19   2-oxoglutarate/2-oxoacid ferredoxin oxidoreduc...     20        11
# 204                GTP cyclohydrolase II [EC:3.5.4.25]      2         2
# 76   5-(carboxyamino)imidazole ribonucleotide synth...      2         2
# 49              inorganic pyrophosphatase [EC:3.6.1.1]      2         2
# 7    pyruvate dehydrogenase E2 component (dihydroli...     12         7
# 89                      thymidine kinase [EC:2.7.1.21]      2         2
# 119  5'-methylthioadenosine phosphorylase [EC:2.4.2...      2         2
# ..                                                 ...    ...       ...
# 36   2-dehydro-3-deoxy-D-gluconate aldolase [EC:4.1...      4         1
# 0                      aldose 1-epimerase [EC:5.1.3.3]      4         1
# 170  methylmalonyl-CoA mutase, N-terminal domain [E...      2         0
# 193             dihydropteroate synthase [EC:2.5.1.15]      4         1
# 72   ribonucleoside-diphosphate reductase alpha cha...      8         3
# 209       uroporphyrinogen decarboxylase [EC:4.1.1.37]      2         0
# 42                galactonate dehydratase [EC:4.2.1.6]      2         0
# 43                 acyl-CoA dehydrogenase [EC:1.3.8.7]      2         0
# 45    hydroxymethylglutaryl-CoA synthase [EC:2.3.3.10]      6         2
# 85                      uridylate kinase [EC:2.7.4.22]      2         0
# 166  malate dehydrogenase (oxaloacetate-decarboxyla...      8         3
# 169                    glycolate oxidase [EC:1.1.3.15]      2         0
# 187  nicotinamide-nucleotide adenylyltransferase [E...      4         1
# 65   phosphoribosylaminoimidazole-succinocarboxamid...      2         0
# 71                       adenylate kinase [EC:2.7.4.3]      9         3
# 75   GMP synthase (glutamine-hydrolysing) [EC:6.3.5.2]      3         0
# 67   phosphoribosylaminoimidazolecarboxamide formyl...     11         4
# 9                        pyruvate kinase [EC:2.7.1.40]     13         5
# 32         deoxyribose-phosphate aldolase [EC:4.1.2.4]      3         0
# 198                    GTP 3',8-cyclase [EC:4.1.99.22]      3         0
# 79   carbamoyl-phosphate synthase large subunit [EC...      6         1
# 173      formate--tetrahydrofolate ligase [EC:6.3.4.3]      6         1
# 17                  acetyl-CoA synthetase [EC:6.2.1.1]     14         5
# 30     ribose-phosphate pyrophosphokinase [EC:2.7.6.1]      4         0
# 167     pyruvate, orthophosphate dikinase [EC:2.7.9.1]      6         1
# 73          nucleoside-diphosphate kinase [EC:2.7.4.6]     14         5
# 60        amidophosphoribosyltransferase [EC:2.4.2.14]      7         1
# 94   1-pyrroline-5-carboxylate dehydrogenase [EC:1....      7         1
# 68              adenylosuccinate synthase [EC:6.3.4.4]      9         1
# 58             argininosuccinate synthase [EC:6.3.4.5]      8         0
#
#      grado_out  dif_grado
# 55           2          7
# 92           1          6
# 44           4          5
# 70           0          5
# 10           0          4
# 210          0          4
# 165          0          4
# 40           1          3
# 78           0          3
# 62           5          3
# 74           1          3
# 218          1          3
# 53           3          3
# 54           3          3
# 59           0          3
# 66           1          3
# 182          0          3
# 31           1          3
# 14           0          3
# 6            6          3
# 8            2          2
# 162          0          2
# 84           0          2
# 19           9          2
# 204          0          2
# 76           0          2
# 49           0          2
# 7            5          2
# 89           0          2
# 119          0          2
# ..         ...        ...
# 36           3         -2
# 0            3         -2
# 170          2         -2
# 193          3         -2
# 72           5         -2
# 209          2         -2
# 42           2         -2
# 43           2         -2
# 45           4         -2
# 85           2         -2
# 166          5         -2
# 169          2         -2
# 187          3         -2
# 65           2         -2
# 71           6         -3
# 75           3         -3
# 67           7         -3
# 9            8         -3
# 32           3         -3
# 198          3         -3
# 79           5         -4
# 173          5         -4
# 17           9         -4
# 30           4         -4
# 167          5         -4
# 73           9         -4
# 60           6         -5
# 94           6         -5
# 68           8         -7
# 58           8         -8
#
# [240 rows x 5 columns]

# %%
intr=nx.betweenness_centrality(G) #dicionario en python
intr = pd.DataFrame([[key, intr[key]] for key in intr.keys()], columns=['Name', 'intermediacion'])
print(intr.sort_values(by='intermediacion', ascending=False))
# Out:
#                                                   Name  intermediacion
# 170  aspartate aminotransferase, cytoplasmic [EC:2....        0.080279
# 19                       pyruvate kinase [EC:2.7.1.40]        0.066031
# 1                              hexokinase [EC:2.7.1.1]        0.065222
# 11   2,3-bisphosphoglycerate-dependent phosphoglyce...        0.056590
# 18          aldehyde dehydrogenase (NAD+) [EC:1.2.1.3]        0.055253
# 4                      phosphoglucomutase [EC:5.4.2.2]        0.049236
# 243  glutamine---fructose-6-phosphate transaminase ...        0.048742
# 44                          transketolase [EC:2.2.1.1]        0.045338
# 10                phosphoglycerate kinase [EC:2.7.2.3]        0.041271
# 9    glyceraldehyde 3-phosphate dehydrogenase [EC:1...        0.040072
# 245              glutamate decarboxylase [EC:4.1.1.15]        0.039165
# 12                               enolase [EC:4.2.1.11]        0.035353
# 241            glutamate synthase (NADH) [EC:1.4.1.14]        0.035244
# 70                   alpha-galactosidase [EC:3.2.1.22]        0.032228
# 484                       phospholipase C [EC:3.1.4.3]        0.032175
# 251                 D-glycerate 3-kinase [EC:2.7.1.31]        0.030824
# 472  1,2-diacylglycerol 3-beta-galactosyltransferas...        0.028767
# 242                         omega-amidase [EC:3.5.1.3]        0.026382
# 548                       malate synthase [EC:2.3.3.9]        0.024093
# 78                     alpha-glucosidase [EC:3.2.1.20]        0.022261
# 109        acetyl-CoA C-acetyltransferase [EC:2.3.1.9]        0.022130
# 55   UTP--glucose-1-phosphate uridylyltransferase [...        0.021490
# 22   phosphoenolpyruvate carboxykinase (ATP) [EC:4....        0.021415
# 91   acetyl-CoA carboxylase / biotin carboxylase 1 ...        0.021399
# 29                  malate dehydrogenase [EC:1.1.1.37]        0.021257
# 25   multiple inositol-polyphosphate phosphatase / ...        0.019683
# 467  diacylglycerol diphosphate phosphatase / phosp...        0.019014
# 167                  glutamine synthetase [EC:6.3.1.2]        0.018339
# 53           UDP-sugar pyrophosphorylase [EC:2.7.7.64]        0.017414
# 74               beta-fructofuranosidase [EC:3.2.1.26]        0.017242
# ..                                                 ...             ...
# 370  2-oxoglutarate-dependent dioxygenase [EC:1.14....        0.000000
# 363                               amidase [EC:3.5.1.4]        0.000000
# 362  benzaldehyde dehydrogenase (NAD+) / indole-3-a...        0.000000
# 359  acetylserotonin O-methyltransferase, plant [EC...        0.000000
# 357                          myrosinase [EC:3.2.1.147]        0.000000
# 430       alpha-1,6-mannosyltransferase [EC:2.4.1.260]        0.000000
# 434  mannosyl-oligosaccharide alpha-1,3-glucosidase...        0.000000
# 492  inositol-pentakisphosphate 2-kinase [EC:2.7.1....        0.000000
# 459  alpha-1,4-galacturonosyltransferase [EC:2.4.1.43]        0.000000
# 489  3'(2'), 5'-bisphosphate nucleotidase / inosito...        0.000000
# 488     myo-inositol-1-phosphate synthase [EC:5.5.1.4]        0.000000
# 478  phosphatidylinositol-3,4,5-trisphosphate 3-pho...        0.000000
# 476     2-lysophosphatidate phosphatase [EC:3.1.3.106]        0.000000
# 475  UTP---glucose-1-phosphate uridylyltransferase ...        0.000000
# 464                      glycerol kinase [EC:2.7.1.30]        0.000000
# 462        alpha-N-acetylglucosaminidase [EC:3.2.1.50]        0.000000
# 461  heparan-alpha-glucosaminide N-acetyltransferas...        0.000000
# 460  reversibly glycosylated polypeptide / UDP-arab...        0.000000
# 458     3,5-epimerase/4-reductase [EC:5.1.3.- 1.1.1.-]        0.000000
# 438  beta-1,4-mannosyl-glycoprotein beta-1,4-N-acet...        0.000000
# 454            xylan 1,4-beta-xylosidase [EC:3.2.1.37]        0.000000
# 449          alpha-L-arabinofuranosidase [EC:3.2.1.55]        0.000000
# 448                      L-arabinokinase [EC:2.7.1.46]        0.000000
# 447  UDP-N-acetylglucosamine/UDP-N-acetylgalactosam...        0.000000
# 445  glucosamine-phosphate N-acetyltransferase [EC:...        0.000000
# 443                            chitinase [EC:3.2.1.14]        0.000000
# 442  mannosyl-oligosaccharide alpha-1,2-mannosidase...        0.000000
# 441  3-oxo-5-alpha-steroid 4-dehydrogenase 3 / poly...        0.000000
# 440  endoplasmic reticulum Man9GlcNAc2 1,2-alpha-ma...        0.000000
# 786  pinoresinol/lariciresinol reductase [EC:1.23.1...        0.000000
#
# [787 rows x 2 columns]
