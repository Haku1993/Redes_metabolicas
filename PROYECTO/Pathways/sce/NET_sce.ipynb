# %% [markdown]
# # Libreria

# %%
import pandas as pd
import networkx as nx
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
#parsear XML
import csv   
from lxml import etree
#Parsear HTML
import requests
import urllib.request
from bs4 import BeautifulSoup
from urllib.request import urlopen
from bs4.builder import HTMLParserTreeBuilder
#para medir tiempo
from time import time 
import time

# %% [markdown]
# # Carga de Archivos XML

# %%
org = 'sce'
ORGANISM = org
maxi ='01040'

pathways = requests.get('http://rest.kegg.jp/list/pathway/' + ORGANISM)  #lista de las vias metabolicas y otra informacion porpocionada por KEGG

for line in pathways.text.split('\n'):         # Se recorre la lista propocionada por  KEGG donde se estraen los nombres de las vias de KEGG
      pathwayid = line.split('\t')[0].replace('path:', '') 
      A = pathwayid+'.xml'                     # Le ponemos la extencion .xml para poder cargar los archivos
      if A == str(org)+str(maxi)+'.xml':           
            break
      locals()[str(pathwayid)] = etree.parse(A) # Guarda los  XML com el nombre de la via asignado por KEGG
      locals()[str(pathwayid)] = locals()[str(pathwayid)].getroot()  # Para transformar todos lo XML en directorios de python

# %% [markdown]
# ## ARMANDO BASE DE DATOS CON PANDAS

# %% [markdown]
# ##### crear archivo csv para guardar los datos.

# %%
#data= pd.DataFrame(columns=('n', 'enzima', 'gen', 'nob_Keeg', 'path' ,'link')) # Crear tabla csv. 
#data.to_csv('data_'+org+'.csv', sep=';')

# %%
save=len(pd.read_csv('data_'+org+'.csv',index_col=0, delimiter=';')[['n']].values)
print(save)
# Out:
# 1440

# %%
save=len(pd.read_csv('data_'+org+'.csv',index_col=0, delimiter=';')[['n']].values)

n=0

for line in pathways.text.split('\n'):
    
    pathwayid = line.split('\t')[0].replace('path:', '') 
    
    if pathwayid ==  str(org)+str(maxi):           
            break
    
    ii=locals()[str(pathwayid)]
    
    
    for i in range(0,len(ii)):
       
        if ii[i].tag=='entry':         
            A=ii[i].attrib            
            if A['type'] == 'gene':
                n=1+n
                
                if n > save:
                    
                    url = A['link']
                
                    response = requests.get(url)
                    soup = BeautifulSoup(response.text, "html.parser")
                    
                    gen    = soup.html.body.div.table.form.td.table.find_all('td')[3].find_all('div')[0].text.replace('\n', ' ').strip().split()[0].replace(',','')
                    
                    if gen == '(GenBank)' or gen == '(RefSeq)' :
                        ll=6
                    else:
                        ll=7
                    
                    enzima = soup.html.body.div.table.form.td.table.find_all('td')[ll].text.strip()
                    
                    NewDat = [n , A['id'] , enzima, gen , A['name'].split( )[0] , pathwayid , A['link'] ]
                
                                
                    with open(r'data_'+org+'.csv', 'a' , newline='') as f:
                        writer = csv.writer(f,delimiter=';')
                        writer.writerow(NewDat)

# %%
n=0

for line in pathways.text.split('\n'):
    
    pathwayid = line.split('\t')[0].replace('path:', '') 
    
    if pathwayid == str(org)+str(maxi):           
            break
            
  
    ii=locals()[str(pathwayid)]
    
        
    
    for i in range(0,len(ii)):
       
        if ii[i].tag=='entry':         
            A=ii[i].attrib            
            if A['type'] == 'group':
                n=1+n 
                
                NewDat = [n , A['id'] , 'undefined_Enzima'+pathwayid , 'none' ,  A['name'] , pathwayid , 'no link']
                
                        
                with open(r'data_'+org+'.csv', 'a' , newline='') as f:
                    writer = csv.writer(f , delimiter=';')
                    writer.writerow(NewDat)

# %%
data=pd.read_csv('data_'+org+'.csv',index_col=0, sep=';')
data=data[['n' ,'enzima', 'nob_Keeg' ,'path']]
data=data.values
data
# Out:
# array([["'18'", 'fructose-bisphosphate aldolase, class II [EC:4.1.2.13]',
#         'sce:YKL060C', 'sce00010'],
#        ['18', 'fructose-bisphosphate aldolase, class II [EC:4.1.2.13]',
#         'sce:YKL060C', 'sce00010'],
#        ['42', 'aldehyde dehydrogenase (NAD+) [EC:1.2.1.3]',
#         'sce:YER073W', 'sce00010'],
#        ...,
#        ['72', 'undefined_Enzimasce00563', 'undefined', 'sce00563'],
#        ['73', 'undefined_Enzimasce00563', 'undefined', 'sce00563'],
#        ['74', 'undefined_Enzimasce00563', 'undefined', 'sce00563']],
#       dtype=object)

# %%
for line in pathways.text.split('\n'):
    
    pathwayid = line.split('\t')[0].replace('path:', '') 
    
    if pathwayid == str(org)+str(maxi):           
            break
    
    locals()['NODES_'+str(pathwayid)]={}
    
    for i in data:
        if i[3] == pathwayid:
            locals()['NODES_'+str(pathwayid)][i[0]]= i[1] 
            print(i[0],i[1], i[2], i[3])
# Out:
# '18' fructose-bisphosphate aldolase, class II [EC:4.1.2.13] sce:YKL060C sce00010
# 18 fructose-bisphosphate aldolase, class II [EC:4.1.2.13] sce:YKL060C sce00010
# 42 aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] sce:YER073W sce00010
# 44 aldehyde dehydrogenase (NAD(P)+) [EC:1.2.1.5] sce:YMR169C sce00010
# 48 pyruvate decarboxylase [EC:4.1.1.1] sce:YDL080C sce00010
# 49 alcohol dehydrogenase (NADP+) [EC:1.1.1.2] sce:YCR105W sce00010
# 50 alcohol dehydrogenase, propanol-preferring [EC:1.1.1.1] sce:YBR145W sce00010
# 51 pyruvate decarboxylase [EC:4.1.1.1] sce:YDL080C sce00010
# 52 pyruvate dehydrogenase E1 component beta subunit [EC:1.2.4.1] sce:YBR221C sce00010
# 53 pyruvate dehydrogenase E1 component beta subunit [EC:1.2.4.1] sce:YBR221C sce00010
# 54 pyruvate dehydrogenase E2 component (dihydrolipoamide acetyltransferase) [EC:2.3.1.12] sce:YNL071W sce00010
# 57 pyruvate kinase [EC:2.7.1.40] sce:YAL038W sce00010
# 59 enolase [EC:4.2.1.11] sce:YGR254W sce00010
# 60 2,3-bisphosphoglycerate-dependent phosphoglycerate mutase [EC:5.4.2.11] sce:YDL021W sce00010
# 61 glyceraldehyde 3-phosphate dehydrogenase [EC:1.2.1.12] sce:YGR192C sce00010
# 62 triosephosphate isomerase (TIM) [EC:5.3.1.1] sce:YDR050C sce00010
# 63 6-phosphofructokinase 1 [EC:2.7.1.11] sce:YGR240C sce00010
# 64 fructose-1,6-bisphosphatase I [EC:3.1.3.11] sce:YLR377C sce00010
# 66 glucose-6-phosphate isomerase [EC:5.3.1.9] sce:YBR196C sce00010
# 67 phosphoglucomutase [EC:5.4.2.2] sce:YKL127W sce00010
# 68 glucose-6-phosphate isomerase [EC:5.3.1.9] sce:YBR196C sce00010
# 69 hexokinase [EC:2.7.1.1] sce:YCL040W sce00010
# 71 glucose-6-phosphate isomerase [EC:5.3.1.9] sce:YBR196C sce00010
# 72 glucose-6-phosphate 1-epimerase [EC:5.1.3.15] sce:YMR099C sce00010
# 73 UDP-glucose 4-epimerase [EC:5.1.3.2] sce:YBR019C sce00010
# 75 hexokinase [EC:2.7.1.1] sce:YCL040W sce00010
# 79 dihydrolipoamide dehydrogenase [EC:1.8.1.4] sce:YFL018C sce00010
# 80 phosphoglycerate kinase [EC:2.7.2.3] sce:YCR012W sce00010
# 121 phosphoenolpyruvate carboxykinase (ATP) [EC:4.1.1.49] sce:YKR097W sce00010
# 140 acetyl-CoA synthetase [EC:6.2.1.1] sce:YAL054C sce00010
# 33 dihydrolipoamide dehydrogenase [EC:1.8.1.4] sce:YFL018C sce00020
# 34 2-oxoglutarate dehydrogenase E1 component [EC:1.2.4.2] sce:YIL125W sce00020
# 35 2-oxoglutarate dehydrogenase E1 component [EC:1.2.4.2] sce:YIL125W sce00020
# 36 2-oxoglutarate dehydrogenase E2 component (dihydrolipoamide succinyltransferase) [EC:2.3.1.61] sce:YDR148C sce00020
# 37 succinyl-CoA synthetase beta subunit [EC:6.2.1.4 6.2.1.5] sce:YGR244C sce00020
# 38 succinyl-CoA synthetase beta subunit [EC:6.2.1.4 6.2.1.5] sce:YGR244C sce00020
# 39 isocitrate dehydrogenase [EC:1.1.1.42] sce:YDL066W sce00020
# 40 isocitrate dehydrogenase (NAD+) [EC:1.1.1.41] sce:YNL037C sce00020
# 41 isocitrate dehydrogenase [EC:1.1.1.42] sce:YDL066W sce00020
# 43 fumarate hydratase, class II [EC:4.2.1.2] sce:YPL262W sce00020
# 44 aconitate hydratase [EC:4.2.1.3] sce:YLR304C sce00020
# 45 aconitate hydratase [EC:4.2.1.3] sce:YLR304C sce00020
# 46 citrate synthase [EC:2.3.3.1] sce:YCR005C sce00020
# 47 malate dehydrogenase [EC:1.1.1.37] sce:YDL078C sce00020
# 48 pyruvate carboxylase [EC:6.4.1.1] sce:YBR218C sce00020
# 84 pyruvate dehydrogenase E1 component beta subunit [EC:1.2.4.1] sce:YBR221C sce00020
# 86 pyruvate dehydrogenase E1 component beta subunit [EC:1.2.4.1] sce:YBR221C sce00020
# 89 dihydrolipoamide dehydrogenase [EC:1.8.1.4] sce:YFL018C sce00020
# 91 pyruvate dehydrogenase E2 component (dihydrolipoamide acetyltransferase) [EC:2.3.1.12] sce:YNL071W sce00020
# 96 phosphoenolpyruvate carboxykinase (ATP) [EC:4.1.1.49] sce:YKR097W sce00020
# 107 succinate dehydrogenase (ubiquinone) membrane anchor subunit sce:YDR178W sce00020
# 37 glucose-6-phosphate isomerase [EC:5.3.1.9] sce:YBR196C sce00030
# 40 ribokinase [EC:2.7.1.15] sce:YCR036W sce00030
# 43 ribose-phosphate pyrophosphokinase [EC:2.7.6.1] sce:YBL068W sce00030
# 45 ribokinase [EC:2.7.1.15] sce:YCR036W sce00030
# 46 transketolase [EC:2.2.1.1] sce:YBR117C sce00030
# 47 ribose 5-phosphate isomerase A [EC:5.3.1.6] sce:YOR095C sce00030
# 48 ribulose-phosphate 3-epimerase [EC:5.1.3.1] sce:YJL121C sce00030
# 49 transketolase [EC:2.2.1.1] sce:YBR117C sce00030
# 50 fructose-bisphosphate aldolase, class II [EC:4.1.2.13] sce:YKL060C sce00030
# 51 6-phosphofructokinase 1 [EC:2.7.1.11] sce:YGR240C sce00030
# 52 fructose-1,6-bisphosphatase I [EC:3.1.3.11] sce:YLR377C sce00030
# 53 glucose-6-phosphate isomerase [EC:5.3.1.9] sce:YBR196C sce00030
# 56 6-phosphogluconate dehydrogenase [EC:1.1.1.44 1.1.1.343] sce:YGR256W sce00030
# 57 6-phosphogluconolactonase [EC:3.1.1.31] sce:YCR073W-A sce00030
# 58 glucose-6-phosphate 1-dehydrogenase [EC:1.1.1.49 1.1.1.363] sce:YNL241C sce00030
# 62 gluconokinase [EC:2.7.1.12] sce:YDR248C sce00030
# 77 transaldolase [EC:2.2.1.2] sce:YGR043C sce00030
# 78 phosphoglucomutase [EC:5.4.2.2] sce:YKL127W sce00030
# 156 6-phosphogluconate dehydrogenase [EC:1.1.1.44 1.1.1.343] sce:YGR256W sce00030
# 157 glucose-6-phosphate 1-dehydrogenase [EC:1.1.1.49 1.1.1.363] sce:YNL241C sce00030
# 66 polygalacturonase [EC:3.2.1.15] sce:YJR153W sce00040
# 78 ribulose-phosphate 3-epimerase [EC:5.1.3.1] sce:YJL121C sce00040
# 84 xylulokinase [EC:2.7.1.17] sce:YGR194C sce00040
# 90 D-xylulose reductase [EC:1.1.1.9] sce:YLR070C sce00040
# 100 UTP--glucose-1-phosphate uridylyltransferase [EC:2.7.7.9] sce:YHL012W sce00040
# 125 polygalacturonase [EC:3.2.1.15] sce:YJR153W sce00040
# 214 D-xylose reductase [EC:1.1.1.307] sce:YHR104W sce00040
# 215 L-iditol 2-dehydrogenase [EC:1.1.1.14] sce:YDL246C sce00040
# 216 alcohol dehydrogenase (NADP+) [EC:1.1.1.2] sce:YCR105W sce00040
# 58 L-iditol 2-dehydrogenase [EC:1.1.1.14] sce:YDL246C sce00051
# 63 mannitol 2-dehydrogenase [EC:1.1.1.67] sce:YEL070W sce00051
# 70 hexokinase [EC:2.7.1.1] sce:YCL040W sce00051
# 73 hexokinase [EC:2.7.1.1] sce:YCL040W sce00051
# 75 6-phosphofructo-2-kinase / fructose-2,6-biphosphatase 2 [EC:2.7.1.105 3.1.3.46] sce:YJL155C sce00051
# 76 6-phosphofructo-2-kinase [EC:2.7.1.105] sce:YIL107C sce00051
# 78 mannose-6-phosphate isomerase [EC:5.3.1.8] sce:YER003C sce00051
# 79 phosphomannomutase [EC:5.4.2.8] sce:YFL045C sce00051
# 84 mannose-1-phosphate guanylyltransferase [EC:2.7.7.13] sce:YDL055C sce00051
# 88 6-phosphofructokinase 1 [EC:2.7.1.11] sce:YGR240C sce00051
# 93 triosephosphate isomerase (TIM) [EC:5.3.1.1] sce:YDR050C sce00051
# 94 fructose-bisphosphate aldolase, class II [EC:4.1.2.13] sce:YKL060C sce00051
# 95 triose/dihydroxyacetone kinase / FAD-AMP lyase (cyclizing) [EC:2.7.1.28 2.7.1.29 4.6.1.15] sce:YFL053W sce00051
# 96 fructose-bisphosphate aldolase, class II [EC:4.1.2.13] sce:YKL060C sce00051
# 105 fructose-1,6-bisphosphatase I [EC:3.1.3.11] sce:YLR377C sce00051
# 57 6-phosphofructokinase 1 [EC:2.7.1.11] sce:YGR240C sce00052
# 62 beta-fructofuranosidase [EC:3.2.1.26] sce:YIL162W sce00052
# 66 beta-fructofuranosidase [EC:3.2.1.26] sce:YIL162W sce00052
# 74 hexokinase [EC:2.7.1.1] sce:YCL040W sce00052
# 77 phosphoglucomutase [EC:5.4.2.2] sce:YKL127W sce00052
# 79 UDP-glucose 4-epimerase [EC:5.1.3.2] sce:YBR019C sce00052
# 80 UTP--glucose-1-phosphate uridylyltransferase [EC:2.7.7.9] sce:YHL012W sce00052
# 82 UDPglucose--hexose-1-phosphate uridylyltransferase [EC:2.7.7.12] sce:YBR018C sce00052
# 156 oligo-1,6-glucosidase [EC:3.2.1.10] sce:YBR299W sce00052
# 171 galactokinase [EC:2.7.1.6] sce:YBR020W sce00052
# 172 UDP-glucose 4-epimerase [EC:5.1.3.2] sce:YBR019C sce00052
# 59 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] sce:YER061C sce00061
# 60 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] sce:YKL055C sce00061
# 64 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] sce:YER061C sce00061
# 65 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] sce:YER061C sce00061
# 66 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] sce:YER061C sce00061
# 67 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] sce:YER061C sce00061
# 68 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] sce:YER061C sce00061
# 69 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] sce:YER061C sce00061
# 77 fatty acid synthase subunit beta, fungi type [EC:2.3.1.86] sce:YKL182W sce00061
# 79 fatty acid synthase subunit beta, fungi type [EC:2.3.1.86] sce:YKL182W sce00061
# 81 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] sce:YKL055C sce00061
# 82 fatty acid synthase subunit alpha, fungi type [EC:2.3.1.86] sce:YPL231W sce00061
# 85 fatty acid synthase subunit alpha, fungi type [EC:2.3.1.86] sce:YPL231W sce00061
# 88 fatty acid synthase subunit beta, fungi type [EC:2.3.1.86] sce:YKL182W sce00061
# 90 fatty acid synthase subunit beta, fungi type [EC:2.3.1.86] sce:YKL182W sce00061
# 92 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] sce:YKL055C sce00061
# 93 fatty acid synthase subunit alpha, fungi type [EC:2.3.1.86] sce:YPL231W sce00061
# 96 fatty acid synthase subunit alpha, fungi type [EC:2.3.1.86] sce:YPL231W sce00061
# 99 fatty acid synthase subunit beta, fungi type [EC:2.3.1.86] sce:YKL182W sce00061
# 101 fatty acid synthase subunit beta, fungi type [EC:2.3.1.86] sce:YKL182W sce00061
# 103 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] sce:YKL055C sce00061
# 104 fatty acid synthase subunit alpha, fungi type [EC:2.3.1.86] sce:YPL231W sce00061
# 107 fatty acid synthase subunit alpha, fungi type [EC:2.3.1.86] sce:YPL231W sce00061
# 110 fatty acid synthase subunit beta, fungi type [EC:2.3.1.86] sce:YKL182W sce00061
# 112 fatty acid synthase subunit beta, fungi type [EC:2.3.1.86] sce:YKL182W sce00061
# 114 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] sce:YKL055C sce00061
# 115 fatty acid synthase subunit alpha, fungi type [EC:2.3.1.86] sce:YPL231W sce00061
# 118 fatty acid synthase subunit alpha, fungi type [EC:2.3.1.86] sce:YPL231W sce00061
# 121 fatty acid synthase subunit beta, fungi type [EC:2.3.1.86] sce:YKL182W sce00061
# 123 fatty acid synthase subunit beta, fungi type [EC:2.3.1.86] sce:YKL182W sce00061
# 125 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] sce:YKL055C sce00061
# 126 fatty acid synthase subunit alpha, fungi type [EC:2.3.1.86] sce:YPL231W sce00061
# 129 fatty acid synthase subunit alpha, fungi type [EC:2.3.1.86] sce:YPL231W sce00061
# 132 fatty acid synthase subunit beta, fungi type [EC:2.3.1.86] sce:YKL182W sce00061
# 134 fatty acid synthase subunit beta, fungi type [EC:2.3.1.86] sce:YKL182W sce00061
# 136 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] sce:YKL055C sce00061
# 137 fatty acid synthase subunit alpha, fungi type [EC:2.3.1.86] sce:YPL231W sce00061
# 141 fatty acid synthase subunit alpha, fungi type [EC:2.3.1.86] sce:YPL231W sce00061
# 143 fatty acid synthase subunit beta, fungi type [EC:2.3.1.86] sce:YKL182W sce00061
# 146 fatty acid synthase subunit beta, fungi type [EC:2.3.1.86] sce:YKL182W sce00061
# 148 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] sce:YKL055C sce00061
# 149 fatty acid synthase subunit alpha, fungi type [EC:2.3.1.86] sce:YPL231W sce00061
# 151 fatty acid synthase subunit alpha, fungi type [EC:2.3.1.86] sce:YPL231W sce00061
# 153 [acyl-carrier-protein] S-malonyltransferase [EC:2.3.1.39] sce:YOR221C sce00061
# 154 fatty acid synthase subunit beta, fungi type [EC:2.3.1.86] sce:YKL182W sce00061
# 157 fatty acid synthase subunit beta, fungi type [EC:2.3.1.86] sce:YKL182W sce00061
# 159 acetyl-CoA carboxylase / biotin carboxylase 1 [EC:6.4.1.2 6.3.4.14 2.1.3.15] sce:YMR207C sce00061
# 260 fatty acid synthase subunit beta, fungi type [EC:2.3.1.86] sce:YKL182W sce00061
# 265 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] sce:YER061C sce00061
# 301 long-chain acyl-CoA synthetase [EC:6.2.1.3] sce:YER015W sce00061
# 307 mitochondrial enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase [EC:1.3.1.- 1.3.1.38] sce:YBR026C sce00061
# 313 mitochondrial enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase [EC:1.3.1.- 1.3.1.38] sce:YBR026C sce00061
# 314 mitochondrial enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase [EC:1.3.1.- 1.3.1.38] sce:YBR026C sce00061
# 315 mitochondrial enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase [EC:1.3.1.- 1.3.1.38] sce:YBR026C sce00061
# 316 mitochondrial enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase [EC:1.3.1.- 1.3.1.38] sce:YBR026C sce00061
# 317 mitochondrial enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase [EC:1.3.1.- 1.3.1.38] sce:YBR026C sce00061
# 318 mitochondrial enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase [EC:1.3.1.- 1.3.1.38] sce:YBR026C sce00061
# 333 3-hydroxyacyl-thioester dehydratase, fungi type [EC:4.2.1.-] sce:YHR067W sce00061
# 334 3-hydroxyacyl-thioester dehydratase, fungi type [EC:4.2.1.-] sce:YHR067W sce00061
# 335 3-hydroxyacyl-thioester dehydratase, fungi type [EC:4.2.1.-] sce:YHR067W sce00061
# 336 3-hydroxyacyl-thioester dehydratase, fungi type [EC:4.2.1.-] sce:YHR067W sce00061
# 337 3-hydroxyacyl-thioester dehydratase, fungi type [EC:4.2.1.-] sce:YHR067W sce00061
# 338 3-hydroxyacyl-thioester dehydratase, fungi type [EC:4.2.1.-] sce:YHR067W sce00061
# 339 3-hydroxyacyl-thioester dehydratase, fungi type [EC:4.2.1.-] sce:YHR067W sce00061
# 348 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] sce:YKL055C sce00061
# 362 mitochondrial enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase [EC:1.3.1.- 1.3.1.38] sce:YBR026C sce00061
# 363 3-hydroxyacyl-thioester dehydratase, fungi type [EC:4.2.1.-] sce:YHR067W sce00061
# 384 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] sce:YER061C sce00061
# 388 long-chain acyl-CoA synthetase [EC:6.2.1.3] sce:YER015W sce00061
# 395 long-chain acyl-CoA synthetase [EC:6.2.1.3] sce:YER015W sce00061
# 398 fatty acid synthase subunit beta, fungi type [EC:2.3.1.86] sce:YKL182W sce00061
# 402 [acyl-carrier-protein] S-malonyltransferase [EC:2.3.1.39] sce:YOR221C sce00061
# 403 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] sce:YKL055C sce00061
# 405 [acyl-carrier-protein] S-malonyltransferase [EC:2.3.1.39] sce:YOR221C sce00061
# 406 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] sce:YER061C sce00061
# 409 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] sce:YER061C sce00061
# 410 acetyl-CoA carboxylase / biotin carboxylase 1 [EC:6.4.1.2 6.3.4.14 2.1.3.15] sce:YMR207C sce00061
# 411 acetyl-CoA carboxylase / biotin carboxylase 1 [EC:6.4.1.2 6.3.4.14 2.1.3.15] sce:YMR207C sce00061
# 412 acetyl-CoA carboxylase / biotin carboxylase 1 [EC:6.4.1.2 6.3.4.14 2.1.3.15] sce:YMR207C sce00061
# 30 mitochondrial enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase [EC:1.3.1.- 1.3.1.38] sce:YBR026C sce00062
# 34 mitochondrial enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase [EC:1.3.1.- 1.3.1.38] sce:YBR026C sce00062
# 38 mitochondrial enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase [EC:1.3.1.- 1.3.1.38] sce:YBR026C sce00062
# 42 mitochondrial enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase [EC:1.3.1.- 1.3.1.38] sce:YBR026C sce00062
# 47 mitochondrial enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase [EC:1.3.1.- 1.3.1.38] sce:YBR026C sce00062
# 52 mitochondrial enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase [EC:1.3.1.- 1.3.1.38] sce:YBR026C sce00062
# 113 17beta-estradiol 17-dehydrogenase / very-long-chain 3-oxoacyl-CoA reductase [EC:1.1.1.62 1.1.1.330] sce:YBR159W sce00062
# 114 very-long-chain enoyl-CoA reductase [EC:1.3.1.93] sce:YDL015C sce00062
# 115 very-long-chain (3R)-3-hydroxyacyl-CoA dehydratase [EC:4.2.1.134] sce:YJL097W sce00062
# 132 mitochondrial enoyl-[acyl-carrier protein] reductase / trans-2-enoyl-CoA reductase [EC:1.3.1.- 1.3.1.38] sce:YBR026C sce00062
# 141 acyl-coenzyme A thioesterase 1/2/4 [EC:3.1.2.2] sce:YJR019C sce00062
# 143 fatty acid elongase 2 [EC:2.3.1.199] sce:YCR034W sce00062
# 51 Delta3-Delta2-enoyl-CoA isomerase [EC:5.3.3.8] sce:YLR284C sce00071
# 53 acetyl-CoA C-acetyltransferase [EC:2.3.1.9] sce:YPL028W sce00071
# 54 acetyl-CoA acyltransferase 1 [EC:2.3.1.16] sce:YIL160C sce00071
# 62 acetyl-CoA acyltransferase 1 [EC:2.3.1.16] sce:YIL160C sce00071
# 69 acetyl-CoA acyltransferase 1 [EC:2.3.1.16] sce:YIL160C sce00071
# 79 acetyl-CoA acyltransferase 1 [EC:2.3.1.16] sce:YIL160C sce00071
# 84 alcohol dehydrogenase, propanol-preferring [EC:1.1.1.1] sce:YBR145W sce00071
# 94 acetyl-CoA acyltransferase 1 [EC:2.3.1.16] sce:YIL160C sce00071
# 105 acetyl-CoA acyltransferase 1 [EC:2.3.1.16] sce:YIL160C sce00071
# 109 long-chain acyl-CoA synthetase [EC:6.2.1.3] sce:YER015W sce00071
# 115 acyl-CoA oxidase [EC:1.3.3.6] sce:YGL205W sce00071
# 116 acyl-CoA oxidase [EC:1.3.3.6] sce:YGL205W sce00071
# 117 acyl-CoA oxidase [EC:1.3.3.6] sce:YGL205W sce00071
# 118 acyl-CoA oxidase [EC:1.3.3.6] sce:YGL205W sce00071
# 119 acyl-CoA oxidase [EC:1.3.3.6] sce:YGL205W sce00071
# 120 acyl-CoA oxidase [EC:1.3.3.6] sce:YGL205W sce00071
# 121 acyl-CoA oxidase [EC:1.3.3.6] sce:YGL205W sce00071
# 202 acetyl-CoA C-acetyltransferase [EC:2.3.1.9] sce:YPL028W sce00071
# 213 aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] sce:YER073W sce00071
# 217 acetyl-CoA acyltransferase 1 [EC:2.3.1.16] sce:YIL160C sce00071
# 11 hydroxymethylglutaryl-CoA synthase [EC:2.3.3.10] sce:YML126C sce00072
# 14 acetyl-CoA C-acetyltransferase [EC:2.3.1.9] sce:YPL028W sce00072
# 44 Delta7-sterol 5-desaturase [EC:1.14.19.20] sce:YLR056W sce00100
# 47 Delta7-sterol 5-desaturase [EC:1.14.19.20] sce:YLR056W sce00100
# 49 Delta24(24(1))-sterol reductase [EC:1.3.1.71] sce:YGL012W sce00100
# 50 sterol 22-desaturase [EC:1.14.19.41] sce:YMR015C sce00100
# 51 Delta7-sterol 5-desaturase [EC:1.14.19.20] sce:YLR056W sce00100
# 52 C-8 sterol isomerase [EC:5.-.-.-] sce:YMR202W sce00100
# 58 Delta7-sterol 5-desaturase [EC:1.14.19.20] sce:YLR056W sce00100
# 68 sterol 14alpha-demethylase [EC:1.14.14.154 1.14.15.36] sce:YHR007C sce00100
# 70 Delta14-sterol reductase [EC:1.3.1.70] sce:YNL280C sce00100
# 71 sterol 24-C-methyltransferase [EC:2.1.1.41] sce:YML008C sce00100
# 89 lanosterol synthase [EC:5.4.99.7] sce:YHR072W sce00100
# 90 Delta14-sterol reductase [EC:1.3.1.70] sce:YNL280C sce00100
# 92 sterol-4alpha-carboxylate 3-dehydrogenase (decarboxylating) [EC:1.1.1.170] sce:YGL001C sce00100
# 96 sterol 24-C-methyltransferase [EC:2.1.1.41] sce:YML008C sce00100
# 98 methylsterol monooxygenase [EC:1.14.18.9] sce:YGR060W sce00100
# 99 sterol 14alpha-demethylase [EC:1.14.14.154 1.14.15.36] sce:YHR007C sce00100
# 100 3-keto steroid reductase [EC:1.1.1.270] sce:YLR100W sce00100
# 131 lysosomal acid lipase/cholesteryl ester hydrolase [EC:3.1.1.13] sce:YKL140W sce00100
# 133 sterol O-acyltransferase [EC:2.3.1.26] sce:YCR048W sce00100
# 157 farnesyl-diphosphate farnesyltransferase [EC:2.5.1.21] sce:YHR190W sce00100
# 158 farnesyl-diphosphate farnesyltransferase [EC:2.5.1.21] sce:YHR190W sce00100
# 160 squalene monooxygenase [EC:1.14.14.17] sce:YGR175C sce00100
# 170 sterol 14alpha-demethylase [EC:1.14.14.154 1.14.15.36] sce:YHR007C sce00100
# 195 methylsterol monooxygenase [EC:1.14.18.9] sce:YGR060W sce00100
# 196 sterol-4alpha-carboxylate 3-dehydrogenase (decarboxylating) [EC:1.1.1.170] sce:YGL001C sce00100
# 197 3-keto steroid reductase [EC:1.1.1.270] sce:YLR100W sce00100
# 65 flavin prenyltransferase [EC:2.5.1.129] sce:YDR538W sce00130
# 66 4-hydroxybenzoate polyprenyltransferase [EC:2.5.1.39] sce:YNR041C sce00130
# 68 polyprenyldihydroxybenzoate methyltransferase / 3-demethylubiquinol 3-O-methyltransferase [EC:2.1.1.114 2.1.1.64] sce:YOL096C sce00130
# 102 aromatic amino acid aminotransferase I / 2-aminoadipate transaminase [EC:2.6.1.57 2.6.1.39 2.6.1.27 2.6.1.5] sce:YGL202W sce00130
# 131 ubiquinone biosynthesis monooxygenase Coq6 [EC:1.14.13.-] sce:YGR255C sce00130
# 132 2-methoxy-6-polyprenyl-1,4-benzoquinol methylase [EC:2.1.1.201] sce:YML110C sce00130
# 133 3-demethoxyubiquinol 3-hydroxylase [EC:1.14.99.60] sce:YOR125C sce00130
# 134 polyprenyldihydroxybenzoate methyltransferase / 3-demethylubiquinol 3-O-methyltransferase [EC:2.1.1.114 2.1.1.64] sce:YOL096C sce00130
# 2 cytochrome c oxidase subunit 4 sce:YIL111W sce00190
# 28 NADH dehydrogenase (ubiquinone) 1 alpha/beta subcomplex 1, acyl-carrier protein sce:YKL192C sce00190
# 91 cytochrome c oxidase assembly protein subunit 17 sce:YLL009C sce00190
# 92 cytochrome c oxidase assembly protein subunit 15 sce:YER141W sce00190
# 93 cytochrome c oxidase assembly protein subunit 11 sce:YPL132W sce00190
# 94 NADH dehydrogenase (ubiquinone) 1 alpha/beta subcomplex 1, acyl-carrier protein sce:YKL192C sce00190
# 96 cytochrome c oxidase subunit 7c sce:YLR395C sce00190
# 98 cytochrome c oxidase subunit 7 sce:YDL067C sce00190
# 109 NADH dehydrogenase (ubiquinone) 1 alpha/beta subcomplex 1, acyl-carrier protein sce:YKL192C sce00190
# 110 ubiquinol-cytochrome c reductase cytochrome b subunit sce:Q0105 sce00190
# 111 cytochrome c oxidase subunit 1 [EC:7.1.1.9] sce:Q0045 sce00190
# 112 F-type H+-transporting ATPase subunit 8 sce:Q0080 sce00190
# 114 H+-transporting ATPase [EC:7.1.2.1] sce:YGL008C sce00190
# 115 inorganic pyrophosphatase [EC:3.6.1.1] sce:YBR011C sce00190
# 136 succinate dehydrogenase (ubiquinone) cytochrome b560 subunit sce:YKL141W sce00190
# 137 succinate dehydrogenase (ubiquinone) membrane anchor subunit sce:YDR178W sce00190
# 138 succinate dehydrogenase (ubiquinone) flavoprotein subunit [EC:1.3.5.1] sce:YJL045W sce00190
# 139 succinate dehydrogenase (ubiquinone) iron-sulfur subunit [EC:1.3.5.1] sce:YLL041C sce00190
# 148 ubiquinol-cytochrome c reductase subunit 10 sce:YHR001W-A sce00190
# 149 ubiquinol-cytochrome c reductase subunit 9 sce:YGR183C sce00190
# 150 ubiquinol-cytochrome c reductase subunit 8 sce:YJL166W sce00190
# 151 ubiquinol-cytochrome c reductase subunit 7 sce:YDR529C sce00190
# 152 ubiquinol-cytochrome c reductase subunit 6 sce:YFR033C sce00190
# 153 ubiquinol-cytochrome c reductase core subunit 2 sce:YPR191W sce00190
# 154 ubiquinol-cytochrome c reductase core subunit 1 sce:YBL045C sce00190
# 155 ubiquinol-cytochrome c reductase cytochrome c1 subunit sce:YOR065W sce00190
# 156 ubiquinol-cytochrome c reductase cytochrome b subunit sce:Q0105 sce00190
# 157 ubiquinol-cytochrome c reductase iron-sulfur subunit [EC:7.1.1.8] sce:YEL024W sce00190
# 164 cytochrome c oxidase subunit 6b sce:YLR038C sce00190
# 165 cytochrome c oxidase subunit 6a sce:YGL191W sce00190
# 166 cytochrome c oxidase subunit 5b sce:YGL187C sce00190
# 167 cytochrome c oxidase subunit 5a sce:YHR051W sce00190
# 168 cytochrome c oxidase subunit 2 sce:Q0250 sce00190
# 171 heme o synthase [EC:2.5.1.141] sce:YPL172C sce00190
# 173 cytochrome c oxidase subunit 1 [EC:7.1.1.9] sce:Q0045 sce00190
# 174 cytochrome c oxidase subunit 3 sce:Q0275 sce00190
# 176 heme o synthase [EC:2.5.1.141] sce:YPL172C sce00190
# 177 F-type H+-transporting ATPase subunit j sce:YML081C-A sce00190
# 186 F-type H+-transporting ATPase subunit beta [EC:7.1.2.2] sce:YJR121W sce00190
# 187 F-type H+-transporting ATPase subunit alpha sce:YBL099W sce00190
# 188 F-type H+-transporting ATPase subunit gamma sce:YBR039W sce00190
# 189 F-type H+-transporting ATPase subunit O sce:YDR298C sce00190
# 190 F-type H+-transporting ATPase subunit delta sce:YDL004W sce00190
# 191 F-type H+-transporting ATPase subunit epsilon sce:YPL271W sce00190
# 192 F-type H+-transporting ATPase subunit c sce:Q0130 sce00190
# 193 F-type H+-transporting ATPase subunit a sce:Q0085 sce00190
# 194 F-type H+-transporting ATPase subunit b sce:YPL078C sce00190
# 195 F-type H+-transporting ATP synthase subunit e sce:YDR322C-A sce00190
# 196 F-type H+-transporting ATPase subunit h sce:YLR295C sce00190
# 197 F-type H+-transporting ATPase subunit f sce:YDR377W sce00190
# 198 F-type H+-transporting ATPase subunit 8 sce:Q0080 sce00190
# 199 F-type H+-transporting ATPase subunit d sce:YKL016C sce00190
# 200 F-type H+-transporting ATPase subunit k sce:YOL077W-A sce00190
# 201 F-type H+-transporting ATPase subunit g sce:YPR020W sce00190
# 210 V-type H+-transporting ATPase subunit A [EC:7.1.2.2] sce:YDL185W sce00190
# 211 V-type H+-transporting ATPase subunit B sce:YBR127C sce00190
# 212 V-type H+-transporting ATPase subunit C sce:YKL080W sce00190
# 213 V-type H+-transporting ATPase subunit D sce:YEL051W sce00190
# 214 V-type H+-transporting ATPase subunit E sce:YOR332W sce00190
# 215 V-type H+-transporting ATPase subunit F sce:YGR020C sce00190
# 216 V-type H+-transporting ATPase subunit G sce:YHR039C-A sce00190
# 217 V-type H+-transporting ATPase subunit H sce:YPR036W sce00190
# 218 V-type H+-transporting ATPase subunit a sce:YMR054W sce00190
# 219 V-type H+-transporting ATPase subunit d sce:YLR447C sce00190
# 222 V-type H+-transporting ATPase 16kDa proteolipid subunit sce:YEL027W sce00190
# 255 succinate dehydrogenase (ubiquinone) membrane anchor subunit sce:YDR178W sce00190
# 46 glutamine synthetase [EC:6.3.1.2] sce:YPR035W sce00220
# 49 ornithine carbamoyltransferase [EC:2.1.3.3] sce:YJL088W sce00220
# 50 argininosuccinate synthase [EC:6.3.4.5] sce:YOL058W sce00220
# 52 argininosuccinate lyase [EC:4.3.2.1] sce:YHR018C sce00220
# 53 arginase [EC:3.5.3.1] sce:YPL111W sce00220
# 54 amino-acid N-acetyltransferase [EC:2.3.1.1] sce:YJL071W sce00220
# 55 N-acetyl-gamma-glutamyl-phosphate reductase / acetylglutamate kinase [EC:1.2.1.38 2.7.2.8] sce:YER069W sce00220
# 56 N-acetyl-gamma-glutamyl-phosphate reductase / acetylglutamate kinase [EC:1.2.1.38 2.7.2.8] sce:YER069W sce00220
# 57 acetylornithine aminotransferase [EC:2.6.1.11] sce:YOL140W sce00220
# 60 glutamate N-acetyltransferase / amino-acid N-acetyltransferase [EC:2.3.1.35 2.3.1.1] sce:YMR062C sce00220
# 61 urea carboxylase / allophanate hydrolase [EC:6.3.4.6 3.5.1.54] sce:YBR208C sce00220
# 62 urea carboxylase / allophanate hydrolase [EC:6.3.4.6 3.5.1.54] sce:YBR208C sce00220
# 66 glutamate dehydrogenase [EC:1.4.1.2] sce:YDL215C sce00220
# 68 glutamate dehydrogenase (NADP+) [EC:1.4.1.4] sce:YAL062W sce00220
# 88 aspartate aminotransferase, mitochondrial [EC:2.6.1.1] sce:YKL106W sce00220
# 89 alanine transaminase [EC:2.6.1.2] sce:YDR111C sce00220
# 137 ribonucleoside-diphosphate reductase subunit M1 [EC:1.17.4.1] sce:YER070W sce00230
# 157 ribose-phosphate pyrophosphokinase [EC:2.7.6.1] sce:YBL068W sce00230
# 158 amidophosphoribosyltransferase [EC:2.4.2.14] sce:YMR300C sce00230
# 160 phosphoribosylamine--glycine ligase / phosphoribosylformylglycinamidine cyclo-ligase [EC:6.3.4.13 6.3.3.1] sce:YGL234W sce00230
# 161 phosphoribosylglycinamide formyltransferase [EC:2.1.2.2] sce:YDR408C sce00230
# 162 phosphoribosylamine--glycine ligase / phosphoribosylformylglycinamidine cyclo-ligase [EC:6.3.4.13 6.3.3.1] sce:YGL234W sce00230
# 163 phosphoribosylaminoimidazolecarboxamide formyltransferase / IMP cyclohydrolase [EC:2.1.2.3 3.5.4.10] sce:YLR028C sce00230
# 164 adenylosuccinate lyase [EC:4.3.2.2] sce:YLR359W sce00230
# 165 phosphoribosylaminoimidazole-succinocarboxamide synthase [EC:6.3.2.6] sce:YAR015W sce00230
# 166 phosphoribosylaminoimidazole carboxylase [EC:4.1.1.21] sce:YOR128C sce00230
# 167 phosphoribosylaminoimidazolecarboxamide formyltransferase / IMP cyclohydrolase [EC:2.1.2.3 3.5.4.10] sce:YLR028C sce00230
# 168 3',5'-cyclic-nucleotide phosphodiesterase [EC:3.1.4.17] sce:YGL248W sce00230
# 169 adenylate cyclase [EC:4.6.1.1] sce:YJL005W sce00230
# 171 golgi apyrase [EC:3.6.1.5] sce:YER005W sce00230
# 173 nucleoside-diphosphate kinase [EC:2.7.4.6] sce:YKL067W sce00230
# 174 nucleoside-diphosphate kinase [EC:2.7.4.6] sce:YKL067W sce00230
# 175 ribonucleoside-diphosphate reductase subunit M1 [EC:1.17.4.1] sce:YER070W sce00230
# 176 golgi apyrase [EC:3.6.1.5] sce:YER005W sce00230
# 177 adenylate kinase [EC:2.7.4.3] sce:YDL166C sce00230
# 178 adenylosuccinate lyase [EC:4.3.2.2] sce:YLR359W sce00230
# 179 adenylosuccinate synthase [EC:6.3.4.4] sce:YNL220W sce00230
# 180 AMP deaminase [EC:3.5.4.6] sce:YML035C sce00230
# 182 adenosine kinase [EC:2.7.1.20] sce:YJR105W sce00230
# 183 adenine phosphoribosyltransferase [EC:2.4.2.7] sce:YDR441C sce00230
# 186 adenosine deaminase [EC:3.5.4.4] sce:YNL141W sce00230
# 187 purine-nucleoside phosphorylase [EC:2.4.2.1] sce:YLR209C sce00230
# 189 purine-nucleoside phosphorylase [EC:2.4.2.1] sce:YLR209C sce00230
# 192 adenosine deaminase [EC:3.5.4.4] sce:YNL141W sce00230
# 196 golgi apyrase [EC:3.6.1.5] sce:YER005W sce00230
# 197 nucleoside-diphosphate kinase [EC:2.7.4.6] sce:YKL067W sce00230
# 198 golgi apyrase [EC:3.6.1.5] sce:YER005W sce00230
# 200 IMP dehydrogenase [EC:1.1.1.205] sce:YHR216W sce00230
# 201 GMP synthase (glutamine-hydrolysing) [EC:6.3.5.2] sce:YMR217W sce00230
# 202 golgi apyrase [EC:3.6.1.5] sce:YER005W sce00230
# 204 hypoxanthine phosphoribosyltransferase [EC:2.4.2.8] sce:YDR399W sce00230
# 206 purine-nucleoside phosphorylase [EC:2.4.2.1] sce:YLR209C sce00230
# 209 purine-nucleoside phosphorylase [EC:2.4.2.1] sce:YLR209C sce00230
# 211 hypoxanthine phosphoribosyltransferase [EC:2.4.2.8] sce:YDR399W sce00230
# 214 hypoxanthine phosphoribosyltransferase [EC:2.4.2.8] sce:YDR399W sce00230
# 215 guanylate kinase [EC:2.7.4.8] sce:YDR454C sce00230
# 216 purine-nucleoside phosphorylase [EC:2.4.2.1] sce:YLR209C sce00230
# 217 guanine deaminase [EC:3.5.4.3] sce:YDL238C sce00230
# 218 ureidoglycolate lyase [EC:4.3.2.3] sce:YIR032C sce00230
# 219 allantoicase [EC:3.5.3.4] sce:YIR029W sce00230
# 220 allantoinase [EC:3.5.2.5] sce:YIR027C sce00230
# 225 sulfate adenylyltransferase (ADP) / ATP adenylyltransferase [EC:2.7.7.5 2.7.7.53] sce:YCL050C sce00230
# 229 exopolyphosphatase [EC:3.6.1.11] sce:YHR201C sce00230
# 231 golgi apyrase [EC:3.6.1.5] sce:YER005W sce00230
# 232 nucleoside-diphosphate kinase [EC:2.7.4.6] sce:YKL067W sce00230
# 233 guanylate kinase [EC:2.7.4.8] sce:YDR454C sce00230
# 234 nucleoside-diphosphate kinase [EC:2.7.4.6] sce:YKL067W sce00230
# 237 purine-nucleoside phosphorylase [EC:2.4.2.1] sce:YLR209C sce00230
# 240 3',5'-cyclic-nucleotide phosphodiesterase [EC:3.1.4.17] sce:YGL248W sce00230
# 244 sulfate adenylyltransferase [EC:2.7.7.4] sce:YJR010W sce00230
# 245 adenylylsulfate kinase [EC:2.7.1.25] sce:YKL001C sce00230
# 252 phosphoribosylformylglycinamidine synthase [EC:6.3.5.3] sce:YGR061C sce00230
# 254 inosine triphosphate pyrophosphatase [EC:3.6.1.-] sce:YJR069C sce00230
# 257 inosine triphosphate pyrophosphatase [EC:3.6.1.-] sce:YJR069C sce00230
# 258 inosine triphosphate pyrophosphatase [EC:3.6.1.-] sce:YJR069C sce00230
# 269 inosine triphosphate pyrophosphatase [EC:3.6.1.-] sce:YJR069C sce00230
# 274 ADP-ribose pyrophosphatase [EC:3.6.1.13] sce:YBR111C sce00230
# 278 purine-nucleoside phosphorylase [EC:2.4.2.1] sce:YLR209C sce00230
# 279 adenylate kinase [EC:2.7.4.3] sce:YDL166C sce00230
# 287 nucleoside-diphosphate kinase [EC:2.7.4.6] sce:YKL067W sce00230
# 288 inosine triphosphate pyrophosphatase [EC:3.6.1.-] sce:YJR069C sce00230
# 289 sulfate adenylyltransferase (ADP) / ATP adenylyltransferase [EC:2.7.7.5 2.7.7.53] sce:YCL050C sce00230
# 290 bis(5'-adenosyl)-triphosphatase [EC:3.6.1.29] sce:YDR305C sce00230
# 291 adenylate cyclase [EC:4.6.1.1] sce:YJL005W sce00230
# 292 pyruvate kinase [EC:2.7.1.40] sce:YAL038W sce00230
# 293 pyruvate kinase [EC:2.7.1.40] sce:YAL038W sce00230
# 294 adenine phosphoribosyltransferase [EC:2.4.2.7] sce:YDR441C sce00230
# 296 adenine phosphoribosyltransferase [EC:2.4.2.7] sce:YDR441C sce00230
# 304 pyruvate kinase [EC:2.7.1.40] sce:YAL038W sce00230
# 305 pyruvate kinase [EC:2.7.1.40] sce:YAL038W sce00230
# 423 phosphoglucomutase [EC:5.4.2.2] sce:YKL127W sce00230
# 436 IMP and pyridine-specific 5'-nucleotidase [EC:3.1.3.99 3.1.3.-] sce:YOR155C sce00230
# 81 ribonucleoside-diphosphate reductase subunit M1 [EC:1.17.4.1] sce:YER070W sce00240
# 88 carbamoyl-phosphate synthase / aspartate carbamoyltransferase [EC:6.3.5.5 2.1.3.2] sce:YJL130C sce00240
# 94 carbamoyl-phosphate synthase / aspartate carbamoyltransferase [EC:6.3.5.5 2.1.3.2] sce:YJL130C sce00240
# 95 dihydroorotase [EC:3.5.2.3] sce:YLR420W sce00240
# 97 dihydroorotate dehydrogenase (fumarate) [EC:1.3.98.1] sce:YKL216W sce00240
# 98 orotate phosphoribosyltransferase [EC:2.4.2.10] sce:YML106W sce00240
# 99 nucleoside-diphosphate kinase [EC:2.7.4.6] sce:YKL067W sce00240
# 100 UMP-CMP kinase [EC:2.7.4.14] sce:YKL024C sce00240
# 102 CTP synthase [EC:6.3.4.2] sce:YBL039C sce00240
# 103 golgi apyrase [EC:3.6.1.5] sce:YER005W sce00240
# 106 golgi apyrase [EC:3.6.1.5] sce:YER005W sce00240
# 107 uracil phosphoribosyltransferase [EC:2.4.2.9] sce:YHR128W sce00240
# 108 uridine kinase [EC:2.7.1.48] sce:YDR020C sce00240
# 111 uridine nucleosidase [EC:3.2.2.3] sce:YDR400W sce00240
# 116 golgi apyrase [EC:3.6.1.5] sce:YER005W sce00240
# 117 nucleoside-diphosphate kinase [EC:2.7.4.6] sce:YKL067W sce00240
# 118 golgi apyrase [EC:3.6.1.5] sce:YER005W sce00240
# 119 UMP-CMP kinase [EC:2.7.4.14] sce:YKL024C sce00240
# 120 uridine kinase [EC:2.7.1.48] sce:YDR020C sce00240
# 122 cytidine deaminase [EC:3.5.4.5] sce:YLR245C sce00240
# 123 cytosine/creatinine deaminase [EC:3.5.4.1 3.5.4.21] sce:YPR062W sce00240
# 131 ribonucleoside-diphosphate reductase subunit M1 [EC:1.17.4.1] sce:YER070W sce00240
# 132 nucleoside-diphosphate kinase [EC:2.7.4.6] sce:YKL067W sce00240
# 134 UMP-CMP kinase [EC:2.7.4.14] sce:YKL024C sce00240
# 139 dCMP deaminase [EC:3.5.4.12] sce:YHR144C sce00240
# 140 nucleoside-diphosphate kinase [EC:2.7.4.6] sce:YKL067W sce00240
# 142 dTMP kinase [EC:2.7.4.9] sce:YJR057W sce00240
# 144 cytidine deaminase [EC:3.5.4.5] sce:YLR245C sce00240
# 146 purine-nucleoside phosphorylase [EC:2.4.2.1] sce:YLR209C sce00240
# 148 thymidylate synthase [EC:2.1.1.45] sce:YOR074C sce00240
# 149 nucleoside-diphosphate kinase [EC:2.7.4.6] sce:YKL067W sce00240
# 150 golgi apyrase [EC:3.6.1.5] sce:YER005W sce00240
# 152 dTMP kinase [EC:2.7.4.9] sce:YJR057W sce00240
# 153 golgi apyrase [EC:3.6.1.5] sce:YER005W sce00240
# 158 cytosine/creatinine deaminase [EC:3.5.4.1 3.5.4.21] sce:YPR062W sce00240
# 169 orotidine-5'-phosphate decarboxylase [EC:4.1.1.23] sce:YEL021W sce00240
# 257 3-hydroxy acid dehydrogenase / malonic semialdehyde reductase [EC:1.1.1.381 1.1.1.-] sce:YMR226C sce00240
# 274 nucleoside-diphosphate kinase [EC:2.7.4.6] sce:YKL067W sce00240
# 288 dUTP pyrophosphatase [EC:3.6.1.23] sce:YBR252W sce00240
# 33 omega-amidase [EC:3.5.1.3] sce:YLR351C sce00250
# 35 asparagine synthase (glutamine-hydrolysing) [EC:6.3.5.4] sce:YGR124W sce00250
# 38 L-asparaginase [EC:3.5.1.1] sce:YDR321W sce00250
# 49 aspartate aminotransferase, mitochondrial [EC:2.6.1.1] sce:YKL106W sce00250
# 55 argininosuccinate synthase [EC:6.3.4.5] sce:YOL058W sce00250
# 56 adenylosuccinate synthase [EC:6.3.4.4] sce:YNL220W sce00250
# 58 argininosuccinate lyase [EC:4.3.2.1] sce:YHR018C sce00250
# 59 adenylosuccinate lyase [EC:4.3.2.2] sce:YLR359W sce00250
# 61 alanine-glyoxylate transaminase / serine-glyoxylate transaminase / serine-pyruvate transaminase [EC:2.6.1.44 2.6.1.45 2.6.1.51] sce:YFL030W sce00250
# 63 alanine transaminase [EC:2.6.1.2] sce:YDR111C sce00250
# 71 carbamoyl-phosphate synthase / aspartate carbamoyltransferase [EC:6.3.5.5 2.1.3.2] sce:YJL130C sce00250
# 85 succinate-semialdehyde dehydrogenase / glutarate-semialdehyde dehydrogenase [EC:1.2.1.16 1.2.1.79 1.2.1.20] sce:YBR006W sce00250
# 90 glutamate synthase (NADH) [EC:1.4.1.14] sce:YDL171C sce00250
# 92 glutamate dehydrogenase [EC:1.4.1.2] sce:YDL215C sce00250
# 94 glutamate dehydrogenase (NADP+) [EC:1.4.1.4] sce:YAL062W sce00250
# 97 4-aminobutyrate aminotransferase / (S)-3-amino-2-methylpropionate transaminase [EC:2.6.1.19 2.6.1.22] sce:YGR019W sce00250
# 99 glutamate decarboxylase [EC:4.1.1.15] sce:YMR250W sce00250
# 102 glutamine synthetase [EC:6.3.1.2] sce:YPR035W sce00250
# 110 carbamoyl-phosphate synthase / aspartate carbamoyltransferase [EC:6.3.5.5 2.1.3.2] sce:YJL130C sce00250
# 118 omega-amidase [EC:3.5.1.3] sce:YLR351C sce00250
# 121 1-pyrroline-5-carboxylate dehydrogenase [EC:1.2.1.88] sce:YHR037W sce00250
# 123 glutamine---fructose-6-phosphate transaminase (isomerizing) [EC:2.6.1.16] sce:YKL104C sce00250
# 125 amidophosphoribosyltransferase [EC:2.4.2.14] sce:YMR300C sce00250
# 160 succinate-semialdehyde dehydrogenase / glutarate-semialdehyde dehydrogenase [EC:1.2.1.16 1.2.1.79 1.2.1.20] sce:YBR006W sce00250
# 71 D-glycerate 3-kinase [EC:2.7.1.31] sce:YGR205W sce00260
# 76 alanine-glyoxylate transaminase / serine-glyoxylate transaminase / serine-pyruvate transaminase [EC:2.6.1.44 2.6.1.45 2.6.1.51] sce:YFL030W sce00260
# 77 alanine-glyoxylate transaminase / serine-glyoxylate transaminase / serine-pyruvate transaminase [EC:2.6.1.44 2.6.1.45 2.6.1.51] sce:YFL030W sce00260
# 80 D-3-phosphoglycerate dehydrogenase / 2-oxoglutarate reductase [EC:1.1.1.95 1.1.1.399] sce:YER081W sce00260
# 83 cystathionine beta-synthase [EC:4.2.1.22] sce:YGR155W sce00260
# 84 cystathionine gamma-lyase [EC:4.4.1.1] sce:YAL012W sce00260
# 86 aspartate kinase [EC:2.7.2.4] sce:YER052C sce00260
# 88 phosphoserine aminotransferase [EC:2.6.1.52] sce:YOR184W sce00260
# 91 phosphoserine phosphatase [EC:3.1.3.3] sce:YGR208W sce00260
# 92 glycine hydroxymethyltransferase [EC:2.1.2.1] sce:YBR263W sce00260
# 93 L-serine/L-threonine ammonia-lyase [EC:4.3.1.17 4.3.1.19] sce:YCL064C sce00260
# 94 threonine aldolase [EC:4.1.2.48] sce:YEL046C sce00260
# 97 threonine synthase [EC:4.2.3.1] sce:YCR053W sce00260
# 103 aspartate-semialdehyde dehydrogenase [EC:1.2.1.11] sce:YDR158W sce00260
# 105 L-serine/L-threonine ammonia-lyase [EC:4.3.1.17 4.3.1.19] sce:YCL064C sce00260
# 109 homoserine kinase [EC:2.7.1.39] sce:YHR025W sce00260
# 111 glycine dehydrogenase [EC:1.4.4.2] sce:YMR189W sce00260
# 112 5-aminolevulinate synthase [EC:2.3.1.37] sce:YDR232W sce00260
# 113 homoserine dehydrogenase [EC:1.1.1.3] sce:YJR139C sce00260
# 114 D-serine ammonia-lyase [EC:4.3.1.18] sce:YGL196W sce00260
# 120 aminomethyltransferase [EC:2.1.2.10] sce:YDR019C sce00260
# 123 dihydrolipoamide dehydrogenase [EC:1.8.1.4] sce:YFL018C sce00260
# 126 L-serine/L-threonine ammonia-lyase [EC:4.3.1.17 4.3.1.19] sce:YCL064C sce00260
# 138 threonine aldolase [EC:4.1.2.48] sce:YEL046C sce00260
# 195 CDP-diacylglycerol---serine O-phosphatidyltransferase [EC:2.7.8.8] sce:YER026C sce00260
# 199 tryptophan synthase [EC:4.2.1.20] sce:YGL026C sce00260
# 202 alanine-glyoxylate transaminase / serine-glyoxylate transaminase / serine-pyruvate transaminase [EC:2.6.1.44 2.6.1.45 2.6.1.51] sce:YFL030W sce00260
# 203 cystathionine beta-synthase [EC:4.2.1.22] sce:YGR155W sce00260
# 207 alanine-glyoxylate transaminase / serine-glyoxylate transaminase / serine-pyruvate transaminase [EC:2.6.1.44 2.6.1.45 2.6.1.51] sce:YFL030W sce00260
# 217 2,3-bisphosphoglycerate-dependent phosphoglycerate mutase [EC:5.4.2.11] sce:YDL021W sce00260
# 228 glycine cleavage system H protein sce:YAL044C sce00260
# 236 3-hydroxy acid dehydrogenase / malonic semialdehyde reductase [EC:1.1.1.381 1.1.1.-] sce:YMR226C sce00260
# 62 aspartate kinase [EC:2.7.2.4] sce:YER052C sce00261
# 63 aspartate-semialdehyde dehydrogenase [EC:1.2.1.11] sce:YDR158W sce00261
# 101 sulfate adenylyltransferase [EC:2.7.7.4] sce:YJR010W sce00261
# 77 aromatic amino acid aminotransferase I / 2-aminoadipate transaminase [EC:2.6.1.57 2.6.1.39 2.6.1.27 2.6.1.5] sce:YGL202W sce00270
# 78 aromatic amino acid aminotransferase I / 2-aminoadipate transaminase [EC:2.6.1.57 2.6.1.39 2.6.1.27 2.6.1.5] sce:YGL202W sce00270
# 80 1,2-dihydroxy-3-keto-5-methylthiopentene dioxygenase [EC:1.13.11.53 1.13.11.54] sce:YMR009W sce00270
# 81 1,2-dihydroxy-3-keto-5-methylthiopentene dioxygenase [EC:1.13.11.53 1.13.11.54] sce:YMR009W sce00270
# 83 methylthioribulose-1-phosphate dehydratase [EC:4.2.1.109] sce:YJR024C sce00270
# 84 methylthioribose-1-phosphate isomerase [EC:5.3.1.23] sce:YPR118W sce00270
# 86 5'-methylthioadenosine phosphorylase [EC:2.4.2.28] sce:YLR017W sce00270
# 89 spermidine synthase [EC:2.5.1.16] sce:YPR069C sce00270
# 90 S-adenosylmethionine decarboxylase [EC:4.1.1.50] sce:YOL052C sce00270
# 91 L-methionine (R)-S-oxide reductase [EC:1.8.4.14] sce:YKL069W sce00270
# 94 cystathionine gamma-lyase [EC:4.4.1.1] sce:YAL012W sce00270
# 96 cystathionine beta-synthase [EC:4.2.1.22] sce:YGR155W sce00270
# 98 cysteine-S-conjugate beta-lyase [EC:4.4.1.13] sce:YFR055W sce00270
# 99 5-methyltetrahydropteroyltriglutamate--homocysteine methyltransferase [EC:2.1.1.14] sce:YER091C sce00270
# 101 S-adenosylmethionine synthetase [EC:2.5.1.6] sce:YDR502C sce00270
# 102 adenosylhomocysteinase [EC:3.3.1.1] sce:YER043C sce00270
# 107 homocysteine S-methyltransferase [EC:2.1.1.10] sce:YLL062C sce00270
# 110 cystathionine gamma-synthase [EC:2.5.1.48] sce:YJR130C sce00270
# 129 enolase-phosphatase E1 [EC:3.1.3.77] sce:YEL038W sce00270
# 132 cysteine synthase [EC:2.5.1.47] sce:YGR012W sce00270
# 149 L-serine/L-threonine ammonia-lyase [EC:4.3.1.17 4.3.1.19] sce:YCL064C sce00270
# 158 aspartate aminotransferase, mitochondrial [EC:2.6.1.1] sce:YKL106W sce00270
# 179 cystathionine gamma-lyase [EC:4.4.1.1] sce:YAL012W sce00270
# 185 aspartate aminotransferase, mitochondrial [EC:2.6.1.1] sce:YKL106W sce00270
# 194 cysteine-S-conjugate beta-lyase [EC:4.4.1.13] sce:YFR055W sce00270
# 195 cystathionine gamma-lyase [EC:4.4.1.1] sce:YAL012W sce00270
# 198 thiosulfate/3-mercaptopyruvate sulfurtransferase [EC:2.8.1.1 2.8.1.2] sce:YOR251C sce00270
# 199 aspartate aminotransferase, mitochondrial [EC:2.6.1.1] sce:YKL106W sce00270
# 207 homoserine O-acetyltransferase/O-succinyltransferase [EC:2.3.1.31 2.3.1.46] sce:YNL277W sce00270
# 208 homoserine O-acetyltransferase/O-succinyltransferase [EC:2.3.1.31 2.3.1.46] sce:YNL277W sce00270
# 212 cystathionine gamma-synthase [EC:2.5.1.48] sce:YJR130C sce00270
# 213 cystathionine gamma-synthase [EC:2.5.1.48] sce:YJR130C sce00270
# 214 cystathionine gamma-synthase [EC:2.5.1.48] sce:YJR130C sce00270
# 217 cystathionine gamma-synthase [EC:2.5.1.48] sce:YJR130C sce00270
# 224 homoserine dehydrogenase [EC:1.1.1.3] sce:YJR139C sce00270
# 227 aspartate-semialdehyde dehydrogenase [EC:1.2.1.11] sce:YDR158W sce00270
# 230 aspartate kinase [EC:2.7.2.4] sce:YER052C sce00270
# 242 spermine synthase [EC:2.5.1.22] sce:YLR146C sce00270
# 253 malate dehydrogenase [EC:1.1.1.37] sce:YDL078C sce00270
# 260 branched-chain amino acid aminotransferase [EC:2.6.1.42] sce:YHR208W sce00270
# 262 glutamate--cysteine ligase catalytic subunit [EC:6.3.2.2] sce:YJL101C sce00270
# 265 glutathione synthase [EC:6.3.2.3] sce:YOL049W sce00270
# 285 cysteine-S-conjugate beta-lyase [EC:4.4.1.13] sce:YFR055W sce00270
# 290 D-3-phosphoglycerate dehydrogenase / 2-oxoglutarate reductase [EC:1.1.1.95 1.1.1.399] sce:YER081W sce00270
# 291 phosphoserine aminotransferase [EC:2.6.1.52] sce:YOR184W sce00270
# 295 cysteine synthase [EC:2.5.1.47] sce:YGR012W sce00270
# 59 dihydrolipoamide dehydrogenase [EC:1.8.1.4] sce:YFL018C sce00280
# 67 dihydrolipoamide dehydrogenase [EC:1.8.1.4] sce:YFL018C sce00280
# 73 dihydrolipoamide dehydrogenase [EC:1.8.1.4] sce:YFL018C sce00280
# 77 acetyl-CoA C-acetyltransferase [EC:2.3.1.9] sce:YPL028W sce00280
# 80 hydroxymethylglutaryl-CoA synthase [EC:2.3.3.10] sce:YML126C sce00280
# 90 branched-chain amino acid aminotransferase [EC:2.6.1.42] sce:YHR208W sce00280
# 91 acetyl-CoA acyltransferase 1 [EC:2.3.1.16] sce:YIL160C sce00280
# 97 branched-chain amino acid aminotransferase [EC:2.6.1.42] sce:YHR208W sce00280
# 103 aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] sce:YER073W sce00280
# 105 4-aminobutyrate aminotransferase / (S)-3-amino-2-methylpropionate transaminase [EC:2.6.1.19 2.6.1.22] sce:YGR019W sce00280
# 108 3-hydroxyisobutyryl-CoA hydrolase [EC:3.1.2.4] sce:YDR036C sce00280
# 116 branched-chain amino acid aminotransferase [EC:2.6.1.42] sce:YHR208W sce00280
# 23 3-isopropylmalate dehydrogenase [EC:1.1.1.85] sce:YCL018W sce00290
# 24 L-serine/L-threonine ammonia-lyase [EC:4.3.1.17 4.3.1.19] sce:YCL064C sce00290
# 32 branched-chain amino acid aminotransferase [EC:2.6.1.42] sce:YHR208W sce00290
# 34 branched-chain amino acid aminotransferase [EC:2.6.1.42] sce:YHR208W sce00290
# 35 ketol-acid reductoisomerase [EC:1.1.1.86] sce:YLR355C sce00290
# 36 3-isopropylmalate dehydratase [EC:4.2.1.33] sce:YGL009C sce00290
# 37 3-isopropylmalate dehydrogenase [EC:1.1.1.85] sce:YCL018W sce00290
# 38 3-isopropylmalate dehydratase [EC:4.2.1.33] sce:YGL009C sce00290
# 39 2-isopropylmalate synthase [EC:2.3.3.13] sce:YNL104C sce00290
# 41 branched-chain amino acid aminotransferase [EC:2.6.1.42] sce:YHR208W sce00290
# 42 dihydroxy-acid dehydratase [EC:4.2.1.9] sce:YJR016C sce00290
# 43 ketol-acid reductoisomerase [EC:1.1.1.86] sce:YLR355C sce00290
# 45 ketol-acid reductoisomerase [EC:1.1.1.86] sce:YLR355C sce00290
# 46 dihydroxy-acid dehydratase [EC:4.2.1.9] sce:YJR016C sce00290
# 47 ketol-acid reductoisomerase [EC:1.1.1.86] sce:YLR355C sce00290
# 48 acetolactate synthase I/III small subunit [EC:2.2.1.6] sce:YCL009C sce00290
# 86 acetolactate synthase I/III small subunit [EC:2.2.1.6] sce:YCL009C sce00290
# 55 aspartate kinase [EC:2.7.2.4] sce:YER052C sce00300
# 56 aspartate-semialdehyde dehydrogenase [EC:1.2.1.11] sce:YDR158W sce00300
# 57 homoserine dehydrogenase [EC:1.1.1.3] sce:YJR139C sce00300
# 69 saccharopine dehydrogenase (NAD+, L-lysine forming) [EC:1.5.1.7] sce:YIR034C sce00300
# 70 saccharopine dehydrogenase (NADP+, L-glutamate forming) [EC:1.5.1.10] sce:YNR050C sce00300
# 71 L-2-aminoadipate reductase [EC:1.2.1.95] sce:YBR115C sce00300
# 72 L-2-aminoadipate reductase [EC:1.2.1.95] sce:YBR115C sce00300
# 73 aromatic amino acid aminotransferase I / 2-aminoadipate transaminase [EC:2.6.1.57 2.6.1.39 2.6.1.27 2.6.1.5] sce:YGL202W sce00300
# 74 homoisocitrate dehydrogenase [EC:1.1.1.87] sce:YIL094C sce00300
# 75 homoaconitate hydratase [EC:4.2.1.36] sce:YDR234W sce00300
# 76 homocitrate synthase [EC:2.3.3.14] sce:YDL131W sce00300
# 81 L-2-aminoadipate reductase [EC:1.2.1.95] sce:YBR115C sce00300
# 114 aromatic amino acid aminotransferase I / 2-aminoadipate transaminase [EC:2.6.1.57 2.6.1.39 2.6.1.27 2.6.1.5] sce:YGL202W sce00300
# 131 homoaconitase [EC:4.2.1.-] sce:YJL200C sce00300
# 77 saccharopine dehydrogenase (NADP+, L-glutamate forming) [EC:1.5.1.10] sce:YNR050C sce00310
# 86 saccharopine dehydrogenase (NAD+, L-lysine forming) [EC:1.5.1.7] sce:YIR034C sce00310
# 90 2-oxoglutarate dehydrogenase E2 component (dihydrolipoamide succinyltransferase) [EC:2.3.1.61] sce:YDR148C sce00310
# 91 acetyl-CoA C-acetyltransferase [EC:2.3.1.9] sce:YPL028W sce00310
# 95 succinate-semialdehyde dehydrogenase / glutarate-semialdehyde dehydrogenase [EC:1.2.1.16 1.2.1.79 1.2.1.20] sce:YBR006W sce00310
# 140 [cytochrome c]-lysine N-methyltransferase [EC:2.1.1.59] sce:YHR109W sce00310
# 141 [histone H3]-lysine79 N-trimethyltransferase [EC:2.1.1.360] sce:YDR440W sce00310
# 144 [cytochrome c]-lysine N-methyltransferase [EC:2.1.1.59] sce:YHR109W sce00310
# 145 [histone H3]-lysine79 N-trimethyltransferase [EC:2.1.1.360] sce:YDR440W sce00310
# 148 [cytochrome c]-lysine N-methyltransferase [EC:2.1.1.59] sce:YHR109W sce00310
# 149 [histone H3]-lysine79 N-trimethyltransferase [EC:2.1.1.360] sce:YDR440W sce00310
# 151 aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] sce:YER073W sce00310
# 47 arginase [EC:3.5.3.1] sce:YPL111W sce00330
# 53 amidase [EC:3.5.1.4] sce:YDR242W sce00330
# 66 aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] sce:YER073W sce00330
# 67 spermidine synthase [EC:2.5.1.16] sce:YPR069C sce00330
# 68 S-adenosylmethionine decarboxylase [EC:4.1.1.50] sce:YOL052C sce00330
# 69 spermine synthase [EC:2.5.1.22] sce:YLR146C sce00330
# 73 aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] sce:YER073W sce00330
# 104 cytosine/creatinine deaminase [EC:3.5.4.1 3.5.4.21] sce:YPR062W sce00330
# 142 polyamine oxidase [EC:1.5.3.17] sce:YMR020W sce00330
# 144 polyamine oxidase [EC:1.5.3.17] sce:YMR020W sce00330
# 172 ornithine--oxo-acid transaminase [EC:2.6.1.13] sce:YLR438W sce00330
# 173 pyrroline-5-carboxylate reductase [EC:1.5.1.2] sce:YER023W sce00330
# 174 proline dehydrogenase [EC:1.5.5.2] sce:YLR142W sce00330
# 175 1-pyrroline-5-carboxylate dehydrogenase [EC:1.2.1.88] sce:YHR037W sce00330
# 176 glutamate 5-kinase [EC:2.7.2.11] sce:YDR300C sce00330
# 177 glutamate-5-semialdehyde dehydrogenase [EC:1.2.1.41] sce:YOR323C sce00330
# 181 1-pyrroline-5-carboxylate dehydrogenase [EC:1.2.1.88] sce:YHR037W sce00330
# 206 pyrroline-5-carboxylate reductase [EC:1.5.1.2] sce:YER023W sce00330
# 207 1-pyrroline-5-carboxylate dehydrogenase [EC:1.2.1.88] sce:YHR037W sce00330
# 208 1-pyrroline-5-carboxylate dehydrogenase [EC:1.2.1.88] sce:YHR037W sce00330
# 209 aspartate aminotransferase, mitochondrial [EC:2.6.1.1] sce:YKL106W sce00330
# 236 ornithine decarboxylase [EC:4.1.1.17] sce:YKL184W sce00330
# 5 glutamate 5-kinase [EC:2.7.2.11] sce:YDR300C sce00332
# 8 glutamate-5-semialdehyde dehydrogenase [EC:1.2.1.41] sce:YOR323C sce00332
# 47 carnosine N-methyltransferase [EC:2.1.1.22] sce:YNL092W sce00340
# 53 aldehyde dehydrogenase (NAD+) [EC:1.2.1.3] sce:YER073W sce00340
# 55 aldehyde dehydrogenase (NAD(P)+) [EC:1.2.1.5] sce:YMR169C sce00340
# 59 ATP phosphoribosyltransferase [EC:2.4.2.17] sce:YER055C sce00340
# ...
# 64 thiamine pyrophosphokinase [EC:2.7.6.2] sce:YOR143C sce00730
# 68 hydroxymethylpyrimidine/phosphomethylpyrimidine kinase / thiaminase [EC:2.7.1.49 2.7.4.7 3.5.99.2] sce:YOL055C sce00730
# 72 cysteine desulfurase [EC:2.8.1.7] sce:YCL017C sce00730
# 74 thiamine-phosphate diphosphorylase / hydroxyethylthiazole kinase [EC:2.5.1.3 2.7.1.50] sce:YPL214C sce00730
# 75 hydroxymethylpyrimidine/phosphomethylpyrimidine kinase / thiaminase [EC:2.7.1.49 2.7.4.7 3.5.99.2] sce:YOL055C sce00730
# 76 hydroxymethylpyrimidine/phosphomethylpyrimidine kinase / thiaminase [EC:2.7.1.49 2.7.4.7 3.5.99.2] sce:YOL055C sce00730
# 82 cysteine-dependent adenosine diphosphate thiazole synthase [EC:2.4.2.60] sce:YGR144W sce00730
# 86 pyrimidine precursor biosynthesis enzyme sce:YDL244W sce00730
# 93 thiamine-phosphate diphosphorylase / hydroxyethylthiazole kinase [EC:2.5.1.3 2.7.1.50] sce:YPL214C sce00730
# 97 thiamine-phosphate diphosphorylase / hydroxyethylthiazole kinase [EC:2.5.1.3 2.7.1.50] sce:YPL214C sce00730
# 103 alkaline phosphatase [EC:3.1.3.1] sce:YDR481C sce00730
# 104 repressible acid phosphatase [EC:3.1.3.2] sce:YAR071W sce00730
# 110 hydroxymethylpyrimidine/phosphomethylpyrimidine kinase / thiaminase [EC:2.7.1.49 2.7.4.7 3.5.99.2] sce:YOL055C sce00730
# 32 3,4-dihydroxy 2-butanone 4-phosphate synthase [EC:4.1.99.12] sce:YDR487C sce00740
# 35 FAD synthetase [EC:2.7.7.2] sce:YDL045C sce00740
# 37 riboflavin kinase [EC:2.7.1.26] sce:YDR236C sce00740
# 38 GTP cyclohydrolase II [EC:3.5.4.25] sce:YBL033C sce00740
# 41 6,7-dimethyl-8-ribityllumazine synthase [EC:2.5.1.78] sce:YOL143C sce00740
# 42 riboflavin synthase [EC:2.5.1.9] sce:YBR256C sce00740
# 47 2,5-diamino-6-(ribosylamino)-4(3H)-pyrimidinone 5'-phosphate reductase [EC:1.1.1.302] sce:YBR153W sce00740
# 59 tRNA pseudouridine32 synthase / 2,5-diamino-6-(5-phospho-D-ribitylamino)-pyrimidin-4(3H)-one deaminase [EC:5.4.99.28] sce:YOL066C sce00740
# 74 repressible acid phosphatase [EC:3.1.3.2] sce:YAR071W sce00740
# 7 pyridoxal 5'-phosphate synthase pdxS subunit [EC:4.3.3.6] sce:YFL059W sce00750
# 20 pyridoxamine 5'-phosphate oxidase [EC:1.4.3.5] sce:YBR035C sce00750
# 82 pyridoxamine 5'-phosphate oxidase [EC:1.4.3.5] sce:YBR035C sce00750
# 84 pyridoxine kinase [EC:2.7.1.35] sce:YEL029C sce00750
# 86 pyridoxine kinase [EC:2.7.1.35] sce:YEL029C sce00750
# 88 pyridoxine kinase [EC:2.7.1.35] sce:YEL029C sce00750
# 89 threonine synthase [EC:4.2.3.1] sce:YCR053W sce00750
# 91 phosphoserine aminotransferase [EC:2.6.1.52] sce:YOR184W sce00750
# 96 pyridoxamine 5'-phosphate oxidase [EC:1.4.3.5] sce:YBR035C sce00750
# 98 pyridoxine 4-dehydrogenase [EC:1.1.1.65] sce:YPR127W sce00750
# 99 pyridoxamine 5'-phosphate oxidase [EC:1.4.3.5] sce:YBR035C sce00750
# 74 NAD+ diphosphatase [EC:3.6.1.22] sce:YGL067W sce00760
# 80 nicotinate-nucleotide pyrophosphorylase (carboxylating) [EC:2.4.2.19] sce:YFR047C sce00760
# 87 pyrimidine and pyridine-specific 5'-nucleotidase [EC:3.1.3.-] sce:YGL224C sce00760
# 88 nicotinamide/nicotinate riboside kinase [EC:2.7.1.22 2.7.1.173] sce:YNL129W sce00760
# 89 purine-nucleoside phosphorylase [EC:2.4.2.1] sce:YLR209C sce00760
# 90 nicotinamide mononucleotide adenylyltransferase [EC:2.7.7.1 2.7.7.18] sce:YGR010W sce00760
# 91 nicotinamide-nucleotide adenylyltransferase [EC:2.7.7.1] sce:YCL047C sce00760
# 92 NAD+ synthase (glutamine-hydrolysing) [EC:6.3.5.1] sce:YHR074W sce00760
# 95 nicotinate phosphoribosyltransferase [EC:6.3.4.21] sce:YOR209C sce00760
# 96 nicotinamidase [EC:3.5.1.19] sce:YGL037C sce00760
# 98 NAD+ diphosphatase [EC:3.6.1.22] sce:YGL067W sce00760
# 100 nicotinamide mononucleotide adenylyltransferase [EC:2.7.7.1 2.7.7.18] sce:YGR010W sce00760
# 101 nicotinamide-nucleotide adenylyltransferase [EC:2.7.7.1] sce:YCL047C sce00760
# 102 pyrimidine and pyridine-specific 5'-nucleotidase [EC:3.1.3.-] sce:YGL224C sce00760
# 103 nicotinamide/nicotinate riboside kinase [EC:2.7.1.22 2.7.1.173] sce:YNL129W sce00760
# 105 purine-nucleoside phosphorylase [EC:2.4.2.1] sce:YLR209C sce00760
# 111 NAD+ kinase [EC:2.7.1.23] sce:YJR049C sce00760
# 189 NAD+-dependent protein deacetylase SIR2 [EC:2.3.1.286] sce:YDL042C sce00760
# 191 uridine nucleosidase [EC:3.2.2.3] sce:YDR400W sce00760
# 192 uridine nucleosidase [EC:3.2.2.3] sce:YDR400W sce00760
# 222 succinate-semialdehyde dehydrogenase / glutarate-semialdehyde dehydrogenase [EC:1.2.1.16 1.2.1.79 1.2.1.20] sce:YBR006W sce00760
# 224 succinate-semialdehyde dehydrogenase / glutarate-semialdehyde dehydrogenase [EC:1.2.1.16 1.2.1.79 1.2.1.20] sce:YBR006W sce00760
# 67 dephospho-CoA kinase [EC:2.7.1.24] sce:YDR196C sce00770
# 68 holo-[acyl-carrier protein] synthase [EC:2.7.8.7] sce:YPL148C sce00770
# 71 type II pantothenate kinase [EC:2.7.1.33] sce:YDR531W sce00770
# 72 phosphopantothenoylcysteine decarboxylase [EC:4.1.1.36] sce:YKL088W sce00770
# 74 type II pantothenate kinase [EC:2.7.1.33] sce:YDR531W sce00770
# 76 type II pantothenate kinase [EC:2.7.1.33] sce:YDR531W sce00770
# 81 pantoate--beta-alanine ligase [EC:6.3.2.1] sce:YIL145C sce00770
# 82 2-dehydropantoate 2-reductase [EC:1.1.1.169] sce:YHR063C sce00770
# 83 3-methyl-2-oxobutanoate hydroxymethyltransferase [EC:2.1.2.11] sce:YBR176W sce00770
# 85 dihydroxy-acid dehydratase [EC:4.2.1.9] sce:YJR016C sce00770
# 86 ketol-acid reductoisomerase [EC:1.1.1.86] sce:YLR355C sce00770
# 87 acetolactate synthase I/III small subunit [EC:2.2.1.6] sce:YCL009C sce00770
# 90 branched-chain amino acid aminotransferase [EC:2.6.1.42] sce:YHR208W sce00770
# 92 pantetheine-phosphate adenylyltransferase [EC:2.7.7.3] sce:YGR277C sce00770
# 103 4'-phosphopantetheinyl transferase [EC:2.7.8.-] sce:YGL154C sce00770
# 107 phosphopantothenate---cysteine ligase (ATP) [EC:6.3.2.51] sce:YIL083C sce00770
# 27 biotin---protein ligase [EC:6.3.4.9 6.3.4.10 6.3.4.11 6.3.4.15] sce:YDL141W sce00780
# 28 biotin---protein ligase [EC:6.3.4.9 6.3.4.10 6.3.4.11 6.3.4.15] sce:YDL141W sce00780
# 29 biotin---protein ligase [EC:6.3.4.9 6.3.4.10 6.3.4.11 6.3.4.15] sce:YDL141W sce00780
# 30 biotin---protein ligase [EC:6.3.4.9 6.3.4.10 6.3.4.11 6.3.4.15] sce:YDL141W sce00780
# 31 biotin---protein ligase [EC:6.3.4.9 6.3.4.10 6.3.4.11 6.3.4.15] sce:YDL141W sce00780
# 32 biotin---protein ligase [EC:6.3.4.9 6.3.4.10 6.3.4.11 6.3.4.15] sce:YDL141W sce00780
# 33 biotin synthase [EC:2.8.1.6] sce:YGR286C sce00780
# 34 dethiobiotin synthetase [EC:6.3.3.3] sce:YNR057C sce00780
# 35 adenosylmethionine---8-amino-7-oxononanoate aminotransferase [EC:2.6.1.62] sce:YNR058W sce00780
# 39 biotin---protein ligase [EC:6.3.4.9 6.3.4.10 6.3.4.11 6.3.4.15] sce:YDL141W sce00780
# 42 biotin---protein ligase [EC:6.3.4.9 6.3.4.10 6.3.4.11 6.3.4.15] sce:YDL141W sce00780
# 56 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] sce:YKL055C sce00780
# 70 3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100] sce:YKL055C sce00780
# 77 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] sce:YER061C sce00780
# 102 3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179] sce:YER061C sce00780
# 12 lipoyl synthase [EC:2.8.1.8] sce:YOR196C sce00785
# 31 octanoyl-CoA:protein transferase [EC:2.3.1.-] sce:YJL046W sce00785
# 40 lipoyl synthase [EC:2.8.1.8] sce:YOR196C sce00785
# 47 lipoyl(octanoyl) transferase 2 [EC:2.3.1.181] sce:YLR239C sce00785
# 65 para-aminobenzoate synthetase [EC:2.6.1.85] sce:YNR033W sce00790
# 66 4-amino-4-deoxychorismate lyase [EC:4.1.3.38] sce:YMR289W sce00790
# 67 folylpolyglutamate synthase [EC:6.3.2.17] sce:YOR241W sce00790
# 68 folylpolyglutamate synthase [EC:6.3.2.17] sce:YOR241W sce00790
# 69 dihydrofolate reductase [EC:1.5.1.3] sce:YOR236W sce00790
# 70 dihydrofolate reductase [EC:1.5.1.3] sce:YOR236W sce00790
# 71 dihydrofolate synthase [EC:6.3.2.12] sce:YKL132C sce00790
# 72 dihydroneopterin aldolase / 2-amino-4-hydroxy-6-hydroxymethyldihydropteridine diphosphokinase / dihydropteroate synthase [EC:4.1.2.25 2.7.6.3 2.5.1.15] sce:YNL256W sce00790
# 73 dihydroneopterin aldolase / 2-amino-4-hydroxy-6-hydroxymethyldihydropteridine diphosphokinase / dihydropteroate synthase [EC:4.1.2.25 2.7.6.3 2.5.1.15] sce:YNL256W sce00790
# 74 dihydroneopterin aldolase / 2-amino-4-hydroxy-6-hydroxymethyldihydropteridine diphosphokinase / dihydropteroate synthase [EC:4.1.2.25 2.7.6.3 2.5.1.15] sce:YNL256W sce00790
# 75 dihydroneopterin aldolase / 2-amino-4-hydroxy-6-hydroxymethyldihydropteridine diphosphokinase / dihydropteroate synthase [EC:4.1.2.25 2.7.6.3 2.5.1.15] sce:YNL256W sce00790
# 79 GTP cyclohydrolase IA [EC:3.5.4.16] sce:YGR267C sce00790
# 80 GTP cyclohydrolase IA [EC:3.5.4.16] sce:YGR267C sce00790
# 81 GTP cyclohydrolase IA [EC:3.5.4.16] sce:YGR267C sce00790
# 82 dihydrofolate reductase [EC:1.5.1.3] sce:YOR236W sce00790
# 83 folylpolyglutamate synthase [EC:6.3.2.17] sce:YOR241W sce00790
# 85 alkaline phosphatase [EC:3.1.3.1] sce:YDR481C sce00790
# 136 4a-hydroxytetrahydrobiopterin dehydratase [EC:4.2.1.96] sce:YHL018W sce00790
# 180 GTP cyclohydrolase IA [EC:3.5.4.16] sce:YGR267C sce00790
# 181 GTP cyclohydrolase II [EC:3.5.4.25] sce:YBL033C sce00790
# 189 dihydrofolate reductase [EC:1.5.1.3] sce:YOR236W sce00790
# 25 cyanamide hydratase [EC:4.2.1.69] sce:YFL061W sce00791
# 41 urea carboxylase / allophanate hydrolase [EC:6.3.4.6 3.5.1.54] sce:YBR208C sce00791
# 69 urea carboxylase / allophanate hydrolase [EC:6.3.4.6 3.5.1.54] sce:YBR208C sce00791
# 75 coproporphyrinogen III oxidase [EC:1.3.3.3] sce:YDR044W sce00860
# 262 cytochrome c heme-lyase [EC:4.4.1.17] sce:YAL039C sce00860
# 267 heme o synthase [EC:2.5.1.141] sce:YPL172C sce00860
# 268 protoporphyrin/coproporphyrin ferrochelatase [EC:4.99.1.1 4.99.1.9] sce:YOR176W sce00860
# 270 frataxin [EC:1.16.3.1] sce:YDL120W sce00860
# 273 protoporphyrinogen/coproporphyrinogen III oxidase [EC:1.3.3.4 1.3.3.15] sce:YER014W sce00860
# 274 uroporphyrinogen decarboxylase [EC:4.1.1.37] sce:YDR047W sce00860
# 275 uroporphyrinogen-III synthase [EC:4.2.1.75] sce:YOR278W sce00860
# 276 uroporphyrin-III C-methyltransferase [EC:2.1.1.107] sce:YKR069W sce00860
# 277 uroporphyrinogen decarboxylase [EC:4.1.1.37] sce:YDR047W sce00860
# 278 hydroxymethylbilane synthase [EC:2.5.1.61] sce:YDL205C sce00860
# 279 porphobilinogen synthase [EC:4.2.1.24] sce:YGL040C sce00860
# 282 5-aminolevulinate synthase [EC:2.3.1.37] sce:YDR232W sce00860
# 284 glutamyl-tRNA synthetase [EC:6.1.1.17] sce:YGL245W sce00860
# 285 precorrin-2 dehydrogenase / sirohydrochlorin ferrochelatase [EC:1.3.1.76 4.99.1.4] sce:YBR213W sce00860
# 286 precorrin-2 dehydrogenase / sirohydrochlorin ferrochelatase [EC:1.3.1.76 4.99.1.4] sce:YBR213W sce00860
# 319 cytochrome c oxidase assembly protein subunit 15 sce:YER141W sce00860
# 414 protoporphyrinogen/coproporphyrinogen III oxidase [EC:1.3.3.4 1.3.3.15] sce:YER014W sce00860
# 418 protoporphyrin/coproporphyrin ferrochelatase [EC:4.99.1.1 4.99.1.9] sce:YOR176W sce00860
# 70 mevalonate kinase [EC:2.7.1.36] sce:YMR208W sce00900
# 71 acetyl-CoA C-acetyltransferase [EC:2.3.1.9] sce:YPL028W sce00900
# 72 hydroxymethylglutaryl-CoA synthase [EC:2.3.3.10] sce:YML126C sce00900
# 75 hydroxymethylglutaryl-CoA reductase (NADPH) [EC:1.1.1.34] sce:YLR450W sce00900
# 98 isopentenyl-diphosphate Delta-isomerase [EC:5.3.3.2] sce:YPL117C sce00900
# 100 diphosphomevalonate decarboxylase [EC:4.1.1.33] sce:YNR043W sce00900
# 101 phosphomevalonate kinase [EC:2.7.4.2] sce:YMR220W sce00900
# 103 farnesyl diphosphate synthase [EC:2.5.1.1 2.5.1.10] sce:YJL167W sce00900
# 105 farnesyl diphosphate synthase [EC:2.5.1.1 2.5.1.10] sce:YJL167W sce00900
# 116 geranylgeranyl diphosphate synthase, type III [EC:2.5.1.1 2.5.1.10 2.5.1.29] sce:YPL069C sce00900
# 119 ditrans,polycis-polyprenyl diphosphate synthase [EC:2.5.1.87] sce:YBR002C sce00900
# 124 hexaprenyl-diphosphate synthase [EC:2.5.1.82 2.5.1.83] sce:YBR003W sce00900
# 125 hexaprenyl-diphosphate synthase [EC:2.5.1.82 2.5.1.83] sce:YBR003W sce00900
# 133 protein farnesyltransferase subunit beta [EC:2.5.1.58] sce:YDL090C sce00900
# 134 prenyl protein peptidase [EC:3.4.22.-] sce:YMR274C sce00900
# 135 protein-S-isoprenylcysteine O-methyltransferase [EC:2.1.1.100] sce:YDR410C sce00900
# 151 STE24 endopeptidase [EC:3.4.24.84] sce:YJR117W sce00900
# 169 farnesyl-diphosphate farnesyltransferase [EC:2.5.1.21] sce:YHR190W sce00909
# 170 farnesyl-diphosphate farnesyltransferase [EC:2.5.1.21] sce:YHR190W sce00909
# 202 squalene monooxygenase [EC:1.14.14.17] sce:YGR175C sce00909
# 31 nitronate monooxygenase [EC:1.13.12.16] sce:YJR149W sce00910
# 69 carbonic anhydrase [EC:4.2.1.1] sce:YNL036W sce00910
# 83 glutamine synthetase [EC:6.3.1.2] sce:YPR035W sce00910
# 88 glutamate synthase (NADH) [EC:1.4.1.14] sce:YDL171C sce00910
# 92 glutamate dehydrogenase [EC:1.4.1.2] sce:YDL215C sce00910
# 94 glutamate dehydrogenase (NADP+) [EC:1.4.1.4] sce:YAL062W sce00910
# 31 sulfite reductase (NADPH) flavoprotein alpha-component [EC:1.8.1.2] sce:YFR030W sce00920
# 38 3'(2'), 5'-bisphosphate nucleotidase [EC:3.1.3.7] sce:YOL064C sce00920
# 39 adenylylsulfate kinase [EC:2.7.1.25] sce:YKL001C sce00920
# 41 sulfate adenylyltransferase (ADP) / ATP adenylyltransferase [EC:2.7.7.5 2.7.7.53] sce:YCL050C sce00920
# 42 sulfate adenylyltransferase [EC:2.7.7.4] sce:YJR010W sce00920
# 48 phosphoadenosine phosphosulfate reductase [EC:1.8.4.8 1.8.4.10] sce:YPR167C sce00920
# 90 thiosulfate/3-mercaptopyruvate sulfurtransferase [EC:2.8.1.1 2.8.1.2] sce:YOR251C sce00920
# 103 cysteine synthase [EC:2.5.1.47] sce:YGR012W sce00920
# 121 cystathionine gamma-synthase [EC:2.5.1.48] sce:YJR130C sce00920
# 125 homoserine O-acetyltransferase/O-succinyltransferase [EC:2.3.1.31 2.3.1.46] sce:YNL277W sce00920
# 150 phosphoadenosine phosphosulfate reductase [EC:1.8.4.8 1.8.4.10] sce:YPR167C sce00920
# 153 sulfite reductase (NADPH) flavoprotein alpha-component [EC:1.8.1.2] sce:YFR030W sce00920
# 158 sulfate adenylyltransferase [EC:2.7.7.4] sce:YJR010W sce00920
# 159 adenylylsulfate kinase [EC:2.7.1.25] sce:YKL001C sce00920
# 164 sulfate adenylyltransferase [EC:2.7.7.4] sce:YJR010W sce00920
# 24 isoleucyl-tRNA synthetase [EC:6.1.1.5] sce:YBL076C sce00970
# 58 asparaginyl-tRNA synthetase [EC:6.1.1.22] sce:YCR024C sce00970
# 59 histidyl-tRNA synthetase [EC:6.1.1.21] sce:YPR033C sce00970
# 60 phenylalanyl-tRNA synthetase alpha chain [EC:6.1.1.20] sce:YFL022C sce00970
# 61 arginyl-tRNA synthetase [EC:6.1.1.19] sce:YDR341C sce00970
# 62 glutaminyl-tRNA synthetase [EC:6.1.1.18] sce:YOR168W sce00970
# 63 cysteinyl-tRNA synthetase [EC:6.1.1.16] sce:YNL247W sce00970
# 64 glycyl-tRNA synthetase [EC:6.1.1.14] sce:YBR121C sce00970
# 65 aspartyl-tRNA synthetase [EC:6.1.1.12] sce:YLL018C sce00970
# 66 seryl-tRNA synthetase [EC:6.1.1.11] sce:YDR023W sce00970
# 67 methionyl-tRNA synthetase [EC:6.1.1.10] sce:YGR171C sce00970
# 68 valyl-tRNA synthetase [EC:6.1.1.9] sce:YGR094W sce00970
# 69 alanyl-tRNA synthetase [EC:6.1.1.7] sce:YOR335C sce00970
# 70 lysyl-tRNA synthetase, class II [EC:6.1.1.6] sce:YDR037W sce00970
# 71 leucyl-tRNA synthetase [EC:6.1.1.4] sce:YLR382C sce00970
# 72 threonyl-tRNA synthetase [EC:6.1.1.3] sce:YIL078W sce00970
# 73 tryptophanyl-tRNA synthetase [EC:6.1.1.2] sce:YDR268W sce00970
# 74 methionyl-tRNA formyltransferase [EC:2.1.2.9] sce:YBL013W sce00970
# 75 tyrosyl-tRNA synthetase [EC:6.1.1.1] sce:YGR185C sce00970
# 76 prolyl-tRNA synthetase [EC:6.1.1.15] sce:YER087W sce00970
# 77 glutamyl-tRNA synthetase [EC:6.1.1.17] sce:YGL245W sce00970
# 128 aspartyl-tRNA(Asn)/glutamyl-tRNA(Gln) amidotransferase subunit B [EC:6.3.5.6 6.3.5.7] sce:YBL080C sce00970
# 131 aspartyl-tRNA(Asn)/glutamyl-tRNA(Gln) amidotransferase subunit B [EC:6.3.5.6 6.3.5.7] sce:YBL080C sce00970
# 137 seryl-tRNA synthetase [EC:6.1.1.11] sce:YDR023W sce00970
# 156 tRNA Glu sce:tE_CUC_D sce00970
# 157 tRNA Gln sce:tQ_CUG_M sce00970
# 158 tRNA Ala sce:tA_AGC_D sce00970
# 159 tRNA Asp sce:tD_GUC_B sce00970
# 160 tRNA Ser sce:tS_AGA_A sce00970
# 161 tRNA Thr sce:tT_AGU_B sce00970
# 162 tRNA Asn sce:tN_GUU_C sce00970
# 163 tRNA Gly sce:tG_CCC_D sce00970
# 164 tRNA Cys sce:tC_GCA_B sce00970
# 165 tRNA Sec sce:tW_UCA_Q sce00970
# 166 tRNA Met sce:tM_CAU_C sce00970
# 167 tRNA Val sce:tV_AAC_E1 sce00970
# 168 tRNA Leu sce:tL_CAA_A sce00970
# 169 tRNA Ile sce:tI_AAU_B sce00970
# 170 tRNA Lys sce:tK_CUU_C sce00970
# 172 tRNA Arg sce:tR_ACG_D sce00970
# 173 tRNA Pro sce:tP_AGG_C sce00970
# 174 tRNA His sce:tH_GUG_E1 sce00970
# 175 tRNA Phe sce:tF_GAA_B sce00970
# 176 tRNA Tyr sce:tY_GUA_D sce00970
# 177 tRNA Trp sce:tW_CCA_G1 sce00970

# %%
NODES_sce00010
# Out:
# {"'18'": 'fructose-bisphosphate aldolase, class II [EC:4.1.2.13]',
#  '18': 'fructose-bisphosphate aldolase, class II [EC:4.1.2.13]',
#  '42': 'aldehyde dehydrogenase (NAD+) [EC:1.2.1.3]',
#  '44': 'aldehyde dehydrogenase (NAD(P)+) [EC:1.2.1.5]',
#  '48': 'pyruvate decarboxylase [EC:4.1.1.1]',
#  '49': 'alcohol dehydrogenase (NADP+) [EC:1.1.1.2]',
#  '50': 'alcohol dehydrogenase, propanol-preferring [EC:1.1.1.1]',
#  '51': 'pyruvate decarboxylase [EC:4.1.1.1]',
#  '52': 'pyruvate dehydrogenase E1 component beta subunit [EC:1.2.4.1]',
#  '53': 'pyruvate dehydrogenase E1 component beta subunit [EC:1.2.4.1]',
#  '54': 'pyruvate dehydrogenase E2 component (dihydrolipoamide acetyltransferase) [EC:2.3.1.12]',
#  '57': 'pyruvate kinase [EC:2.7.1.40]',
#  '59': 'enolase [EC:4.2.1.11]',
#  '60': '2,3-bisphosphoglycerate-dependent phosphoglycerate mutase [EC:5.4.2.11]',
#  '61': 'glyceraldehyde 3-phosphate dehydrogenase [EC:1.2.1.12]',
#  '62': 'triosephosphate isomerase (TIM) [EC:5.3.1.1]',
#  '63': '6-phosphofructokinase 1 [EC:2.7.1.11]',
#  '64': 'fructose-1,6-bisphosphatase I [EC:3.1.3.11]',
#  '66': 'glucose-6-phosphate isomerase [EC:5.3.1.9]',
#  '67': 'phosphoglucomutase [EC:5.4.2.2]',
#  '68': 'glucose-6-phosphate isomerase [EC:5.3.1.9]',
#  '69': 'hexokinase [EC:2.7.1.1]',
#  '71': 'glucose-6-phosphate isomerase [EC:5.3.1.9]',
#  '72': 'glucose-6-phosphate 1-epimerase [EC:5.1.3.15]',
#  '73': 'UDP-glucose 4-epimerase [EC:5.1.3.2]',
#  '75': 'hexokinase [EC:2.7.1.1]',
#  '79': 'dihydrolipoamide dehydrogenase [EC:1.8.1.4]',
#  '80': 'phosphoglycerate kinase [EC:2.7.2.3]',
#  '121': 'phosphoenolpyruvate carboxykinase (ATP) [EC:4.1.1.49]',
#  '140': 'acetyl-CoA synthetase [EC:6.2.1.1]'}

# %% [markdown]
# ## PRIMERA RED

# %%
EDGES=[]

for line in pathways.text.split('\n'):        
    pathwayid = line.split('\t')[0].replace('path:', '') 
    
    if pathwayid == str(org)+str(maxi):           
            break
            
    ii=locals()[str(pathwayid)]
    
    NODES=locals()['NODES_'+str(pathwayid)]
   
    for i in range(0,len(ii)):
        if ii[i].tag=='relation':         
            A=ii[i].attrib            
            if A['type'] == 'ECrel':    #relación enzima-enzima, que indica dos enzimas que catalizan pasos de reacción sucesivos
                #print(A)
                EDGES.append( [  NODES[ A['entry1'] ] , NODES[ A['entry2'] ]  ]  ) 

print(EDGES)
# Out:
# [['UDP-glucose 4-epimerase [EC:5.1.3.2]', 'hexokinase [EC:2.7.1.1]'], ['hexokinase [EC:2.7.1.1]', 'UDP-glucose 4-epimerase [EC:5.1.3.2]'], ['glucose-6-phosphate isomerase [EC:5.3.1.9]', 'hexokinase [EC:2.7.1.1]'], ['hexokinase [EC:2.7.1.1]', 'glucose-6-phosphate 1-epimerase [EC:5.1.3.15]'], ['glucose-6-phosphate isomerase [EC:5.3.1.9]', 'glucose-6-phosphate 1-epimerase [EC:5.1.3.15]'], ['glucose-6-phosphate isomerase [EC:5.3.1.9]', 'hexokinase [EC:2.7.1.1]'], ['glucose-6-phosphate isomerase [EC:5.3.1.9]', 'glucose-6-phosphate 1-epimerase [EC:5.1.3.15]'], ['glucose-6-phosphate isomerase [EC:5.3.1.9]', 'phosphoglucomutase [EC:5.4.2.2]'], ['glucose-6-phosphate 1-epimerase [EC:5.1.3.15]', 'hexokinase [EC:2.7.1.1]'], ['glucose-6-phosphate isomerase [EC:5.3.1.9]', 'hexokinase [EC:2.7.1.1]'], ['phosphoglucomutase [EC:5.4.2.2]', 'hexokinase [EC:2.7.1.1]'], ['phosphoglucomutase [EC:5.4.2.2]', 'glucose-6-phosphate 1-epimerase [EC:5.1.3.15]'], ['phosphoglucomutase [EC:5.4.2.2]', 'glucose-6-phosphate isomerase [EC:5.3.1.9]'], ['fructose-1,6-bisphosphatase I [EC:3.1.3.11]', 'glucose-6-phosphate isomerase [EC:5.3.1.9]'], ['6-phosphofructokinase 1 [EC:2.7.1.11]', 'glucose-6-phosphate isomerase [EC:5.3.1.9]'], ['fructose-bisphosphate aldolase, class II [EC:4.1.2.13]', 'fructose-1,6-bisphosphatase I [EC:3.1.3.11]'], ['fructose-bisphosphate aldolase, class II [EC:4.1.2.13]', '6-phosphofructokinase 1 [EC:2.7.1.11]'], ['triosephosphate isomerase (TIM) [EC:5.3.1.1]', 'fructose-bisphosphate aldolase, class II [EC:4.1.2.13]'], ['glyceraldehyde 3-phosphate dehydrogenase [EC:1.2.1.12]', 'phosphoglycerate kinase [EC:2.7.2.3]'], ['2,3-bisphosphoglycerate-dependent phosphoglycerate mutase [EC:5.4.2.11]', 'phosphoglycerate kinase [EC:2.7.2.3]'], ['enolase [EC:4.2.1.11]', '2,3-bisphosphoglycerate-dependent phosphoglycerate mutase [EC:5.4.2.11]'], ['pyruvate dehydrogenase E1 component beta subunit [EC:1.2.4.1]', 'pyruvate dehydrogenase E2 component (dihydrolipoamide acetyltransferase) [EC:2.3.1.12]'], ['pyruvate decarboxylase [EC:4.1.1.1]', 'pyruvate dehydrogenase E1 component beta subunit [EC:1.2.4.1]'], ['pyruvate dehydrogenase E1 component beta subunit [EC:1.2.4.1]', 'dihydrolipoamide dehydrogenase [EC:1.8.1.4]'], ['pyruvate dehydrogenase E2 component (dihydrolipoamide acetyltransferase) [EC:2.3.1.12]', 'dihydrolipoamide dehydrogenase [EC:1.8.1.4]'], ['pyruvate decarboxylase [EC:4.1.1.1]', 'alcohol dehydrogenase, propanol-preferring [EC:1.1.1.1]'], ['pyruvate decarboxylase [EC:4.1.1.1]', 'alcohol dehydrogenase (NADP+) [EC:1.1.1.2]'], ['aldehyde dehydrogenase (NAD+) [EC:1.2.1.3]', 'pyruvate decarboxylase [EC:4.1.1.1]'], ['aldehyde dehydrogenase (NAD(P)+) [EC:1.2.1.5]', 'pyruvate decarboxylase [EC:4.1.1.1]'], ['aldehyde dehydrogenase (NAD+) [EC:1.2.1.3]', 'alcohol dehydrogenase, propanol-preferring [EC:1.1.1.1]'], ['aldehyde dehydrogenase (NAD(P)+) [EC:1.2.1.5]', 'alcohol dehydrogenase, propanol-preferring [EC:1.1.1.1]'], ['aldehyde dehydrogenase (NAD+) [EC:1.2.1.3]', 'alcohol dehydrogenase (NADP+) [EC:1.1.1.2]'], ['aldehyde dehydrogenase (NAD(P)+) [EC:1.2.1.5]', 'alcohol dehydrogenase (NADP+) [EC:1.1.1.2]'], ['pyruvate kinase [EC:2.7.1.40]', 'enolase [EC:4.2.1.11]'], ['fructose-1,6-bisphosphatase I [EC:3.1.3.11]', 'glucose-6-phosphate isomerase [EC:5.3.1.9]'], ['6-phosphofructokinase 1 [EC:2.7.1.11]', 'glucose-6-phosphate isomerase [EC:5.3.1.9]'], ['pyruvate dehydrogenase E1 component beta subunit [EC:1.2.4.1]', 'pyruvate kinase [EC:2.7.1.40]'], ['pyruvate decarboxylase [EC:4.1.1.1]', 'pyruvate kinase [EC:2.7.1.40]'], ['hexokinase [EC:2.7.1.1]', 'glucose-6-phosphate isomerase [EC:5.3.1.9]'], ['enolase [EC:4.2.1.11]', 'phosphoenolpyruvate carboxykinase (ATP) [EC:4.1.1.49]'], ['phosphoenolpyruvate carboxykinase (ATP) [EC:4.1.1.49]', 'pyruvate kinase [EC:2.7.1.40]'], ['pyruvate dehydrogenase E1 component beta subunit [EC:1.2.4.1]', 'pyruvate decarboxylase [EC:4.1.1.1]'], ['pyruvate dehydrogenase E1 component beta subunit [EC:1.2.4.1]', 'pyruvate decarboxylas ...

# %%
G = nx.DiGraph() #--->DiGrafo para hacer un grado dirigido 
 
G.add_edges_from(EDGES)


plt.figure(3,figsize=(50,50))
nx.draw_kamada_kawai(G,font_size=15,node_size=1000,node_color='orange',with_labels=False)
plt.savefig("net_"+org+"1.pdf")# Guardar la red en pdf. 
plt.show()

# %%
g=nx.number_of_nodes(G)
print('g=',g)
L=nx.number_of_edges(G)
print('L=',L)
# Out:
# g= 495
# L= 1253

# %%
nodos=G.nodes

D=[] # un vector donde vamos a colocar el numero de vinvulos de todos los nodos
d=nx.degree(G) # Vector que contiene el par ordenado del nodo y su numero de vinculos
for i in nodos: 
    D.append(d[i])
    

D_in=[] # un vector donde vamos a colocar el numero de vinvulos de todos los nodos
d=G.in_degree(G) # Vector que contiene el par ordenado del nodo y su numero de vinculos
for i in nodos: 
    D_in.append(d[i])
    
    
D_out=[] # un vector donde vamos a colocar el numero de vinvulos de todos los nodos
d=G.out_degree(G) # Vector que contiene el par ordenado del nodo y su numero de vinculos
for i in nodos: 
    D_out.append(d[i])
    
    
P=[]
X=[]
for i in range(1,max(D)+1):
    if D.count(i) != 0: 
        P.append(D.count(i)/len(D))
        X.append(i)
        
P_in=[]
X_in=[]
for i in range(1,max(D_in)+1):
    if D_in.count(i) != 0: 
        P_in.append(D_in.count(i)/len(D_in))
        X_in.append(i)  

P_out=[]
X_out=[]
for i in range(1,max(D)+1):
    if D_out.count(i) != 0: 
        P_out.append(D_out.count(i)/len(D_out))
        X_out.append(i)
        
        
        
# GRAFICA DE LA PROVAVILIDAD VS EL NUMERO DE GRADO        
fig, axs = plt.subplots( 3 ,sharex = True, sharey = True, figsize=(15,8))

fig.suptitle('Distribución de grado 2012',fontsize=20)
axs[0].plot(X,P,'ko')         
axs[0].set_xlabel(r'$K$',fontsize=20)
axs[0].set_ylabel(r'$P(K)$',fontsize=20)

axs[1].plot(X_in,P_in,'o')         
axs[1].set_xlabel(r'$K_{in}$',fontsize=20)
axs[1].set_ylabel(r'$P(K_{in})$',fontsize=20)

axs[2].plot(X_out,P_out, 'ro')         
axs[2].set_xlabel(r'$K_{out}$',fontsize=20)
axs[2].set_ylabel(r'$P(K_{out})$',fontsize=20)

#plt.savefig("P_vs_k_2012.pdf")# Guardar la red en pdf.    

plt.show()

# %%
fig, (ax1, ax2 , ax3) = plt.subplots(1, 3 ,sharex = True, sharey = True, figsize=(15,5))
fig.suptitle('Distribucion Log-Log 2012',fontsize=20)
ax1.plot(X,P,'ko')
ax1.set_xlabel(r'$K$',fontsize=20)
ax1.set_ylabel(r'$P(K)$',fontsize=20)

ax2.plot(X_in,P_in,'o')
ax2.set_xlabel(r'$K_{in}$',fontsize=20)
ax2.set_ylabel(r'$P(K_{in})$',fontsize=20)

ax3.plot(X_out,P_out,'ro')
ax3.set_xlabel(r'$K_{out}$',fontsize=20)
ax3.set_ylabel(r'$P(K_{out})$',fontsize=20)

# Escala log-log
plt.xscale('log') 
plt.yscale('log') 

#plt.savefig("Ley_de_potencias_2012.pdf")# Guardar la red en pdf.

plt.show()

# %%
d=G.degree(G) #Vector con el par ordenado de numero de aristas de entrada a cada uno de los nodos
d_in=G.in_degree(G)
d_out=G.out_degree(G)
degre=[]

for i in G.nodes:
    degre.append([i,d[i],d_in[i],d_out[i], d_in[i]-d_out[i] ])
df=pd.DataFrame(degre,columns=['Nombre', 'grado', 'grado_in', 'grado_out','dif_grado'])
df.sort_values(by='dif_grado', ascending=False)
# Out:
#                                                 Nombre  grado  grado_in  \
# 89      adenine phosphoribosyltransferase [EC:2.4.2.7]     12        11
# 96   hypoxanthine phosphoribosyltransferase [EC:2.4...     11        10
# 38                          transaldolase [EC:2.2.1.2]      7         6
# 112  uridine monophosphate synthetase [EC:2.4.2.10 ...      7         6
# 83   aspartate aminotransferase, mitochondrial [EC:...     15        10
# 139      cysteine-S-conjugate beta-lyase [EC:4.4.1.13]      7         6
# 95                    IMP dehydrogenase [EC:1.1.1.205]      6         5
# 254      methionyl-tRNA formyltransferase [EC:2.1.2.9]      6         5
# 100                     adenosine kinase [EC:2.7.1.20]      8         6
# 219      phosphatidylinositol 4-kinase A [EC:2.7.1.67]      4         4
# 240      3-dehydrosphinganine reductase [EC:1.1.1.102]      3         3
# 273  protoporphyrin/coproporphyrin ferrochelatase [...      5         4
# 16          alcohol dehydrogenase (NADP+) [EC:1.1.1.2]      3         3
# 155  glutamate--cysteine ligase catalytic subunit [...      5         4
# 184               glutathione peroxidase [EC:1.11.1.9]      3         3
# 252  methylenetetrahydrofolate reductase (NADPH) [E...      5         4
# 258                          NAD+ kinase [EC:2.7.1.23]      3         3
# 284  protein farnesyltransferase subunit beta [EC:2...      3         3
# 80                   glutamine synthetase [EC:6.3.1.2]      7         5
# 12   pyruvate dehydrogenase E1 component alpha subu...     11         7
# 101  ribonucleoside-diphosphate reductase subunit M...     12         7
# 102                     adenylate cyclase [EC:4.6.1.1]      8         5
# 249  malate dehydrogenase (oxaloacetate-decarboxyla...      6         4
# 150  5'-methylthioadenosine phosphorylase [EC:2.4.2...      2         2
# 230   phosphatidate cytidylyltransferase [EC:2.7.7.41]      4         3
# 231  CDP-diacylglycerol---glycerol-3-phosphate 3-ph...      2         2
# 245      hydroxyacylglutathione hydrolase [EC:3.1.2.6]      2         2
# 174         phenylalanine-4-hydroxylase [EC:1.14.16.1]      6         4
# 82        glutamate dehydrogenase (NADP+) [EC:1.4.1.4]      6         4
# 268             lipoate---protein ligase [EC:6.3.1.20]      2         2
# ..                                                 ...    ...       ...
# 115      UMP-CMP kinase 2, mitochondrial [EC:2.7.4.14]      6         2
# 250     pyruvate, orthophosphate dikinase [EC:2.7.9.1]      4         1
# 221  myo-inositol-1(or 4)-monophosphatase [EC:3.1.3...      2         0
# 220       phosphatidylinositol 3-kinase [EC:2.7.1.137]      2         0
# 179            methionyl-tRNA synthetase [EC:6.1.1.10]      2         0
# 20                  acetyl-CoA synthetase [EC:6.2.1.1]      9         3
# 124  1-pyrroline-5-carboxylate dehydrogenase [EC:1....      9         3
# 36                            ribokinase [EC:2.7.1.15]      5         1
# 190                dolichyldiphosphatase [EC:3.6.1.43]      3         0
# 91   inosine triphosphate pyrophosphatase [EC:3.6.1.-]     15         6
# 108          carbamoyl-phosphate synthase [EC:6.3.5.5]      3         0
# 208  glycerol-3-phosphate O-acyltransferase / dihyd...      3         0
# 187                leucyl aminopeptidase [EC:3.4.11.1]      3         0
# 215  phosphatidylinositol phospholipase C, delta [E...      3         0
# 213  phospholipid:diacylglycerol acyltransferase [E...      5         1
# 94   ectonucleoside triphosphate diphosphohydrolase...     15         6
# 202  N-acetylglucosamine-6-phosphate deacetylase [E...      4         0
# 121                 dUTP pyrophosphatase [EC:3.6.1.23]      4         0
# 37     ribose-phosphate pyrophosphokinase [EC:2.7.6.1]      4         0
# 87             argininosuccinate synthase [EC:6.3.4.5]      6         1
# 204  glucosamine-phosphate N-acetyltransferase [EC:...      4         0
# 128      glycine hydroxymethyltransferase [EC:2.1.2.1]     12         4
# 143     homocysteine S-methyltransferase [EC:2.1.1.10]      5         0
# 92                          AMP deaminase [EC:3.5.4.6]     11         3
# 119  dihydrofolate reductase / thymidylate synthase...     15         5
# 144  5-methyltetrahydropteroyltriglutamate--homocys...      5         0
# 107      cAMP-specific phosphodiesterase [EC:3.1.4.53]      6         0
# 104  GMP synthase (glutamine-hydrolysing) [EC:6.3.5.2]      8         1
# 103  3',5'-cyclic-nucleotide phosphodiesterase [EC:...     12         3
# 93              adenylosuccinate synthase [EC:6.3.4.4]     11         2
#
#      grado_out  dif_grado
# 89           1         10
# 96           1          9
# 38           1          5
# 112          1          5
# 83           5          5
# 139          1          5
# 95           1          4
# 254          1          4
# 100          2          4
# 219          0          4
# 240          0          3
# 273          1          3
# 16           0          3
# 155          1          3
# 184          0          3
# 252          1          3
# 258          0          3
# 284          0          3
# 80           2          3
# 12           4          3
# 101          5          2
# 102          3          2
# 249          2          2
# 150          0          2
# 230          1          2
# 231          0          2
# 245          0          2
# 174          2          2
# 82           2          2
# 268          0          2
# ..         ...        ...
# 115          4         -2
# 250          3         -2
# 221          2         -2
# 220          2         -2
# 179          2         -2
# 20           6         -3
# 124          6         -3
# 36           4         -3
# 190          3         -3
# 91           9         -3
# 108          3         -3
# 208          3         -3
# 187          3         -3
# 215          3         -3
# 213          4         -3
# 94           9         -3
# 202          4         -4
# 121          4         -4
# 37           4         -4
# 87           5         -4
# 204          4         -4
# 128          8         -4
# 143          5         -5
# 92           8         -5
# 119         10         -5
# 144          5         -5
# 107          6         -6
# 104          7         -6
# 103          9         -6
# 93           9         -7
#
# [288 rows x 5 columns]

# %%
intr=nx.betweenness_centrality(G) #dicionario en python
intr = pd.DataFrame([[key, intr[key]] for key in intr.keys()], columns=['Name', 'intermediacion'])
print(intr.sort_values(by='intermediacion', ascending=False))
# Out:
#                                                   Name  intermediacion
# 170  aspartate aminotransferase, cytoplasmic [EC:2....        0.080279
# 19                       pyruvate kinase [EC:2.7.1.40]        0.066031
# 1                              hexokinase [EC:2.7.1.1]        0.065222
# 11   2,3-bisphosphoglycerate-dependent phosphoglyce...        0.056590
# 18          aldehyde dehydrogenase (NAD+) [EC:1.2.1.3]        0.055253
# 4                      phosphoglucomutase [EC:5.4.2.2]        0.049236
# 243  glutamine---fructose-6-phosphate transaminase ...        0.048742
# 44                          transketolase [EC:2.2.1.1]        0.045338
# 10                phosphoglycerate kinase [EC:2.7.2.3]        0.041271
# 9    glyceraldehyde 3-phosphate dehydrogenase [EC:1...        0.040072
# 245              glutamate decarboxylase [EC:4.1.1.15]        0.039165
# 12                               enolase [EC:4.2.1.11]        0.035353
# 241            glutamate synthase (NADH) [EC:1.4.1.14]        0.035244
# 70                   alpha-galactosidase [EC:3.2.1.22]        0.032228
# 484                       phospholipase C [EC:3.1.4.3]        0.032175
# 251                 D-glycerate 3-kinase [EC:2.7.1.31]        0.030824
# 472  1,2-diacylglycerol 3-beta-galactosyltransferas...        0.028767
# 242                         omega-amidase [EC:3.5.1.3]        0.026382
# 548                       malate synthase [EC:2.3.3.9]        0.024093
# 78                     alpha-glucosidase [EC:3.2.1.20]        0.022261
# 109        acetyl-CoA C-acetyltransferase [EC:2.3.1.9]        0.022130
# 55   UTP--glucose-1-phosphate uridylyltransferase [...        0.021490
# 22   phosphoenolpyruvate carboxykinase (ATP) [EC:4....        0.021415
# 91   acetyl-CoA carboxylase / biotin carboxylase 1 ...        0.021399
# 29                  malate dehydrogenase [EC:1.1.1.37]        0.021257
# 25   multiple inositol-polyphosphate phosphatase / ...        0.019683
# 467  diacylglycerol diphosphate phosphatase / phosp...        0.019014
# 167                  glutamine synthetase [EC:6.3.1.2]        0.018339
# 53           UDP-sugar pyrophosphorylase [EC:2.7.7.64]        0.017414
# 74               beta-fructofuranosidase [EC:3.2.1.26]        0.017242
# ..                                                 ...             ...
# 370  2-oxoglutarate-dependent dioxygenase [EC:1.14....        0.000000
# 363                               amidase [EC:3.5.1.4]        0.000000
# 362  benzaldehyde dehydrogenase (NAD+) / indole-3-a...        0.000000
# 359  acetylserotonin O-methyltransferase, plant [EC...        0.000000
# 357                          myrosinase [EC:3.2.1.147]        0.000000
# 430       alpha-1,6-mannosyltransferase [EC:2.4.1.260]        0.000000
# 434  mannosyl-oligosaccharide alpha-1,3-glucosidase...        0.000000
# 492  inositol-pentakisphosphate 2-kinase [EC:2.7.1....        0.000000
# 459  alpha-1,4-galacturonosyltransferase [EC:2.4.1.43]        0.000000
# 489  3'(2'), 5'-bisphosphate nucleotidase / inosito...        0.000000
# 488     myo-inositol-1-phosphate synthase [EC:5.5.1.4]        0.000000
# 478  phosphatidylinositol-3,4,5-trisphosphate 3-pho...        0.000000
# 476     2-lysophosphatidate phosphatase [EC:3.1.3.106]        0.000000
# 475  UTP---glucose-1-phosphate uridylyltransferase ...        0.000000
# 464                      glycerol kinase [EC:2.7.1.30]        0.000000
# 462        alpha-N-acetylglucosaminidase [EC:3.2.1.50]        0.000000
# 461  heparan-alpha-glucosaminide N-acetyltransferas...        0.000000
# 460  reversibly glycosylated polypeptide / UDP-arab...        0.000000
# 458     3,5-epimerase/4-reductase [EC:5.1.3.- 1.1.1.-]        0.000000
# 438  beta-1,4-mannosyl-glycoprotein beta-1,4-N-acet...        0.000000
# 454            xylan 1,4-beta-xylosidase [EC:3.2.1.37]        0.000000
# 449          alpha-L-arabinofuranosidase [EC:3.2.1.55]        0.000000
# 448                      L-arabinokinase [EC:2.7.1.46]        0.000000
# 447  UDP-N-acetylglucosamine/UDP-N-acetylgalactosam...        0.000000
# 445  glucosamine-phosphate N-acetyltransferase [EC:...        0.000000
# 443                            chitinase [EC:3.2.1.14]        0.000000
# 442  mannosyl-oligosaccharide alpha-1,2-mannosidase...        0.000000
# 441  3-oxo-5-alpha-steroid 4-dehydrogenase 3 / poly...        0.000000
# 440  endoplasmic reticulum Man9GlcNAc2 1,2-alpha-ma...        0.000000
# 786  pinoresinol/lariciresinol reductase [EC:1.23.1...        0.000000
#
# [787 rows x 2 columns]
